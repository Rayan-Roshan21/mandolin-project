# %% [markdown]
# ## Loading Model and Input Files

# %%
# 🔄 CLEAN INITIALIZATION - RESTART KERNEL IF NEEDED
print("🔄 Initializing environment...")
import pathlib
from google import genai
from google.genai import types
import os
import asyncio
import json
import fitz  # PyMuPDF for PDF processing
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Check if API key is loaded
api_key = os.getenv("GOOGLE_API_KEY")
if not api_key:
    raise ValueError("GOOGLE_API_KEY not found in environment variables. Please check your .env file.")

# Configure the API
client = genai.Client(api_key=api_key)


pa_file = "PA.pdf"
referral_file = "referral_package.pdf"

# Retrieve and encode the PDF byte
filepath = pathlib.Path('Input Data/Adbulla/' + pa_file)

print("✅ Setup complete!")
# Out:
# 🔄 Initializing environment...
# ✅ Setup complete!

# %% [markdown]
# ## 📄 Referral Package Analysis & Information Extraction to Json Using Gemeni

# %%
# 🔄 DIRECT GEMINI OCR & ANALYSIS - Bypassing Mistral
print("🔄 Using Gemini directly for OCR and information extraction...")

# Enhanced prompt for direct PDF analysis
referral_prompt = """You are analyzing a referral package PDF (collection of scanned medical documents) to extract patient information that will be used to fill a Prior Authorization form.

CONTEXT: This referral package contains scanned documents like insurance cards, medical history notes, test results, and other supporting documentation. You need to perform OCR on the PDF and extract structured information.

EXTRACTION FOCUS: Use your vision capabilities to read and extract all available information and display it in order as it is read from the PDF. Then turn that output into JSON format:

PATIENT DEMOGRAPHICS:
- Full name, DOB, gender, address, phone numbers
- Patient ID numbers, MRN, account numbers
- Emergency contacts and relationships

INSURANCE INFORMATION:
- Insurance company name and plan details
- Member ID, group number, policy number
- Subscriber information and relationship to patient
- Coverage details and effective dates

CLINICAL INFORMATION:
- Primary and secondary diagnoses with ICD codes
- Current medications, dosages, and frequencies
- Allergies and adverse reactions
- Vital signs and lab results
- Previous treatments and outcomes
- Medical history and comorbidities

PROVIDER INFORMATION:
- Referring physician name, specialty, and contact info
- Practice name and address
- NPI numbers and license information
- Facility details where treatment will occur

TREATMENT DETAILS:
- Requested medication/procedure/device
- Dosage, frequency, duration
- Medical necessity justification
- Previous treatment failures
- Clinical criteria met for approval

SUPPORTING EVIDENCE:
- Lab results supporting diagnosis
- Imaging studies and results
- Functional assessments
- Specialist consultations
- Treatment response documentation

INSTRUCTIONS:
1. Carefully read through all pages of the PDF
2. Extract text and data from tables, forms, and documents
3. Pay attention to medical terminology and abbreviations
4. Look for provider contact information sections
5. Identify medication/product information from clinical notes
6. First return all info read in the document. List all information from tables including reference ranges and other details. Do not skip anything that has information
7. Then return a structured JSON with all relevant extracted information, using null for missing data"""

# Load and process the referral package PDF directly with Gemini
referral_pdf_path = 'Input Data/Adbulla/referral_package.pdf'

# Upload the PDF file to Gemini using new API
print(f"📄 Loading referral package: {referral_pdf_path}")
referral_file = client.files.upload(file=referral_pdf_path)
print(f"✅ File uploaded successfully: {referral_file.name}")

# Wait for file processing
import time
while referral_file.state == "PROCESSING":
    print("⏳ Processing file...")
    time.sleep(2)
    referral_file = client.files.get(name=referral_file.name)

if referral_file.state == "FAILED":
    raise ValueError("❌ File processing failed")
print("✅ File processed successfully")

# Extract structured data from referral package using Gemini vision
referral_response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents=[referral_prompt, referral_file]
)
referral_data = referral_response.text
print("📊 Referral Package Data Extracted:")
print(referral_data)

# Store the extracted text for compatibility with existing code
referral_package_text = referral_data
# Out:
# 🔄 Using Gemini directly for OCR and information extraction...
# 📄 Loading referral package: Input Data/Adbulla/referral_package.pdf
# ✅ File uploaded successfully: files/jh0qsa6qsg4z
# ✅ File processed successfully
# 📊 Referral Package Data Extracted:
# Here's the comprehensive extraction of information from the provided PDF, followed by the structured JSON output.
#
# ## Full Information Read from the PDF
#
# ### Page 1
# *   **FAX TRANSMISSION**
# *   **Header:** 04/22/2024 WED 11:32 FAX 2001/028
# *   **Sender Organization:** Better Life Multiple Sclerosis Center
# *   **Sender Address:** 3320 Montgomery Dr. Nashville, TN 37361
# *   **Sender Fax:** F: 615-562-4820
# *   **Sender Phone:** P: 615-562-4848
# *   **Doctors:** Dr. Asriel Han | Dr. Aditya Shah
# *   **Recipient:** TO: Golden Gate Infusion Center
# *   **Recipient Fax:** Fax: 614-278-3355
# *   **Recipient Phone:** Phone: 614-895-7655
# *   **From:** Erfan Rostami, BSN, RN
# *   **Sender Personal Phone:** P: 615-343-1176
# *   **Sender Personal Fax:** F: 615-343-1219
# *   **Pages:** (including cover sheet)
# *   **Comments:**
#     *   Arabic - Spoken / English - Written
#     *   Rituxan (Truxima) TP
#     *   MRI Reports
#     *   Hospital D/C note
#     *   Demographics
# *   **Disclaimer:** The documents accompanying this transmission may contain health information that is legally protected. This information is intended only for the use of the individual or entity named above. The authorized recipient of this information is prohibited from disclosing this information to any other party unless permitted by law or regulation. If you are not the intended recipient, you are hereby notified that any use, disclosure, copying or distribution of these documents is strictly prohibited. If you have received this information in error, please notify the sender immediately and arrange for the return or destruction of these documents.
#
# ### Page 2
# *   **Header:** 05/22/2024 WED 11:32 FAX 2002/028
# *   **Patient Name:** Abdulla, Shakh
# *   **MRN:** 041152153
# *   **Communication Date:** 5/16/2024
# *   **Status:** Open
# *   **Referring Center:** Better Life Multiple Sclerosis Center
# *   **Provider:** Erfan Rostemi, RN
# *   **Reason for call:** Truxima Second Initial Dose Needed Week of June 3
# *   **All Conversations: Truxima Second Initial Dose Needed Week of June 3 (Newest Message First)**
#     *   **Date:** May 21, 2024
#     *   **Sender:** Jha, Vedant
#     *   **Recipient:** to Erfan Rostami, RN
#     *   **Message:** Hi Erfan. The only way Extraordinary Care could see his Medicaid plan would be at home :( I'm not sure if he is able to be seen at a hospital based infusion center closer to home? We will hold off on this one for now- let me know if you're not able to find a provider who can see him in the infusion suite and we will re-open the referral.
#     *   **Timestamp:** 5/21/24 4:44 PM
#     *   **Sender:** Vedant
#     *   **Routing:** Erfan Rostami, RN routed this conversation to Jha, Vedant
#     *   **Timestamp:** 5/21/24 2:32 PM
#     *   **Date:** May 20, 2024
#     *   **Sender:** Gu, Hao H, MD
#     *   **Recipient:** to Erfan Rostami, RN
#     *   **Message:** Note. Hi. No home infusion. Her first dose is scheduled may 23. Second dos 2 weeks from may 23 first.
#     *   **Timestamp:** 5/20/24 5:13 PM
#     *   **Routing:** Erfan Rostami, RN routed this conversation to Gu, Hao H, MD
#     *   **Timestamp:** 5/20/24 3:41 PM
#     *   **Sender:** Jha, Vedant
#     *   **Recipient:** to Erfan Rostami, RN
#     *   **Message:** Hi. Is Dr. Gu comfortable with this patient being seen for home infusion? Thanks,
#     *   **Timestamp:** 5/20/24 2:54 PM
#
# ### Page 3
# *   **Header:** 05/22/2024 WED 11:33 FAX 2003/028
# *   **Patient Context:** Abdulla, Shakh (MR #041152153) DOB: 04/01/2001
# *   **Therapy Plan 1 Summary**
# *   **Patient Name:** Shakh Abdulla
# *   **MRN:** 041152153
# *   **Description:** male
# *   **DOB:** 4/1/2001
# *   **Patient Demographics**
#     *   **Patient Name:** Abdulla. Shakh
#     *   **Legal Sex:** male
#     *   **DOB:** 4/1/2001
#     *   **Address:** 425 Sherman Ave, Nashville TN 37995
#     *   **Phone (Home):** 865-395-3958
#     *   **Phone (Mobile):** 865-395-0481 (*Preferred*)
# *   **Medication**
#     *   Rituximab Or Biosimilar Days 1, 15 Load Then Once Every 24 Weeks
# *   **Associated Problems**
#     *   **Problem:** Multiple sclerosis in pediatric patient (CMS/HCC) [G35]
#     *   **Selected Diagnosis:** Multiple sclerosis in pediatric patient (CMS/HCC) [G35]
# *   **Infusion Orders**
#     *   **All Current Orders**
#         *   **Nursing Orders: IV access**
#             *   Interval: Every visit
#             *   Duration: Every visit
#             *   Due: Every visit
#             *   Care Instructions: Obtain IV access (PIV, PORT, etc.) and start NS 0.9% @ KVO
#             *   Until discontinued Starting when released Until Specified
#             *   Last released: Never
#             *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
#         *   **Nursing Orders: Monitor pt for hypersensitivity reaction**
#             *   Interval: Every visit
#             *   Duration: Every visit
#             *   Due: Every visit
#             *   Once Starting when released for 1 occurrence
#             *   Care Instructions: If allergic reaction or infusion related reaction occurs, initiate adult hypersensitivity reaction protocol or pediatric guideline and CALL MD for additional orders.
#             *   Last released: Never
#             *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
#         *   **Nursing Orders: NURSING COMMUNICATION (Antihypertensive meds)**
#             *   Interval: Every visit
#             *   Duration: Every visit
#             *   Due: Every visit
#             *   Care Instructions: Ensure that patient has not taken antihypertensive medications in the 12 hours prior to infusion
#             *   Until discontinued Starting when released Until Specified
#             *   Last released: Never
#             *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
#         *   **Nursing Orders: NURSING COMMUNICATION (Hypotension)**
#             *   Interval: Every visit
#             *   Duration: Every visit
#             *   Due: Every visit
#             *   Care Instructions: For Hypotension, place patient in Trendelenberg position, support with NS, and call MD
#             *   Until discontinued Starting when released Until Specified
#             *   Last released: Never
#             *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
#
# ### Page 4
# *   **Header:** 05/22/2024 WED 11:33 FAX 2004/028
# *   **Patient Context:** Abdulla, Shakh (MR #041152153) DOB: 04/01/2001
# *   **Labs: IgG**
#     *   Interval: Every 24 weeks
#     *   Duration: Week of 5/19/2024
#     *   Clinic Collect, Blood
#     *   Last released: Never
#     *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
# *   **Labs: CBC w/ Differential**
#     *   Interval: Every visit
#     *   Duration: Every visit
#     *   Due: Every visit
#     *   Once Starting when released, Blood
#     *   Last released: Never
#     *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
# *   **Labs: Flow Lymphocytes Subsets (TBNK)**
#     *   Interval: Every visit
#     *   Duration: Every visit
#     *   Due: Every visit
#     *   Once Starting when released, Blood
#     *   Last released: Never
#     *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
# *   **Vitals: Vital Signs**
#     *   Interval: Every visit
#     *   Duration: Every visit
#     *   Due: Every visit
#     *   Care Instructions: Obtain VS prior to start therapy, Q30 minutes with each dose increase and at the end of treatment.
#     *   As needed Starting when released Until Specified
#     *   Last released: Never
#     *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
# *   **Hydration: heparin, porcine (PF) 100 unit/mL syringe 5 mL**
#     *   PRN
#     *   PRN
#     *   5 mL, intraVENOUS, As needed, For flushing Ports/ PICC lines/ Central Lines IF NEEDED, Starting when released, Until Discontinued
#     *   Last released: Never
#     *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
# *   **Pre-Medications: acetaminophen (TYLENOL) tablet 650 mg**
#     *   Interval: Every visit
#     *   Duration: Every visit
#     *   Due: Every visit
#     *   650 mg, oral, Once, Starting when released
#     *   Last released: Never
#     *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
# *   **Pre-Medications: diphenhydrAMINE (BENADRYL) 50 mg in 50 mL NS**
#     *   Interval: Every visit
#     *   Duration: Every visit
#     *   Due: Every visit
#     *   50 mg, intraVENOUS, Once, Administer 30 minutes before starting infusion.
#     *   Last released: Never
#     *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
# *   **Pre-Medications: methylPREDNISolone sod succinate (SOLU-Medral) (20 mg/mL) 125 mg in NS 6.2 mL**
#     *   Interval: Every visit
#     *   Duration: Every visit
#     *   Due: Every visit
#     *   125 mg, intraVENOUS, Once, Starting when released
#     *   Administer 30 minutes before starting infusion.
#     *   Last released: Never
#     *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
#
# ### Page 5
# *   **Header:** 05/22/2024 WED 11:33 FAX 2005/028
# *   **Patient Context:** Abdulnabi, Noor (MR #048152163) DOB: 01/01/2008 (Note: This patient name/DOB is inconsistent with others. Assuming OCR error, defaulting to Shakh Abdulla.)
# *   **Infusion Therapy: NURSING COMMUNICATION (Infusion Rate)**
#     *   Interval: Every visit
#     *   Duration: Every visit
#     *   Due: Every visit
#     *   Until discontinued Starting when released Until Specified
#     *   Infusion rate (standard only):
#         *   1st infusion - initiate at 50mg/hr and if no infusion toxicity reaction, may increase by 50mg/hr ever 30 minutes; Max Rate 400mg/hr
#         *   Subsequent infusions - initiate at 100mg/hr and if no infusion toxicity reaction, may increase by 100mg/hr every 30 min; Max Rate 400mg/hr
#     *   Last released: Never
#     *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
# *   **Infusion Therapy - Initial Dose: riTUXimab-abbs (TRUXIMA) IVPB**
#     *   Interval: Every 2 weeks
#     *   Duration: 2/2 remaining
#     *   Due: Week of 5/19/2024
#     *   Dosage: 694 mg (rounded from 693.75 mg = 375 mg/m2 x 1.85 m2 - BSA might be out of date), intraVENOUS, Once, Starting 30 minutes after treatment start time
#     *   Last released: Never
#     *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
# *   **Infusion Therapy - Maintenance Dose: riTUXimab-abbs (TRUXIMA) IVPB**
#     *   Interval: Every 24 weeks
#     *   Due: Mon 11/4/2024
#     *   Defer until: Mon 11/4/2024
#     *   Dosage: 694 mg (rounded from 693.75 mg = 375 mg/m2 x 1.85 m2 - BSA might be out of date), intraVENOUS, Once, Starting when released
#     *   Last released: Never
#     *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
# *   **PRN Medications: diphenhydrAMINE (BENADRYL) injection 25 mg**
#     *   PRN
#     *   PRN
#     *   Dosage: 25 mg, intraVENOUS, As needed, chills, Starting when released, for 2 doses
#     *   Last released: Never
#     *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
# *   **PRN Medications: meperidine (DEMEROL) injection 25 mg**
#     *   PRN
#     *   PRN
#     *   Dosage: 25 mg, intraVENOUS, As needed, rigors, Starting when released, for 2 doses
#     *   Last released: Never
#     *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
# *   **PRN Medications: ondansetron (ZOFRAN) injection 4 mg**
#     *   PRN
#     *   PRN
#     *   Dosage: 4 mg, intraVENOUS, As needed, nausea, vomiting, Starting when released, for 2 doses
#     *   Doses up to 4 mg may be administered undiluted. Inject over at least 30 seconds, but preferably over 2-5 minutes.
#     *   Last released: Never
#     *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
# *   **eSignature Information:** All order signatures are valid for 1 (one) year from the signature date.
# *   **Provider Contact Information** (Section heading only, no data on this page)
#
# ### Page 6
# *   **Header:** 05/22/2024 WED 11:34 FAX 2006/028
# *   **Patient Context:** Abdulnabi, Noor (MR #048152153) DOB: 01/01/2008 (Note: This patient name/DOB is inconsistent with others. Assuming OCR error, defaulting to Shakh Abdulla.)
# *   **Provider Information:**
#     *   **Physician:** Hao H Gu, MD
#     *   **NPI:** 1154611523
#     *   **Practice Name:** Better Life Multiple Sclerosis Center
#     *   **Practice Address:** 3320 Montgomery Dr NASHVILLE TN 37361
#     *   **Practice Phone:** 614-936-0065
#
# ### Page 7
# *   **Header:** 05/22/2024 WED 11:34 FAX 2007/028
# *   **Patient:** Shakh Abdulla
# *   **Hospital A/C:** (blank)
# *   **Care Everywhere ID#:** VDJ-7KR2-4847-LGF8
# *   **Center:** Better Life Multiple Sclerosis Center
# *   **ENCOUNTER**
#     *   **Patient Class:** (blank)
#     *   **Admission Date/Time:** 5/17/2024
#     *   **Admission User:** (blank)
#     *   **Referring Physician:** (blank)
#     *   **Admitting Provider:** (blank)
#     *   **Attending Provider:** (blank)
#     *   **Adm Diagnosis:** MyHealth Bundle Status: (blank)
# *   **PATIENT**
#     *   **Name:** Shakh Abdulla
#     *   **DOB:** 4/1/2001 (23 yrs)
#     *   **Sex:** male
#     *   **Address:** 425 Sherman Aves APT D, Nashville TN 37923
#     *   **Preferred Language:** Arabic
#     *   **Primary Care Provider:** James David, PNP
#     *   **Primary Phone:** 865-839-7458
#     *   **Marital Status:** Single
#     *   **Mobile Phone:** 865-839-7458
# *   **EMERGENCY CONTACT**
#     *   **Contact Name:**
#         *   1. Sina, Amin
#         *   2. Mohammedreza, Mustafa
#     *   **Legal Guardian?:** Yes, Yes
#     *   **Relationship to Patient:** Father, Mother
#     *   **Home Phone:** (blank), (blank)
#     *   **Work Phone:** (blank), (blank)
# *   **GUARANTOR**
#     *   **Guarantor:** (blank)
#     *   **DOB:** 10/29/1979
#     *   **Sex:** Female
#     *   **Address:** (blank)
#     *   **Relation to Patient:** (blank)
#     *   **Home Phone:** (blank)
#     *   **Guarantor ID:** (blank)
#     *   **Mobile Phone:** (blank)
#     *   **Work Phone:** (blank)
# *   **GUARANTOR EMPLOYER**
#     *   There is no guarantor Information entered for this encounter.
#     *   **Status:** NOT EMPLO
# *   **COVERAGE**
#     *   **PRIMARY INSURANCE**
#         *   **Payor:** (blank, but identified as BC TENNCARE on page 8)
#         *   **Plan:** TC BLUE CARE NO COPAY
#         *   **Group Number:** (blank, but identified as 435000 on page 8)
#         *   **Insurance Type:** (blank)
#         *   **Subscriber Name:** (blank, but identified as ABDULLA, SHAKH on page 8)
#         *   **Subscriber DOB:** (blank)
#         *   **Subscriber ID:** (blank, but identified as LAJM14345116 on page 8)
#         *   **Pat. Rel. to Subscriber:** (blank)
#         *   **Financial Class:** (blank)
#     *   **SECONDARY INSURANCE**
#         *   **Payor:** (blank)
#         *   **Plan:** (blank)
#         *   **Group Number:** (blank)
#         *   **Insurance Type:** (blank)
#         *   **Subscriber Name:** (blank)
#         *   **Subscriber DOB:** (blank)
#         *   **Subscriber ID:** (blank)
#         *   **Pat. Rel. to Subscriber:** (blank)
#
# ### Page 8
# *   **Header:** 05/22/2024 WED 11:34 FAX 2008/028
# *   **Patient Context:** Abdulnabi, Noor (MRN: 041152153) DOB: 4/1/2001 (Note: This patient name/DOB is inconsistent with others. Assuming OCR error, defaulting to Shakh Abdulla.)
# *   **Primary Coverage**
#     *   **Payer:** BC TENNCARE
#     *   **Plan:** TC BLUE CARE NO COPAY
#     *   **Sponsor Code:** (blank)
#     *   **Group Number:** 435000
#     *   **Group Name:** TENNCARE/BLUECARE
# *   **Primary Subscriber**
#     *   **ID:** LAJM14345116
#     *   **Name:** ABDULLA, SHAKH
#     *   **SSN:** xxx-xx-8143
#     *   **Address:** 8327 BROADWAY LN APT D, KNOXVILLE, TN 37923
#
# ### Page 9
# *   **Header:** 05/22/2024 WED 11:34 FAX 2009/028
# *   **Patient Name:** Abdulla, Shakh
# *   **MRN:** 048152153 (Note: This MRN is inconsistent with the one on page 2, 3, 7, 8. Using 041152153 as primary, but noting this discrepancy).
# *   **ED to Hosp-Admission**
#     *   **Dates:** 5/14/2024 - 5/17/2024 (3 days)
#     *   **Status:** Discharged
#     *   **Hospital:** Monroe Carell Jr. Children's Hospital
#     *   **Last attending:** Harry, Tom, MD with Treatment team
#     *   **Principal problem:** Abnormal MRI
# *   **Discharge Summary**
#     *   **Cosigned by:** Gu, Hao H, MD at 5/17/2024 1:56 PM
#     *   **Resident Physician:** Kaine, Adam Jason, MD (Pediatric Neurology)
#     *   **Attestation signed by:** Gu, Hao H, MD at 5/17/2024 1:56 PM (Updated)
#     *   **Patient Encounter Details:** I saw the patient on: 5/17/2024 with Dr Kaine, I discussed the care with Dr Kaine, patient and his father at bedside and agree with the findings and plan as documented in the attached note. I personally spent more than 30 minutes on the patient's care unit in the preparation and execution of the hospital discharge.
#     *   **Treatment Post-Discharge:** S/p 4 days of high dose IVMP (1g/dose) today- Discharge home with oral decadron 180mg (equivalent to 1000mg IVMP) x 1 to round out 5 days of high dose steroid treatment for active demyelinating lesion (family wishes to be discharged today instead of Saturday) he will then start oral prednisone taper- instructions provided +PPI
#     *   **Future Treatment/Appointments:** First dose of Rituximab or biosimilar scheduled for May 22 at 9am; second dose of first course of Rituximab within 2 weeks after, we are working with local infusion facility in Knoxville to get this set up for her moving forward to minimize travel. he will follow up with ophthalmologist in Knoxville. School note for this week and next week. PT/OT locally. Continue vitamin D. I will see her tentatively 3 months after completion of 1st course of Rituximab -with same day MRI (she does not need sedation)- looking to early or mid September. Will update family once we have that arranged.
#     *   **Signed by:** Hao Gu MD
# *   **Neurology Discharge Summary**
# *   **Patient Name:** Shakh Abdulla
# *   **DOB:** 4/1/2001
# *   **Service:** Pediatric Neurology
# *   **Attending:** Harry, Tom, MD
# *   **Date of Admission:** 5/14/2024
#
# ### Page 10
# *   **Header:** 05/22/2024 WED 11:34 FAX 2010/028
# *   **Date of Discharge:** 5/17/2024
# *   **Diagnosis:**
#     *   **Principal Problem:** Abnormal MRI
#     *   **Resolved Problems:** * No resolved hospital problems. *
# *   **Procedures:**
#     *   **Bedside Procedures:** No orders of the defined types were placed in this encounter.
#     *   **OR Procedures:** * Cannot find OR case *
# *   **Synopsis:** Shakh Abdulla is a 23 year old male who established care with VCH neurology; with MRI brain and spine demonstrating multiple lesions consistent with atypical pediatric MS.
# *   **Hospital Course:**
#     *   **Admission Reason:** Shakh Abdulla is a 23 year old male with history of optic neuritis and abnormal MRI brain concerning for MS who presented for admission following clinic visit and neuroimaging today. History from primary neurologist, clinic visit and patient and father at bedside. Patient referred to Dr. Gu by Dr. Fazal in East Bay. Confirms predominant symptoms since April of numbness in his right hand and urinary hesitancy/urgency. Additionally reporting right eye pain since time of clinic visit this morning. MRI brain and spine obtained following clinic visit and multiple lesions noted on brain and spine suggestive of pediatric MS. Presents for admission for IVMP.
#     *   **Clinic Visit Details (05/14/2024):** Per clinic visit earlier today with Dr. Gu and confirmed with family at bedside: Shakh is a 23 years old male, previously healthy who has been referred to neuroimmunology clinic for diagnosis of optic neuritis and abnormal brain MRI concerning for MS. He is referred by Dr Fazal-pediatric neurology in East Bay.
#     *   **Information Gathering:** he is here with dad; patient himself is an excellent historian and provided the following information- I do not have CSF results nor clinic note- I do have MRI report from Jan 21 2024 (no actual images)- with father and his permission, I reached out to Dr Shane- Dr Fazal's colleague on service who can help assist with quick access to Shakh's chart.
#     *   **Symptom Onset and Progression:** Today, Shakh tells me that around early Oct 2023- he started to notice in right eye "neon bright color" fuzzy vision, and eye pain with movement and perhaps right side of his face in discomfort triggered by physical activities. Symptoms improved once he rested. By end of Oct 2023, he brought this up to parents and was brought to local eye doctor and recalled being told that"right eye being inflamed" and he recalled visual field deficits appreciated during exam.
#     *   **Previous Referrals/Treatments:** He was referred to UT ophthalmology Dr Derrek in Jan this year, per report negative MOG and AQP4 [While waiting on this appt, he thought some improvement but not back to baseline entirely -"not completely normal"]. When he saw UT ophthalmology clinic, recommended brain and orbit and noted WM changes and MS was mentioned. He was treated with 5 days of IVMP and referred to see Dr Kosentka ped neurology.
#     *   **MRI Report (Jan 21 2024):** "Diffuse T2 hyperintensity and decreased volume throughout the right optic nerve is similar to prior examination however associated abnormal enhancement seen on prior study has resolved, presumably secondary to interval treatment. Left optic nerve is subtle but diffusely small in caliber without significant change from last exam. Several intracranial WM lesions, stable from last"
#     *   **Further Evaluation:** He saw Dr Fazal in Feb 2024-who obtained LP and had markers of MS and referred to MS clinic today.
#     *   **Referral Source:** Below are information provided by Dr Shane. Per note recommended referral to our MS center for further evaluation and treatment.
#
# ### Page 11
# *   **Header:** 05/22/2024 WED 11:35 FAX 2011/028
# *   **CSF Results:** CSF: WBC, 837 rbc, IgG Index 0.87 (elevated), +OCB
# *   **Recent Symptom Details (April 2024):** Prior to appt today May 14- he noted that in April of this year, started to have involvement of LEFT eye - again similar with "neon colors appearance", some eye discomfort; it happened several times during the day for a few days and has since resolved.
# *   **Other Symptoms (Since April):** Since April he has had intermittent numbness in his right hand (dominant hand)+ along with muscle twitch in his hands and shoulder like tics. He has noticed a change with urinary hesitancy- taking a long time to empty his bladder and in addition urinary urgency. He has not noticed weakness but noted intermittent drifting to right side, bumping into things. He does note that at times when he laughs, bends his neck, does note electrical sensation.
# *   **Current Status:** Academically doing very well, no difficulty. Sleeps well.
# *   **Family history:** parents and brothers are healthy
# *   **Floor course (05/14 -):** Patient was admitted to the wards in a stable condition. Patient was initiated on high dose steroids for 5 days and tolerated well. MRI consistent with lesions in the brain and spinal cord consistent with atypical MS. ANA was positive as well as SSB so rheumatology was consulted but felt she did not have evidence of another systemic autoimmune disease. PT/OT evaluated his and he will follow outpatient. He was dc with Decadron and then steroid taper with Pepcid prophylaxis. He was arranged to have outpatient rituximab and Dr. Gu will follow his in clinic.
# *   **Physical Exam (First Entry):**
#     *   **Temp:** [36.5 °C (97.7 °F)-36.7 °C (98.1 °F)] 36.7 °C (98 °F)
#     *   **Pulse:** [81-99] 84
#     *   **Resp:** [16-18] 16
#     *   **BP:** (122-136)/(63-99) 126/63
#     *   **SpO2:** [98%] 98%
# *   **Physical Exam (Second Entry, repeated):**
#     *   **Temp:** [36.5 °C (97.7 °F)-36.7 °C (98.1 °F)] 36.7 °C (98 °F)
#     *   **Pulse:** [81-99] 84
#     *   **Resp:** [16-18] 16
#     *   **BP:** (122-136)/(63-99) 126/63
#     *   **SpO2:** [98%] 98%
# *   **General Appearance:** -Well appearing; NAD
# *   **CV:** -RRR
# *   **HIGHER INTEGRATIVE FUNCTIONS:**
#     *   -Attention & concentration: Normal
#     *   -Orientation: Oriented to person, place & time
#     *   -Memory: Recent and remote memory intact
#     *   -Language: Normal
#     *   -Fund of Knowledge: Normal
# *   **CRANIAL NERVES:**
#     *   -CN 2: Visual fields full
#     *   -CN 2,3: PERRL; rAPD
#     *   -CN 3,4,6: EOMI
#     *   -CN 5: Facial sensation intact
#     *   -CN 7: Facial strength/movement intact bilaterally
#
# ### Page 12
# *   **Header:** 05/22/2024 WED 11:35 FAX 2012/028
# *   **CRANIAL NERVES (continued):**
#     *   -CN 8: Hearing normal bilaterally
#     *   -CN 9,10: Palate elevates symmetrically
#     *   -CN 11: Normal shoulder shrug and head turn
#     *   -CN 12: Tongue protrudes midline
# *   **MOTOR:**
#     *   -Muscle tone normal in upper and lower extremities
#     *   -Muscle strength 5/5 In upper and lower extremities; RLE 4+ proximally
# *   **SENSATION:**
#     *   -Intact to light touch in upper and lower extremities bilaterally
# *   **COORDINATION:**
#     *   -Finger/nose intact bilaterally
# *   **GAIT:**
#     *   -Normal gait
# *   **Immunizations/Injections Administered for This Admission:** No immunizations on file.
# *   **Allergies:** No Known Allergies
# *   **Diagnostic Studies: Recent Results (from the past 24 hour(s))**
#     *   **CBC w/ Differential**
#         *   Collection Time: 05/14/24 10:47 AM
#         *   **Result** | **Value** | **Ref Range**
#         *   White Blood Cells | 7.7 | 3.4-10.2 x10(3)/mcL
#         *   Red Blood Cells | 4.63 | 3.80-5.50 x10(6)/mcL
#         *   Hemoglobin | 13.0 | 12.0-16.0 gm/dL
#         *   Hematocrit | 40 | 35-49%
#         *   Mean Cell Volume | 86 | 76-96 fL
#         *   Mean Cell Hemoglobin | 28.1 | 25.0-35.0 pg
#         *   Mean Cell Hemoglobin Concentration | 32.7 | 32.0-37.0 gm/dL
#         *   RDW SD | 38.4 | 37.4-52.4 fL
#         *   RDW CV | 12.3 | 11.1-14.3 %
#         *   Platelet | 300 | 150-400 x10(3)/mcL
#
# ### Page 13
# *   **Header:** 05/22/2024 WED 11:35 FAX 2013/028
# *   **Diagnostic Studies (continued):**
#     *   **Result** | **Value** | **Ref Range**
#     *   Mean Platelet Volume | 10.0 | 9.3 - 12.8 fL
#     *   Nucleated RBC | 0 | 0 - 0/100 WBC
#     *   Nucleated RBC Abs | 0.00 | 0.00-0.00 x10(3)/mcL
#     *   Auto Neutrophil Absolute | 4.52 | 1.80-7.70 x10(3)/mcL
#     *   **CMP**
#         *   Collection Time: 05/14/24 10:47 AM
#         *   **Result** | **Value** | **Ref Range**
#         *   Sodium Level | 139 | 138-145 mmol/L
#         *   Potassium Level | 3.8 | 3.3-4.8 mmol/L
#         *   Chloride Level | 101 | 98-107 mmol/L
#         *   Carbon Dioxide | 22 | 17-28 mmol/L
#         *   Anion Gap | 16 | mmol/L
#         *   Glucose Level | 95 | 60-99 mg/dL
#         *   Blood Urea Nitrogen | 13 | 7-18 mg/dL
#         *   Creatinine Level | 0.67 | 0.50-0.90 mg/dL
#         *   Calcium Level Total | 9.9 | 8.4-10.2 mg/dL
#         *   Billrubin Total | 0.4 | 0.0-0.7 mg/dL
#         *   Albumin Level | 4.7 | 4.0-5.3 gm/dL
#         *   Protein Total | 8.4 (H) | 6.3-7.8 gm/dL (H indicates High)
#         *   Alkaline Phosphatase | 55 | 50-117 unit/L
#         *   Aspartate Aminotransferase | 25 | 21-34 unit/L
#         *   Alanine Aminotransferase | <6 | 0-17 unit/L
#     *   **Hepatitis B Pnl**
#         *   Collection Time: 05/14/24 10:47 AM
#         *   **Result** | **Value** | **Ref Range**
#         *   Hepatitis B Surface Antigen | Negative | Negative
#         *   Hep B Core Ab Total | Negative | Negative
#         *   Hepatitis B Surface Ab Unit | 44.7 (H) | <=10.0 mlU/mL (H indicates High)
#         *   Hep Bs Ab Interp | Positive (A) | Negative (A indicates Abnormal)
#     *   **IgG**
#         *   Collection Time: 05/14/24 10:47 AM
#         *   **Result** | **Value** | **Ref Range**
#         *   IgG Quantitative | 1,355 (H) | 600-1,310 mg/dL (H indicates High)
#
# ### Page 14
# *   **Header:** 05/22/2024 WED 11:35 FAX 2014/028
# *   **Diagnostic Studies (continued):**
#     *   **IgA**
#         *   Collection Time: 05/14/24 10:47 AM
#         *   **Result** | **Value** | **Ref Range**
#         *   IgA Quantitative | 279 | 40-290 mg/dL
#     *   **Auto Diff**
#         *   Collection Time: 05/14/24 10:47 AM
#         *   **Result** | **Value** | **Ref Range**
#         *   Neutrophils | 58.3 | %
#         *   Absolute Neutrophils | 4.52 | 1.80-7.70 x10(3)/mcL
#         *   Lymphs | 33.6 | %
#         *   Absolute Lymphocytes | 2.60 | 1.70-4.50 x10(3)/mcL
#         *   Monocytes | 6.5 | %
#         *   Absolute Monocytes | 0.50 | 0.20-1.00 x10(3)/mcL
#         *   Eosinophils | 0.5 | %
#         *   Absolute Eosinophils | 0.04 | 0.00-0.50 x10(3)/mcL
#         *   Basophils | 0.8 | %
#         *   Absolute Basophils | 0.06 | 0.01-0.08 x10(3)/mcL
#         *   Imm Gran Automated | 0.3 | %
#         *   Absolute Imm Gran Automated | 0.02 | 0.00-0.03 x10(3)/mcL
# *   **Consultations Obtained:**
#     *   Orders Placed This Encounter
#     *   Procedures:
#         *   Inpatient Consult to Pediatric Ophthalmology
#         *   Inpatient Consult to Pediatric Rheumatology
#         *   Inpatient consult to Case Management
# *   **Condition at Discharge:** Stable
# *   **Disposition:** Home or Self Care
# *   **Patient Instructions:** (blank)
# *   **Discharge Medications**
#     *   **New Medications:**
#         *   **dexamethasone 4 mg/mL CONCENTRATED solution**
#             *   Sig: Take 45 mL (180 mg total) by mouth daily for 1 dose. See comment.
#         *   **famotidine 40 mg tablet**
#             *   Commonly known as: PEPCID
#             *   Sig: Take 1 tablet (40 mg total) by mouth daily.
#
# ### Page 15
# *   **Header:** 05/22/2024 WED 11:35 FAX 2015/028
# *   **Discharge Medications (continued):**
#     *   **predniSONE 20 mg tablet**
#         *   Commonly known as: DELTASONE
#         *   Start taking on: May 16, 2024
#         *   Sig: Take 3 tablets (60 mg total) by mouth daily for 7 days, THEN 2 tablets (40 mg total) daily for 7 days, THEN 1 tablet (20 mg total) daily for 7 days, THEN 0.5 tablets (10 mg total) daily for 7 days. Then stop.
# *   **Activity Instructions:**
#     *   **Discharge activity - Normal Activity**
#     *   **Caution for Driving/Operating Machinery:** Some medications such as for example pain medications and sleeping or anti-anxiety agents may affect your ability to operate heavy machinery including driving. Please always carefully read the labels on the medications that you take. If you have experienced confusion, seizures, lightheadedness or blackouts then it may not be safe or even legal for you to operate heavy machinery (including driving). Please act in the interest of your own safety and that of others. Speak to a physician If you are not sure whether it is safe or legal for you to drive.
#     *   **Care Instructions (Exercise):** You should engage in exercise as tolerated to improve your health. You may go to the website of the American Heart Association for additional information and tips on how to exercise right (www.americanheart.org).
# *   **Scheduled Appointments:**
#     *   **Date/Time:** May 22, 2024 10:30 AM
#     *   **Appointment Type:** Peds Infusion (Leantaas) with PEDS INF UMBRELLA, PEDS 241+ MIN INFUSION
#     *   **Department/Service:** Children's Hematology - Oncology (Peds DOT 6)
#     *   **Location:** 2211 Broad Way, Tower 4th FL, Suite 6102, Nashville TN 37232
#     *   **Phone:** 615-936-1762
#
# ---
#
# ## Structured JSON Output
#
# ```json
# {
#   "PATIENT_DEMOGRAPHICS": {
#     "full_name": "Shakh Abdulla",
#     "dob": "2001-04-01",
#     "gender": "male",
#     "address": {
#       "primary": "425 Sherman Ave, Nashville TN 37995",
#       "subscriber_address": "8327 BROADWAY LN APT D, KNOXVILLE, TN 37923"
#     },
#     "phone_numbers": {
#       "home": "865-395-3958",
#       "mobile": "865-395-0481"
#     },
#     "patient_id_numbers": {
#       "mrn": "041152153",
#       "care_everywhere_id": "VDJ-7KR2-4847-LGF8"
#     },
#     "emergency_contacts": [
#       {
#         "name": "Sina, Amin",
#         "relationship": "Father",
#         "is_legal_guardian": true,
#         "phone_home": null,
#         "phone_work": null
#       },
#       {
#         "name": "Mohammedreza, Mustafa",
#         "relationship": "Mother",
#         "is_legal_guardian": true,
#         "phone_home": null,
#         "phone_work": null
#       }
#     ]
#   },
#   "INSURANCE_INFORMATION": {
#     "primary_insurance": {
#       "insurance_company_name": "BC TENNCARE / TENNCARE/BLUECARE",
#       "plan_details": "TC BLUE CARE NO COPAY",
#       "member_id": "LAJM14345116",
#       "group_number": "435000",
#       "policy_number": null,
#       "subscriber_information": {
#         "name": "ABDULLA, SHAKH",
#         "relationship_to_patient": "Self",
#         "dob": null,
#         "ssn": "xxx-xx-8143"
#       },
#       "coverage_details": null,
#       "effective_dates": null
#     },
#     "secondary_insurance": null
#   },
#   "CLINICAL_INFORMATION": {
#     "primary_diagnoses": [
#       {
#         "diagnosis": "Multiple sclerosis in pediatric patient",
#         "icd_code": "G35"
#       },
#       {
#         "diagnosis": "Abnormal MRI"
#       }
#     ],
#     "secondary_diagnoses": [
#       {
#         "diagnosis": "Optic neuritis"
#       },
#       {
#         "diagnosis": "Active demyelinating lesion"
#       }
#     ],
#     "current_medications": [
#       {
#         "name": "Rituximab / Biosimilar (Truxima)",
#         "type": "Infusion",
#         "dosage": "694 mg (rounded from 693.75 mg = 375 mg/m2 x 1.85 m2 - BSA might be out of date)",
#         "frequency": "Initial: Every 2 weeks (2 doses remaining); Maintenance: Every 24 weeks",
#         "route": "intraVENOUS (IVPB)",
#         "instructions": "Administer 30 minutes after treatment start time. 1st infusion: initiate at 50mg/hr, increase by 50mg/hr every 30 min, Max Rate 400mg/hr. Subsequent infusions: initiate at 100mg/hr, increase by 100mg/hr every 30 min, Max Rate 400mg/hr."
#       },
#       {
#         "name": "Heparin, porcine (PF)",
#         "dosage": "100 unit/mL syringe 5 mL",
#         "frequency": "PRN",
#         "route": "intraVENOUS",
#         "instructions": "As needed, for flushing Ports/ PICC lines/ Central Lines IF NEEDED"
#       },
#       {
#         "name": "Acetaminophen (Tylenol)",
#         "dosage": "650 mg",
#         "frequency": "Once, Every visit (as pre-medication)",
#         "route": "oral",
#         "instructions": "Starting when released"
#       },
#       {
#         "name": "Diphenhydramine (Benadryl)",
#         "dosage": "50 mg",
#         "frequency": "Once, Every visit (as pre-medication)",
#         "route": "intraVENOUS",
#         "instructions": "Administer 30 minutes before starting infusion."
#       },
#       {
#         "name": "Methylprednisolone sod succinate (Solu-Medral)",
#         "dosage": "125 mg in NS 6.2 mL (20 mg/mL)",
#         "frequency": "Once, Every visit (as pre-medication)",
#         "route": "intraVENOUS",
#         "instructions": "Administer 30 minutes before starting infusion."
#       },
#       {
#         "name": "Diphenhydramine (Benadryl) injection",
#         "dosage": "25 mg",
#         "frequency": "PRN",
#         "route": "intraVENOUS",
#         "instructions": "As needed, chills, for 2 doses"
#       },
#       {
#         "name": "Meperidine (Demerol) injection",
#         "dosage": "25 mg",
#         "frequency": "PRN",
#         "route": "intraVENOUS",
#         "instructions": "As needed, rigors, for 2 doses"
#       },
#       {
#         "name": "Ondansetron (Zofran) injection",
#         "dosage": "4 mg",
#         "frequency": "PRN",
#         "route": "intraVENOUS",
#         "instructions": "As needed, nausea, vomiting, for 2 doses. Doses up to 4 mg may be administered undiluted. Inject over at least 30 seconds, but preferably over 2-5 minutes."
#       },
#       {
#         "name": "Dexamethasone",
#         "dosage": "180 mg total (45 mL of 4 mg/mL solution)",
#         "frequency": "Daily for 1 dose",
#         "route": "oral",
#         "instructions": "Discharge medication. Equivalent to 1000mg IVMP for 5 days of high dose steroid treatment."
#       },
#       {
#         "name": "Famotidine (Pepcid)",
#         "dosage": "40 mg",
#         "frequency": "Daily",
#         "route": "oral",
#         "instructions": "Discharge medication."
#       },
#       {
#         "name": "Prednisone (Deltasone)",
#         "dosage": "Tapering schedule: 60mg daily for 7 days, then 40mg daily for 7 days, then 20mg daily for 7 days, then 10mg daily for 7 days, then stop.",
#         "frequency": "Daily, tapering",
#         "route": "oral",
#         "instructions": "Start taking on May 16, 2024. Discharge medication."
#       },
#       {
#         "name": "Vitamin D",
#         "dosage": null,
#         "frequency": null,
#         "route": null,
#         "instructions": "Continue."
#       }
#     ],
#     "allergies": "No Known Allergies",
#     "adverse_reactions": null,
#     "vital_signs": {
#       "collection_time": "05/14/2024 10:47 AM",
#       "temperature": {
#         "value": "36.7 °C (98 °F)",
#         "reference_range": "36.5 °C (97.7 °F)-36.7 °C (98.1 °F)"
#       },
#       "pulse": {
#         "value": "84",
#         "reference_range": "81-99"
#       },
#       "respiration": {
#         "value": "16",
#         "reference_range": "16-18"
#       },
#       "blood_pressure": {
#         "value": "126/63",
#         "reference_range": "122-136/63-99"
#       },
#       "spo2": {
#         "value": "98%",
#         "reference_range": "98%"
#       }
#     },
#     "lab_results": {
#       "collection_time": "05/14/2024 10:47 AM",
#       "cbc_w_differential": [
#         { "test": "White Blood Cells", "value": "7.7", "unit": "x10(3)/mcL", "reference_range": "3.4-10.2" },
#         { "test": "Red Blood Cells", "value": "4.63", "unit": "x10(6)/mcL", "reference_range": "3.80-5.50" },
#         { "test": "Hemoglobin", "value": "13.0", "unit": "gm/dL", "reference_range": "12.0-16.0" },
#         { "test": "Hematocrit", "value": "40", "unit": "%", "reference_range": "35-49" },
#         { "test": "Mean Cell Volume", "value": "86", "unit": "fL", "reference_range": "76-96" },
#         { "test": "Mean Cell Hemoglobin", "value": "28.1", "unit": "pg", "reference_range": "25.0-35.0" },
#         { "test": "Mean Cell Hemoglobin Concentration", "value": "32.7", "unit": "gm/dL", "reference_range": "32.0-37.0" },
#         { "test": "RDW SD", "value": "38.4", "unit": "fL", "reference_range": "37.4-52.4" },
#         { "test": "RDW CV", "value": "12.3", "unit": "%", "reference_range": "11.1-14.3" },
#         { "test": "Platelet", "value": "300", "unit": "x10(3)/mcL", "reference_range": "150-400" },
#         { "test": "Mean Platelet Volume", "value": "10.0", "unit": "fL", "reference_range": "9.3-12.8" },
#         { "test": "Nucleated RBC", "value": "0", "unit": "WBC", "reference_range": "0-0/100" },
#         { "test": "Nucleated RBC Abs", "value": "0.00", "unit": "x10(3)/mcL", "reference_range": "0.00-0.00" },
#         { "test": "Auto Neutrophil Absolute", "value": "4.52", "unit": "x10(3)/mcL", "reference_range": "1.80-7.70" }
#       ],
#       "cmp": [
#         { "test": "Sodium Level", "value": "139", "unit": "mmol/L", "reference_range": "138-145" },
#         { "test": "Potassium Level", "value": "3.8", "unit": "mmol/L", "reference_range": "3.3-4.8" },
#         { "test": "Chloride Level", "value": "101", "unit": "mmol/L", "reference_range": "98-107" },
#         { "test": "Carbon Dioxide", "value": "22", "unit": "mmol/L", "reference_range": "17-28" },
#         { "test": "Anion Gap", "value": "16", "unit": "mmol/L", "reference_range": null },
#         { "test": "Glucose Level", "value": "95", "unit": "mg/dL", "reference_range": "60-99" },
#         { "test": "Blood Urea Nitrogen", "value": "13", "unit": "mg/dL", "reference_range": "7-18" },
#         { "test": "Creatinine Level", "value": "0.67", "unit": "mg/dL", "reference_range": "0.50-0.90" },
#         { "test": "Calcium Level Total", "value": "9.9", "unit": "mg/dL", "reference_range": "8.4-10.2" },
#         { "test": "Billrubin Total", "value": "0.4", "unit": "mg/dL", "reference_range": "0.0-0.7" },
#         { "test": "Albumin Level", "value": "4.7", "unit": "gm/dL", "reference_range": "4.0-5.3" },
#         { "test": "Protein Total", "value": "8.4", "unit": "gm/dL", "reference_range": "6.3-7.8", "abnormal_flag": "H" },
#         { "test": "Alkaline Phosphatase", "value": "55", "unit": "unit/L", "reference_range": "50-117" },
#         { "test": "Aspartate Aminotransferase", "value": "25", "unit": "unit/L", "reference_range": "21-34" },
#         { "test": "Alanine Aminotransferase", "value": "<6", "unit": "unit/L", "reference_range": "0-17" }
#       ],
#       "hepatitis_b_pnl": [
#         { "test": "Hepatitis B Surface Antigen", "value": "Negative", "reference_range": "Negative" },
#         { "test": "Hep B Core Ab Total", "value": "Negative", "reference_range": "Negative" },
#         { "test": "Hepatitis B Surface Ab Unit", "value": "44.7", "unit": "mlU/mL", "reference_range": "<=10.0", "abnormal_flag": "H" },
#         { "test": "Hep Bs Ab Interp", "value": "Positive", "reference_range": "Negative", "abnormal_flag": "A" }
#       ],
#       "igg_quantitative": {
#         "value": "1,355",
#         "unit": "mg/dL",
#         "reference_range": "600-1,310",
#         "abnormal_flag": "H"
#       },
#       "iga_quantitative": {
#         "value": "279",
#         "unit": "mg/dL",
#         "reference_range": "40-290"
#       },
#       "auto_diff": [
#         { "test": "Neutrophils", "value": "58.3", "unit": "%", "reference_range": null },
#         { "test": "Absolute Neutrophils", "value": "4.52", "unit": "x10(3)/mcL", "reference_range": "1.80-7.70" },
#         { "test": "Lymphs", "value": "33.6", "unit": "%", "reference_range": null },
#         { "test": "Absolute Lymphocytes", "value": "2.60", "unit": "x10(3)/mcL", "reference_range": "1.70-4.50" },
#         { "test": "Monocytes", "value": "6.5", "unit": "%", "reference_range": null },
#         { "test": "Absolute Monocytes", "value": "0.50", "unit": "x10(3)/mcL", "reference_range": "0.20-1.00" },
#         { "test": "Eosinophils", "value": "0.5", "unit": "%", "reference_range": null },
#         { "test": "Absolute Eosinophils", "value": "0.04", "unit": "x10(3)/mcL", "reference_range": "0.00-0.50" },
#         { "test": "Basophils", "value": "0.8", "unit": "%", "reference_range": null },
#         { "test": "Absolute Basophils", "value": "0.06", "unit": "x10(3)/mcL", "reference_range": "0.01-0.08" },
#         { "test": "Imm Gran Automated", "value": "0.3", "unit": "%", "reference_range": null },
#         { "test": "Absolute Imm Gran Automated", "value": "0.02", "unit": "x10(3)/mcL", "reference_range": "0.00-0.03" }
#       ],
#       "csf_results": {
#         "wbc": null,
#         "rbc": "837",
#         "igg_index": "0.87",
#         "igg_index_status": "elevated",
#         "ocb": "positive"
#       }
#     },
#     "previous_treatments_and_outcomes": [
#       {
#         "treatment": "High dose IVMP (1g/dose)",
#         "duration": "4 days",
#         "outcome": "Tolerated well. MRI consistent with lesions in brain and spinal cord. Symptoms resolved or improved."
#       },
#       {
#         "treatment": "Oral Decadron",
#         "dosage": "180mg (equivalent to 1000mg IVMP)",
#         "outcome": "Used to round out 5 days of high dose steroid treatment."
#       },
#       {
#         "treatment": "Oral Prednisone taper",
#         "outcome": "Discharge medication."
#       },
#       {
#         "treatment": "5 days of IVMP (after UT ophthalmology clinic)",
#         "outcome": "Improvement noted, but not back to baseline. Associated abnormal enhancement seen on prior MRI resolved."
#       },
#       {
#         "treatment": "LP (Lumbar Puncture)",
#         "outcome": "Markers of MS obtained."
#       }
#     ],
#     "medical_history_and_comorbidities": [
#       "History of optic neuritis",
#       "Abnormal MRI brain concerning for MS",
#       "Atypical pediatric MS",
#       "ANA positive",
#       "SSB positive",
#       "Family history of healthy parents and brothers"
#     ],
#     "social_history": {
#       "preferred_language": "Arabic (Spoken/English-Written)",
#       "marital_status": "Single",
#       "academics": "Doing very well, no difficulty",
#       "sleep": "Sleeps well"
#     },
#     "physical_exam_findings": {
#       "general_appearance": "Well appearing; NAD",
#       "cardiovascular": "-RRR",
#       "higher_integrative_functions": {
#         "attention_concentration": "Normal",
#         "orientation": "Oriented to person, place & time",
#         "memory": "Recent and remote memory intact",
#         "language": "Normal",
#         "fund_of_knowledge": "Normal"
#       },
#       "cranial_nerves": {
#         "cn_2": "Visual fields full",
#         "cn_2_3": "PERRL; rAPD",
#         "cn_3_4_6": "EOMI",
#         "cn_5": "Facial sensation intact",
#         "cn_7": "Facial strength/movement intact bilaterally",
#         "cn_8": "Hearing normal bilaterally",
#         "cn_9_10": "Palate elevates symmetrically",
#         "cn_11": "Normal shoulder shrug and head turn",
#         "cn_12": "Tongue protrudes midline"
#       },
#       "motor": {
#         "muscle_tone": "Normal in upper and lower extremities",
#         "muscle_strength": "5/5 In upper and lower extremities; RLE 4+ proximally"
#       },
#       "sensation": "Intact to light touch in upper and lower extremities bilaterally",
#       "coordination": "Finger/nose intact bilaterally",
#       "gait": "Normal gait"
#     }
#   },
#   "PROVIDER_INFORMATION": {
#     "referring_physician": {
#       "name": "Dr Fazal",
#       "specialty": "Pediatric Neurology",
#       "contact_info": "East Bay (location)"
#     },
#     "primary_care_provider": {
#       "name": "James David, PNP",
#       "specialty": null,
#       "contact_info": null
#     },
#     "attending_physician": {
#       "name": "Harry, Tom, MD",
#       "specialty": null,
#       "contact_info": null
#     },
#     "cosigning_physician": {
#       "name": "Gu, Hao H, MD",
#       "specialty": null,
#       "npi": "1154611523",
#       "contact_info": null
#     },
#     "resident_physician": {
#       "name": "Kaine, Adam Jason, MD",
#       "specialty": "Pediatric Neurology",
#       "contact_info": null
#     },
#     "other_providers": [
#       {
#         "name": "Erfan Rostami, BSN, RN",
#         "specialty": null,
#         "contact_info": {
#           "phone": "615-343-1176",
#           "fax": "615-343-1219"
#         }
#       },
#       {
#         "name": "Dr Shane",
#         "specialty": null,
#         "contact_info": null
#       },
#       {
#         "name": "Dr Derrek",
#         "specialty": "UT ophthalmology",
#         "contact_info": null
#       },
#       {
#         "name": "Dr Kosentka",
#         "specialty": "Pediatric Neurology",
#         "contact_info": null
#       }
#     ],
#     "practice_name": "Better Life Multiple Sclerosis Center",
#     "practice_address": "3320 Montgomery Dr, Nashville, TN 37361",
#     "practice_contact_info": {
#       "phone": "615-562-4848",
#       "fax": "615-562-4820"
#     },
#     "facility_details": {
#       "hospital_admission": "Monroe Carell Jr. Children's Hospital",
#       "infusion_center": "Golden Gate Infusion Center"
#     }
#   },
#   "TREATMENT_DETAILS": {
#     "requested_medication_procedure_device": "Rituximab/Truxima Infusion",
#     "dosage_frequency_duration": {
#       "initial_dose": {
#         "amount": "694 mg",
#         "frequency": "Every 2 weeks",
#         "duration": "2 doses remaining",
#         "start_date": "Week of 5/19/2024",
#         "notes": "Rounded from 693.75 mg = 375 mg/m2 x 1.85 m2 (BSA might be out of date). First dose scheduled May 22 at 9am; second dose within 2 weeks after."
#       },
#       "maintenance_dose": {
#         "amount": "694 mg",
#         "frequency": "Every 24 weeks",
#         "duration": null,
#         "start_date": "Starting when released",
#         "due_date": "Mon 11/4/2024",
#         "notes": "Rounded from 693.75 mg = 375 mg/m2 x 1.85 m2 (BSA might be out of date). Defer until Mon 11/4/2024."
#       },
#       "infusion_rate_guidelines": {
#         "first_infusion": "Initiate at 50mg/hr, may increase by 50mg/hr every 30 minutes; Max Rate 400mg/hr.",
#         "subsequent_infusions": "Initiate at 100mg/hr, may increase by 100mg/hr every 30 min; Max Rate 400mg/hr."
#       }
#     },
#     "medical_necessity_justification": "Patient diagnosed with atypical pediatric MS, history of optic neuritis and abnormal MRI brain, presents with active demyelinating lesion. Requires ongoing management to minimize travel burden and for follow-up care.",
#     "previous_treatment_failures": null,
#     "clinical_criteria_met_for_approval": null
#   },
#   "SUPPORTING_EVIDENCE": {
#     "lab_results_supporting_diagnosis": [
#       "CSF: IgG Index 0.87 (elevated), +OCB",
#       "ANA positive",
#       "SSB positive",
#       "High IgG Quantitative 1,355 mg/dL (Ref: 600-1,310 mg/dL)"
#     ],
#     "imaging_studies_and_results": [
#       {
#         "type": "MRI brain and spine",
#         "date": null,
#         "findings": "Multiple lesions consistent with atypical pediatric MS, diffuse T2 hyperintensity and decreased volume throughout the right optic nerve, associated abnormal enhancement seen on prior study has resolved, several intracranial WM lesions stable."
#       },
#       {
#         "type": "MRI brain and orbit",
#         "date": null,
#         "findings": "WM changes noted."
#       }
#     ],
#     "functional_assessments": [
#       "PT/OT evaluated, patient will follow outpatient.",
#       "Neurological exam findings (Attention & concentration: Normal, Orientation: Oriented to person, place & time, Memory: Recent and remote memory intact, Language: Normal, Fund of Knowledge: Normal, Cranial Nerves: full and intact, Motor: normal tone, strength 5/5, Sensation: intact, Coordination: intact, Gait: Normal)."
#     ],
#     "specialist_consultations": [
#       "Pediatric Ophthalmology (Inpatient Consult)",
#       "Pediatric Rheumatology (Inpatient Consult)",
#       "Case Management (Inpatient Consult)",
#       "Dr Fazal (Pediatric Neurology)",
#       "Dr Derrek (UT Ophthalmology)",
#       "Dr Kosentka (Pediatric Neurology)"
#     ],
#     "treatment_response_documentation": [
#       "Patient admitted in stable condition and tolerated high dose steroids well.",
#       "Symptoms improved after steroid treatment, but not back to baseline entirely.",
#       "MRI shows resolved abnormal enhancement post-treatment.",
#       "Patient stable at discharge, arranged for outpatient Rituximab and follow-up."
#     ],
#     "other_documents": [
#       "Arabic - Spoken / English - Written (language preference)",
#       "Hospital D/C note",
#       "Demographics"
#     ]
#   }
# }
# ```

# %% [markdown]
# ## PA widget input info extraction

# %%
import fitz

# Code from Headstarter tutorial to extract fields from PDF
def extracting_fields_from_pdf(pdf_file):
    """
    Extracts form fields from a PDF file and returns them as a list of dictionaries.
    Each dictionary contains field name, type, value, page number, and other metadata.
    """
    if not pathlib.Path(pdf_file).exists():
        raise FileNotFoundError(f"The file {pdf_file} does not exist.")
    doc = fitz.open(pdf_file)
    fields = []
    for page_num, page in enumerate(doc, start = 1):
        for w in page.widgets() or []:
            field = {
                "name": w.field_name,
                "type": "checkbox" if w.field_type == fitz.PDF_WIDGET_TYPE_CHECKBOX else "text",
                "value": w.field_value,
                "page": page_num,
                "field_type": w.field_type,
                "field_type_string": w.field_type_string,
                "field_label": w.field_label,
            }
            print(field)
            fields.append(field)

    field_by_page = {}
    for field in fields:
        page_num = field["page"]
        if page_num not in field_by_page:
            field_by_page[page_num] = []
    
    return field_by_page

pa_fields = extracting_fields_from_pdf("Input Data/Adbulla/PA.pdf")
# Out:
# {'name': 'CB1', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Start of treatment'}
# {'name': 'T2', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Start date: (MM)'}
# {'name': 'T3', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Start date: (DD)'}
# {'name': 'T4', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Start date: (YYYY)'}
# {'name': 'CB5', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Continuation of therapy'}
# {'name': 'T6', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date of last treatment: (MM)'}
# {'name': 'T7', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date of last treatment: (DD)'}
# {'name': 'T8', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date of last treatment: (YYYY)'}
# {'name': 'T9', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Precertification Requested By:'}
# {'name': 'T10', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Phone:'}
# {'name': 'T11', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Fax:'}
# {'name': 'T12', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient First Name'}
# {'name': 'T13', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient Last Name'}
# {'name': 'T14', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient DOB (MM/DD/YYYY)'}
# {'name': 'T15', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Address:'}
# {'name': 'T16', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'City:'}
# {'name': 'T17', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'State:'}
# {'name': 'T18', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'ZIP:'}
# {'name': 'T19', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient Phone'}
# {'name': 'T20', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Work Phone:'}
# {'name': 'T21', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Cell Phone:'}
# {'name': 'T22', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'E-mail:'}
# {'name': 'T24', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'lbs'}
# {'name': 'T25', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'kgs'}
# {'name': 'T26', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'inches'}
# {'name': 'T27', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'cms'}
# {'name': 'T23', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Allergies:'}
# {'name': 'T28', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Member ID #:'}
# {'name': 'T29', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Group #:'}
# {'name': 'T30', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Insured:'}
# {'name': 'CB31', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB32', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'T33', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'If yes, provide ID#:'}
# {'name': 'T34', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Carrier Name:'}
# {'name': 'T35', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Insured:'}
# {'name': 'T42', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'First Name:'}
# {'name': 'T43', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Last Name:'}
# {'name': 'CB44', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'M.D.'}
# {'name': 'CB45', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'D.O.'}
# {'name': 'CB46', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'N.P.'}
# {'name': 'CB47', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'P.A.'}
# {'name': 'T48', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Address:'}
# {'name': 'T49', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'City:'}
# {'name': 'T50', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'State:'}
# {'name': 'T51', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'ZIP:'}
# {'name': 'T52', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Phone:'}
# {'name': 'T53', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Fax:'}
# {'name': 'T54', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'St Lic #:'}
# {'name': 'T55', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'NPI #:'}
# {'name': 'T56', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'DEA #:'}
# {'name': 'T57', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'UPIN:'}
# {'name': 'T58.0', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Provider Email:'}
# {'name': 'T58.1', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Office Contact Name:'}
# {'name': 'T59', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Phone:'}
# {'name': 'Provider Admin CB.1', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Self-administered'}
# {'name': 'Provider Admin CB.2', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Physician’s Office'}
# {'name': 'Provider Admin CB.3', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Home'}
# {'name': 'Provider Admin CB.4', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Outpatient Infusion Center'}
# {'name': 'Provider Admin T.5', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Name:'}
# {'name': 'Provider Admin CB.7', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Home Infusion Center'}
# {'name': 'Provider Admin T.6', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Phone:'}
# {'name': 'Provider Admin T.8', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Agency Name:'}
# {'name': 'Provider Admin CB.10', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Administration code(s)'}
# {'name': 'Provider Admin T.9', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'CPT:'}
# {'name': 'Provider Admin T.11A', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Address:'}
# {'name': 'Provider Admin T.13', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'City:'}
# {'name': 'Provider Admin T.14', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'State:'}
# {'name': 'Provider Admin T.15', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'ZIP:'}
# {'name': 'Provider Admin T.16', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Phone:'}
# {'name': 'Provider Admin T.17A', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Fax:'}
# {'name': 'Provider Admin T.18', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'TIN:'}
# {'name': 'Provider Admin T.19', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'PIN:'}
# {'name': 'Provider Admin T.20', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'NPI:'}
# {'name': 'Provider Admin CB.21', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Outpatient Dialysis Center'}
# {'name': 'Provider Admin CB.22', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Physician’s Office'}
# {'name': 'Provider Admin CB.23.0.0', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Retail Pharmacy'}
# {'name': 'Provider Admin CB.24.0.0', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Specialty Pharmacy'}
# {'name': 'Provider Admin CB.25', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Mail Order'}
# {'name': 'Provider Admin CB.26', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Other:'}
# {'name': 'Provider Admin T.27', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Other:'}
# {'name': 'Provider Admin T.28', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Name:'}
# {'name': 'Provider Admin T.29a', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Address:'}
# {'name': 'Provider Admin T.30a', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'City:'}
# {'name': 'Provider Admin T.31', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'State:'}
# {'name': 'Provider Admin T.32', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'ZIP:'}
# {'name': 'Provider Admin T.33', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Phone:'}
# {'name': 'Provider Admin T.34', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Fax:'}
# {'name': 'Provider Admin T.35', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'TIN:'}
# {'name': 'Provider Admin T.36', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'PIN:'}
# {'name': 'Provider Admin T.37', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'NPI:'}
# {'name': 'CB60', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Riabni (rituximab-arrx)'}
# {'name': 'CB61', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Rituxan (rituximab)'}
# {'name': 'CB62', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Ruxience (rituximab-pvvr)'}
# {'name': 'CB63', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Truxima (rituximab-abbs)'}
# {'name': 'T64', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Dose:'}
# {'name': 'T65', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Directions for Use:'}
# {'name': 'T66', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'HCPCS Code:'}
# {'name': 'T67', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Primary ICD Code:'}
# {'name': 'CB68', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Other ICD Code:'}
# {'name': 'T69', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Other ICD Code:'}
# {'name': 'CB70', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB71', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB72', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB73', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Ruxience (rituximab-pvvr)'}
# {'name': 'CB74', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Truxima (rituximab-abbs)'}
# {'name': 'T75', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'When was the member’s trial and failure of the preferred drug?'}
# {'name': 'T76', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please describe the nature of the failure of the preferred drug'}
# {'name': 'CB77', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB78', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Ruxience (rituximab-pvvr)'}
# {'name': 'CB79', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Truxima (rituximab-abbs)'}
# {'name': 'T80', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'When was the member’s adverse reaction to the preferred drug?'}
# {'name': 'T81', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please describe the nature of the adverse reaction to the preferred drug'}
# {'name': 'T84', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please explain if there are any contraindications or other medical reason(s) that the patient cannot use any of the following preferred biosimilar products when indicated for the patient’s diagnosis?'}
# {'name': 'CB82', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Ruxience (rituximab-pvvr)'}
# {'name': 'CB83', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Truxima (rituximab-abbs)'}
# {'name': 'T12', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient First Name'}
# {'name': 'T13', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient Last Name'}
# {'name': 'T19', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient Phone'}
# {'name': 'T14', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient DOB (MM/DD/YYYY)'}
# {'name': 'CB86', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Inflectra (infliximab-dyyb)'}
# {'name': 'CB87', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Renflexis (infliximab-abda)'}
# {'name': 'CB88', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Simponi Aria (golimumab)'}
# {'name': 'T89', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'When was the member’s trial and failure of the preferred drug?'}
# {'name': 'T90', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please describe the nature of the failure of the preferred drug'}
# {'name': 'CB85', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB92', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Inflectra (infliximab-dyyb)'}
# {'name': 'CB93', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Renflexis (infliximab-abda)'}
# {'name': 'CB94', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Simponi Aria (golimumab)'}
# {'name': 'T95', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'When was the member’s adverse reaction to the preferred drug?'}
# {'name': 'T96a', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please describe the nature of the adverse reaction to the preferred drug'}
# {'name': 'CB91', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB98a', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Enbrel (etanercept)'}
# {'name': 'CB99a', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Humira (adalimumab)'}
# {'name': 'CB100a', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Idacio (adalimumab-aacf)'}
# {'name': 'CB101a', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Rinvoq (upadacitinib)'}
# {'name': 'CB102a', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Tyenne SC (tocilizumab-aazg)'}
# {'name': 'CB103a', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Xeljanz/Xeljanz XR (tofacitinib)'}
# {'name': 'T104', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'When was the member’s trial and failure of the preferred drug?'}
# {'name': 'T105', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please describe the nature of the failure of the preferred drug'}
# {'name': 'CB97', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB107z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Enbrel (etanercept)'}
# {'name': 'CB108z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Humira (adalimumab)'}
# {'name': 'CB109z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Idacio (adalimumab-aacf)'}
# {'name': 'CB110z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Rinvoq (upadacitinib)'}
# {'name': 'CB111z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Tyenne SC (tocilizumab-aazg)'}
# {'name': 'CB112z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Xeljanz/Xeljanz XR (tofacitinib)'}
# {'name': 'T113', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'When was the member’s adverse reaction to the preferred drug?'}
# {'name': 'T114', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please describe the nature of the adverse reaction to the preferred drug'}
# {'name': 'CB106z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'T118', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please explain if there are any contraindications or other medical reason(s) that the patient cannot use any of the following preferred products when indicated for the patient’s diagnosis?'}
# {'name': 'CB115z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Inflectra (infliximab-dyyb)'}
# {'name': 'CB116z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Renflexis (infliximab-abda)'}
# {'name': 'CB117z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Simponi Aria (golimumab)'}
# {'name': 'T125', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please explain if there are contraindications or any other medical reason(s) that the patient cannot use any of the following preferred products when indicated for the patient’s diagnosis?'}
# {'name': 'CB119z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Enbrel (etanercept)'}
# {'name': 'CB120z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Humira (adalimumab)'}
# {'name': 'CB121z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Idacio (adalimumab-aacf)'}
# {'name': 'CB122z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Rinvoq (upadacitinib)'}
# {'name': 'CB123z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Tyenne SC (tocilizumab-aazg)'}
# {'name': 'CB124z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Xeljanz/Xeljanz XR (tofacitinib)'}
# {'name': 'CB96.4.0', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB98', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB99.0', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB100.0', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB101.0', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB102.0', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB103', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB104', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB104a', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Wegener granulomatosis'}
# {'name': 'CB104b', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Churg-Strauss syndrome'}
# {'name': 'CB104c', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'microscopic polyangiitis'}
# {'name': 'CB104d', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'pauci-immune glomerulonephritis'}
# {'name': 'CB105', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB106', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB106a', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB107', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'pemphigus vulgaris'}
# {'name': 'CB108', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'pemphigus folliaceus'}
# {'name': 'CB109', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'bullous pemphigoid'}
# {'name': 'CB110', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'cicatricial pemphigoid'}
# {'name': 'CB111', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'epidermolysis bullosa acquisita'}
# {'name': 'CB112', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'paraneoplastic pemphigus'}
# {'name': 'CB113', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'None of the above'}
# {'name': 'CB106b', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB114', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'AIDS-related B-cell lymphoma'}
# {'name': 'CB115', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Burkitt lymphoma'}
# {'name': 'CB116', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Diffuse large B-cell lymphoma'}
# {'name': 'CB117', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Follicular lymphoma'}
# {'name': 'CB118', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Gastric MALT lymphoma'}
# {'name': 'CB119', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'High-grade B-Cell lymphoma'}
# {'name': 'CB120', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Mantle cell lymphoma'}
# {'name': 'CB121', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Nodal marginal zone lymphoma'}
# {'name': 'CB122', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Nongastric MALT lymphoma'}
# {'name': 'CB123', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Primary cutaneous B-cell lymphomas'}
# {'name': 'CB124', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Splenic marginal zone lymphoma'}
# {'name': 'CB125', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Other:'}
# {'name': 'T126', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Other:'}
# {'name': 'T12', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient First Name'}
# {'name': 'T13', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient Last Name'}
# {'name': 'T19', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient Phone'}
# {'name': 'T14', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient DOB (MM/DD/YYYY)'}
# {'name': 'CB127', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB128', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB129', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'leptomeningeal metastases from lymphoma'}
# {'name': 'CB130', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'primary CNS lymphoma'}
# {'name': 'CB131', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'none of the above'}
# {'name': 'CB132', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'chronic lymphocytic leukemia (CLL)'}
# {'name': 'CB133', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'small lymphocytic leukemia'}
# {'name': 'CB134', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'none of the above'}
# {'name': 'CB135', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB136', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB139', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB140', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB144', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB145', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB141', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'relapsed hairy cell leukemia'}
# {'name': 'CB142', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'refractory hairy cell leukemia'}
# {'name': 'CB143', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'none of the above'}
# {'name': 'CB137', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB146', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'heart transplant recipient'}
# {'name': 'CB147', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'other solid organ transplant recipient'}
# {'name': 'CB138', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB148', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Bavencio (avelumab)'}
# {'name': 'CB149', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Imfinzi (durvalumab)'}
# {'name': 'CB150', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Keytruda (pembrolizumab)'}
# {'name': 'CB151', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Opdivo (nivolumab)'}
# {'name': 'CB152', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Tecentriq (atezolizumab)'}
# {'name': 'CB153', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yervoy (ipilimumab)'}
# {'name': 'CB154', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Other:'}
# {'name': 'T155', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Other:'}
# {'name': 'CB156', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB158', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'refractory immune thrombocytopenic purpura'}
# {'name': 'CB159', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'idiopathic thrombocytopenic purpura (ITP)'}
# {'name': 'CB157', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB160', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB161', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB162', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB163', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB164', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Relapsing-remitting MS (RRMS)'}
# {'name': 'CB165', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Secondary-progressive MS (SPMS)'}
# {'name': 'CB166', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Primary-progressive MS (PPMS)'}
# {'name': 'CB167', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Progressive-relapsing MS (PRMS)'}
# {'name': 'CB168', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB169', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB170', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB172', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB173', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB171', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB174', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB175', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB176', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB177', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB178', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB179', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB180', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'T189', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Medication:'}
# {'name': 'T190', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T191', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T192', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}
# {'name': 'T193', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T194', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T195', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}
# {'name': 'T196', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Medication:'}
# {'name': 'T197', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T198', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T199', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}
# {'name': 'T200', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T201', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T202', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}
# {'name': 'CB181', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB203', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB204', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB205', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB206', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'T12', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient First Name'}
# {'name': 'T13', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient Last Name'}
# {'name': 'T19', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient Phone'}
# {'name': 'T14', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient DOB (MM/DD/YYYY)'}
# {'name': 'CB207', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Mild'}
# {'name': 'CB208', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Moderate'}
# {'name': 'CB209', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Severe'}
# {'name': 'CB210', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB211', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB212', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB213', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB214', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB216', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'ineffective'}
# {'name': 'CB217', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'not tolerated'}
# {'name': 'CB218', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'contraindicated'}
# {'name': 'CB215', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB223', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB225', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'azathioprine'}
# {'name': 'CB226', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'cyclosporine'}
# {'name': 'CB227', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'hydroxychloroquine'}
# {'name': 'CB228', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'leflunomide'}
# {'name': 'CB229', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'sulfasalazine'}
# {'name': 'CB224', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB281', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB282', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB283', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'T285', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Medication:'}
# {'name': 'T286', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T287', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T288', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}
# {'name': 'T289', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T290', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T291', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}
# {'name': 'T292', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Medication:'}
# {'name': 'T293', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T294', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T295', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}
# {'name': 'T296', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T297', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T298', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}
# {'name': 'CB284', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB299', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB300', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB301', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB302', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB303', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB304', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'T305', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please indicate the length of time on Rituxan (rituximab):'}
# {'name': 'CB310', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Mild'}
# {'name': 'CB311', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Moderate'}
# {'name': 'CB312', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Severe'}
# {'name': 'CB306', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB307', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB308', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB309', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB313', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB314', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB315', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB316', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'T317', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T318', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T319', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}

# %% [markdown]
# ## PA feild organization Prompt template for Gemeni

# %%
def format_fields_for_pa(pa_fields):
  return """
  You are given an array of dictionaries, each representing a form field extracted from a PDF. Each dictionary contains:
  - "name": the field name
  - "type": the field type (e.g., "text", "checkbox")
  - "value": the field value (may be null)
  - "page": the 1-based page number
  - "field_type": the PDF widget type code
  - "field_type_string": the PDF widget type as a string
  - "field_label": the field label (may be null)

  TASK:
  1. Organize these fields into a hierarchical JSON tree grouped by page number.
  2. For each page, create an array of fields, preserving all metadata.
  3. The top-level JSON should be:
  {
    "pages": {
      "1": [ ...fields... ],
      "2": [ ...fields... ],
      ...
    }
  }
  4. Do not omit any fields or metadata.
  5. Return only valid JSON (no markdown, no extra commentary).

  Example output:
  {
    "pages": {
      "1": [
        {
          "name": "T1",
          "type": "text",
          "value": "",
          "page": 1,
          "field_type": 2,
          "field_type_string": "Text",
          "field_label": "First Name"
        },
        ...
      ],
      "2": [
        ...
      ]
    }
  }

  <PA_FIELDS>
  {pa_fields}
  </PA_FIELDS> """

# %% [markdown]
# ## Send Prompt to Gemeni

# %%
# Send to Gemini using NEW 2025 SDK

async def query_gemini_async(prompt, pdf_path, model_name='gemini-2.5-flash'):
    """
    Async function to query Gemini with a PDF and prompt using the new 2025 Google Gen AI SDK
    """
    filepath = pathlib.Path(pdf_path)
    
    # Create PDF part using new SDK structure
    pdf_bytes = filepath.read_bytes()
    pdf_part = types.Part.from_bytes(
        data=pdf_bytes, 
        mime_type="application/pdf"
    )
    
    # Use async client from new SDK
    response = await client.aio.models.generate_content(
        model=model_name,
        contents=[pdf_part, prompt]
    )
    
    print(response.text)
    return response.text

# %%
pa_fields_context = {}

# Process each page of the PA form
async def process_page(page):
    prompt = format_fields_for_pa(pa_fields[page])
    print (prompt)

    result = await query_gemini_async(prompt, "Input Data/Adbulla/PA.pdf")
    print ("---------------------------------")
    return page, result
# create a list of tasks to run in parallel
tasks = [process_page(page) for page in pa_fields]

# running the tasks in parallel
results = await asyncio.gather(*tasks)

# 
for page, result in results:
    pa_fields_context[page] = result
# Out:
#   You are given an array of dictionaries, each representing a form field extracted from a PDF. Each dictionary contains:
#   - "name": the field name
#   - "type": the field type (e.g., "text", "checkbox")
#   - "value": the field value (may be null)
#   - "page": the 1-based page number
#   - "field_type": the PDF widget type code
#   - "field_type_string": the PDF widget type as a string
#   - "field_label": the field label (may be null)
#
#   TASK:
#   1. Organize these fields into a hierarchical JSON tree grouped by page number.
#   2. For each page, create an array of fields, preserving all metadata.
#   3. The top-level JSON should be:
#   {
#     "pages": {
#       "1": [ ...fields... ],
#       "2": [ ...fields... ],
#       ...
#     }
#   }
#   4. Do not omit any fields or metadata.
#   5. Return only valid JSON (no markdown, no extra commentary).
#
#   Example output:
#   {
#     "pages": {
#       "1": [
#         {
#           "name": "T1",
#           "type": "text",
#           "value": "",
#           "page": 1,
#           "field_type": 2,
#           "field_type_string": "Text",
#           "field_label": "First Name"
#         },
#         ...
#       ],
#       "2": [
#         ...
#       ]
#     }
#   }
#
#   <PA_FIELDS>
#   {pa_fields}
#   </PA_FIELDS>
#
#   You are given an array of dictionaries, each representing a form field extracted from a PDF. Each dictionary contains:
#   - "name": the field name
#   - "type": the field type (e.g., "text", "checkbox")
#   - "value": the field value (may be null)
#   - "page": the 1-based page number
#   - "field_type": the PDF widget type code
#   - "field_type_string": the PDF widget type as a string
#   - "field_label": the field label (may be null)
#
#   TASK:
#   1. Organize these fields into a hierarchical JSON tree grouped by page number.
#   2. For each page, create an array of fields, preserving all metadata.
#   3. The top-level JSON should be:
#   {
#     "pages": {
#       "1": [ ...fields... ],
#       "2": [ ...fields... ],
#       ...
#     }
#   }
#   4. Do not omit any fields or metadata.
#   5. Return only valid JSON (no markdown, no extra commentary).
#
#   Example output:
#   {
#     "pages": {
#       "1": [
#         {
#           "name": "T1",
#           "type": "text",
#           "value": "",
#           "page": 1,
#           "field_type": 2,
#           "field_type_string": "Text",
#           "field_label": "First Name"
#         },
#         ...
#       ],
#       "2": [
#         ...
#       ]
#     }
#   }
#
#   <PA_FIELDS>
#   {pa_fields}
#   </PA_FIELDS>
#
#   You are given an array of dictionaries, each representing a form field extracted from a PDF. Each dictionary contains:
#   - "name": the field name
#   - "type": the field type (e.g., "text", "checkbox")
#   - "value": the field value (may be null)
#   - "page": the 1-based page number
#   - "field_type": the PDF widget type code
#   - "field_type_string": the PDF widget type as a string
#   - "field_label": the field label (may be null)
#
#   TASK:
#   1. Organize these fields into a hierarchical JSON tree grouped by page number.
#   2. For each page, create an array of fields, preserving all metadata.
#   3. The top-level JSON should be:
#   {
#     "pages": {
#       "1": [ ...fields... ],
#       "2": [ ...fields... ],
#       ...
#     }
#   }
#   4. Do not omit any fields or metadata.
#   5. Return only valid JSON (no markdown, no extra commentary).
#
#   Example output:
#   {
#     "pages": {
#       "1": [
#         {
#           "name": "T1",
#           "type": "text",
#           "value": "",
#           "page": 1,
#           "field_type": 2,
#           "field_type_string": "Text",
#           "field_label": "First Name"
#         },
#         ...
#       ],
#       "2": [
#         ...
#       ]
#     }
#   }
#
#   <PA_FIELDS>
#   {pa_fields}
#   </PA_FIELDS>
#
#   You are given an array of dictionaries, each representing a form field extracted from a PDF. Each dictionary contains:
#   - "name": the field name
#   - "type": the field type (e.g., "text", "checkbox")
#   - "value": the field value (may be null)
#   - "page": the 1-based page number
#   - "field_type": the PDF widget type code
#   - "field_type_string": the PDF widget type as a string
#   - "field_label": the field label (may be null)
#
#   TASK:
#   1. Organize these fields into a hierarchical JSON tree grouped by page number.
#   2. For each page, create an array of fields, preserving all metadata.
#   3. The top-level JSON should be:
#   {
#     "pages": {
#       "1": [ ...fields... ],
#       "2": [ ...fields... ],
#       ...
#     }
#   }
#   4. Do not omit any fields or metadata.
#   5. Return only valid JSON (no markdown, no extra commentary).
#
#   Example output:
#   {
#     "pages": {
#       "1": [
#         {
#           "name": "T1",
#           "type": "text",
#           "value": "",
#           "page": 1,
#           "field_type": 2,
#           "field_type_string": "Text",
#           "field_label": "First Name"
#         },
#         ...
#       ],
#       "2": [
#         ...
#       ]
#     }
#   }
#
#   <PA_FIELDS>
#   {pa_fields}
#   </PA_FIELDS>
# ```json
# {
#   "pages": {
#     "1": [
#       {
#         "name": "Phone",
#         "type": "text",
#         "value": "1-866-503-0857",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax",
#         "type": "text",
#         "value": "1-844-268-7263",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity",
#         "type": "text",
#         "value": "https://www.aetna.com/health-care-professionals/resource-center/availity.html",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_2",
#         "type": "text",
#         "value": "1-855-463-0933",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_2",
#         "type": "text",
#         "value": "1-833-280-5224",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_2",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/virginia-hmosnp/providers/portal",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_3",
#         "type": "text",
#         "value": "1-844-362-0934",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_3",
#         "type": "text",
#         "value": "1-833-322-0034",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_3",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/new-jersey-hmosnp/providers/portal.html",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_4",
#         "type": "text",
#         "value": "1-866-600-2139",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "FAX",
#         "type": "text",
#         "value": "1-855-320-8445",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_4",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/illinois/providers/portal",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_5",
#         "type": "text",
#         "value": "1-855-364-0974",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_4",
#         "type": "text",
#         "value": "1-855-734-9389",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_5",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/ohio/providers/portal",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_6",
#         "type": "text",
#         "value": "1-855-676-5772",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_5",
#         "type": "text",
#         "value": "1-844-241-2495",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_6",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/michigan/providers/portal.html",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       }
#     ],
#     "2": [
#       {
#         "name": "Start of treatment, start date",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Continuation of therapy, date of last treatment",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "First Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "First Name"
#       },
#       {
#         "name": "Last Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Last Name"
#       },
#       {
#         "name": "DOB",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "DOB"
#       },
#       {
#         "name": "Address",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Address"
#       },
#       {
#         "name": "City",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "City"
#       },
#       {
#         "name": "State",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "State"
#       },
#       {
#         "name": "ZIP",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "ZIP"
#       },
#       {
#         "name": "Home Phone",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Home Phone"
#       },
#       {
#         "name": "Work Phone",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Work Phone"
#       },
#       {
#         "name": "Cell Phone",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Cell Phone"
#       },
#       {
#         "name": "E-mail",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "E-mail"
#       },
#       {
#         "name": "Current Weight",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Current Weight"
#       },
#       {
#         "name": "Height",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Height"
#       },
#       {
#         "name": "Allergies",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Allergies"
#       },
#       {
#         "name": "Member ID #",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Member ID #"
#       },
#       {
#         "name": "Group #",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Group #"
#       },
#       {
#         "name": "Carrier Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Carrier Name"
#       },
#       {
#         "name": "Insured",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Insured"
#       },
#       {
#         "name": "First Name_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "First Name"
#       },
#       {
#         "name": "Last Name_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Last Name"
#       },
#       {
#         "name": "Address_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Address"
#       },
#       {
#         "name": "City_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "City"
#       },
#       {
#         "name": "State_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "State"
#       },
#       {
#         "name": "ZIP_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "ZIP"
#       },
#       {
#         "name": "Phone_7",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Phone"
#       },
#       {
#         "name": "Fax_6",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Fax"
#       },
#       {
#         "name": "St Lic #",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "St Lic #"
#       },
#       {
#         "name": "NPI #",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "NPI #"
#       },
#       {
#         "name": "DEA #",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "DEA #"
#       },
#       {
#         "name": "UPIN",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "UPIN"
#       },
#       {
#         "name": "Provider Email",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Provider Email"
#       },
#       {
#         "name": "Office Contact Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Office Contact Name"
#       },
#       {
#         "name": "Phone_8",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Phone"
#       },
#       {
#         "name": "Outpatient Infusion Center Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Outpatient Infusion Center Name"
#       },
#       {
#         "name": "Home Infusion Center Agency Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Home Infusion Center Agency Name"
#       },
#       {
#         "name": "Phone_9",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Phone"
#       },
#       {
#         "name": "Administration code(s) (CPT)",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Administration code(s) (CPT)"
#       },
#       {
#         "name": "Address_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Address"
#       },
#       {
#         "name": "City_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "City"
#       },
#       {
#         "name": "State_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "State"
#       },
#       {
#         "name": "ZIP_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "ZIP"
#       },
#       {
#         "name": "Phone_10",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Phone"
#       },
#       {
#         "name": "Fax_7",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Fax"
#       },
#       {
#         "name": "TIN",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "TIN"
#       },
#       {
#         "name": "NPI",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "NPI"
#       },
#       {
#         "name": "Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Name"
#       },
#       {
#         "name": "Address_4",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Address"
#       },
#       {
#         "name": "City_4",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "City"
#       },
#       {
#         "name": "State_4",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "State"
#       },
#       {
#         "name": "ZIP_4",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "ZIP"
#       },
#       {
#         "name": "Phone_11",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Phone"
#       },
#       {
#         "name": "Fax_8",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Fax"
#       },
#       {
#         "name": "PIN",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "PIN"
#       },
#       {
#         "name": "TIN_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "TIN"
#       },
#       {
#         "name": "NPI_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "NPI"
#       },
#       {
#         "name": "Dose",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Dose"
#       },
#       {
#         "name": "Directions for Use",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Directions for Use"
#       },
#       {
#         "name": "HCPCS Code",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "HCPCS Code"
#       },
#       {
#         "name": "Primary ICD Code",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Primary ICD Code"
#       },
#       {
#         "name": "Other ICD Code",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Other ICD Code"
#       },
#       {
#         "name": "Please describe the nature of the failure of the preferred drug",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the adverse reaction to the preferred drug",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       }
#     ],
#     "3": [
#       {
#         "name": "Patient First Name",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient First Name"
#       },
#       {
#         "name": "Patient Last Name",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient Last Name"
#       },
#       {
#         "name": "Patient Phone",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient Phone"
#       },
#       {
#         "name": "Patient DOB",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient DOB"
#       },
#       {
#         "name": "Please describe the nature of the failure of the preferred drug_2",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the adverse reaction to the preferred drug_2",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the failure of the preferred drug_3",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the adverse reaction to the preferred drug_3",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       }
#     ],
#     "4": [
#       {
#         "name": "Patient First Name",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient First Name"
#       },
#       {
#         "name": "Patient Last Name",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient Last Name"
#       },
#       {
#         "name": "Patient Phone",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient Phone"
#       },
#       {
#         "name": "Patient DOB",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient DOB"
#       },
#       {
#         "name": "Medication",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Medication"
#       },
#       {
#         "name": "Dates",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Dates"
#       },
#       {
#         "name": "Medication_2",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Medication"
#       },
#       {
#         "name": "Dates_2",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Dates"
#       }
#     ],
#     "5": [
#       {
#         "name": "Patient First Name",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient First Name"
#       },
#       {
#         "name": "Patient Last Name",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient Last Name"
#       },
#       {
#         "name": "Patient Phone",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient Phone"
#       },
#       {
#         "name": "Patient DOB",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient DOB"
#       },
#       {
#         "name": "Medication_3",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Medication"
#       },
#       {
#         "name": "Dates_3",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Dates"
#       },
#       {
#         "name": "Medication_4",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Medication"
#       },
#       {
#         "name": "Dates_4",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Dates"
#       },
#       {
#         "name": "Please indicate the length of time on Rituxan (rituximab)",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Date",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Date"
#       }
#     ]
#   }
# }
# ```
# ---------------------------------
# ```json
# {
#   "pages": {
#     "1": [
#       {
#         "name": "Phone",
#         "type": "text",
#         "value": "1-866-503-0857",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax",
#         "type": "text",
#         "value": "1-844-268-7263",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity",
#         "type": "text",
#         "value": "https://www.aetna.com/health-care-professionals/resource-center/availity.html",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_2",
#         "type": "text",
#         "value": "1-855-463-0933",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_2",
#         "type": "text",
#         "value": "1-833-280-5224",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_2",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/virginia-hmosnp/providers/portal",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_3",
#         "type": "text",
#         "value": "1-844-362-0934",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_3",
#         "type": "text",
#         "value": "1-833-322-0034",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_3",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/new-jersey-hmosnp/providers/portal.html",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_4",
#         "type": "text",
#         "value": "1-866-600-2139",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "FAX",
#         "type": "text",
#         "value": "1-855-320-8445",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_4",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/illinois/providers/portal",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_5",
#         "type": "text",
#         "value": "1-855-364-0974",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_5",
#         "type": "text",
#         "value": "1-855-734-9389",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_5",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/ohio/providers/portal",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_6",
#         "type": "text",
#         "value": "1-855-676-5772",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_6",
#         "type": "text",
#         "value": "1-844-241-2495",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_6",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/michigan/providers/portal.html",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       }
#     ],
#     "2": [
#       {
#         "name": "Start of treatment",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "date",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Continuation of therapy",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "date of last treatment",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Last Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "First Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Address",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "City",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "State",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "DOB",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Home Phone",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Work Phone",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Cell Phone",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "E-mail",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Current Weight",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Height",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Allergies",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Member ID",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Does patient have other coverage?",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Does patient have other coverage?",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Group",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Carrier Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Insured",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Last Name_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "First Name_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Check one",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Check one_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Check one_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Check one_4",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Check one_5",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Address_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "City_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "State_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "ZIP",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "St Lic",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "NPI",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "DEA",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "UPIN",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Provider Email",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Office Contact Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Self-administered",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Physician's Office",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Home",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Outpatient Infusion Center Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Home Infusion Center",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Agency Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_4",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Administration code(s) (CPT)",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Address_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "City_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "State_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "ZIP_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_5",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "TIN",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "NPI",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Outpatient Dialysis Center",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Physician's Office_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Retail Pharmacy",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Specialty Pharmacy",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Mail Order",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Other",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Address_4",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "City_4",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "State_4",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "ZIP_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_6",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "PIN",
#         "type": "text",
#         "value": null,
#         "page": 2,
# ...
#         "field_label": "No"
#       },
#       {
#         "name": "Relapsing-remitting MS (RRMS)",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "Relapsing-remitting MS (RRMS)"
#       },
#       {
#         "name": "Secondary-progressive MS (SPMS)",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "Secondary-progressive MS (SPMS)"
#       },
#       {
#         "name": "Primary-progressive MS (PPMS)",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "Primary-progressive MS (PPMS)"
#       },
#       {
#         "name": "Progressive-relapsing MS (PRMS)",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "Progressive-relapsing MS (PRMS)"
#       },
#       {
#         "name": "Yes_21",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "No_23",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "Yes_22",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "No_24",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "Yes_23",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "No_25",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "Yes_24",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "No_26",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "Yes_25",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "No_27",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "Yes_26",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "No_28",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "Medication",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Medication"
#       },
#       {
#         "name": "Dates",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Dates"
#       },
#       {
#         "name": "Medication_2",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Medication"
#       },
#       {
#         "name": "Dates_2",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Dates"
#       },
#       {
#         "name": "Yes_27",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "No_29",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "Yes_28",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "No_30",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "No"
#       }
#     ],
#     "5": [
#       {
#         "name": "Patient First Name_6",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient First Name"
#       },
#       {
#         "name": "Patient Last Name_6",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient Last Name"
#       },
#       {
#         "name": "Patient Phone_6",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient Phone"
#       },
#       {
#         "name": "Patient DOB_6",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient DOB"
#       },
#       {
#         "name": "Mild",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "Mild"
#       },
#       {
#         "name": "Moderate",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "Moderate"
#       },
#       {
#         "name": "Severe",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "Severe"
#       },
#       {
#         "name": "Yes_29",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "No_31",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "Yes_30",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "No_32",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "Yes_31",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "No_33",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "ineffective",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "ineffective"
#       },
#       {
#         "name": "not tolerated",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "not tolerated"
#       },
#       {
#         "name": "contraindicated",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "contraindicated"
#       },
#       {
#         "name": "Yes_32",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "No_34",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "azathioprine",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "azathioprine"
#       },
#       {
#         "name": "cyclosporine",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "cyclosporine"
#       },
#       {
#         "name": "hydroxychloroquine",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "hydroxychloroquine"
#       },
#       {
#         "name": "leflunomide",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "leflunomide"
#       },
#       {
#         "name": "sulfasalazine",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "sulfasalazine"
#       },
#       {
#         "name": "Yes_33",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "No_35",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "Yes_34",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "No_36",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "Medication_3",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Medication"
#       },
#       {
#         "name": "Dates_3",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Dates"
#       },
#       {
#         "name": "Medication_4",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Medication"
#       },
#       {
#         "name": "Dates_4",
#         "type": 2,
#         "value": null,
#         "page": 5,
#         "field_type_string": "Text",
#         "field_label": "Dates"
#       },
#       {
#         "name": "Yes_35",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "No_37",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "Yes_36",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "No_38",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "Yes_37",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "No_39",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "length of time on Rituxan (rituximab)",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "length of time on Rituxan (rituximab)"
#       },
#       {
#         "name": "Mild_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "Mild"
#       },
#       {
#         "name": "Moderate_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "Moderate"
#       },
#       {
#         "name": "Severe_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "Severe"
#       },
#       {
#         "name": "Yes_38",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "No_40",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "Yes_39",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "No_41",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "Yes_40",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "No_42",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "Yes_41",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "No_43",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "Date",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Date"
#       },
#       {
#         "name": "Signature Required",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Signature Required"
#       }
#     ]
#   }
# }
# ```
# ---------------------------------

# %%
# Create PA_form_analysis from pa_fields_context
# This combines all the processed PA field data into a single analysis

if 'pa_fields_context' in locals() and pa_fields_context:
    # Combine all page results into a single analysis
    PA_form_analysis = ""
    for page, result in pa_fields_context.items():
        PA_form_analysis += f"PAGE {page}:\n{result}\n\n"
    print("✅ PA_form_analysis created successfully!")
    print(f"Length: {len(PA_form_analysis)} characters")
else:
    # Fallback: create from raw pa_fields if pa_fields_context isn't ready
    PA_form_analysis = json.dumps(pa_fields, indent=2)
    print("⚠️  Using fallback: PA_form_analysis created from raw pa_fields")
    print("Note: Run cell 12 first to get processed analysis")

print("PA_form_analysis preview:")
print(PA_form_analysis)
# Out:
# ✅ PA_form_analysis created successfully!
# Length: 222336 characters
# PA_form_analysis preview:
# PAGE 2:
# ```json
# {
#   "pages": {
#     "1": [
#       {
#         "name": "Phone",
#         "type": "text",
#         "value": "1-866-503-0857",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax",
#         "type": "text",
#         "value": "1-844-268-7263",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity",
#         "type": "text",
#         "value": "https://www.aetna.com/health-care-professionals/resource-center/availity.html",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_2",
#         "type": "text",
#         "value": "1-855-463-0933",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_2",
#         "type": "text",
#         "value": "1-833-280-5224",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_2",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/virginia-hmosnp/providers/portal",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_3",
#         "type": "text",
#         "value": "1-844-362-0934",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_3",
#         "type": "text",
#         "value": "1-833-322-0034",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_3",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/new-jersey-hmosnp/providers/portal.html",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_4",
#         "type": "text",
#         "value": "1-866-600-2139",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "FAX",
#         "type": "text",
#         "value": "1-855-320-8445",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_4",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/illinois/providers/portal",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_5",
#         "type": "text",
#         "value": "1-855-364-0974",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_5",
#         "type": "text",
#         "value": "1-855-734-9389",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_5",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/ohio/providers/portal",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_6",
#         "type": "text",
#         "value": "1-855-676-5772",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_6",
#         "type": "text",
#         "value": "1-844-241-2495",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_6",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/michigan/providers/portal.html",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       }
#     ],
#     "2": [
#       {
#         "name": "Start of treatment",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Start date",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Continuation of therapy",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Date of last treatment",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Precertification Phone",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Precertification Fax",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "First Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Last Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Address",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "City",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "State",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "DOB",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Home Phone",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Work Phone",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Cell Phone",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "E-mail",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "ZIP",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Current Weight lbs or kgs",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Height inches or cms",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Allergies",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Member ID",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "ID",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Carrier Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Group",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Insured",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "First Name_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "M.D.",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "D.O.",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "N.P.",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "P.A.",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Last Name_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Address_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "City_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "State_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "ZIP_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_7",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_7",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "St Lic",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "NPI",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "DEA",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "UPIN",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Provider Email",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Office Contact Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_8",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Self-administered",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Physician's Office",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Home",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Outpatient Infusion Center Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Home Infusion Center Agency Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_9",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Administration code(s) (CPT)",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Address_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "City_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "State_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "ZIP_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_10",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "TIN",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "NPI_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Outpatient Dialysis Center",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Retail Pharmacy",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Mail Order",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Physician's Office_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Specialty Pharmacy",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Other",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Address_4",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "City_4",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "State_4",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "ZIP_4",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_11",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_8",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "PIN",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "TIN_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "NPI_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "PIN_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Riabni (rituximab-arrx)",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Rituxan (rituximab)",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Ruxience (rituximab-pvvr)",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Truxima (rituximab-abbs)",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Dose",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Directions for Use",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "HCPCS Code",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Primary ICD Code",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Other ICD Code",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Ruxience (rituximab-pvvr)",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Truxima (rituximab-abbs)",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "When was the member's trial and failure of the preferred drug",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the failure of the preferred drug",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "No_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Ruxience (rituximab-pvvr)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Truxima (rituximab-abbs)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "When was the member's adverse reaction to the preferred drug",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the adverse reaction to the preferred drug",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Ruxience (rituximab-pvvr)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Truxima (rituximab-abbs)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       }
#     ],
#     "3": [
#       {
#         "name": "Patient First Name",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Patient Last Name",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Patient Phone",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Patient DOB",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "No",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Inflectra (infliximab-dyyb)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Renflexis (infliximab-abda)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Simponi Aria (golimumab)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "When was the member's trial and failure of the preferred drug_2",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the failure of the preferred drug_2",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "No_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Inflectra (infliximab-dyyb)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Renflexis (infliximab-abda)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Simponi Aria (golimumab)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "When was the member's adverse reaction to the preferred drug_2",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the adverse reaction to the preferred drug_2",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "No_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Enbrel (etanercept)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Humira (adalimumab)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Idacio (adalimumab-aacf)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Rinvoq (upadacitinib)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Tyenne SC (tocilizumab-aazg)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Xeljanz/Xeljanz XR (tofacitinib)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "When was the member's trial and failure of the preferred drug_3",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the failure of the preferred drug_3",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "No_4",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Enbrel (etanercept)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Humira (adalimumab)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Idacio (adalimumab-aacf)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Rinvoq (upadacitinib)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Tyenne SC (tocilizumab-aazg)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Xeljanz/Xeljanz XR (tofacitinib)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "When was the member's adverse reaction to the preferred drug_2",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the adverse reaction to the preferred drug_3",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Inflectra (infliximab-dyyb)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Renflexis (infliximab-abda)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Simponi Aria (golimumab)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Enbrel (etanercept)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Humira (adalimumab)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Idacio (adalimumab-aacf)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Rinvoq (upadacitinib)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Tyenne SC (tocilizumab-aazg)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Xeljanz/Xeljanz XR (tofacitinib)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_5",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_6",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_4",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_7",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_5",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_8",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Wegener granulomatosis",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Churg-Strauss syndrome",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "microscopic polyangiitis",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "pauci-immune glomerulonephritis",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_6",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_9",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_7",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_10",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "pemphigus vulgaris",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "pemphigus folliaceus",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "bullous pemphigoid",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "cicatricial pemphigoid",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "epidermolysis bullosa acquisita",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "paraneoplastic pemphigus",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "None of the above",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "AIDS-related B-cell lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Burkitt lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Diffuse large B-cell lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Follicular lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Gastric MALT lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "High-grade B-Cell lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Mantle cell lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Nodal marginal zone lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Nongastric MALT lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Primary cutaneous B-cell lymphomas",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Splenic marginal zone lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Other",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       }
#     ],
#     "4": [
#       {
#         "name": "Patient First Name",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Patient Last Name",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Patient Phone",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Patient DOB",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "leptomeningeal metastases from lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "primary CNS lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "none of the above",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "chronic lymphocytic leukemia (CLL)",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "small lymphocytic leukemia",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "none of the above_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_4",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_4",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "relapsed hairy cell leukemia",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "refractory hairy cell leukemia",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "none of the above_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_5",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_5",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "heart transplant recipient",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "other solid organ transplant recipient",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Bavencio (avelumab)",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
# ...
#       },
#       {
#         "name": "Member ID #",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Member ID #"
#       },
#       {
#         "name": "Group #",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Group #"
#       },
#       {
#         "name": "Carrier Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Carrier Name"
#       },
#       {
#         "name": "Insured",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Insured"
#       },
#       {
#         "name": "First Name_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "First Name"
#       },
#       {
#         "name": "Last Name_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Last Name"
#       },
#       {
#         "name": "Address_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Address"
#       },
#       {
#         "name": "City_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "City"
#       },
#       {
#         "name": "State_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "State"
#       },
#       {
#         "name": "ZIP_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "ZIP"
#       },
#       {
#         "name": "Phone_7",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Phone"
#       },
#       {
#         "name": "Fax_6",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Fax"
#       },
#       {
#         "name": "St Lic #",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "St Lic #"
#       },
#       {
#         "name": "NPI #",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "NPI #"
#       },
#       {
#         "name": "DEA #",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "DEA #"
#       },
#       {
#         "name": "UPIN",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "UPIN"
#       },
#       {
#         "name": "Provider Email",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Provider Email"
#       },
#       {
#         "name": "Office Contact Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Office Contact Name"
#       },
#       {
#         "name": "Phone_8",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Phone"
#       },
#       {
#         "name": "Outpatient Infusion Center Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Outpatient Infusion Center Name"
#       },
#       {
#         "name": "Home Infusion Center Agency Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Home Infusion Center Agency Name"
#       },
#       {
#         "name": "Phone_9",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Phone"
#       },
#       {
#         "name": "Administration code(s) (CPT)",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Administration code(s) (CPT)"
#       },
#       {
#         "name": "Address_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Address"
#       },
#       {
#         "name": "City_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "City"
#       },
#       {
#         "name": "State_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "State"
#       },
#       {
#         "name": "ZIP_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "ZIP"
#       },
#       {
#         "name": "Phone_10",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Phone"
#       },
#       {
#         "name": "Fax_7",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Fax"
#       },
#       {
#         "name": "TIN",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "TIN"
#       },
#       {
#         "name": "NPI",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "NPI"
#       },
#       {
#         "name": "Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Name"
#       },
#       {
#         "name": "Address_4",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Address"
#       },
#       {
#         "name": "City_4",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "City"
#       },
#       {
#         "name": "State_4",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "State"
#       },
#       {
#         "name": "ZIP_4",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "ZIP"
#       },
#       {
#         "name": "Phone_11",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Phone"
#       },
#       {
#         "name": "Fax_8",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Fax"
#       },
#       {
#         "name": "PIN",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "PIN"
#       },
#       {
#         "name": "TIN_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "TIN"
#       },
#       {
#         "name": "NPI_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "NPI"
#       },
#       {
#         "name": "Dose",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Dose"
#       },
#       {
#         "name": "Directions for Use",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Directions for Use"
#       },
#       {
#         "name": "HCPCS Code",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "HCPCS Code"
#       },
#       {
#         "name": "Primary ICD Code",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Primary ICD Code"
#       },
#       {
#         "name": "Other ICD Code",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Other ICD Code"
#       },
#       {
#         "name": "Please describe the nature of the failure of the preferred drug",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the adverse reaction to the preferred drug",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       }
#     ],
#     "3": [
#       {
#         "name": "Patient First Name",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient First Name"
#       },
#       {
#         "name": "Patient Last Name",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient Last Name"
#       },
#       {
#         "name": "Patient Phone",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient Phone"
#       },
#       {
#         "name": "Patient DOB",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient DOB"
#       },
#       {
#         "name": "Please describe the nature of the failure of the preferred drug_2",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the adverse reaction to the preferred drug_2",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the failure of the preferred drug_3",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the adverse reaction to the preferred drug_3",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       }
#     ],
#     "4": [
#       {
#         "name": "Patient First Name",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient First Name"
#       },
#       {
#         "name": "Patient Last Name",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient Last Name"
#       },
#       {
#         "name": "Patient Phone",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient Phone"
#       },
#       {
#         "name": "Patient DOB",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient DOB"
#       },
#       {
#         "name": "Medication",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Medication"
#       },
#       {
#         "name": "Dates",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Dates"
#       },
#       {
#         "name": "Medication_2",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Medication"
#       },
#       {
#         "name": "Dates_2",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Dates"
#       }
#     ],
#     "5": [
#       {
#         "name": "Patient First Name",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient First Name"
#       },
#       {
#         "name": "Patient Last Name",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient Last Name"
#       },
#       {
#         "name": "Patient Phone",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient Phone"
#       },
#       {
#         "name": "Patient DOB",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient DOB"
#       },
#       {
#         "name": "Medication_3",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Medication"
#       },
#       {
#         "name": "Dates_3",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Dates"
#       },
#       {
#         "name": "Medication_4",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Medication"
#       },
#       {
#         "name": "Dates_4",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Dates"
#       },
#       {
#         "name": "Please indicate the length of time on Rituxan (rituximab)",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Date",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Date"
#       }
#     ]
#   }
# }
# ```

# %%
pa_fields_context
# Out:
# {2: '```json\n{\n  "pages": {\n    "1": [\n      {\n        "name": "Phone",\n        "type": "text",\n        "value": "1-866-503-0857",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax",\n        "type": "text",\n        "value": "1-844-268-7263",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity",\n        "type": "text",\n        "value": "https://www.aetna.com/health-care-professionals/resource-center/availity.html",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_2",\n        "type": "text",\n        "value": "1-855-463-0933",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_2",\n        "type": "text",\n        "value": "1-833-280-5224",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_2",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/virginia-hmosnp/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_3",\n        "type": "text",\n        "value": "1-844-362-0934",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_3",\n        "type": "text",\n        "value": "1-833-322-0034",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_3",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/new-jersey-hmosnp/providers/portal.html",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_4",\n        "type": "text",\n        "value": "1-866-600-2139",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "FAX",\n        "type": "text",\n        "value": "1-855-320-8445",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_4",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/illinois/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_5",\n        "type": "text",\n        "value": "1-855-364-0974",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_5",\n        "type": "text",\n        "value": "1-855-734-9389",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_5",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/ohio/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_6",\n        "type": "text",\n        "value": "1-855-676-5772",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_6",\n        "type": "text",\n        "value": "1-844-241-2495",\n        "page": 1,\n        "field_type": 2,\n        "field_type_st ...
#  3: '```json\n{\n  "pages": {\n    "1": [\n      {\n        "name": "Phone",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_2",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_2",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_2",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_3",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_3",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_3",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_4",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "FAX",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_4",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_5",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_5",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_5",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_6",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_6",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_6",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      }\n    ],\n    "2": [\n      {\n        "name": "Start of treatment",\n        "type": "checkbox",\n        "value": null,\n        "page": 2,\n        "field_type": 1,\n        "field_type_string": "B ...
#  4: '```json\n{\n  "pages": {\n    "1": [\n      {\n        "name": "Phone",\n        "type": "text",\n        "value": "1-866-503-0857",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax",\n        "type": "text",\n        "value": "1-844-268-7263",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity",\n        "type": "text",\n        "value": "https://www.aetna.com/health-care-professionals/resource-center/availity.html",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_2",\n        "type": "text",\n        "value": "1-855-463-0933",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_2",\n        "type": "text",\n        "value": "1-833-280-5224",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_2",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/virginia-hmosnp/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_3",\n        "type": "text",\n        "value": "1-844-362-0934",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_3",\n        "type": "text",\n        "value": "1-833-322-0034",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_3",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/new-jersey-hmosnp/providers/portal.html",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_4",\n        "type": "text",\n        "value": "1-866-600-2139",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "FAX",\n        "type": "text",\n        "value": "1-855-320-8445",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_4",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/illinois/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_5",\n        "type": "text",\n        "value": "1-855-364-0974",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_5",\n        "type": "text",\n        "value": "1-855-734-9389",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_5",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/ohio/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_6",\n        "type": "text",\n        "value": "1-855-676-5772",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_6",\n        "type": "text",\n        "value": "1-844-241-2495",\n        "page": 1,\n        "field_type": 2,\n        "field_type_st ...
#  5: '```json\n{\n  "pages": {\n    "1": [\n      {\n        "name": "Phone",\n        "type": "text",\n        "value": "1-866-503-0857",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax",\n        "type": "text",\n        "value": "1-844-268-7263",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity",\n        "type": "text",\n        "value": "https://www.aetna.com/health-care-professionals/resource-center/availity.html",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_2",\n        "type": "text",\n        "value": "1-855-463-0933",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_2",\n        "type": "text",\n        "value": "1-833-280-5224",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_2",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/virginia-hmosnp/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_3",\n        "type": "text",\n        "value": "1-844-362-0934",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_3",\n        "type": "text",\n        "value": "1-833-322-0034",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_3",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/new-jersey-hmosnp/providers/portal.html",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_4",\n        "type": "text",\n        "value": "1-866-600-2139",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "FAX",\n        "type": "text",\n        "value": "1-855-320-8445",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_4",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/illinois/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_5",\n        "type": "text",\n        "value": "1-855-364-0974",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_4",\n        "type": "text",\n        "value": "1-855-734-9389",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_5",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/ohio/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_6",\n        "type": "text",\n        "value": "1-855-676-5772",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_5",\n        "type": "text",\n        "value": "1-844-241-2495",\n        "page": 1,\n        "field_type": 2,\n        "field_type_st ...

# %% [markdown]
# ## form filling strategy

# %%
# 🤖 INTELLIGENT AUTO-MAPPING: Let AI map actual field names to patient data
print("🤖 Creating intelligent automated field mapping...")

# Get all actual PDF fields with their labels
doc = fitz.open("Input Data/Adbulla/PA.pdf")
pdf_fields = []
for page_num in range(len(doc)):
    page = doc[page_num]
    for widget in page.widgets():
        if widget.field_name and widget.field_label:
            pdf_fields.append({
                'field_name': widget.field_name,
                'field_type': widget.field_type_string,
                'field_label': widget.field_label,
                'page': page_num + 1
            })
doc.close()

    # Fill PDF with AI mappings - Enhanced with debugging
def fill_pdf_with_ai_mappings(input_pdf_path, output_pdf_path, mappings):
    doc = fitz.open(input_pdf_path)
    filled_count = 0
    skipped_count = 0
    unmapped_count = 0
    
    print(f"🔧 Starting PDF filling with {len(mappings)} mappings...")
    
    for page_num in range(len(doc)):
        page = doc[page_num]
        
        for widget in page.widgets():
            field_name = widget.field_name
            
            if field_name in mappings:
                value = mappings[field_name]
                
                # Skip empty values
                if value == "" or value is None:
                    skipped_count += 1
                    continue
                
                try:
                    if widget.field_type == fitz.PDF_WIDGET_TYPE_CHECKBOX:
                        widget.field_value = bool(value)
                    elif widget.field_type == fitz.PDF_WIDGET_TYPE_TEXT:
                        widget.field_value = str(value)
                    else:
                        print(f"⚠️  Unknown field type for {field_name}: {widget.field_type}")
                        continue
                    
                    widget.update()
                    filled_count += 1
                    print(f"✅ {field_name}: {value}")
                    
                except Exception as e:
                    print(f"⚠️  Error filling {field_name}: {e}")
            else:
                unmapped_count += 1
                # Debug: Show unmapped fields (first 50 only)
                if unmapped_count < 50:
                    print(f"🔍 Field '{field_name}' not in mappings (Page {page.number + 1})")
    
    print(f"📊 Summary: {filled_count} fields filled, {skipped_count} skipped (empty values), {unmapped_count} not in mappings.")
    doc.save(output_pdf_path)
    doc.close()
    return filled_count
# Out:
# 🤖 Creating intelligent automated field mapping...

# %%
# 🚀 IMPROVED INTELLIGENT AUTO-MAPPING with Enhanced Coverage
print("🚀 Creating ENHANCED intelligent automated field mapping...")

# Enhanced mapping prompt that addresses all the gaps
enhanced_mapping_prompt = f"""You are an expert medical form automation specialist. Create comprehensive JSON mapping for a Prior Authorization form.

Pay attention to the whole context of the form and the patient data. And pay attention to this whole prompt including the middle parts

CRITICAL REQUIREMENTS:
1. Fill ALL possible fields where patient data is available
2. Handle checkbox dependencies (if main checkbox is checked, fill related sub-fields)
3. Include product/treatment information from clinical data
4. Use medical terminology appropriately
5. Format dates correctly for each field type
6. Handle multiple choice selections intelligently
7. NEVER use placeholder text like "(From Clinical Data)" - use actual data or leave blank

PDF FIELDS AVAILABLE:
{json.dumps(pdf_fields, indent=2)}

PATIENT DATA AVAILABLE:
{referral_data}

SPECIFIC MAPPING INSTRUCTIONS:

A. PATIENT INFORMATION SECTION:
- Map full name to separate first/last name fields
- Map complete address (street, city, state, zip)
- Map all phone numbers (home, work, cell)
- Map DOB in correct format
- Map patient demographics

B. INSURANCE INFORMATION:
- Map member ID, group number, insured name
- Check for secondary coverage and map if available
- Map insurance carrier information

C. PRESCRIBER INFORMATION - CRITICAL RULES:
- Look for "Provider Contact Information" or similar headings in the clinical data
- Search for doctor/physician names in message records or clinical notes for inference if no difinitive contact information is found
- Extract actual prescriber contact details (address, phone, fax)
- Look for NPI numbers, DEA numbers in provider sections
- Check credentials (M.D., D.O., N.P., P.A.) from provider information
- If prescriber information is not clearly available, LEAVE FIELDS BLANK
- DO NOT use placeholder text like "Prescriber Address (From Clinical Data)"

D. TREATMENT/PRODUCT INFORMATION - ENHANCED SEARCH:
- Look for headings containing "Product", "Medication", "Drug", "Treatment"
- Search doctor comments and clinical notes for prescribed medications
- Look for drug names, dosages, frequencies in clinical documentation
- Check for diagnosis codes (ICD-10) in clinical data
- Search for treatment justification in physician notes
- If specific product/medication is not found, LEAVE FIELDS BLANK

E. DISPENSING/ADMINISTRATION:
- Determine administration method from clinical data
- Map pharmacy/dispensing location if specified
- Map administration codes if available

F. CHECKBOX LOGIC:
- If "Start of treatment" is checked, fill start date fields
- If "Continuation of therapy" is checked, fill last treatment date
- For dispensing location, check appropriate option based on data
- For prescriber type, check M.D., D.O., N.P., or P.A. based on credentials

G. DATE FORMATTING:
- For separate MM/DD/YYYY fields, split dates accordingly
- For single date fields, use MM/DD/YYYY format
- Extract dates from clinical timeline

H. MISSING DATA HANDLING - STRICT RULES:
- Only map fields where you have ACTUAL, SPECIFIC subject data
- If information is not clearly available in the clinical data, LEAVE THE FIELD BLANK
- Do not guess, weakly infer, or fabricate information
- Do not use placeholder text or generic descriptions
- Better to have fewer accurate fields than many inaccurate ones

SEARCH STRATEGY FOR PRESCRIBER INFO:
1. Search for "Provider Contact", "Physician Contact", "Doctor Information"
2. Look in message records for sender/physician information
3. Check clinical notes for prescribing physician details
4. If no specific prescriber info found, leave prescriber fields blank

SEARCH STRATEGY FOR PRODUCT INFO:
1. Look for explicit "Product" or "Medication" sections
2. Search doctor comments for drug names and prescriptions
3. Check treatment plans for specific medications
4. Look for pharmaceutical names in clinical documentation
5. If no specific product found, leave product fields blank

OUTPUT FORMAT - CRITICAL JSON REQUIREMENTS:
1. Return ONLY valid JSON (no markdown blocks, no extra text)
2. Ensure all JSON brackets and braces are properly closed
3. Use double quotes for all strings
4. Boolean values must be true/false (not True/False)
5. Do not truncate the JSON response

{{
  "field_mappings": {{
    "T12": "Shakh",
    "T13": "Abdulla", 
    "CB1": true,
    "T2": "05",
    "T3": "22", 
    "T4": "2024",
    "CB5": false,
    "T14": "04/01/2001",
    "T15": "425 Sherman Ave APT D",
    "T16": "Nashville",
    "T17": "TN",
    "T18": "37995"
  }},
  "mapping_notes": {{
    "total_fields_mapped": 0,
    "sections_completed": [],
    "missing_data_areas": [],
    "checkbox_decisions": {{}}
  }}
}}

IMPORTANT: Complete the entire JSON response. Do not truncate or cut off the JSON in the middle.

ANALYZE THE CLINICAL DATA THOROUGHLY and create comprehensive mappings using ONLY actual data found."""

# Send enhanced prompt to Gemini
print("🧠 Asking AI for ENHANCED comprehensive field mappings...")
# Extract structured data from referral package using Gemini vision
enhanced_response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents=[enhanced_mapping_prompt]
)


# Extract and apply enhanced mappings with ROBUST error handling
def robust_json_parser(json_text):
    """Advanced JSON parser that handles common formatting issues and truncation"""
    import re
    
    # Step 1: Extract JSON content
    if "```json" in json_text:
        json_start = json_text.find("```json") + 7
        json_end = json_text.find("```", json_start)
        if json_end == -1:  # No closing ```
            json_content = json_text[json_start:].strip()
        else:
            json_content = json_text[json_start:json_end].strip()
    else:
        json_content = json_text.strip()
    
    # Step 2: Try direct parsing first
    try:
        return json.loads(json_content)
    except json.JSONDecodeError:
        pass
    
    # Step 3: Advanced cleaning and repair
    print("🔧 Applying advanced JSON repair...")
    
    # Fix common issues
    json_content = re.sub(r'"CB\d+": tr(?![ue])', lambda m: m.group(0).replace('tr', 'true'), json_content)
    json_content = re.sub(r'"CB\d+": fa(?![lse])', lambda m: m.group(0).replace('fa', 'false'), json_content)
    
    # Step 4: Extract field mappings manually using regex
    field_mappings = {}
    
    # Pattern for text fields: "T12": "value"
    text_pattern = r'"(T\d+(?:\.\d+)?|CB\d+|Provider Admin [^"]+)"\s*:\s*"([^"]*)"'
    for match in re.finditer(text_pattern, json_content):
        field_mappings[match.group(1)] = match.group(2)
    
    # Pattern for boolean fields: "CB1": true/false
    bool_pattern = r'"(T\d+(?:\.\d+)?|CB\d+|Provider Admin [^"]+)"\s*:\s*(true|false)'
    for match in re.finditer(bool_pattern, json_content):
        field_mappings[match.group(1)] = match.group(2) == 'true'
    
    # Pattern for null fields: "T1": null
    null_pattern = r'"(T\d+(?:\.\d+)?|CB\d+|Provider Admin [^"]+)"\s*:\s*null'
    for match in re.finditer(null_pattern, json_content):
        field_mappings[match.group(1)] = None
    
    if field_mappings:
        print(f"✅ Extracted {len(field_mappings)} field mappings using regex parsing")
        return {"field_mappings": field_mappings, "mapping_notes": {"extraction_method": "regex"}}
    
    # Step 5: Last resort - create minimal mapping from visible data
    print("⚠️  Using fallback minimal mapping")
    return {
        "field_mappings": {
            "T12": "Shakh",
            "T13": "Abdulla", 
            "T14": "04/01/2001",
            "T15": "425 Sherman Aves APT D",
            "T16": "Nashville",
            "T17": "TN",
            "T18": "37923"
        },
        "mapping_notes": {"extraction_method": "fallback"}
    }

try:
    # Use the robust parser
    enhanced_mappings = robust_json_parser(enhanced_response.text)
    
    enhanced_field_mappings = enhanced_mappings.get("field_mappings", {})
    mapping_notes = enhanced_mappings.get("mapping_notes", {})
    
    print(f"\n🎯 ENHANCED AI created {len(enhanced_field_mappings)} comprehensive field mappings")
    
    # Show mapping summary
    if mapping_notes:
        print(f"📊 Total fields mapped: {mapping_notes.get('total_fields_mapped', len(enhanced_field_mappings))}")
        print(f"📋 Sections completed: {', '.join(mapping_notes.get('sections_completed', []))}")
        if mapping_notes.get('missing_data_areas'):
            print(f"⚠️  Missing data areas: {', '.join(mapping_notes.get('missing_data_areas', []))}")
    
    # Show sample enhanced mappings
    print("\nSample enhanced mappings:")
    for i, (field, value) in enumerate(list(enhanced_field_mappings.items())[:8]):
        print(f"  • {field} → {value}")
    
    # Apply enhanced mappings to PDF
    output_pdf_enhanced = "Input Data/Adbulla/PA_FILLED_ENHANCED.pdf"
    filled_count = fill_pdf_with_ai_mappings("Input Data/Adbulla/PA.pdf", output_pdf_enhanced, enhanced_field_mappings)
    
    print(f"\n🎉 ENHANCED MAPPING SUCCESS!")
    print(f"✅ Filled {filled_count} fields using enhanced AI mapping")
    print(f"📄 Enhanced PDF saved as: {output_pdf_enhanced}")
    
    # Compare with previous version
    previous_count = len(field_mappings) if 'field_mappings' in locals() else 0
    improvement = filled_count - previous_count
    if improvement > 0:
        print(f"🚀 IMPROVEMENT: +{improvement} more fields filled than previous version!")
    
except Exception as e:
    print(f"❌ Error in enhanced mapping: {e}")
    print("Full enhanced response:")
    print(enhanced_response.text)
# Out:
# 🚀 Creating ENHANCED intelligent automated field mapping...
# 🧠 Asking AI for ENHANCED comprehensive field mappings...
#
# 🎯 ENHANCED AI created 323 comprehensive field mappings
# 📊 Total fields mapped: 133
# 📋 Sections completed: Patient Information, Insurance Information, Prescriber Information, Treatment/Product Information, Administration Location
# ⚠️  Missing data areas: Patient Work Phone, Patient Email, Patient Weight/Height, Secondary Insurance Details, Prescriber State License #, Prescriber DEA #, Prescriber UPIN, Prescriber Email, Administration CPT Code, Administration TIN/PIN/NPI, Dispensing Pharmacy Information (Name, Address, Phone, Fax, TIN, PIN, NPI), HCPCS Code for product, Other ICD Codes (specific codes), Details for failed preferred drugs (dates/descriptions), Details for adverse reactions to preferred drugs (dates/descriptions), Contraindications for other preferred drugs (text), Prior Rituximab Use (dates), Rheumatoid Arthritis/Psoriatic Arthritis specific questions (not applicable), Systemic Lupus Erythematosus specific questions (not applicable), Vasculitis specific questions (not applicable), Cryoglobulinemia specific questions (not applicable), Sjögren’s syndrome specific questions (not applicable), Polyarteritis Nodosa (PAN) specific questions (not applicable), Dermatomyositis/Polymyositis (DM/PM) specific questions (not applicable), Myasthenia Gravis specific questions (not applicable)
#
# Sample enhanced mappings:
#   • T12 → Shakh
#   • T13 → Abdulla
#   • CB1 → True
#   • T2 → 05
#   • T3 → 22
#   • T4 → 2024
#   • CB5 → False
#   • T6 →
# 🔧 Starting PDF filling with 323 mappings...
# ✅ CB1: True
# ✅ T2: 05
# ✅ T3: 22
# ✅ T4: 2024
# ✅ CB5: False
# ✅ T9: Erfan Rostami, BSN, RN
# ✅ T10: 615-343-1176
# ✅ T11: 615-343-1219
# ✅ T12: Shakh
# ✅ T13: Abdulla
# ✅ T14: 04/01/2001
# ✅ T15: 425 Sherman Aves APT D
# ✅ T16: Nashville
# ✅ T17: TN
# ✅ T18: 37923
# ✅ T19: 865-395-0481
# ✅ T21: 865-395-0481
# ✅ T23: No Known Allergies
# ✅ T28: LAJM14345116
# ✅ T29: 435000
# ✅ T30: ABDULLA, SHAKH
# ✅ CB31: False
# ✅ CB32: True
# ✅ T42: Hao H
# ✅ T43: Gu
# ✅ CB44: True
# ✅ CB45: False
# ✅ CB46: False
# ✅ CB47: False
# ✅ T48: 3320 Montgomery Dr
# ✅ T49: NASHVILLE
# ✅ T50: TN
# ✅ T51: 37361
# ✅ T52: 614-936-0065
# ✅ T53: 615-562-4820
# ✅ T55: 1154611523
# ✅ T58.1: Erfan Rostami, BSN, RN
# ✅ T59: 615-343-1176
# ✅ Provider Admin CB.1: False
# ✅ Provider Admin CB.2: False
# ✅ Provider Admin CB.3: False
# ✅ Provider Admin CB.4: True
# ✅ Provider Admin T.5: Children's Hematology - Oncology (Peds DOT 6)
# ✅ Provider Admin CB.7: False
# ✅ Provider Admin T.6: 615-936-1762
# ✅ Provider Admin CB.10: False
# ✅ Provider Admin T.11A: 2211 Broad Way, Tower 4th FL, Suite 6102
# ✅ Provider Admin T.13: Nashville
# ✅ Provider Admin T.14: TN
# ✅ Provider Admin T.15: 37232
# ✅ Provider Admin T.16: 615-936-1762
# ✅ Provider Admin CB.21: False
# ✅ Provider Admin CB.22: False
# ✅ Provider Admin CB.23.0.0: False
# ✅ Provider Admin CB.24.0.0: False
# ✅ Provider Admin CB.25: False
# ✅ Provider Admin CB.26: False
# ✅ CB60: False
# ✅ CB61: False
# ✅ CB62: False
# ✅ CB63: True
# ✅ T64: 694 mg
# ✅ T65: Initial: Every 2 weeks (2 doses remaining); Maintenance: Every 24 weeks. Administer 30 minutes after treatment start time. 1st infusion: initiate at 50mg/hr, increase by 50mg/hr every 30 min, Max Rate 400mg/hr. Subsequent infusions: initiate at 100mg/hr, increase by 100mg/hr every 30 min, Max Rate 400mg/hr.
# ✅ T67: G35
# ✅ CB68: False
# ✅ CB70: False
# ✅ CB71: True
# ✅ CB72: True
# ✅ CB73: False
# ✅ CB74: False
# ✅ CB77: True
# ✅ CB78: False
# ✅ CB79: False
# ✅ CB82: False
# ✅ CB83: False
# ✅ T12: Shakh
# ✅ T13: Abdulla
# ✅ T19: 865-395-0481
# ✅ T14: 04/01/2001
# ✅ CB86: False
# ✅ CB87: False
# ✅ CB88: False
# ✅ CB85: True
# ✅ CB92: False
# ✅ CB93: False
# ✅ CB94: False
# ✅ CB91: True
# ✅ CB98a: False
# ✅ CB99a: False
# ✅ CB100a: False
# ✅ CB101a: False
# ✅ CB102a: False
# ✅ CB103a: False
# ✅ CB97: True
# ✅ CB107z: False
# ✅ CB108z: False
# ✅ CB109z: False
# ✅ CB110z: False
# ✅ CB111z: False
# ✅ CB112z: False
# ✅ CB106z: True
# ✅ CB115z: False
# ✅ CB116z: False
# ✅ CB117z: False
# ✅ CB119z: False
# ✅ CB120z: False
# ✅ CB121z: False
# ✅ CB122z: False
# ✅ CB123z: False
# ✅ CB124z: False
# ✅ CB96.4.0: True
# ✅ CB98: False
# ✅ CB99.0: False
# ✅ CB100.0: True
# ✅ CB101.0: False
# ✅ CB102.0: True
# ✅ CB103: False
# ✅ CB104: True
# ✅ CB104a: False
# ✅ CB104b: False
# ✅ CB104c: False
# ✅ CB104d: False
# ✅ CB105: False
# ✅ CB106: True
# ✅ CB106a: False
# ✅ CB107: False
# ✅ CB108: False
# ✅ CB109: False
# ✅ CB110: False
# ✅ CB111: False
# ✅ CB112: False
# ✅ CB113: True
# ✅ CB106b: True
# ✅ CB114: False
# ✅ CB115: False
# ✅ CB116: False
# ✅ CB117: False
# ✅ CB118: False
# ✅ CB119: False
# ✅ CB120: False
# ✅ CB121: False
# ✅ CB122: False
# ✅ CB123: False
# ✅ CB124: False
# ✅ CB125: False
# ✅ T12: Shakh
# ✅ T13: Abdulla
# ✅ T19: 865-395-0481
# ✅ T14: 04/01/2001
# ✅ CB127: False
# ✅ CB128: True
# ✅ CB129: False
# ✅ CB130: False
# ✅ CB131: True
# ✅ CB132: False
# ✅ CB133: False
# ✅ CB134: True
# ✅ CB135: False
# ✅ CB136: True
# ✅ CB139: False
# ✅ CB140: True
# ✅ CB144: False
# ✅ CB145: True
# ✅ CB141: False
# ✅ CB142: False
# ✅ CB143: True
# ✅ CB137: False
# ✅ CB146: False
# ✅ CB147: False
# ✅ CB138: True
# ✅ CB148: False
# ✅ CB149: False
# ✅ CB150: False
# ✅ CB151: False
# ✅ CB152: False
# ✅ CB153: False
# ✅ CB154: False
# ✅ CB156: False
# ✅ CB158: False
# ✅ CB159: False
# ✅ CB157: True
# ✅ CB160: False
# ✅ CB161: True
# ✅ CB162: True
# ✅ CB163: False
# ✅ CB164: True
# ✅ CB165: False
# ✅ CB166: False
# ✅ CB167: False
# ✅ CB168: True
# ✅ CB169: False
# ✅ CB170: True
# ✅ CB172: False
# ✅ CB173: True
# ✅ CB171: False
# ✅ CB174: False
# ✅ CB175: True
# ✅ CB176: False
# ✅ CB177: True
# ✅ CB178: False
# ✅ CB179: True
# ✅ CB180: False
# ✅ CB181: True
# ✅ CB203: False
# ✅ CB204: True
# ✅ CB205: False
# ✅ CB206: True
# ✅ T12: Shakh
# ✅ T13: Abdulla
# ✅ T19: 865-395-0481
# ✅ T14: 04/01/2001
# ✅ CB207: False
# ✅ CB208: False
# ✅ CB209: False
# ✅ CB210: False
# ✅ CB211: True
# ✅ CB212: False
# ✅ CB213: True
# ✅ CB214: False
# ✅ CB216: False
# ✅ CB217: False
# ✅ CB218: False
# ✅ CB215: True
# ✅ CB223: False
# ✅ CB225: False
# ✅ CB226: False
# ✅ CB227: False
# ✅ CB228: False
# ✅ CB229: False
# ✅ CB224: True
# ✅ CB281: False
# ✅ CB282: True
# ✅ CB283: False
# ✅ CB284: True
# ✅ CB299: False
# ✅ CB300: True
# ✅ CB301: False
# ✅ CB302: True
# ✅ CB303: False
# ✅ CB304: True
# ✅ CB310: False
# ✅ CB311: False
# ✅ CB312: False
# ✅ CB306: False
# ✅ CB307: True
# ✅ CB308: False
# ✅ CB309: True
# ✅ CB313: False
# ✅ CB314: True
# ✅ CB315: False
# ✅ CB316: True
# 📊 Summary: 251 fields filled, 84 skipped (empty values), 0 not in mappings.
#
# 🎉 ENHANCED MAPPING SUCCESS!
# ✅ Filled 251 fields using enhanced AI mapping
# 📄 Enhanced PDF saved as: Input Data/Adbulla/PA_FILLED_ENHANCED.pdf
# 🚀 IMPROVEMENT: +251 more fields filled than previous version!
