# %% [markdown]
# ## Loading Model and Input Files

# %%
# 🔄 CLEAN INITIALIZATION - RESTART KERNEL IF NEEDED
print("🔄 Initializing environment...")
import pathlib
from google import genai
from google.genai import types
import os
import asyncio
import json
import fitz  # PyMuPDF for PDF processing
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Check if API key is loaded
api_key = os.getenv("GOOGLE_API_KEY")
if not api_key:
    raise ValueError("GOOGLE_API_KEY not found in environment variables. Please check your .env file.")

# Configure the API
client = genai.Client(api_key=api_key)


pa_file = "PA.pdf"
referral_file = "referral_package.pdf"

# Retrieve and encode the PDF byte
filepath = pathlib.Path('Input Data/Adbulla/' + pa_file)

print("✅ Setup complete!")
# Out:
# 🔄 Initializing environment...
# ✅ Setup complete!

# %% [markdown]
# ## 📄 Referral Package Analysis & Information Extraction to Json Using Gemeni

# %%
# 🔄 DIRECT GEMINI OCR & ANALYSIS - Bypassing Mistral
print("🔄 Using Gemini directly for OCR and information extraction...")

# Enhanced prompt for direct PDF analysis
referral_prompt = """You are analyzing a referral package PDF (collection of scanned medical documents) to extract patient information that will be used to fill a Prior Authorization form.

CONTEXT: This referral package contains scanned documents like insurance cards, medical history notes, test results, and other supporting documentation. You need to perform OCR on the PDF and extract structured information.

EXTRACTION FOCUS: Use your vision capabilities to read and extract all available information and display it in order as it is read from the PDF. Then turn that output into JSON format:

PATIENT DEMOGRAPHICS:
- Full name, DOB, gender, address, phone numbers
- Patient ID numbers, MRN, account numbers
- Emergency contacts and relationships

INSURANCE INFORMATION:
- Insurance company name and plan details
- Member ID, group number, policy number
- Subscriber information and relationship to patient
- Coverage details and effective dates

CLINICAL INFORMATION:
- Primary and secondary diagnoses with ICD codes
- Current medications, dosages, and frequencies
- Allergies and adverse reactions
- Vital signs and lab results
- Previous treatments and outcomes
- Medical history and comorbidities

PROVIDER INFORMATION:
- Referring physician name, specialty, and contact info
- Practice name and address
- NPI numbers and license information
- Facility details where treatment will occur

TREATMENT DETAILS:
- Requested medication/procedure/device
- Dosage, frequency, duration
- Medical necessity justification
- Previous treatment failures
- Clinical criteria met for approval

SUPPORTING EVIDENCE:
- Lab results supporting diagnosis
- Imaging studies and results
- Functional assessments
- Specialist consultations
- Treatment response documentation

INSTRUCTIONS:
1. Carefully read through all pages of the PDF
2. Extract text and data from tables, forms, and documents
3. Pay attention to medical terminology and abbreviations
4. Look for provider contact information sections
5. Identify medication/product information from clinical notes
6. First return all info read in the document. List all information from tables including reference ranges and other details. Do not skip anything that has information
7. Then return a structured JSON with all relevant extracted information, using null for missing data"""

# Load and process the referral package PDF directly with Gemini
referral_pdf_path = 'Input Data/Adbulla/referral_package.pdf'

# Upload the PDF file to Gemini using new API
print(f"📄 Loading referral package: {referral_pdf_path}")
referral_file = client.files.upload(file=referral_pdf_path)
print(f"✅ File uploaded successfully: {referral_file.name}")

# Wait for file processing
import time
while referral_file.state == "PROCESSING":
    print("⏳ Processing file...")
    time.sleep(2)
    referral_file = client.files.get(name=referral_file.name)

if referral_file.state == "FAILED":
    raise ValueError("❌ File processing failed")
print("✅ File processed successfully")

# Extract structured data from referral package using Gemini vision
referral_response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents=[referral_prompt, referral_file]
)
referral_data = referral_response.text
print("📊 Referral Package Data Extracted:")
print(referral_data)

# Store the extracted text for compatibility with existing code
referral_package_text = referral_data
# Out:
# 🔄 Using Gemini directly for OCR and information extraction...
# 📄 Loading referral package: Input Data/Adbulla/referral_package.pdf
# ✅ File uploaded successfully: files/ohrncyy1cab3
# ✅ File processed successfully
# 📊 Referral Package Data Extracted:
# Here is the extracted information from the referral package PDF, first as raw text in order of appearance, and then in the requested structured JSON format.
#
# ---
#
# **1. All Information Read from the Document (Ordered by Page)**
#
# **Page 1**
# *   **FAX TRANSMISSION**
# *   **Date:** 04/22/2024
# *   **Time:** 11:32
# *   **Page Number:** 1/028 (Likely 1 of 28 total pages, though only 15 are provided)
# *   **Sender Organization:** Better Life Multiple Sclerosis Center
# *   **Sender Address:** 3320 Montgomery Dr. Nashville, TN 37361
# *   **Sender Fax Number:** F 615-562-4820
# *   **Sender Phone Number:** P: 615-562-4848
# *   **Sender Doctors:** Dr. Asriel Han | Dr. Aditya Shah
# *   **Recipient Organization (TO):** Golden Gate Infusion Center
# *   **Recipient Fax Number:** Fax: 614-278-3355
# *   **Recipient Phone Number:** Phone: 614-895-7655
# *   **From (Individual):** Erfan Rostami, BSN, RN
# *   **From (Individual) Phone Number:** P: 615-343-1176
# *   **From (Individual) Fax Number:** F: 615-343-1219
# *   **Comments:**
#     *   Arabic - Spoken / English - Written
#     *   Rituxan (Truxima) TP
#     *   MRI Reports
#     *   Hospital D/C note
#     *   Demographics
# *   **Confidentiality Notice:** The documents accompanying this transmission may contain health information that is legally protected. This information is intended only for the use of the Individual or entity named above. The authorized recipient of this information is prohibited from disclosing this Information to any other party unless permitted by law or regulation. If you are not the intended recipient, you are hereby notifled that any use, disclosure, copying or distribution of these documents is strictly prohibited. If you have received this Information in error, please notify the sender Immediately and arrange for the return or destruction of these documents.
#
# **Page 2**
# *   **Patient Name (Header):** Abdulla, Shakh
# *   **MRN (Header):** 041152153
# *   **Communication Date:** 5/16/2024
# *   **Status:** Open
# *   **Center:** Better Life Multiple Sclerosis Center
# *   **Provider:** Erfan Rostami, RN
# *   **Reason for call:** Truxima Second Initial Dose Needed Week of June 3
# *   **All Conversations: Truxima Second Initial Dose Needed Week of June 3 (Newest Message First)**
#     *   **From:** Jha, Vedant
#     *   **To:** Erfan Rostami, RN
#     *   **Date/Time:** May 21, 2024 / 5/21/24 4:44 PM
#     *   **Message:** Hi Erfan. The only way Extraodinary Care could see his Medicaid plan would be at home :( I'm not sure if he is able to be seen at a hospital based infusion center closer to home? We will hold off on this one for now- let me know if you're not able to find a provider who can see him in the infusion suite and we will re-open the referral.
#     *   **From:** Erfan Rostami, RN
#     *   **Action:** routed this conversation
#     *   **To:** Jha, Vedant
#     *   **Date/Time:** 5/21/24 2:32 PM
#     *   **From:** Gu, Hao H, MD
#     *   **To:** Erfan Rostami, RN
#     *   **Date/Time:** May 20, 2024 / 5/20/24 5:13 PM
#     *   **Note:** No home infusion. Her first dose is scheduled may 23. Second dos 2 weeks from may 23 first.
#     *   **From:** Erfan Rostami, RN
#     *   **Action:** routed this conversation
#     *   **To:** Gu, Hao H, MD
#     *   **Date/Time:** 5/20/24 3:41 PM
#     *   **From:** Jha, Vedant
#     *   **To:** Erfan Rostami, RN
#     *   **Date/Time:** 5/20/24 2:54 PM
#     *   **Message:** Hi, Is Dr. Gu comfortable with this patient being seen for home infusion? Thanks,
#
# **Page 3**
# *   **Patient Name (Header):** Abdulla, Shakh
# *   **MRN (Header):** 041152153
# *   **DOB (Header):** 04/01/2001
# *   **Therapy Plan 1 Summary**
# *   **MRN:** 041152153
# *   **Description:** male
# *   **DOB:** 4/1/2001
# *   **Patient Demographics:**
#     *   **Patient Name:** Abdulla, Shakh
#     *   **Legal Sex:** male
#     *   **DOB:** 4/1/2001
#     *   **Address:** 425 Sherman Ave, Nashville TN 37995
#     *   **Phone (Home):** 865-395-3958
#     *   **Phone (Mobile):** 865-395-0481 (*Preferred*)
# *   **Medication:**
#     *   Rituximab Or Biosimilar Days 1, 15 Load Then Once Every 24 Weeks
# *   **Associated Problems:**
#     *   **Problem:** Multiple sclerosis in pediatric patient (CMS/HCC) [G35]
#     *   **Selected Diagnosis:** Multiple sclerosis in pediatric patient (CMS/HCC) [G35]
# *   **Infusion Orders - All Current Orders:**
#     *   **IV access**
#         *   **Interval:** Every visit
#         *   **Duration:** Every visit
#         *   **Care Instructions:** Obtain IV access (PIV, PORT, etc.) and start NS 0.9% @ KVO. Until discontinued Starting when released Until Specified.
#         *   **Last released:** Never
#         *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024 5:11 PM
#     *   **Monitor pt for hypersensitivity reaction**
#         *   **Interval:** Every visit
#         *   **Duration:** Every visit
#         *   **Care Instructions:** Once Starting when released for 1 occurrence. If allergic reaction or infusion related reaction occurs, initiate adult hypersensitivity reaction protocol or pediatric guideline and CALL MD for additional orders.
#         *   **Last released:** Never
#         *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024 5:11 PM
#     *   **NURSING COMMUNICATION (1)**
#         *   **Interval:** Every visit
#         *   **Duration:** Every visit
#         *   **Care Instructions:** Ensure that patient has not taken antihypertensive medications in the 12 hours prior to infusion. Until discontinued Starting when released Until Specified.
#         *   **Last released:** Never
#         *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024 5:11 PM
#     *   **NURSING COMMUNICATION (2)**
#         *   **Interval:** Every visit
#         *   **Duration:** Every visit
#         *   **Care Instructions:** For Hypotension, place patient in Trendelenberg position, support with NS, and call MD. Until discontinued Starting when released Until Specified.
#
# **Page 4**
# *   **Labs:**
#     *   **IgG**
#         *   **Care Instructions:** Clinic Collect, Blood.
#         *   **Last released:** Never
#         *   **Interval:** Every 24 weeks
#         *   **Duration:** Week of 5/19/2024
#         *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024 5:11 PM
#     *   **CBC w/ Differential**
#         *   **Care Instructions:** Once Starting when released, Blood.
#         *   **Last released:** Never
#         *   **Interval:** Every visit
#         *   **Duration:** Every visit
#         *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024 5:11 PM
#     *   **Flow Lymphocytes Subsets (TBNK)**
#         *   **Care Instructions:** Once Starting when released, Blood.
#         *   **Last released:** Never
#         *   **Interval:** Every visit
#         *   **Duration:** Every visit
#         *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024 5:11 PM
# *   **Vitals:**
#     *   **Vital Signs**
#         *   **Interval:** Every visit
#         *   **Duration:** Every visit
#         *   **Care Instructions:** Obtain VS prior to start therapy, Q30 minutes with each dose increase and at the end of treatment. As needed Starting when released Until Specified.
#         *   **Last released:** Never
#         *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024
# *   **Hydration:**
#     *   **heparin, porcine (PF) 100 unit/mL syringe 5 mL**
#         *   **Interval:** PRN
#         *   **Duration:** PRN
#         *   **Care Instructions:** 5 mL, intraVENOUS, As needed, For flushing Ports/ PICC lines/ Central Lines IF NEEDED, Starting when released, Until Discontinued.
#         *   **Last released:** Never
#         *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024 5:11 PM
# *   **Pre-Medications:**
#     *   **acetaminophen (TYLENOL) tablet 650 mg**
#         *   **Care Instructions:** 650 mg, oral, Once, Starting when released.
#         *   **Last released:** Never
#         *   **Interval:** Every visit
#         *   **Duration:** Every visit
#         *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024 5:11 PM
#     *   **diphenhydrAMINE (BENADRYL) 50 mg in 50 mL NS**
#         *   **Care Instructions:** 50 mg, intraVENOUS, Once, Starting when released. Administer 30 minutes before starting infusion.
#         *   **Last released:** Never
#         *   **Interval:** Every visit
#         *   **Duration:** Every visit
#         *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024 5:11 PM
#     *   **methylPREDNISolone sod succinate (SOLU-Medrol) (20 mg/mL) 125 mg in NS 6.2 mL**
#         *   **Care Instructions:** 125 mg, intraVENOUS, Once, Starting when released. Administer 30 minutes before starting infusion.
#         *   **Last released:** Never
#         *   **Interval:** Every visit
#         *   **Duration:** Every visit
#         *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024 5:11 PM
#
# **Page 5**
# *   **Infusion Therapy:**
#     *   **NURSING COMMUNICATION**
#         *   **Interval:** Every visit
#         *   **Duration:** Every visit
#         *   **Care Instructions:** Until discontinued Starting when released Until Specified. Infusion rate (standard only): 1st infusion - initiate at 50mg/hr and if no infusion toxicity reaction, may increase by 50mg/hr ever 30 minutes; Max Rate 400mg/hr. Subsequent infusions - initiate at 100mg/hr and if no infusion toxicity reaction, may increase by 100mg/hr every 30 min; Max Rate 400mg/hr.
#         *   **Last released:** Never
#         *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024 5:11 PM
#     *   **Infusion Therapy - Initial Dose:**
#         *   **Medication:** riTUXimab-abbs (TRUXIMA) IVPB
#         *   **Dosage/Route:** 694 mg (rounded from 693.75 mg = 375 mg/m2 x 1.85 m2 - BSA might be out of date), intraVENOUS, Once.
#         *   **Timing:** Starting 30 minutes after treatment start time.
#         *   **Last released:** Never
#         *   **Interval:** Every 2 weeks
#         *   **Duration:** 2/2 remaining
#         *   **Due:** Week of 5/19/2024
#         *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024 5:11 PM
#     *   **Infusion Therapy - Maintenance Dose:**
#         *   **Medication:** riTUXimab-abbs (TRUXIMA) IVPB
#         *   **Defer until:** Mon 11/4/2024
#         *   **Dosage/Route:** 694 mg (rounded from 693.75 mg = 375 mg/m2 x 1.85 m2 - BSA might be out of date), intraVENOUS, Once.
#         *   **Timing:** Starting when released.
#         *   **Last released:** Never
#         *   **Interval:** Every 24 weeks
#         *   **Due:** Mon 11/4/2024
#         *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024 5:11 PM
# *   **PRN Medications:**
#     *   **diphenhydrAMINE (BENADRYL) injection 25 mg**
#         *   **Dosage/Route:** 25 mg, intraVENOUS, As needed, chills.
#         *   **Timing:** Starting when released, for 2 doses.
#         *   **Last released:** Never
#         *   **Interval:** PRN
#         *   **Duration:** PRN
#         *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024 5:11 PM
#     *   **meperidine (DEMEROL) injection 25 mg**
#         *   **Dosage/Route:** 25 mg, intraVENOUS, As needed, rigors.
#         *   **Timing:** Starting when released, for 2 doses.
#         *   **Last released:** Never
#         *   **Interval:** PRN
#         *   **Duration:** PRN
#         *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024 5:11 PM
#     *   **ondansetron (ZOFRAN) injection 4 mg**
#         *   **Dosage/Route:** 4 mg, intraVENOUS, As needed, nausea, vomiting.
#         *   **Timing:** Starting when released, for 2 doses.
#         *   **Instructions:** Doses up to 4 mg may be administered undiluted. Inject over at least 30 seconds, but preferably over 2-5 minutes.
#         *   **Last released:** Never
#         *   **Interval:** PRN
#         *   **Duration:** PRN
#         *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024 5:11 PM
# *   **eSignature Information:** All order signatures are valid for 1 (one) year from the signature date.
# *   **Provider Contact Information** (section header)
#
# **Page 6**
# *   **Provider Information (continuation):**
#     *   **Name:** Hao H Gu, MD
#     *   **NPI:** 1154611523
#     *   **Practice:** Better Life Multiple Sclerosis Center
#     *   **Address:** 3320 Montgomery Dr NASHVILLE TN 37361
#     *   **Phone:** 614-936-0065
#
# **Page 7**
# *   **Hospital Face Sheet**
# *   **Patient:** Shakh Abdulla
# *   **Hospital A/C:** [Blank]
# *   **Care Everywhere ID#:** VDJ-7KR2-4847-LGF8
# *   **ENCOUNTER:**
#     *   **Patient Class:** [Blank]
#     *   **Admission User:** [Blank]
#     *   **Admitting Provider:** [Blank]
#     *   **Attending Provider:** [Blank]
#     *   **Adm Diagnosis:** MyHealth Bundle Status: [Blank]
#     *   **Admission Date/Time:** 5/17/2024
#     *   **Referring Physician:** [Blank]
# *   **PATIENT:**
#     *   **Name:** Shakh Abdulla
#     *   **Address:** 425 Sherman Aves APT D, Nashville TN 37923
#     *   **DOB:** 4/1/200 (23 yrs) (Note: DOB on Page 3 and 9 is 4/1/2001)
#     *   **Sex:** male
#     *   **Pref Lang:** Arabic
#     *   **Primary Care Provider:** James David, PNP
#     *   **Primary Phone:** 865-839-7458
#     *   **Marital Status:** Single
#     *   **Mobile Phone:** 865-839-7458
# *   **EMERGENCY CONTACT:**
#     *   **Contact 1:** Sina, Amin
#         *   **Legal Guardian?:** Yes
#         *   **Relationship to Patient:** Father
#         *   **Home Phone:** [Blank]
#         *   **Work Phone:** [Blank]
#     *   **Contact 2:** Mohammedreza, Mustala
#         *   **Legal Guardian?:** Yes
#         *   **Relationship to Patient:** Mother
#         *   **Home Phone:** [Blank]
#         *   **Work Phone:** [Blank]
# *   **GUARANTOR:**
#     *   **Guarantor:** [Blank]
#     *   **Address:** [Blank]
#     *   **Relation to Patient:** [Blank]
#     *   **Guarantor ID:** [Blank]
#     *   **DOB:** 10/29/1979
#     *   **Sex:** Female
#     *   **Home Phone:** [Blank]
#     *   **Mobile Phone:** [Blank]
#     *   **Work Phone:** [Blank]
# *   **GUARANTOR EMPLOYER:** There is no guarantor Information entered for this encounter.
#     *   **Status:** NOT EMPLO
# *   **COVERAGE:**
#     *   **PRIMARY INSURANCE:**
#         *   **Payor:** [Blank]
#         *   **Plan:** TC BLUE CARE NO COPAY
#         *   **Group Number:** [Blank]
#         *   **Insurance Type:** [Blank]
#         *   **Subscriber Name:** [Blank]
#         *   **Subscriber DOB:** [Blank]
#         *   **Subscriber ID:** [Blank]
#         *   **Financial Class:** [Blank]
#         *   **Pat. Rel. to Subscriber:** [Blank]
#     *   **SECONDARY INSURANCE:**
#         *   **Payor:** [Blank]
#         *   **Group Number:** [Blank]
#         *   **Subscriber Name:** [Blank]
#         *   **Subscriber ID:** [Blank]
#         *   **Pat. Rel. to Subscriber:** [Blank]
# *   **Document Date:** May 22, 2024
# *   **Document Type:** Hospital Face Sheet
#
# **Page 8**
# *   **Patient Name (Header):** Abdulnabi, Noor (Note: This seems to be a template error as patient is Shakh Abdulla)
# *   **MRN (Header):** 041152153 (Matches Shakh Abdulla's MRN)
# *   **DOB (Header):** 4/1/2001 (Matches Shakh Abdulla's DOB)
# *   **Primary Coverage:**
#     *   **Payer:** BC TENNCARE
#     *   **Plan:** TC BLUE CARE NO COPAY
#     *   **Sponsor Code:** [Blank]
#     *   **Group Number:** 435000
#     *   **Group Name:** TENNCARE/BLUECARE
# *   **Primary Subscriber:**
#     *   **ID:** LAJM14345116
#     *   **Name:** ABDULLA, SHAKH
#     *   **SSN:** xxx-xx-8143
#     *   **Address:** 8327 BROADWAY LN APT D, KNOXVILLE, TN 37923
#
# **Page 9**
# *   **Patient Name:** Abdulla, Shakh
# *   **MRN:** 048152153 (Note: This MRN is inconsistent with 041152153 on previous pages. Assuming 041152153 is correct based on consistency across other pages.)
# *   **ED to Hosp-Admission:**
#     *   **Dates:** 5/14/2024 - 5/17/2024 (3 days)
#     *   **Status:** Discharged
#     *   **Facility:** Monroe Carell Jr. Children's Hospital
#     *   **Last attending:** Harry, Tom, MD with Treatment team
#     *   **Principal problem:** Abnormal MRI
# *   **Discharge Summary:**
#     *   **Cosigned by:** Gu, Hao H, MD at 5/17/2024 1:56 PM
#     *   **Resident Physician:** Kaine, Adam Jason, MD (Pediatric Neurology)
#     *   **Attestation signed by:** Gu, Hao H, MD at 5/17/2024 1:56 PM (Updated)
#     *   **Patient Visit Details:** I saw the patient on: 5/17/2024 with Dr Kaine, I discussed the care with Dr Kaine, patient and his father at bedside and agree with the findings and plan as documented in the attached note.
#     *   **Hospital Execution:** I personally spent more than 30 minutes on the patient's care unit in the preparation and execution of the hospital discharge.
#     *   **Treatment Post-Discharge:** S/p 4 days of high dose IVMP (1g/dose) today- Discharge home with oral decadron 180mg (equivalent to 1000mg IVMP) x 1 to round out 5 days of high dose steroid treatment for active demyelinating lesion (family wishes to be discharged today instead of Saturday). He will then start oral prednisone taper- instructions provided +PPI.
#     *   **Future Treatment Plan:** First dose of Rituximab or biosimilar scheduled for May 22 at 9am; second dose of first course of Rituximab within 2 weeks after, we are working with local infusion facility in Knoxville to get this set up for her moving forward to minimize travel.
#     *   **Follow-ups:** he will follow up with ophthalmologist in Knoxville. School note for this week and next week. PT/OT locally. Continue vitamin D.
#     *   **Future Appointment:** I will see her tentatively 3 months after completion of 1st course of Rituximab -with same day MRI (she does not need sedation)- looking at early or mid September. Will update family once we have that arranged.
#     *   **Signed by:** Hao Gu MD
# *   **Neurology Discharge Summary:**
#     *   **Patient Name:** Shakh Abdulla
#     *   **DOB:** 4/1/2001
#     *   **Service:** Pediatric Neurology
#     *   **Attending:** Harry, Tom, MD
#     *   **Date of Admission:** 5/14/2024
#
# **Page 10**
# *   **Date of Discharge:** 5/17/2024
# *   **Diagnosis:**
#     *   **Principal Problem:** Abnormal MRI
#     *   **Resolved Problems:** No resolved hospital problems.
# *   **Procedures:**
#     *   **Bedside Procedures:** No orders of the defined types were placed in this encounter.
#     *   **OR Procedures:** Cannot find OR case.
# *   **Synopsis:** Shakh Abdulla is a 23 year old male who established care with VCH neurology; with MRI brain and spine demonstrating multiple lesions consistent with atypical pediatric MS.
# *   **Hospital Course:**
#     *   Shakh Abdulla is a 23 year old male with history of optic neuritis and abnormal MRI brain concerning for MS who presented for admission following clinic visit and neuroimaging today.
#     *   History from primary neurologist, clinic visit and patient and father at bedside. Patient referred to Dr. Gu by Dr. Fazal in East Bay.
#     *   Confirms predominant symptoms since April of numbness in his right hand and urinary hesitancy/urgency. Additionally reporting right eye pain since time of clinic visit this morning.
#     *   MRI brain and spine obtained following clinic visit and multiple lesions noted on brain and spine suggestive of pediatric MS. Presents for admission for IVMP.
#     *   **Per clinic visit earlier today with Dr. Gu and confirmed with family at bedside:** Shakh is a 23 years old male, previously healthy who has been referred to neuroimmunology clinic for diagnosis of optic neuritis and abnormal brain MRI concerning for MS. He is referred by Dr Fazal-pediatric neurology in East Bay.
#     *   He is here with dad; patient himself is an excellent historian and provided the following information- I do not have CSF results nor clinic note- I do have MRI report from Jan 21 2024 (no actual images)- with father and his permission, I reached out to Dr Shane- Dr Fazal's colleague on service who can help assist with quick access to Shakh's chart.
#     *   **Today, Shakh tells me that around early Oct 2023:** he started to notice in right eye "neon bright color" fuzzy vision, and eye pain with movement and perhaps right side of his face in discomfort triggered by physical activities. Symptoms improved once he rested. By end of Oct 2023, he brought this up to parents and was brought to local eye doctor and recalled being told that"right eye being inflamed" and he recalled visual field deficits appreciated during exam.
#     *   **He was referred to UT ophthalmology Dr Derrek in Jan this year:** per report negative MOG and AQP4 [While waiting on this appt, he thought some improvement but not back to baseline entirely -"not completely normal"].
#     *   **When he saw UT ophthalmology clinic:** recommended brain and orbit and noted WM changes and MS was mentioned. He was treated with 5 days of IVMP and referred to see Dr Kosentka ped neurology.
#     *   **MRI report from Jan 21 2024:** "Diffuse T2 hyperintensity and decreased volume throughout the right optic nerve is similar to prior examination however assocaited abnormal enhancement seen on prior study has resoved, presumably secondary to interveal treatment. Left optic nerve is subtle but diffusely small in caliber without significant change from last exam. Several intracranial WM lesions, stable from last."
#     *   **He saw Dr Fazal in Feb 2024:** who obtained LP and had markers of MS and referred to MS clinic today. Below are information provided by Dr Shane. Per note recommended referral to our MS center.
#
# **Page 11**
# *   **Further evaluation and treatment.**
# *   **CSF Results:** WBC, 837 rbc, IgG Index 0.87 (elevated), +OCB
# *   **Prior to appt today May 14:** In April this year, started to have involvement of LEFT eye - again similar with "neon colors appearance", some eye discomfort; it happened several times during the day for a few days and has since resovied.
# *   **Symptoms since April:** intermittent numbness in his right hand (dominant hand)+ along with muscle twitch in his hands and shoulder like tics. Noticed a change with urinary hesitancy- taking a long time to empty his bladder and in addition urinary urgency. Not noticed weakness but noted intermittent drifting to right side, bumping in to things. Notes that at times when he laughs, bends his neck, does note electrical sensation.
# *   **Other details:** Academically doing very well, no difficulty. Sleeps well.
# *   **Family history:** parents and brothers are healthy.
# *   **Floor course (05/14 -):** Patient was admitted to the wards in a stable condition. Patient was initiated on high dose steroids for 5 days and tolerated well. MRI consistent with lesions in the brain and spinal cord consistent with atypical MS. ANA was positive as well as SSB so rheumatology was consulted but felt she did not have evidence of another systemic autoimmune disease. PT/OT evaluated his and he will follow outpatient. He was dc with Decadron and then steroid taper with Pepcid prophylaxis. He was arranged to have outpatient rituximab and Dr. Gu will follow his in clinic.
# *   **Physical Exam (1):**
#     *   **Temp:** 36.7 °C (98 °F) (Range: [36.5 °C (97.7 °F)-36.7 °C (98.1 °F)])
#     *   **Pulse:** 84 (Range: [81-99])
#     *   **Resp:** 16 (Range: [16-18])
#     *   **BP:** 126/63 (Range: (122-136)/(63-99))
#     *   **SpO2:** 98% (Range: [98%])
# *   **Physical Exam (2):** (Identical to Physical Exam 1, re-listed in document)
#     *   **Temp:** 36.7 °C (98 °F) (Range: [36.5 °C (97.7 °F)-36.7 °C (98.1 °F)])
#     *   **Pulse:** 84 (Range: [81-99])
#     *   **Resp:** 16 (Range: [16-18])
#     *   **BP:** 126/63 (Range: (122-136)/(63-99))
#     *   **SpO2:** 98% (Range: [98%])
# *   **General Appearance:** Well appearing; NAD (No Acute Distress)
# *   **CV:** -RRR (Regular Rate and Rhythm)
# *   **HIGHER INTEGRATIVE FUNCTIONS:**
#     *   **Attention & concentration:** Normal
#     *   **Orientation:** Oriented to person, place & time
#     *   **Memory:** Recent and remote memory Intact
#     *   **Language:** Normal
#     *   **Fund of Knowledge:** Normal
# *   **CRANIAL NERVES:**
#     *   **CN 2:** Visual fields full
#     *   **CN 2,3:** PERRL; rAPD (Pupils Equal, Round, Reactive to Light; relative Afferent Pupillary Defect)
#     *   **CN 3,4,6:** EOMI (Extraocular Movements Intact)
#     *   **CN 5:** Facial sensation intact
#     *   **CN 7:** Facial strength/movement intact bilaterally
#
# **Page 12**
# *   **CRANIAL NERVES (continued from previous page):**
#     *   **CN 8:** Hearing normal bilaterally
#     *   **CN 9,10:** Palate elevates symmetrically
#     *   **CN 11:** Normal shoulder shrug and head turn
#     *   **CN 12:** Tongue protrudes midline
# *   **MOTOR:**
#     *   **Muscle tone:** normal in upper and lower extremities
#     *   **Muscle strength:** 5/5 In upper and lower extremities; RLE 4+ proximally (Right Lower Extremity)
# *   **SENSATION:**
#     *   Intact to light touch in upper and lower extremities bilaterally
# *   **COORDINATION:**
#     *   Finger/nose intact bilaterally
# *   **GAIT:**
#     *   Normal gait
# *   **Immunizations/Injections Administered for This Admission:** No immunizations on file.
# *   **Allergies:** No Known Allergies
# *   **Diagnostic Studies:** Recent Results (from the past 24 hour(s))
#     *   **CBC w/ Differential**
#         *   **Collection Time:** 05/14/24 10:47 AM
#         *   **Result Name:** White Blood Cells, **Value:** 7.7, **Ref Range:** 3.4-10.2, **Unit:** x10(3)/mcL
#         *   **Result Name:** Red Blood Cells, **Value:** 4.63, **Ref Range:** 3.80-5.50, **Unit:** x10(6)/mcL
#         *   **Result Name:** Hemoglobin, **Value:** 13.0, **Ref Range:** 12.0-16.0, **Unit:** gm/dL
#         *   **Result Name:** Hematocrit, **Value:** 40, **Ref Range:** 35-49, **Unit:** %
#         *   **Result Name:** Mean Cell Volume, **Value:** 86, **Ref Range:** 76-96, **Unit:** fL
#         *   **Result Name:** Mean Cell Hemoglobin, **Value:** 28.1, **Ref Range:** 25.0-35.0, **Unit:** pg
#         *   **Result Name:** Mean Cell Hemoglobin Concentration, **Value:** 32.7, **Ref Range:** 32.0-37.0, **Unit:** gm/dL
#         *   **Result Name:** RDW SD, **Value:** 38.4, **Ref Range:** 37.4-52.4, **Unit:** fL
#         *   **Result Name:** RDW CV, **Value:** 12.3, **Ref Range:** 11.1-14.3, **Unit:** %
#         *   **Result Name:** Platelet, **Value:** 300, **Ref Range:** 150-400, **Unit:** x10(3)/mcL
#
# **Page 13**
# *   **Diagnostic Studies (continued):**
#     *   **Result Name:** Mean Platelet Volume, **Value:** 10.0, **Ref Range:** 9.3-12.8, **Unit:** fL
#     *   **Result Name:** Nucleated RBC, **Value:** 0, **Ref Range:** 0-0/100, **Unit:** WBC
#     *   **Result Name:** Nucleated RBC Abs, **Value:** 0.00, **Ref Range:** 0.00-0.00, **Unit:** x10(3)/mcL
#     *   **Result Name:** Auto Neutrophil Absolute, **Value:** 4.52, **Ref Range:** 1.80-7.70, **Unit:** x10(3)/mcL
# *   **CMP (Comprehensive Metabolic Panel)**
#     *   **Collection Time:** 05/14/24 10:47 AM
#     *   **Result Name:** Sodium Level, **Value:** 139, **Ref Range:** 138-145, **Unit:** mmol/L
#     *   **Result Name:** Potassium Level, **Value:** 3.8, **Ref Range:** 3.3-4.8, **Unit:** mmol/L
#     *   **Result Name:** Chloride Level, **Value:** 101, **Ref Range:** 98-107, **Unit:** mmol/L
#     *   **Result Name:** Carbon Dioxide, **Value:** 22, **Ref Range:** 17-28, **Unit:** mmol/L
#     *   **Result Name:** Anion Gap, **Value:** 16, **Unit:** mmol/L
#     *   **Result Name:** Glucose Level, **Value:** 95, **Ref Range:** 60-99, **Unit:** mg/dL
#     *   **Result Name:** Blood Urea Nitrogen, **Value:** 13, **Ref Range:** 7-18, **Unit:** mg/dL
#     *   **Result Name:** Creatinine Level, **Value:** 0.67, **Ref Range:** 0.50-0.90, **Unit:** mg/dL
#     *   **Result Name:** Calcium Level Total, **Value:** 9.9, **Ref Range:** 8.4-10.2, **Unit:** mg/dL
#     *   **Result Name:** Bilirubin Total, **Value:** 0.4, **Ref Range:** 0.0-0.7, **Unit:** mg/dL
#     *   **Result Name:** Albumin Level, **Value:** 4.7, **Ref Range:** 4.0-5.3, **Unit:** gm/dL
#     *   **Result Name:** Protein Total, **Value:** 8.4 (H), **Ref Range:** 6.3-7.8, **Unit:** gm/dL
#     *   **Result Name:** Alkaline Phosphatase, **Value:** 55, **Ref Range:** 50-117, **Unit:** unit/L
#     *   **Result Name:** Aspartate Aminotransferase, **Value:** 25, **Ref Range:** 21-34, **Unit:** unit/L
#     *   **Result Name:** Alanine Aminotransferase, **Value:** <6, **Ref Range:** 0-17, **Unit:** unit/L
# *   **Hepatitis B Pnl (Panel)**
#     *   **Collection Time:** 05/14/24 10:47 AM
#     *   **Result Name:** Hepatitis B Surface Antigen, **Value:** Negative, **Ref Range:** Negative
#     *   **Result Name:** Hep B Core Ab Total, **Value:** Negative, **Ref Range:** Negative
#     *   **Result Name:** Hepatitis B Surface Ab Unit, **Value:** 44.7 (H), **Ref Range:** <=10.0, **Unit:** mlU/mL
#     *   **Result Name:** Hep Bs Ab Interp, **Value:** Positive (A), **Ref Range:** Negative
# *   **IgG (Immunoglobulin G)**
#     *   **Collection Time:** 05/14/24 10:47 AM
#     *   **Result Name:** IgG Quantitative, **Value:** 1,355 (H), **Ref Range:** 600-1,310, **Unit:** mg/dL
#
# **Page 14**
# *   **IgA (Immunoglobulin A)**
#     *   **Collection Time:** 05/14/24 10:47 AM
#     *   **Result Name:** IgA Quantitative, **Value:** 279, **Ref Range:** 40-290, **Unit:** mg/dL
# *   **Auto Diff (Automated Differential)**
#     *   **Collection Time:** 05/14/24 10:47 AM
#     *   **Result Name:** Neutrophils, **Value:** 58.3, **Unit:** %
#     *   **Result Name:** Absolute Neutrophils, **Value:** 4.52, **Ref Range:** 1.80-7.70, **Unit:** x10(3)/mcL
#     *   **Result Name:** Lymphs, **Value:** 33.6, **Unit:** %
#     *   **Result Name:** Absolute Lymphocytes, **Value:** 2.60, **Ref Range:** 1.70-4.50, **Unit:** x10(3)/mcL
#     *   **Result Name:** Monocytes, **Value:** 6.5, **Unit:** %
#     *   **Result Name:** Absolute Monocytes, **Value:** 0.50, **Ref Range:** 0.20-1.00, **Unit:** x10(3)/mcL
#     *   **Result Name:** Eosinophils, **Value:** 0.5, **Unit:** %
#     *   **Result Name:** Absolute Eosinophils, **Value:** 0.04, **Ref Range:** 0.00-0.50, **Unit:** x10(3)/mcL
#     *   **Result Name:** Basophils, **Value:** 0.8, **Unit:** %
#     *   **Result Name:** Absolute Basophils, **Value:** 0.06, **Ref Range:** 0.01-0.08, **Unit:** x10(3)/mcL
#     *   **Result Name:** Imm Gran Automated, **Value:** 0.3, **Unit:** %
#     *   **Result Name:** Absolute Imm Gran Automated, **Value:** 0.02, **Ref Range:** 0.00-0.03, **Unit:** x10(3)/mcL
# *   **Consultations Obtained:**
#     *   **Orders Placed This Encounter:**
#         *   Inpatient Consult to Pediatric Ophthalmology
#         *   Inpatient Consult to Pediatric Rheumatology
#         *   Inpatient consult to Case Management
# *   **Condition at Discharge:** Stable
# *   **Disposition:** Home or Self Care
# *   **Patient Instructions:**
#     *   **Discharge Medications:**
#         *   **New Medications:**
#             *   **Medication Name:** dexamethasone 4 mg/mL CONCENTRATED solution
#                 *   **Sig:** Take 45 mL (180 mg total) by mouth daily for 1 dose. See comment.
#             *   **Medication Name:** famotidine 40 mg tablet
#                 *   **Commonly known as:** PEPCID
#                 *   **Sig:** Take 1 tablet (40 mg total) by mouth daily.
#
# **Page 15**
# *   **Discharge Medications (continued):**
#     *   **Medication Name:** predniSONE 20 mg tablet
#         *   **Commonly known as:** DELTASONE
#         *   **Start taking on:** May 16, 2024
#         *   **Sig:** Take 3 tablets (60 mg total) by mouth daily for 7 days, THEN 2 tablets (40 mg total) daily for 7 days, THEN 1 tablet (20 mg total) daily for 7 days, THEN 0.5 tablets (10 mg total) daily for 7 days. Then stop.
# *   **Activity Instructions:**
#     *   **Discharge activity - Normal Activity:** Some medications such as for example pain medications and sleeping or anti-anxiety agents may affect your ability to operate heavy machinery including driving. Please always carefully read the labels on the medications that you take. If you have experienced confusion, seizures, lightheadedness or blackouts then it may not be safe or even legal for you to operate heavy machinery (including driving). Please act in the interest of your own safety and that of others. Speak to a physician If you are not sure whether it is safe or legal for you to drive.
#     *   **Care Instructions:** You should engage in exercise as tolerated to improve your health. You may go to the website of the American Heart Association for additional information and tips on how to exercise right (www.americanheart.org).
# *   **Scheduled Appointments:**
#     *   **Date/Time:** May 22, 2024 10:30 AM
#     *   **Appointment Details:** Peds Infusion (Leantaas) with PEDS INF UMBRELLA, PEDS 241+ MIN INFUSION
#     *   **Department:** Children's Hematology - Oncology (Peds DOT 6)
#     *   **Address:** 2211 Broad Way, Tower 4th FL, Suite 6102, Nashville TN 37232
#     *   **Phone:** 615-936-1762
#
# ---
#
# **2. Structured JSON Output**
#
# ```json
# {
#   "PATIENT_DEMOGRAPHICS": {
#     "full_name": "Shakh Abdulla",
#     "dob": "2001-04-01",
#     "gender": "male",
#     "address": {
#       "street": "425 Sherman Ave APT D",
#       "city": "Nashville",
#       "state": "TN",
#       "zip_code": "37923"
#     },
#     "phone_numbers": {
#       "home": "865-395-3958",
#       "mobile": "865-395-0481",
#       "preferred": "mobile"
#     },
#     "patient_id_numbers": {
#       "mrn": "041152153",
#       "care_everywhere_id": "VDJ-7KR2-4847-LGF8",
#       "subscriber_id": "LAJM14345116",
#       "ssn": "xxx-xx-8143"
#     },
#     "emergency_contacts": [
#       {
#         "name": "Sina, Amin",
#         "relationship": "Father",
#         "legal_guardian": true,
#         "phone_home": null,
#         "phone_work": null
#       },
#       {
#         "name": "Mohammedreza, Mustala",
#         "relationship": "Mother",
#         "legal_guardian": true,
#         "phone_home": null,
#         "phone_work": null
#       }
#     ]
#   },
#   "INSURANCE_INFORMATION": {
#     "primary_insurance": {
#       "company_name": "BC TENNCARE",
#       "plan_details": "TC BLUE CARE NO COPAY",
#       "member_id": "LAJM14345116",
#       "group_number": "435000",
#       "policy_number": null,
#       "group_name": "TENNCARE/BLUECARE",
#       "subscriber_information": {
#         "name": "ABDULLA, SHAKH",
#         "relationship_to_patient": "Self",
#         "address": "8327 BROADWAY LN APT D, KNOXVILLE, TN 37923",
#         "dob": "2001-04-01"
#       },
#       "coverage_details": null,
#       "effective_dates": null
#     },
#     "secondary_insurance": {
#       "company_name": null,
#       "plan_details": null,
#       "member_id": null,
#       "group_number": null,
#       "policy_number": null,
#       "subscriber_information": {
#         "name": null,
#         "relationship_to_patient": null,
#         "address": null,
#         "dob": null
#       },
#       "coverage_details": null,
#       "effective_dates": null
#     }
#   },
#   "CLINICAL_INFORMATION": {
#     "diagnoses": [
#       {
#         "type": "Primary",
#         "description": "Multiple sclerosis in pediatric patient",
#         "icd_code": "G35",
#         "status": "active"
#       },
#       {
#         "type": "Principal Problem",
#         "description": "Abnormal MRI",
#         "icd_code": null,
#         "status": "active"
#       }
#     ],
#     "current_medications": [
#       {
#         "name": "Rituximab Or Biosimilar",
#         "dosage": "Days 1, 15 Load Then Once",
#         "frequency": "Every 24 Weeks",
#         "route": null,
#         "prn_status": false,
#         "instructions": null
#       },
#       {
#         "name": "heparin, porcine (PF)",
#         "dosage": "100 unit/mL syringe 5 mL",
#         "frequency": "PRN",
#         "route": "intraVENOUS",
#         "prn_status": true,
#         "instructions": "5 mL, as needed, For flushing Ports/ PICC lines/ Central Lines IF NEEDED, Starting when released, Until Discontinued."
#       },
#       {
#         "name": "acetaminophen (TYLENOL)",
#         "dosage": "650 mg",
#         "frequency": "Once",
#         "route": "oral",
#         "prn_status": false,
#         "instructions": "Starting when released."
#       },
#       {
#         "name": "diphenhydrAMINE (BENADRYL)",
#         "dosage": "50 mg",
#         "frequency": "Once",
#         "route": "intraVENOUS",
#         "prn_status": false,
#         "instructions": "Administer 30 minutes before starting infusion."
#       },
#       {
#         "name": "methylPREDNISolone sod succinate (SOLU-Medrol)",
#         "dosage": "125 mg in NS 6.2 mL (20 mg/mL)",
#         "frequency": "Once",
#         "route": "intraVENOUS",
#         "prn_status": false,
#         "instructions": "Administer 30 minutes before starting infusion."
#       },
#       {
#         "name": "riTUXimab-abbs (TRUXIMA)",
#         "dosage": "694 mg (rounded from 693.75 mg = 375 mg/m2 x 1.85 m2 - BSA might be out of date)",
#         "frequency": "Every 2 weeks",
#         "route": "IVPB (intraVENOUS)",
#         "prn_status": false,
#         "instructions": "Starting 30 minutes after treatment start time. Initial Dose."
#       },
#       {
#         "name": "riTUXimab-abbs (TRUXIMA)",
#         "dosage": "694 mg (rounded from 693.75 mg = 375 mg/m2 x 1.85 m2 - BSA might be out of date)",
#         "frequency": "Every 24 weeks",
#         "route": "IVPB (intraVENOUS)",
#         "prn_status": false,
#         "instructions": "Starting when released. Maintenance Dose. Defer until Mon 11/4/2024."
#       },
#       {
#         "name": "diphenhydrAMINE (BENADRYL)",
#         "dosage": "25 mg",
#         "frequency": "PRN",
#         "route": "intraVENOUS",
#         "prn_status": true,
#         "instructions": "As needed, for chills, Starting when released, for 2 doses."
#       },
#       {
#         "name": "meperidine (DEMEROL)",
#         "dosage": "25 mg",
#         "frequency": "PRN",
#         "route": "intraVENOUS",
#         "prn_status": true,
#         "instructions": "As needed, for rigors, Starting when released, for 2 doses."
#       },
#       {
#         "name": "ondansetron (ZOFRAN)",
#         "dosage": "4 mg",
#         "frequency": "PRN",
#         "route": "intraVENOUS",
#         "prn_status": true,
#         "instructions": "As needed, for nausea, vomiting. Starting when released, for 2 doses. Doses up to 4 mg may be administered undiluted. Inject over at least 30 seconds, but preferably over 2-5 minutes."
#       },
#       {
#         "name": "dexamethasone",
#         "dosage": "45 mL (180 mg total)",
#         "frequency": "daily for 1 dose",
#         "route": "by mouth",
#         "prn_status": false,
#         "instructions": "Concentrated solution. See comment."
#       },
#       {
#         "name": "famotidine (PEPCID)",
#         "dosage": "40 mg",
#         "frequency": "daily",
#         "route": "by mouth",
#         "prn_status": false,
#         "instructions": "Take 1 tablet (40 mg total)."
#       },
#       {
#         "name": "predniSONE (DELTASONE)",
#         "dosage": "Tapering schedule: 60mg for 7 days, 40mg for 7 days, 20mg for 7 days, 10mg for 7 days.",
#         "frequency": "daily",
#         "route": "by mouth",
#         "prn_status": false,
#         "instructions": "Start taking on: May 16, 2024. Then stop."
#       }
#     ],
#     "allergies": [
#       {
#         "allergen": "No Known Allergies",
#         "reaction": null
#       }
#     ],
#     "vital_signs": [
#       {
#         "date": "2024-05-14",
#         "time": "10:47 AM",
#         "temperature_c": 36.7,
#         "temperature_f": 98.0,
#         "temperature_range_c": "36.5-36.7",
#         "temperature_range_f": "97.7-98.1",
#         "pulse_bpm": 84,
#         "pulse_range_bpm": "81-99",
#         "respiration_breaths_per_min": 16,
#         "respiration_range_breaths_per_min": "16-18",
#         "blood_pressure_systolic": 126,
#         "blood_pressure_diastolic": 63,
#         "blood_pressure_range": "122-136/63-99",
#         "spo2_percent": 98,
#         "spo2_range_percent": "98"
#       }
#     ],
#     "lab_results": [
#       {
#         "test_name": "White Blood Cells",
#         "value": 7.7,
#         "unit": "x10(3)/mcL",
#         "reference_range": "3.4-10.2",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "CBC w/ Differential"
#       },
#       {
#         "test_name": "Red Blood Cells",
#         "value": 4.63,
#         "unit": "x10(6)/mcL",
#         "reference_range": "3.80-5.50",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "CBC w/ Differential"
#       },
#       {
#         "test_name": "Hemoglobin",
#         "value": 13.0,
#         "unit": "gm/dL",
#         "reference_range": "12.0-16.0",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "CBC w/ Differential"
#       },
#       {
#         "test_name": "Hematocrit",
#         "value": 40,
#         "unit": "%",
#         "reference_range": "35-49",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "CBC w/ Differential"
#       },
#       {
#         "test_name": "Mean Cell Volume",
#         "value": 86,
#         "unit": "fL",
#         "reference_range": "76-96",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "CBC w/ Differential"
#       },
#       {
#         "test_name": "Mean Cell Hemoglobin",
#         "value": 28.1,
#         "unit": "pg",
#         "reference_range": "25.0-35.0",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "CBC w/ Differential"
#       },
#       {
#         "test_name": "Mean Cell Hemoglobin Concentration",
#         "value": 32.7,
#         "unit": "gm/dL",
#         "reference_range": "32.0-37.0",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "CBC w/ Differential"
#       },
#       {
#         "test_name": "RDW SD",
#         "value": 38.4,
#         "unit": "fL",
#         "reference_range": "37.4-52.4",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "CBC w/ Differential"
#       },
#       {
#         "test_name": "RDW CV",
#         "value": 12.3,
#         "unit": "%",
#         "reference_range": "11.1-14.3",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "CBC w/ Differential"
#       },
#       {
#         "test_name": "Platelet",
#         "value": 300,
#         "unit": "x10(3)/mcL",
#         "reference_range": "150-400",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "CBC w/ Differential"
#       },
#       {
#         "test_name": "Mean Platelet Volume",
#         "value": 10.0,
#         "unit": "fL",
#         "reference_range": "9.3-12.8",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": null
#       },
#       {
#         "test_name": "Nucleated RBC",
#         "value": 0,
#         "unit": "WBC",
#         "reference_range": "0-0/100",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": null
#       },
#       {
#         "test_name": "Nucleated RBC Abs",
#         "value": 0.00,
#         "unit": "x10(3)/mcL",
#         "reference_range": "0.00-0.00",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": null
#       },
#       {
#         "test_name": "Auto Neutrophil Absolute",
#         "value": 4.52,
#         "unit": "x10(3)/mcL",
#         "reference_range": "1.80-7.70",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": null
#       },
#       {
#         "test_name": "Sodium Level",
#         "value": 139,
#         "unit": "mmol/L",
#         "reference_range": "138-145",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "CMP"
#       },
#       {
#         "test_name": "Potassium Level",
#         "value": 3.8,
#         "unit": "mmol/L",
#         "reference_range": "3.3-4.8",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "CMP"
#       },
#       {
#         "test_name": "Chloride Level",
#         "value": 101,
#         "unit": "mmol/L",
#         "reference_range": "98-107",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "CMP"
#       },
#       {
#         "test_name": "Carbon Dioxide",
#         "value": 22,
#         "unit": "mmol/L",
#         "reference_range": "17-28",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "CMP"
#       },
#       {
#         "test_name": "Anion Gap",
#         "value": 16,
#         "unit": "mmol/L",
#         "reference_range": null,
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "CMP"
#       },
#       {
#         "test_name": "Glucose Level",
#         "value": 95,
#         "unit": "mg/dL",
#         "reference_range": "60-99",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "CMP"
#       },
#       {
#         "test_name": "Blood Urea Nitrogen",
#         "value": 13,
#         "unit": "mg/dL",
#         "reference_range": "7-18",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "CMP"
#       },
#       {
#         "test_name": "Creatinine Level",
#         "value": 0.67,
#         "unit": "mg/dL",
#         "reference_range": "0.50-0.90",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "CMP"
#       },
#       {
#         "test_name": "Calcium Level Total",
#         "value": 9.9,
#         "unit": "mg/dL",
#         "reference_range": "8.4-10.2",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "CMP"
#       },
#       {
#         "test_name": "Bilirubin Total",
#         "value": 0.4,
#         "unit": "mg/dL",
#         "reference_range": "0.0-0.7",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "CMP"
#       },
#       {
#         "test_name": "Albumin Level",
#         "value": 4.7,
#         "unit": "gm/dL",
#         "reference_range": "4.0-5.3",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "CMP"
#       },
#       {
#         "test_name": "Protein Total",
#         "value": 8.4,
#         "unit": "gm/dL",
#         "reference_range": "6.3-7.8",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": "H",
#         "panel": "CMP"
#       },
#       {
#         "test_name": "Alkaline Phosphatase",
#         "value": 55,
#         "unit": "unit/L",
#         "reference_range": "50-117",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "CMP"
#       },
#       {
#         "test_name": "Aspartate Aminotransferase",
#         "value": 25,
#         "unit": "unit/L",
#         "reference_range": "21-34",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "CMP"
#       },
#       {
#         "test_name": "Alanine Aminotransferase",
#         "value": "<6",
#         "unit": "unit/L",
#         "reference_range": "0-17",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "CMP"
#       },
#       {
#         "test_name": "Hepatitis B Surface Antigen",
#         "value": "Negative",
#         "unit": null,
#         "reference_range": "Negative",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "Hepatitis B Pnl"
#       },
#       {
#         "test_name": "Hep B Core Ab Total",
#         "value": "Negative",
#         "unit": null,
#         "reference_range": "Negative",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "Hepatitis B Pnl"
#       },
#       {
#         "test_name": "Hepatitis B Surface Ab Unit",
#         "value": 44.7,
#         "unit": "mlU/mL",
#         "reference_range": "<=10.0",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": "H",
#         "panel": "Hepatitis B Pnl"
#       },
#       {
#         "test_name": "Hep Bs Ab Interp",
#         "value": "Positive (A)",
#         "unit": null,
#         "reference_range": "Negative",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "Hepatitis B Pnl"
#       },
#       {
#         "test_name": "IgG Quantitative",
#         "value": 1355,
#         "unit": "mg/dL",
#         "reference_range": "600-1310",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": "H",
#         "panel": "IgG"
#       },
#       {
#         "test_name": "IgA Quantitative",
#         "value": 279,
#         "unit": "mg/dL",
#         "reference_range": "40-290",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "IgA"
#       },
#       {
#         "test_name": "Neutrophils",
#         "value": 58.3,
#         "unit": "%",
# ...
#       },
#       {
#         "test_name": "Absolute Neutrophils",
#         "value": 4.52,
#         "unit": "x10(3)/mcL",
#         "reference_range": "1.80-7.70",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "Auto Diff"
#       },
#       {
#         "test_name": "Lymphs",
#         "value": 33.6,
#         "unit": "%",
#         "reference_range": null,
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "Auto Diff"
#       },
#       {
#         "test_name": "Absolute Lymphocytes",
#         "value": 2.60,
#         "unit": "x10(3)/mcL",
#         "reference_range": "1.70-4.50",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "Auto Diff"
#       },
#       {
#         "test_name": "Monocytes",
#         "value": 6.5,
#         "unit": "%",
#         "reference_range": null,
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "Auto Diff"
#       },
#       {
#         "test_name": "Absolute Monocytes",
#         "value": 0.50,
#         "unit": "x10(3)/mcL",
#         "reference_range": "0.20-1.00",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "Auto Diff"
#       },
#       {
#         "test_name": "Eosinophils",
#         "value": 0.5,
#         "unit": "%",
#         "reference_range": null,
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "Auto Diff"
#       },
#       {
#         "test_name": "Absolute Eosinophils",
#         "value": 0.04,
#         "unit": "x10(3)/mcL",
#         "reference_range": "0.00-0.50",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "Auto Diff"
#       },
#       {
#         "test_name": "Basophils",
#         "value": 0.8,
#         "unit": "%",
#         "reference_range": null,
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "Auto Diff"
#       },
#       {
#         "test_name": "Absolute Basophils",
#         "value": 0.06,
#         "unit": "x10(3)/mcL",
#         "reference_range": "0.01-0.08",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "Auto Diff"
#       },
#       {
#         "test_name": "Imm Gran Automated",
#         "value": 0.3,
#         "unit": "%",
#         "reference_range": null,
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "Auto Diff"
#       },
#       {
#         "test_name": "Absolute Imm Gran Automated",
#         "value": 0.02,
#         "unit": "x10(3)/mcL",
#         "reference_range": "0.00-0.03",
#         "collection_time": "05/14/24 10:47 AM",
#         "flag": null,
#         "panel": "Auto Diff"
#       },
#       {
#         "test_name": "CSF WBC",
#         "value": null,
#         "unit": "WBC",
#         "reference_range": null,
#         "collection_time": null,
#         "flag": null,
#         "notes": "837 rbc"
#       },
#       {
#         "test_name": "CSF IgG Index",
#         "value": 0.87,
#         "unit": null,
#         "reference_range": null,
#         "collection_time": null,
#         "flag": "elevated",
#         "notes": "+OCB"
#       },
#       {
#         "test_name": "ANA",
#         "value": "positive",
#         "unit": null,
#         "reference_range": null,
#         "collection_time": null,
#         "flag": null,
#         "notes": null
#       },
#       {
#         "test_name": "SSB",
#         "value": "positive",
#         "unit": null,
#         "reference_range": null,
#         "collection_time": null,
#         "flag": null,
#         "notes": null
#       }
#     ],
#     "previous_treatments": [
#       {
#         "type": "High dose steroids (IVMP)",
#         "duration": "4 days",
#         "dosage": "1g/dose",
#         "outcome": "tolerated well, discharge home with oral decadron taper. Associated abnormal enhancement on prior study has resolved.",
#         "notes": "Treated for active demyelinating lesion. Implied for acute flares."
#       }
#     ],
#     "medical_history": {
#       "history_of_illness": [
#         "Optic neuritis",
#         "Abnormal MRI brain concerning for MS",
#         "Established care with VCH neurology (Pediatric Neurology)",
#         "Multiple lesions on brain and spine consistent with atypical pediatric MS",
#         "Predominant symptoms since April: numbness in right hand, urinary hesitancy/urgency, right eye pain",
#         "Early Oct 2023: right eye 'neon bright color' fuzzy vision, eye pain with movement, right side of face discomfort (improved with rest)",
#         "Recalled 'right eye being inflamed' and visual field deficits during exam (Oct 2023)",
#         "Intermittent numbness in right dominant hand since April",
#         "Muscle twitch in hands and shoulder like tics since April",
#         "Urinary hesitancy/urgency, taking long time to empty bladder since April",
#         "Intermittent drifting to right side, bumping into things (no weakness noticed)",
#         "Electrical sensation when laughing/bending neck",
#         "Academically doing very well",
#         "Sleeps well"
#       ],
#       "family_history": "Parents and brothers are healthy"
#     },
#     "comorbidities": [
#       "ANA positive",
#       "SSB positive"
#     ]
#   },
#   "PROVIDER_INFORMATION": {
#     "referring_physician": {
#       "name": "Dr. Fazal",
#       "specialty": "Pediatric Neurology",
#       "contact_info": null,
#       "practice_name": "East Bay"
#     },
#     "treating_physicians": [
#       {
#         "name": "Gu, Hao H, MD",
#         "specialty": "Pediatric Neurology",
#         "npi": "1154611523",
#         "practice_name": "Better Life Multiple Sclerosis Center",
#         "practice_address": "3320 Montgomery Dr, Nashville, TN 37361",
#         "contact_info": {
#           "phone": "614-936-0065"
#         }
#       },
#       {
#         "name": "Erfan Rostami, BSN, RN",
#         "specialty": "Nurse",
#         "npi": null,
#         "practice_name": "Better Life Multiple Sclerosis Center",
#         "practice_address": "3320 Montgomery Dr, Nashville, TN 37361",
#         "contact_info": {
#           "phone": "615-343-1176",
#           "fax": "615-343-1219"
#         }
#       },
#       {
#         "name": "Harry, Tom, MD",
#         "specialty": null,
#         "npi": null,
#         "practice_name": null,
#         "practice_address": null,
#         "contact_info": null,
#         "role": "Last Attending"
#       },
#       {
#         "name": "Kaine, Adam Jason, MD",
#         "specialty": "Pediatric Neurology",
#         "npi": null,
#         "practice_name": null,
#         "practice_address": null,
#         "contact_info": null,
#         "role": "Resident Physician"
#       },
#       {
#         "name": "James David, PNP",
#         "specialty": "Primary Care Provider",
#         "npi": null,
#         "practice_name": null,
#         "practice_address": null,
#         "contact_info": {
#           "phone": "865-839-7458"
#         }
#       },
#       {
#         "name": "Dr Shane",
#         "specialty": "Dr Fazal's colleague",
#         "npi": null,
#         "practice_name": null,
#         "practice_address": null,
#         "contact_info": null
#       },
#       {
#         "name": "Dr Derrek",
#         "specialty": "UT ophthalmology",
#         "npi": null,
#         "practice_name": null,
#         "practice_address": null,
#         "contact_info": null
#       },
#       {
#         "name": "Dr Kosentka",
#         "specialty": "ped neurology",
#         "npi": null,
#         "practice_name": null,
#         "practice_address": null,
#         "contact_info": null
#       }
#     ],
#     "practice_name": "Better Life Multiple Sclerosis Center",
#     "practice_address": "3320 Montgomery Dr, Nashville, TN 37361",
#     "facility_details": [
#       {
#         "name": "Monroe Carell Jr. Children's Hospital",
#         "address": null,
#         "phone": null,
#         "role": "Admission/Discharge Facility"
#       },
#       {
#         "name": "Golden Gate Infusion Center",
#         "address": null,
#         "phone": "614-895-7655",
#         "role": "Referral Target Infusion Center"
#       },
#       {
#         "name": "Children's Hematology - Oncology (Peds DOT 6)",
#         "address": "2211 Broad Way, Tower 4th FL, Suite 6102, Nashville TN 37232",
#         "phone": "615-936-1762",
#         "role": "Scheduled Infusion Facility"
#       },
#       {
#         "name": "Local infusion facility in Knoxville",
#         "address": null,
#         "phone": null,
#         "role": "Future Infusion Facility consideration"
#       }
#     ]
#   },
#   "TREATMENT_DETAILS": {
#     "requested_medication_procedure": [
#       {
#         "name": "Rituximab (Truxima) IVPB Infusion",
#         "type": "Medication",
#         "dosage": "694 mg (initial and maintenance)",
#         "frequency": "Initial: Every 2 weeks (2 doses); Maintenance: Every 24 weeks",
#         "duration": "Initial: 2 doses remaining; Maintenance: ongoing (defer until Mon 11/4/2024)",
#         "route": "intraVENOUS",
#         "administration_notes": "Initial dose: Starting 30 minutes after treatment start time. Infusion rate: 1st infusion initiate at 50mg/hr, increase by 50mg/hr every 30 mins, Max Rate 400mg/hr. Subsequent infusions: initiate at 100mg/hr, increase by 100mg/hr every 30 mins, Max Rate 400mg/hr.",
#         "medical_necessity_justification": "Treatment for Multiple Sclerosis in pediatric patient with active demyelinating lesion, history of optic neuritis, and abnormal MRI findings.",
#         "previous_treatment_failures": "Patient had IVMP for acute episodes, not explicitly stated as failure for long-term control, rather an ongoing need for disease modification.",
#         "clinical_criteria_met_for_approval": "Diagnosis of atypical pediatric MS confirmed by clinical presentation, MRI findings, and CSF results. Physician's order for Rituximab indicates meeting clinical criteria for disease modifying therapy."
#       }
#     ],
#     "supporting_treatments": [
#       {
#         "name": "IV access (PIV, PORT)",
#         "type": "Procedure",
#         "frequency": "Every visit",
#         "instructions": "Start NS 0.9% @ KVO. Until discontinued Starting when released Until Specified."
#       },
#       {
#         "name": "Monitor for hypersensitivity reaction",
#         "type": "Procedure",
#         "frequency": "Every visit",
#         "instructions": "Once Starting when released for 1 occurrence. If allergic reaction or infusion related reaction occurs, initiate adult hypersensitivity reaction protocol or pediatric guideline and CALL MD for additional orders."
#       },
#       {
#         "name": "Nursing Communication (Antihypertensive meds)",
#         "type": "Communication",
#         "frequency": "Every visit",
#         "instructions": "Ensure patient has not taken antihypertensive medications in the 12 hours prior to infusion. Until discontinued Starting when released Until Specified."
#       },
#       {
#         "name": "Nursing Communication (Hypotension)",
#         "type": "Communication",
#         "frequency": "Every visit",
#         "instructions": "For Hypotension, place patient in Trendelenberg position, support with NS, and call MD. Until discontinued Starting when released Until Specified."
#       },
#       {
#         "name": "Vital Signs Monitoring",
#         "type": "Procedure",
#         "frequency": "Every visit",
#         "instructions": "Obtain VS prior to start therapy, Q30 minutes with each dose increase and at the end of treatment. As needed Starting when released Until Specified."
#       }
#     ]
#   },
#   "SUPPORTING_EVIDENCE": {
#     "lab_results_supporting_diagnosis": [
#       {
#         "test": "CSF Analysis",
#         "results": "WBC, 837 rbc, IgG Index 0.87 (elevated), +OCB",
#         "implication": "Supports inflammatory process and intrathecal IgG synthesis, characteristic of MS."
#       },
#       {
#         "test": "IgG Quantitative",
#         "results": "1,355 mg/dL (High)",
#         "implication": "Elevated IgG levels (systemic) may be associated with autoimmune conditions."
#       },
#       {
#         "test": "ANA (Antinuclear Antibodies)",
#         "results": "Positive",
#         "implication": "Suggests autoimmune activity, although rheumatology consult did not find evidence of systemic autoimmune disease other than MS."
#       },
#       {
#         "test": "SSB (Sjögren's Syndrome B antibody)",
#         "results": "Positive",
#         "implication": "Suggests autoimmune activity, although rheumatology consult did not find evidence of systemic autoimmune disease other than MS."
#       },
#       {
#         "test": "MOG and AQP4 antibodies",
#         "results": "Negative",
#         "implication": "Helps differentiate MS from other demyelinating diseases like MOGAD or NMO."
#       }
#     ],
#     "imaging_studies_and_results": [
#       {
#         "study": "MRI brain and spine",
#         "date": "2024-01-21",
#         "results": "Multiple lesions consistent with atypical pediatric MS. Diffuse T2 hyperintensity and decreased volume throughout the right optic nerve similar to prior exam. Associated abnormal enhancement seen on prior study resolved. Left optic nerve subtle but diffusely small in caliber without significant change. Several intracranial WM lesions, stable.",
#         "implication": "Confirms demyelinating lesions in CNS, central to MS diagnosis."
#       }
#     ],
#     "functional_assessments": [
#       {
#         "assessment_type": "Neurological Exam",
#         "findings": {
#           "general_appearance": "Well appearing; NAD",
#           "cardiovascular": "RRR",
#           "higher_integrative_functions": {
#             "attention_concentration": "Normal",
#             "orientation": "Oriented to person, place & time",
#             "memory": "Recent and remote memory intact",
#             "language": "Normal",
#             "fund_of_knowledge": "Normal"
#           },
#           "cranial_nerves": [
#             "CN 2: Visual fields full, PERRL, rAPD",
#             "CN 3,4,6: EOMI",
#             "CN 5: Facial sensation intact",
#             "CN 7: Facial strength/movement intact bilaterally",
#             "CN 8: Hearing normal bilaterally",
#             "CN 9,10: Palate elevates symmetrically",
#             "CN 11: Normal shoulder shrug and head turn",
#             "CN 12: Tongue protrudes midline"
#           ],
#           "motor": {
#             "muscle_tone": "normal in upper and lower extremities",
#             "muscle_strength": "5/5 in upper and lower extremities; RLE 4+ proximally"
#           },
#           "sensation": "Intact to light touch in upper and lower extremities bilaterally",
#           "coordination": "Finger/nose intact bilaterally",
#           "gait": "Normal gait"
#         }
#       },
#       {
#         "assessment_type": "Physical Therapy (PT) / Occupational Therapy (OT)",
#         "findings": "Evaluated in-patient, will follow outpatient.",
#         "date": null
#       }
#     ],
#     "specialist_consultations": [
#       {
#         "specialist": "Pediatric Ophthalmology",
#         "date": null,
#         "purpose": "Consult for optic neuritis, follow-up planned."
#       },
#       {
#         "specialist": "Pediatric Rheumatology",
#         "date": null,
#         "purpose": "Consulted due to positive ANA and SSB, but no evidence of other systemic autoimmune disease found."
#       },
#       {
#         "specialist": "Case Management",
#         "date": null,
#         "purpose": "Consult for care coordination, especially regarding infusion facility setup."
#       },
#       {
#         "specialist": "Dr. Fazal (Pediatric Neurology)",
#         "date": "Feb 2024",
#         "purpose": "Referred patient to MS clinic, obtained LP, noted markers of MS."
#       },
#       {
#         "specialist": "Dr. Derrek (UT Ophthalmology)",
#         "date": "Jan 2024",
#         "purpose": "Evaluated patient for visual symptoms, negative MOG/AQP4, recommended brain/orbit MRI."
#       },
#       {
#         "specialist": "Dr. Kosentka (Pediatric Neurology)",
#         "date": null,
#         "purpose": "Patient referred to Dr. Kosentka after initial IVMP treatment."
#       }
#     ],
#     "treatment_response_documentation": [
#       {
#         "treatment": "High dose IVMP",
#         "response": "Tolerated well. Associated abnormal enhancement on prior MRI resolved. Symptoms improved with rest (earlier onset of symptoms)."
#       }
#     ]
#   }
# }
# ```

# %% [markdown]
# ## PA widget input info extraction

# %%
import fitz

# Code from Headstarter tutorial to extract fields from PDF
def extracting_fields_from_pdf(pdf_file):
    """
    Extracts form fields from a PDF file and returns them as a list of dictionaries.
    Each dictionary contains field name, type, value, page number, and other metadata.
    """
    if not pathlib.Path(pdf_file).exists():
        raise FileNotFoundError(f"The file {pdf_file} does not exist.")
    doc = fitz.open(pdf_file)
    fields = []
    for page_num, page in enumerate(doc, start = 1):
        for w in page.widgets() or []:
            field = {
                "name": w.field_name,
                "type": "checkbox" if w.field_type == fitz.PDF_WIDGET_TYPE_CHECKBOX else "text",
                "value": w.field_value,
                "page": page_num,
                "field_type": w.field_type,
                "field_type_string": w.field_type_string,
                "field_label": w.field_label,
            }
            print(field)
            fields.append(field)

    field_by_page = {}
    for field in fields:
        page_num = field["page"]
        if page_num not in field_by_page:
            field_by_page[page_num] = []
    
    return field_by_page

pa_fields = extracting_fields_from_pdf("Input Data/Adbulla/PA.pdf")
# Out:
# {'name': 'CB1', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Start of treatment'}
# {'name': 'T2', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Start date: (MM)'}
# {'name': 'T3', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Start date: (DD)'}
# {'name': 'T4', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Start date: (YYYY)'}
# {'name': 'CB5', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Continuation of therapy'}
# {'name': 'T6', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date of last treatment: (MM)'}
# {'name': 'T7', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date of last treatment: (DD)'}
# {'name': 'T8', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date of last treatment: (YYYY)'}
# {'name': 'T9', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Precertification Requested By:'}
# {'name': 'T10', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Phone:'}
# {'name': 'T11', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Fax:'}
# {'name': 'T12', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient First Name'}
# {'name': 'T13', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient Last Name'}
# {'name': 'T14', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient DOB (MM/DD/YYYY)'}
# {'name': 'T15', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Address:'}
# {'name': 'T16', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'City:'}
# {'name': 'T17', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'State:'}
# {'name': 'T18', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'ZIP:'}
# {'name': 'T19', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient Phone'}
# {'name': 'T20', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Work Phone:'}
# {'name': 'T21', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Cell Phone:'}
# {'name': 'T22', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'E-mail:'}
# {'name': 'T24', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'lbs'}
# {'name': 'T25', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'kgs'}
# {'name': 'T26', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'inches'}
# {'name': 'T27', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'cms'}
# {'name': 'T23', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Allergies:'}
# {'name': 'T28', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Member ID #:'}
# {'name': 'T29', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Group #:'}
# {'name': 'T30', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Insured:'}
# {'name': 'CB31', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB32', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'T33', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'If yes, provide ID#:'}
# {'name': 'T34', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Carrier Name:'}
# {'name': 'T35', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Insured:'}
# {'name': 'T42', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'First Name:'}
# {'name': 'T43', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Last Name:'}
# {'name': 'CB44', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'M.D.'}
# {'name': 'CB45', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'D.O.'}
# {'name': 'CB46', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'N.P.'}
# {'name': 'CB47', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'P.A.'}
# {'name': 'T48', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Address:'}
# {'name': 'T49', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'City:'}
# {'name': 'T50', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'State:'}
# {'name': 'T51', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'ZIP:'}
# {'name': 'T52', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Phone:'}
# {'name': 'T53', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Fax:'}
# {'name': 'T54', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'St Lic #:'}
# {'name': 'T55', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'NPI #:'}
# {'name': 'T56', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'DEA #:'}
# {'name': 'T57', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'UPIN:'}
# {'name': 'T58.0', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Provider Email:'}
# {'name': 'T58.1', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Office Contact Name:'}
# {'name': 'T59', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Phone:'}
# {'name': 'Provider Admin CB.1', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Self-administered'}
# {'name': 'Provider Admin CB.2', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Physician’s Office'}
# {'name': 'Provider Admin CB.3', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Home'}
# {'name': 'Provider Admin CB.4', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Outpatient Infusion Center'}
# {'name': 'Provider Admin T.5', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Name:'}
# {'name': 'Provider Admin CB.7', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Home Infusion Center'}
# {'name': 'Provider Admin T.6', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Phone:'}
# {'name': 'Provider Admin T.8', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Agency Name:'}
# {'name': 'Provider Admin CB.10', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Administration code(s)'}
# {'name': 'Provider Admin T.9', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'CPT:'}
# {'name': 'Provider Admin T.11A', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Address:'}
# {'name': 'Provider Admin T.13', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'City:'}
# {'name': 'Provider Admin T.14', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'State:'}
# {'name': 'Provider Admin T.15', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'ZIP:'}
# {'name': 'Provider Admin T.16', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Phone:'}
# {'name': 'Provider Admin T.17A', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Fax:'}
# {'name': 'Provider Admin T.18', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'TIN:'}
# {'name': 'Provider Admin T.19', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'PIN:'}
# {'name': 'Provider Admin T.20', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'NPI:'}
# {'name': 'Provider Admin CB.21', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Outpatient Dialysis Center'}
# {'name': 'Provider Admin CB.22', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Physician’s Office'}
# {'name': 'Provider Admin CB.23.0.0', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Retail Pharmacy'}
# {'name': 'Provider Admin CB.24.0.0', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Specialty Pharmacy'}
# {'name': 'Provider Admin CB.25', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Mail Order'}
# {'name': 'Provider Admin CB.26', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Other:'}
# {'name': 'Provider Admin T.27', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Other:'}
# {'name': 'Provider Admin T.28', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Name:'}
# {'name': 'Provider Admin T.29a', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Address:'}
# {'name': 'Provider Admin T.30a', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'City:'}
# {'name': 'Provider Admin T.31', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'State:'}
# {'name': 'Provider Admin T.32', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'ZIP:'}
# {'name': 'Provider Admin T.33', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Phone:'}
# {'name': 'Provider Admin T.34', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Fax:'}
# {'name': 'Provider Admin T.35', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'TIN:'}
# {'name': 'Provider Admin T.36', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'PIN:'}
# {'name': 'Provider Admin T.37', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'NPI:'}
# {'name': 'CB60', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Riabni (rituximab-arrx)'}
# {'name': 'CB61', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Rituxan (rituximab)'}
# {'name': 'CB62', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Ruxience (rituximab-pvvr)'}
# {'name': 'CB63', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Truxima (rituximab-abbs)'}
# {'name': 'T64', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Dose:'}
# {'name': 'T65', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Directions for Use:'}
# {'name': 'T66', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'HCPCS Code:'}
# {'name': 'T67', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Primary ICD Code:'}
# {'name': 'CB68', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Other ICD Code:'}
# {'name': 'T69', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Other ICD Code:'}
# {'name': 'CB70', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB71', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB72', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB73', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Ruxience (rituximab-pvvr)'}
# {'name': 'CB74', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Truxima (rituximab-abbs)'}
# {'name': 'T75', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'When was the member’s trial and failure of the preferred drug?'}
# {'name': 'T76', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please describe the nature of the failure of the preferred drug'}
# {'name': 'CB77', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB78', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Ruxience (rituximab-pvvr)'}
# {'name': 'CB79', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Truxima (rituximab-abbs)'}
# {'name': 'T80', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'When was the member’s adverse reaction to the preferred drug?'}
# {'name': 'T81', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please describe the nature of the adverse reaction to the preferred drug'}
# {'name': 'T84', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please explain if there are any contraindications or other medical reason(s) that the patient cannot use any of the following preferred biosimilar products when indicated for the patient’s diagnosis?'}
# {'name': 'CB82', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Ruxience (rituximab-pvvr)'}
# {'name': 'CB83', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Truxima (rituximab-abbs)'}
# {'name': 'T12', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient First Name'}
# {'name': 'T13', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient Last Name'}
# {'name': 'T19', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient Phone'}
# {'name': 'T14', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient DOB (MM/DD/YYYY)'}
# {'name': 'CB86', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Inflectra (infliximab-dyyb)'}
# {'name': 'CB87', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Renflexis (infliximab-abda)'}
# {'name': 'CB88', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Simponi Aria (golimumab)'}
# {'name': 'T89', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'When was the member’s trial and failure of the preferred drug?'}
# {'name': 'T90', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please describe the nature of the failure of the preferred drug'}
# {'name': 'CB85', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB92', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Inflectra (infliximab-dyyb)'}
# {'name': 'CB93', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Renflexis (infliximab-abda)'}
# {'name': 'CB94', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Simponi Aria (golimumab)'}
# {'name': 'T95', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'When was the member’s adverse reaction to the preferred drug?'}
# {'name': 'T96a', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please describe the nature of the adverse reaction to the preferred drug'}
# {'name': 'CB91', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB98a', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Enbrel (etanercept)'}
# {'name': 'CB99a', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Humira (adalimumab)'}
# {'name': 'CB100a', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Idacio (adalimumab-aacf)'}
# {'name': 'CB101a', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Rinvoq (upadacitinib)'}
# {'name': 'CB102a', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Tyenne SC (tocilizumab-aazg)'}
# {'name': 'CB103a', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Xeljanz/Xeljanz XR (tofacitinib)'}
# {'name': 'T104', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'When was the member’s trial and failure of the preferred drug?'}
# {'name': 'T105', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please describe the nature of the failure of the preferred drug'}
# {'name': 'CB97', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB107z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Enbrel (etanercept)'}
# {'name': 'CB108z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Humira (adalimumab)'}
# {'name': 'CB109z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Idacio (adalimumab-aacf)'}
# {'name': 'CB110z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Rinvoq (upadacitinib)'}
# {'name': 'CB111z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Tyenne SC (tocilizumab-aazg)'}
# {'name': 'CB112z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Xeljanz/Xeljanz XR (tofacitinib)'}
# {'name': 'T113', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'When was the member’s adverse reaction to the preferred drug?'}
# {'name': 'T114', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please describe the nature of the adverse reaction to the preferred drug'}
# {'name': 'CB106z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'T118', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please explain if there are any contraindications or other medical reason(s) that the patient cannot use any of the following preferred products when indicated for the patient’s diagnosis?'}
# {'name': 'CB115z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Inflectra (infliximab-dyyb)'}
# {'name': 'CB116z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Renflexis (infliximab-abda)'}
# {'name': 'CB117z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Simponi Aria (golimumab)'}
# {'name': 'T125', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please explain if there are contraindications or any other medical reason(s) that the patient cannot use any of the following preferred products when indicated for the patient’s diagnosis?'}
# {'name': 'CB119z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Enbrel (etanercept)'}
# {'name': 'CB120z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Humira (adalimumab)'}
# {'name': 'CB121z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Idacio (adalimumab-aacf)'}
# {'name': 'CB122z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Rinvoq (upadacitinib)'}
# {'name': 'CB123z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Tyenne SC (tocilizumab-aazg)'}
# {'name': 'CB124z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Xeljanz/Xeljanz XR (tofacitinib)'}
# {'name': 'CB96.4.0', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB98', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB99.0', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB100.0', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB101.0', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB102.0', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB103', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB104', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB104a', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Wegener granulomatosis'}
# {'name': 'CB104b', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Churg-Strauss syndrome'}
# {'name': 'CB104c', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'microscopic polyangiitis'}
# {'name': 'CB104d', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'pauci-immune glomerulonephritis'}
# {'name': 'CB105', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB106', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB106a', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB107', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'pemphigus vulgaris'}
# {'name': 'CB108', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'pemphigus folliaceus'}
# {'name': 'CB109', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'bullous pemphigoid'}
# {'name': 'CB110', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'cicatricial pemphigoid'}
# {'name': 'CB111', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'epidermolysis bullosa acquisita'}
# {'name': 'CB112', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'paraneoplastic pemphigus'}
# {'name': 'CB113', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'None of the above'}
# {'name': 'CB106b', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB114', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'AIDS-related B-cell lymphoma'}
# {'name': 'CB115', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Burkitt lymphoma'}
# {'name': 'CB116', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Diffuse large B-cell lymphoma'}
# {'name': 'CB117', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Follicular lymphoma'}
# {'name': 'CB118', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Gastric MALT lymphoma'}
# {'name': 'CB119', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'High-grade B-Cell lymphoma'}
# {'name': 'CB120', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Mantle cell lymphoma'}
# {'name': 'CB121', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Nodal marginal zone lymphoma'}
# {'name': 'CB122', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Nongastric MALT lymphoma'}
# {'name': 'CB123', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Primary cutaneous B-cell lymphomas'}
# {'name': 'CB124', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Splenic marginal zone lymphoma'}
# {'name': 'CB125', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Other:'}
# {'name': 'T126', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Other:'}
# {'name': 'T12', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient First Name'}
# {'name': 'T13', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient Last Name'}
# {'name': 'T19', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient Phone'}
# {'name': 'T14', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient DOB (MM/DD/YYYY)'}
# {'name': 'CB127', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB128', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB129', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'leptomeningeal metastases from lymphoma'}
# {'name': 'CB130', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'primary CNS lymphoma'}
# {'name': 'CB131', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'none of the above'}
# {'name': 'CB132', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'chronic lymphocytic leukemia (CLL)'}
# {'name': 'CB133', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'small lymphocytic leukemia'}
# {'name': 'CB134', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'none of the above'}
# {'name': 'CB135', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB136', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB139', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB140', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB144', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB145', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB141', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'relapsed hairy cell leukemia'}
# {'name': 'CB142', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'refractory hairy cell leukemia'}
# {'name': 'CB143', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'none of the above'}
# {'name': 'CB137', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB146', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'heart transplant recipient'}
# {'name': 'CB147', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'other solid organ transplant recipient'}
# {'name': 'CB138', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB148', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Bavencio (avelumab)'}
# {'name': 'CB149', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Imfinzi (durvalumab)'}
# {'name': 'CB150', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Keytruda (pembrolizumab)'}
# {'name': 'CB151', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Opdivo (nivolumab)'}
# {'name': 'CB152', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Tecentriq (atezolizumab)'}
# {'name': 'CB153', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yervoy (ipilimumab)'}
# {'name': 'CB154', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Other:'}
# {'name': 'T155', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Other:'}
# {'name': 'CB156', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB158', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'refractory immune thrombocytopenic purpura'}
# {'name': 'CB159', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'idiopathic thrombocytopenic purpura (ITP)'}
# {'name': 'CB157', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB160', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB161', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB162', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB163', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB164', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Relapsing-remitting MS (RRMS)'}
# {'name': 'CB165', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Secondary-progressive MS (SPMS)'}
# {'name': 'CB166', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Primary-progressive MS (PPMS)'}
# {'name': 'CB167', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Progressive-relapsing MS (PRMS)'}
# {'name': 'CB168', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB169', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB170', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB172', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB173', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB171', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB174', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB175', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB176', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB177', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB178', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB179', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB180', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'T189', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Medication:'}
# {'name': 'T190', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T191', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T192', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}
# {'name': 'T193', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T194', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T195', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}
# {'name': 'T196', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Medication:'}
# {'name': 'T197', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T198', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T199', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}
# {'name': 'T200', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T201', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T202', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}
# {'name': 'CB181', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB203', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB204', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB205', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB206', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'T12', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient First Name'}
# {'name': 'T13', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient Last Name'}
# {'name': 'T19', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient Phone'}
# {'name': 'T14', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient DOB (MM/DD/YYYY)'}
# {'name': 'CB207', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Mild'}
# {'name': 'CB208', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Moderate'}
# {'name': 'CB209', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Severe'}
# {'name': 'CB210', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB211', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB212', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB213', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB214', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB216', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'ineffective'}
# {'name': 'CB217', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'not tolerated'}
# {'name': 'CB218', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'contraindicated'}
# {'name': 'CB215', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB223', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB225', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'azathioprine'}
# {'name': 'CB226', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'cyclosporine'}
# {'name': 'CB227', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'hydroxychloroquine'}
# {'name': 'CB228', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'leflunomide'}
# {'name': 'CB229', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'sulfasalazine'}
# {'name': 'CB224', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB281', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB282', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB283', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'T285', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Medication:'}
# {'name': 'T286', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T287', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T288', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}
# {'name': 'T289', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T290', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T291', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}
# {'name': 'T292', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Medication:'}
# {'name': 'T293', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T294', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T295', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}
# {'name': 'T296', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T297', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T298', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}
# {'name': 'CB284', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB299', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB300', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB301', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB302', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB303', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB304', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'T305', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please indicate the length of time on Rituxan (rituximab):'}
# {'name': 'CB310', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Mild'}
# {'name': 'CB311', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Moderate'}
# {'name': 'CB312', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Severe'}
# {'name': 'CB306', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB307', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB308', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB309', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB313', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB314', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB315', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB316', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'T317', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T318', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T319', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}

# %% [markdown]
# ## PA feild organization Prompt template for Gemeni

# %%
def format_fields_for_pa(pa_fields):
  return """
  You are given an array of dictionaries, each representing a form field extracted from a PDF. Each dictionary contains:
  - "name": the field name
  - "type": the field type (e.g., "text", "checkbox")
  - "value": the field value (may be null)
  - "page": the 1-based page number
  - "field_type": the PDF widget type code
  - "field_type_string": the PDF widget type as a string
  - "field_label": the field label (may be null)

  TASK:
  1. Organize these fields into a hierarchical JSON tree grouped by page number.
  2. For each page, create an array of fields, preserving all metadata.
  3. The top-level JSON should be:
  {
    "pages": {
      "1": [ ...fields... ],
      "2": [ ...fields... ],
      ...
    }
  }
  4. Do not omit any fields or metadata.
  5. Return only valid JSON (no markdown, no extra commentary).

  Example output:
  {
    "pages": {
      "1": [
        {
          "name": "T1",
          "type": "text",
          "value": "",
          "page": 1,
          "field_type": 2,
          "field_type_string": "Text",
          "field_label": "First Name"
        },
        ...
      ],
      "2": [
        ...
      ]
    }
  }

  <PA_FIELDS>
  {pa_fields}
  </PA_FIELDS> """

# %% [markdown]
# ## Send Prompt to Gemeni

# %%
# Send to Gemini using NEW 2025 SDK

async def query_gemini_async(prompt, pdf_path, model_name='gemini-2.5-flash'):
    """
    Async function to query Gemini with a PDF and prompt using the new 2025 Google Gen AI SDK
    """
    filepath = pathlib.Path(pdf_path)
    
    # Create PDF part using new SDK structure
    pdf_bytes = filepath.read_bytes()
    pdf_part = types.Part.from_bytes(
        data=pdf_bytes, 
        mime_type="application/pdf"
    )
    
    # Use async client from new SDK
    response = await client.aio.models.generate_content(
        model=model_name,
        contents=[pdf_part, prompt]
    )
    
    print(response.text)
    return response.text

# %%
pa_fields_context = {}

# Process each page of the PA form
async def process_page(page):
    prompt = format_fields_for_pa(pa_fields[page])
    print (prompt)

    result = await query_gemini_async(prompt, "Input Data/Adbulla/PA.pdf")
    print ("---------------------------------")
    return page, result
# create a list of tasks to run in parallel
tasks = [process_page(page) for page in pa_fields]

# running the tasks in parallel
results = await asyncio.gather(*tasks)

# 
for page, result in results:
    pa_fields_context[page] = result
# Out:
# ```json
# {
#   "pages": {
#     "1": [
#       {
#         "name": "aetna_2",
#         "type": "text",
#         "value": "1-866-503-0857",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "aetna_3",
#         "type": "text",
#         "value": "711",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "aetna_4",
#         "type": "text",
#         "value": "1-844-268-7263",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "aetna_5",
#         "type": "text",
#         "value": "https://www.aetna.com/health-care-professionals/resource-center/availity.html",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "aetna_6",
#         "type": "text",
#         "value": "1-855-463-0933",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "aetna_7",
#         "type": "text",
#         "value": "1-833-280-5224",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "aetna_8",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/virginia-hmosnp/providers/portal",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "aetna_9",
#         "type": "text",
#         "value": "1-844-362-0934",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "aetna_10",
#         "type": "text",
#         "value": "1-833-322-0034",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "aetna_11",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/new-jersey-hmosnp/providers/portal.html",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "aetna_12",
#         "type": "text",
#         "value": "1-866-600-2139",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "aetna_13",
#         "type": "text",
#         "value": "1-855-320-8445",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "aetna_14",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/illinois/providers/portal",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "aetna_15",
#         "type": "text",
#         "value": "1-855-364-0974",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "aetna_16",
#         "type": "text",
#         "value": "1-855-734-9389",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "aetna_17",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/ohio/providers/portal",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "aetna_18",
#         "type": "text",
#         "value": "1-855-676-5772",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "aetna_19",
#         "type": "text",
#         "value": "1-844-241-2495",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "aetna_20",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/michigan/providers/portal.html",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       }
#     ],
#     "2": [
#       {
#         "name": "Start of treatment",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Last treatment",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "date",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "date_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "First Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Last Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "DOB",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Address",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "City",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "State",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "ZIP",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Home Phone",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Work Phone",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Cell Phone",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "E-mail",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Current Weight",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Height",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Allergies",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Member ID",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Carrier Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Group",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "ID",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Insured",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "First Name_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Last Name_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "MD",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "DO",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "NP",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "PA",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Address_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "City_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "State_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "ZIP_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "St Lic",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "NPI",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "DEA",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "UPIN",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Provider Email",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Office Contact Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Self-administered",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Physician's Office",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Home",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Outpatient Infusion Center Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Home Infusion Center",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Phone_4",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Agency Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Administration codes",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Address_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "City_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "State_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "ZIP_3",
#         "type": 2,
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_5",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "TIN",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "NPI_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Outpatient Dialysis Center",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Retail Pharmacy",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Mail Order",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Address_4",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "City_4",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "State_4",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "ZIP_4",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_6",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "PIN",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "TIN_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "NPI_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Specialty Pharmacy",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Other",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Physician's Office_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Riabni",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Rituxan",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Ruxience",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Truxima",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Dose",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Directions for Use",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "HCPCS Code",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Primary ICD Code",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Other ICD Code",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Prior Therapy Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Prior Therapy No",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Trial Failure No",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Ruxience (rituximab-pvvr)",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Truxima (rituximab-abbs)",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Trial Failure Date",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Trial Failure Description",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Adverse Reaction No",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Ruxience (rituximab-pvvr)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Truxima (rituximab-abbs)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Adverse Reaction Date",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Adverse Reaction Description",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Ruxience (rituximab-pvvr)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Truxima (rituximab-abbs)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       }
#     ],
#     "3": [
#       {
#         "name": "Patient First Name",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Patient Last Name",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Patient Phone",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Patient DOB",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "No_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Inflectra (infliximab-dyyb)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Renflexis (infliximab-abda)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Simponi Aria (golimumab)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Trial Failure Date",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Trial Failure Description",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Adverse Reaction No",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Inflectra (infliximab-dyyb)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Renflexis (infliximab-abda)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Simponi Aria (golimumab)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Adverse Reaction Date",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Adverse Reaction Description",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "No_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Enbrel (etanercept)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Humira (adalimumab)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Idacio (adalimumab-aacf)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Rinvoq (upadacitinib)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Tyenne SC (tocilizumab-aazg)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Xeljanz/Xeljanz XR (tofacitinib)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Trial Failure Date_2",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Trial Failure Description_2",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Adverse Reaction No_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Enbrel (etanercept)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Humira (adalimumab)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Idacio (adalimumab-aacf)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Rinvoq (upadacitinib)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Tyenne SC (tocilizumab-aazg)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Xeljanz/Xeljanz XR (tofacitinib)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Adverse Reaction Date_2",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Adverse Reaction Description_2",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Inflectra (infliximab-dyyb)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Renflexis (infliximab-abda)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Simponi Aria (golimumab)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Enbrel (etanercept)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Humira (adalimumab)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Idacio (adalimumab-aacf)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Rinvoq (upadacitinib)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Tyenne SC (tocilizumab-aazg)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Xeljanz/Xeljanz XR (tofacitinib)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_4",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_5",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_4",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_6",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_5",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_7",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Wegener granulomatosis",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "microscopic polyangiitis",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Churg-Strauss syndrome",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "pauci-immune glomerulonephritis",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_6",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_8",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_7",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_9",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "pemphigus vulgaris",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "pemphigus folliaceus",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "bullous pemphigoid",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "cicatricial pemphigoid",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "epidermolysis bullosa acquisita",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "paraneoplastic pemphigus",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "None of the above",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "AIDS-related B-cell lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Burkitt lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Diffuse large B-cell lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Follicular lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Gastric MALT lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "High-grade B-Cell lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Mantle cell lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Nodal marginal zone lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Nongastric MALT lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Primary cutaneous B-cell lymphomas",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Splenic marginal zone lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Other_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       }
#     ],
#     "4": [
#       {
#         "name": "Patient First Name",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Patient Last Name",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Patient Phone",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Patient DOB",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "leptomeningeal metastases from lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "primary CNS lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "none of the above",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "chronic lymphocytic leukemia (CLL)",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "small lymphocytic leukemia",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "none of the above_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_4",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_4",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "relapsed hairy cell leukemia",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "refractory hairy cell leukemia",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "none of the above_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_5",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_5",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "heart transplant recipient",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "other solid organ transplant recipient",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Bavencio (avelumab)",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Imfinzi (durvalumab)",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Keytruda (pembrolizumab)",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
# ...
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_21",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Relapsing-remitting MS RRMS",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Secondary-progressive MS SPMS",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Primary-progressive MS PPMS",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Progressive-relapsing MS PRMS",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_17",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_22",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_18",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_23",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_19",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_24",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_20",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_25",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_21",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_26",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_22",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_27",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Medication",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Medication:"
#       },
#       {
#         "name": "Dates",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Dates:"
#       },
#       {
#         "name": "Medication_2",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Medication:"
#       },
#       {
#         "name": "Dates_2",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Dates:"
#       },
#       {
#         "name": "Yes_23",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_28",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_24",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_29",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "GR-68535-3 (1-25)",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       }
#     ],
#     "5": [
#       {
#         "name": "Patient First Name_5",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient First Name"
#       },
#       {
#         "name": "Patient Last Name_5",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient Last Name"
#       },
#       {
#         "name": "Patient Phone_5",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient Phone"
#       },
#       {
#         "name": "Patient DOB_3",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient DOB"
#       },
#       {
#         "name": "Mild",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Moderate",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Severe",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_25",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_30",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_26",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_31",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "ineffective",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "not tolerated",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "contraindicated",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_27",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_32",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "azathioprine",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "cyclosporine",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "hydroxychloroquine",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "leflunomide",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "sulfasalazine",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_28",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_33",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_29",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_34",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Medication_3",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Medication:"
#       },
#       {
#         "name": "Dates_3",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Dates:"
#       },
#       {
#         "name": "Medication_4",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Medication:"
#       },
#       {
#         "name": "Dates_4",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Dates:"
#       },
#       {
#         "name": "Yes_30",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_35",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_31",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_36",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_32",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_37",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "length of time on Rituxan rituximab",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Mild_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Moderate_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Severe_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_33",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_38",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_34",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_39",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_35",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_40",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_36",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_41",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Request Completed By",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Date",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Date:"
#       },
#       {
#         "name": "GR-68535-3 (1-25)",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       }
#     ]
#   }
# }
# ```
# ---------------------------------

# %%
# Create PA_form_analysis from pa_fields_context
# This combines all the processed PA field data into a single analysis

if 'pa_fields_context' in locals() and pa_fields_context:
    # Combine all page results into a single analysis
    PA_form_analysis = ""
    for page, result in pa_fields_context.items():
        PA_form_analysis += f"PAGE {page}:\n{result}\n\n"
    print("✅ PA_form_analysis created successfully!")
    print(f"Length: {len(PA_form_analysis)} characters")
else:
    # Fallback: create from raw pa_fields if pa_fields_context isn't ready
    PA_form_analysis = json.dumps(pa_fields, indent=2)
    print("⚠️  Using fallback: PA_form_analysis created from raw pa_fields")
    print("Note: Run cell 12 first to get processed analysis")

print("PA_form_analysis preview:")
print(PA_form_analysis)
# Out:
# ✅ PA_form_analysis created successfully!
# Length: 257801 characters
# PA_form_analysis preview:
# PAGE 2:
# ```json
# {
#   "pages": {
#     "1": [
#       {
#         "name": "Phone_1",
#         "type": "text",
#         "value": "1-866-503-0857",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_1",
#         "type": "text",
#         "value": "1-844-268-7263",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_1",
#         "type": "text",
#         "value": "https://www.aetna.com/health-care-professionals/resource-center/availity.html",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_2",
#         "type": "text",
#         "value": "1-855-463-0933",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_2",
#         "type": "text",
#         "value": "1-833-280-5224",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_2",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/virginia-hmosnp/providers/portal",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_3",
#         "type": "text",
#         "value": "1-844-362-0934",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_3",
#         "type": "text",
#         "value": "1-833-322-0034",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_3",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/new-jersey-hmosnp/providers/portal.html",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_4",
#         "type": "text",
#         "value": "1-866-600-2139",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_4",
#         "type": "text",
#         "value": "1-855-320-8445",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_4",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/illinois/providers/portal",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_5",
#         "type": "text",
#         "value": "1-855-364-0974",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_5",
#         "type": "text",
#         "value": "1-855-734-9389",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_5",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/ohio/providers/portal",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_6",
#         "type": "text",
#         "value": "1-855-676-5772",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_6",
#         "type": "text",
#         "value": "1-844-241-2495",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_6",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/michigan/providers/portal.html",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       }
#     ],
#     "2": [
#       {
#         "name": "Start of treatment",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "start date",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Continuation of therapy",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "date of last treatment",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_7",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_7",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "First Name_8",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Last Name_8",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "DOB",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Address_8",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "City_8",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "State_8",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "ZIP_8",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Home Phone_8",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Work Phone_8",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Cell Phone_8",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "E-mail_8",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Current Weight",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Height",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Allergies",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Member ID",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Patient has other coverage?",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Patient has other coverage?_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Carrier Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Group",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Insured",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Insured_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "First Name_9",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Last Name_9",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "MD",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "DO",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "NP",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "PA",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Address_9",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "City_9",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "State_9",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "ZIP_9",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_9",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_9",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "St Lic",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "NPI",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "DEA",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "UPIN",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Provider Email",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Office Contact Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_10",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Self-administered",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Physician's Office",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Home",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Outpatient Infusion Center Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Home Infusion Center",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Phone_11",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Agency Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Administration code(s) (CPT)",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Address_10",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "City_10",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "State_10",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "ZIP_10",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_12",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "TIN_10",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_10",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "NPI_10",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Outpatient Dialysis Center",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Retail Pharmacy",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Mail Order",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Address_11",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "City_11",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "State_11",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "ZIP_11",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_13",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "PIN",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_11",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "TIN_11",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "NPI_11",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Physician's Office_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Specialty Pharmacy",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Other",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Riabni",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Rituxan",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Ruxience",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Truxima",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Dose",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Directions for Use",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "HCPCS Code",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Primary ICD Code",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Other ICD Code",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Has the patient had prior therapy with the requested product within the last 365 days?",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Has the patient had prior therapy with the requested product within the last 365 days?_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Has the patient had a trial and failure of any of the following rituximab biosimilars?",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Has the patient had a trial and failure of any of the following rituximab biosimilars?_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Ruxience",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Truxima_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "When was the member's trial and failure of the preferred drug?",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the failure of the preferred drug",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Has the patient had an adverse reaction to any of the following rituximab biosimilars?",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Has the patient had an adverse reaction to any of the following rituximab biosimilars?_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Ruxience_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Truxima_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "When was the member's adverse reaction to the preferred drug?",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the adverse reaction to the preferred drug_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Ruxience_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Truxima_4",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       }
#     ],
#     "3": [
#       {
#         "name": "Patient First Name_14",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Patient Last Name_14",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Patient Phone_14",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Patient DOB_14",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Has the patient had a trial and failure of any of the following?_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Has the patient had a trial and failure of any of the following?_4",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Inflectra",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Renflexis",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Simponi Aria",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "When was the member's trial and failure of the preferred drug_3",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the failure of the preferred drug_4",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Has the patient had an adverse reaction to any of the following?_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Has the patient had an adverse reaction to any of the following?_4",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Inflectra_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Renflexis_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Simponi Aria_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "When was the member's adverse reaction to the preferred drug_3",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the adverse reaction to the preferred drug_5",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Has the patient had a trial and failure of any of the following?_5",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Has the patient had a trial and failure of any of the following?_6",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Enbrel",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Humira",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Idacio",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Rinvoq",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Tyenne SC",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "XeljanzXeljanz XR",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "When was the member's trial and failure of the preferred drug_5",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the failure of the preferred drug_6",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Has the patient had a trial and failure of any of the following?_7",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Has the patient had a trial and failure of any of the following?_8",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Enbrel_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Humira_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Idacio_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Rinvoq_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Tyenne SC_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "XeljanzXeljanz XR_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "When was the member's adverse reaction to the preferred drug_5",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the adverse reaction to the preferred drug_7",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Inflectra_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Renflexis_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Simponi Aria_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Enbrel_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Humira_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Idacio_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Rinvoq_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Tyenne SC_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "XeljanzXeljanz XR_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Will Rituxan be used concomitantly with apremilast, tofacitinib, or other biologic DMARDs?",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Will Rituxan be used concomitantly with apremilast, tofacitinib, or other biologic DMARDs?_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Does the patient have a documented diagnosis of Philadelphia chromosome-negative acute lymphoid leukemia (ALL)?",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Does the patient have a documented diagnosis of Philadelphia chromosome-negative acute lymphoid leukemia (ALL)?_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Is Rituxan being used as inductionconsolidation therapy?",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Is Rituxan being used as inductionconsolidation therapy?_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Does the patient have a documented diagnosis of refractory autoimmune hemolytic anemia?",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Does the patient have a documented diagnosis of refractory autoimmune hemolytic anemia?_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Wegener granulomatosis",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "microscopic polyangiitis",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Churg-Strauss syndrome",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "pauci-immune glomerulonephritis",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Will Rituxan be given in conjunction with glucocorticoids?",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Will Rituxan be given in conjunction with glucocorticoids?_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Does the patient have a documented diagnosis of corticosteroid-refractory autoimmune blistering disease?",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Does the patient have a documented diagnosis of corticosteroid-refractory autoimmune blistering disease?_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "pemphigus vulgaris",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "pemphigus folliaceus",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "bullous pemphigoid",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "cicatricial pemphigoid",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "epidermolysis bullosa acquisita",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "paraneoplastic pemphigus",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "None of the above",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "AIDS-related B-cell lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Burkitt lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Diffuse large B-cell lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Follicular lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Gastric MALT lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "High-grade B-Cell lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Mantle cell lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Nodal marginal zone lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Nongastric MALT lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Primary cutaneous B-cell lymphomas",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Splenic marginal zone lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Other_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       }
#     ],
#     "4": [
#       {
#         "name": "Patient First Name_15",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Patient Last Name_15",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Patient Phone_15",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Patient DOB_15",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Does the patient have a documented diagnosis of multicentric Castleman's disease (angiofollicular lymph node hyperplasia)?",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Does the patient have a documented diagnosis of multicentric Castleman's disease (angiofollicular lymph node hyperplasia)?_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "leptomeningeal metastases from lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "primary CNS lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "none of the above",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "chronic lymphocytic leukemia (CLL)",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "small lymphocytic leukemia",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "none of the above_2",
# ...
#       },
#       {
#         "name": "Does the patient have a documented diagnosis of lymphocyte-predominant Hodgkin's lymphoma_G",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "Does the patient have a documented diagnosis of lymphocyte-predominant Hodgkin's lymphoma?"
#       },
#       {
#         "name": "Relapsing-remitting MS (RRMS)_G",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "Relapsing-remitting MS (RRMS)"
#       },
#       {
#         "name": "Secondary-progressive MS (SPMS)_G",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "Secondary-progressive MS (SPMS)"
#       },
#       {
#         "name": "Primary-progressive MS (PPMS)_G",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "Primary-progressive MS (PPMS)"
#       },
#       {
#         "name": "Progressive-relapsing MS (PRMS)_G",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "Progressive-relapsing MS (PRMS)"
#       },
#       {
#         "name": "Has the patient discontinued other medications used for treating MS (not including Ampyra)_G",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "Has the patient discontinued other medications used for treating MS (not including Ampyra)?"
#       },
#       {
#         "name": "Does the patient have a documented diagnosis of muscle-specific tyrosine kinase myasthenia gravis (MuSK-MG)_G",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "Does the patient have a documented diagnosis of muscle-specific tyrosine kinase myasthenia gravis (MuSK-MG)?"
#       },
#       {
#         "name": "Has the patient had an unsatisfactory response to initial immunotherapy_G",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "Has the patient had an unsatisfactory response to initial immunotherapy?"
#       },
#       {
#         "name": "Does the patient have a documented diagnosis of neuromyelitis optica (Devic's disease)_G",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "Does the patient have a documented diagnosis of neuromyelitis optica (Devic's disease)?"
#       },
#       {
#         "name": "Was the treatment with at least one immunotherapy ineffective_G",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "Was the treatment with at least one immunotherapy ineffective?"
#       },
#       {
#         "name": "Does the patient have a documented diagnosis of opsoclonus-myoclonus-ataxia (OMA) associated with neuroblastoma_G",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "Does the patient have a documented diagnosis of opsoclonus-myoclonus-ataxia (OMA) associated with neuroblastoma?"
#       },
#       {
#         "name": "Is the patient refractory to steroids, chemotherapy and intravenous immunoglobulins_G",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "Is the patient refractory to steroids, chemotherapy and intravenous immunoglobulins?"
#       },
#       {
#         "name": "Medication_G1",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Medication"
#       },
#       {
#         "name": "Dates_G1",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Dates"
#       },
#       {
#         "name": "Medication_G2",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Medication"
#       },
#       {
#         "name": "Dates_G2",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Dates"
#       },
#       {
#         "name": "Is Rituxan (rituximab) being used as treatment of post-transplant lymphoproliferative disorder_G",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "Is Rituxan (rituximab) being used as treatment of post-transplant lymphoproliferative disorder?"
#       },
#       {
#         "name": "Is Rituxan (rituximab) being used as prophylaxis for Epstein-Barr virus (EBV) post-transplant lymphoproliferative disorder_G",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "Is Rituxan (rituximab) being used as prophylaxis for Epstein-Barr virus (EBV) post-transplant lymphoproliferative disorder?"
#       }
#     ],
#     "5": [
#       {
#         "name": "Patient First Name_5",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient First Name"
#       },
#       {
#         "name": "Patient Last Name_5",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient Last Name"
#       },
#       {
#         "name": "Patient Phone_5",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient Phone"
#       },
#       {
#         "name": "Patient DOB_5",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient DOB"
#       },
#       {
#         "name": "Mild_G1",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "Mild"
#       },
#       {
#         "name": "Moderate_G1",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "Moderate"
#       },
#       {
#         "name": "Severe_G1",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "Severe"
#       },
#       {
#         "name": "Is there evidence that the disease is active_G",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "Is there evidence that the disease is active?"
#       },
#       {
#         "name": "Will Rituxan (rituximab) be used in combination with methotrexate_G",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "Will Rituxan (rituximab) be used in combination with methotrexate?"
#       },
#       {
#         "name": "Was treatment with methotrexate ineffective, not tolerated or contraindicated_G",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "Was treatment with methotrexate ineffective, not tolerated or contraindicated?"
#       },
#       {
#         "name": "ineffective_G",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "ineffective"
#       },
#       {
#         "name": "not tolerated_G",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "not tolerated"
#       },
#       {
#         "name": "contraindicated_G",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "contraindicated"
#       },
#       {
#         "name": "Was treatment with another conventional DMARD ineffective_G",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "Was treatment with another conventional DMARD ineffective?"
#       },
#       {
#         "name": "azathioprine_G",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "azathioprine"
#       },
#       {
#         "name": "cyclosporine_G",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "cyclosporine"
#       },
#       {
#         "name": "hydroxychloroquine_G",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "hydroxychloroquine"
#       },
#       {
#         "name": "leflunomide_G",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "leflunomide"
#       },
#       {
#         "name": "sulfasalazine_G",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "sulfasalazine"
#       },
#       {
#         "name": "Does the patient have a documented diagnosis of Sjögren's syndrome_G",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "Does the patient have a documented diagnosis of Sjögren's syndrome?"
#       },
#       {
#         "name": "Was treatment with corticosteroids and other immunosuppressive agents ineffective_G1",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "Was treatment with corticosteroids and other immunosuppressive agents ineffective?"
#       },
#       {
#         "name": "Medication_G3",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Medication"
#       },
#       {
#         "name": "Dates_G3",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Dates"
#       },
#       {
#         "name": "Medication_G4",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Medication"
#       },
#       {
#         "name": "Dates_G4",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Dates"
#       },
#       {
#         "name": "Does the patient have a documented diagnosis of refractory thrombotic thrombocytopenic purpura (TTP)_G",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "Does the patient have a documented diagnosis of refractory thrombotic thrombocytopenic purpura (TTP)?"
#       },
#       {
#         "name": "Does the patient have a documented diagnosis of Waldenström macroglobulinemia_G",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "Does the patient have a documented diagnosis of Waldenström macroglobulinemia?"
#       },
#       {
#         "name": "Is this continuation request a result of the patient receiving samples of Rituxan (rituximab)_G",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "Is this continuation request a result of the patient receiving samples of Rituxan (rituximab)?"
#       },
#       {
#         "name": "Please indicate the length of time on Rituxan (rituximab)_G",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Please indicate the length of time on Rituxan (rituximab)"
#       },
#       {
#         "name": "Mild_G2",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "Mild"
#       },
#       {
#         "name": "Moderate_G2",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "Moderate"
#       },
#       {
#         "name": "Severe_G2",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "Severe"
#       },
#       {
#         "name": "Is there clinical documentation supporting disease stability_G1",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "Is there clinical documentation supporting disease stability?"
#       },
#       {
#         "name": "Is there clinical documentation supporting disease improvement_G1",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "Is there clinical documentation supporting disease improvement?"
#       },
#       {
#         "name": "Is there clinical documentation supporting disease stability_G2",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "Is there clinical documentation supporting disease stability?"
#       },
#       {
#         "name": "Is there clinical documentation supporting disease improvement_G2",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": "Is there clinical documentation supporting disease improvement?"
#       },
#       {
#         "name": "Request Completed By (Signature Required)_H",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Request Completed By (Signature Required)"
#       },
#       {
#         "name": "Date_H",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Date"
#       }
#     ]
#   }
# }
# ```

# %%
pa_fields_context
# Out:
# {2: '```json\n{\n  "pages": {\n    "1": [\n      {\n        "name": "Phone_1",\n        "type": "text",\n        "value": "1-866-503-0857",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_1",\n        "type": "text",\n        "value": "1-844-268-7263",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_1",\n        "type": "text",\n        "value": "https://www.aetna.com/health-care-professionals/resource-center/availity.html",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_2",\n        "type": "text",\n        "value": "1-855-463-0933",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_2",\n        "type": "text",\n        "value": "1-833-280-5224",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_2",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/virginia-hmosnp/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_3",\n        "type": "text",\n        "value": "1-844-362-0934",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_3",\n        "type": "text",\n        "value": "1-833-322-0034",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_3",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/new-jersey-hmosnp/providers/portal.html",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_4",\n        "type": "text",\n        "value": "1-866-600-2139",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_4",\n        "type": "text",\n        "value": "1-855-320-8445",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_4",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/illinois/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_5",\n        "type": "text",\n        "value": "1-855-364-0974",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_5",\n        "type": "text",\n        "value": "1-855-734-9389",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_5",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/ohio/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_6",\n        "type": "text",\n        "value": "1-855-676-5772",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_6",\n        "type": "text",\n        "value": "1-844-241-2495",\n        "page": 1,\n        "field_type": 2,\n        "field ...
#  3: '```json\n{\n  "pages": {\n    "1": [\n      {\n        "name": "F1.0[0]",\n        "type": "text",\n        "value": "1-866-503-0857 (TTY: 711)",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "F1.0[1]",\n        "type": "text",\n        "value": "1-844-268-7263",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "F1.0[2]",\n        "type": "text",\n        "value": "https://www.aetna.com/health-care-professionals/resource-center/availity.html",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "F1.0[3]",\n        "type": "text",\n        "value": "1-855-463-0933",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "F1.0[4]",\n        "type": "text",\n        "value": "1-833-280-5224",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "F1.0[5]",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/virginia-hmosnp/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "F1.0[6]",\n        "type": "text",\n        "value": "1-844-362-0934",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "F1.0[7]",\n        "type": "text",\n        "value": "1-833-322-0034",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "F1.0[8]",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/new-jersey-hmosnp/providers/portal.html",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "F1.0[9]",\n        "type": "text",\n        "value": "1-866-600-2139",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "F1.0[10]",\n        "type": "text",\n        "value": "1-855-320-8445",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "F1.0[11]",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/illinois/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "F1.0[12]",\n        "type": "text",\n        "value": "1-855-364-0974",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "F1.0[13]",\n        "type": "text",\n        "value": "1-855-734-9389",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "F1.0[14]",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/ohio/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "F1.0[15]",\n        "type": "text",\n        "value": "1-855-676-5772",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "F1.0[16]",\n        "type": "text",\n        "value": "1-844-241-2495",\n        "page": 1,\n        "field_type": 2,\ ...
#  4: '```json\n{\n  "pages": {\n    "1": [\n      {\n        "name": "Phone",\n        "type": "text",\n        "value": "1-866-503-0857",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax",\n        "type": "text",\n        "value": "1-844-268-7263",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity",\n        "type": "text",\n        "value": "https://www.aetna.com/health-care-professionals/resource-center/availity.html",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_2",\n        "type": "text",\n        "value": "1-855-463-0933",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_2",\n        "type": "text",\n        "value": "1-833-280-5224",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_2",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/virginia-hmosnp/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_3",\n        "type": "text",\n        "value": "1-844-362-0934",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_3",\n        "type": "text",\n        "value": "1-833-322-0034",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_3",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/new-jersey-hmosnp/providers/portal.html",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_4",\n        "type": "text",\n        "value": "1-866-600-2139",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_4",\n        "type": "text",\n        "value": "1-855-320-8445",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_4",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/illinois/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_5",\n        "type": "text",\n        "value": "1-855-364-0974",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_5",\n        "type": "text",\n        "value": "1-855-734-9389",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_5",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/ohio/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_6",\n        "type": "text",\n        "value": "1-855-676-5772",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_6",\n        "type": "text",\n        "value": "1-844-241-2495",\n        "page": 1,\n        "field_type": 2,\n        "field_type_ ...
#  5: '```json\n{\n  "pages": {\n    "1": [\n      {\n        "name": "Phone_1",\n        "type": "text",\n        "value": "1-866-503-0857",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": "Phone"\n      },\n      {\n        "name": "Phone_2",\n        "type": "text",\n        "value": "1-855-463-0933",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": "Phone"\n      },\n      {\n        "name": "Fax_1",\n        "type": "text",\n        "value": "1-844-268-7263",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": "Fax"\n      },\n      {\n        "name": "Availity_1",\n        "type": "text",\n        "value": "https://www.aetna.com/health-care-professionals/resource-center/availity.html",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": "Availity"\n      },\n      {\n        "name": "Fax_2",\n        "type": "text",\n        "value": "1-833-280-5224",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": "Fax"\n      },\n      {\n        "name": "Availity_2",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/virginia-hmosnp/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": "Availity"\n      },\n      {\n        "name": "Phone_3",\n        "type": "text",\n        "value": "1-844-362-0934",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": "Phone"\n      },\n      {\n        "name": "Fax_3",\n        "type": "text",\n        "value": "1-833-322-0034",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": "Fax"\n      },\n      {\n        "name": "Availity_3",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/new-jersey-hmosnp/providers/portal.html",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": "Availity"\n      },\n      {\n        "name": "Phone_4",\n        "type": "text",\n        "value": "1-866-600-2139",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": "Phone"\n      },\n      {\n        "name": "Fax_4",\n        "type": "text",\n        "value": "1-855-320-8445",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": "FAX"\n      },\n      {\n        "name": "Availity_4",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/illinois/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": "Availity"\n      },\n      {\n        "name": "Phone_5",\n        "type": "text",\n        "value": "1-855-364-0974",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": "Phone"\n      },\n      {\n        "name": "Fax_5",\n        "type": "text",\n        "value": "1-855-734-9389",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": "Fax"\n      },\n      {\n        "name": "Availity_5",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/ohio/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": "Availity"\n      },\n      {\n        "name": "Phone_6",\n        "type": "text",\n        "value": "1-855-676-5772",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": "Phone"\n      },\n      {\n        "name": "Fax_6",\n        "type": "text",\n        "value": "1-844-241-2495",\n        ...

# %% [markdown]
# ## form filling strategy

# %%
# 🤖 INTELLIGENT AUTO-MAPPING: Let AI map actual field names to patient data
print("🤖 Creating intelligent automated field mapping...")

# Get all actual PDF fields with their labels
doc = fitz.open("Input Data/Adbulla/PA.pdf")
pdf_fields = []
for page_num in range(len(doc)):
    page = doc[page_num]
    for widget in page.widgets():
        if widget.field_name and widget.field_label:
            pdf_fields.append({
                'field_name': widget.field_name,
                'field_type': widget.field_type_string,
                'field_label': widget.field_label,
                'page': page_num + 1
            })
doc.close()

    # Fill PDF with AI mappings - Enhanced with debugging
def fill_pdf_with_ai_mappings(input_pdf_path, output_pdf_path, mappings):
    doc = fitz.open(input_pdf_path)
    filled_count = 0
    skipped_count = 0
    
    print(f"🔧 Starting PDF filling with {len(mappings)} mappings...")
    
    for page_num in range(len(doc)):
        page = doc[page_num]
        
        for widget in page.widgets():
            field_name = widget.field_name
            
            if field_name in mappings:
                value = mappings[field_name]
                
                # Skip empty values
                if value == "" or value is None:
                    skipped_count += 1
                    continue
                
                try:
                    if widget.field_type == fitz.PDF_WIDGET_TYPE_CHECKBOX:
                        widget.field_value = bool(value)
                    elif widget.field_type == fitz.PDF_WIDGET_TYPE_TEXT:
                        widget.field_value = str(value)
                    else:
                        print(f"⚠️  Unknown field type for {field_name}: {widget.field_type}")
                        continue
                    
                    widget.update()
                    filled_count += 1
                    print(f"✅ {field_name}: {value}")
                    
                except Exception as e:
                    print(f"⚠️  Error filling {field_name}: {e}")
            else:
                # Debug: Show unmapped fields (first 10 only)
                if filled_count + skipped_count < 10:
                    print(f"🔍 Field '{field_name}' not in mappings")
    
    print(f"📊 Summary: {filled_count} fields filled, {skipped_count} skipped (empty values)")
    doc.save(output_pdf_path)
    doc.close()
    return filled_count
# Out:
# 🤖 Creating intelligent automated field mapping...

# %%
# 🚀 IMPROVED INTELLIGENT AUTO-MAPPING with Enhanced Coverage
print("🚀 Creating ENHANCED intelligent automated field mapping...")

# Enhanced mapping prompt that addresses all the gaps
enhanced_mapping_prompt = f"""You are an expert medical form automation specialist. Create comprehensive JSON mapping for a Prior Authorization form.

Pay attention to the whole context of the form and the patient data. And pay attention to this whole prompt including the middle parts

CRITICAL REQUIREMENTS:
1. Fill ALL possible fields where patient data is available
2. Handle checkbox dependencies (if main checkbox is checked, fill related sub-fields)
3. Include product/treatment information from clinical data
4. Use medical terminology appropriately
5. Format dates correctly for each field type
6. Handle multiple choice selections intelligently
7. NEVER use placeholder text like "(From Clinical Data)" - use actual data or leave blank

PDF FIELDS AVAILABLE:
{json.dumps(pdf_fields[:80], indent=2)}

PATIENT DATA AVAILABLE:
{referral_data}

SPECIFIC MAPPING INSTRUCTIONS:

A. PATIENT INFORMATION SECTION:
- Map full name to separate first/last name fields
- Map complete address (street, city, state, zip)
- Map all phone numbers (home, work, cell)
- Map DOB in correct format
- Map patient demographics

B. INSURANCE INFORMATION:
- Map member ID, group number, insured name
- Check for secondary coverage and map if available
- Map insurance carrier information

C. PRESCRIBER INFORMATION - CRITICAL RULES:
- Look for "Provider Contact Information" or similar headings in the clinical data
- Search for doctor/physician names in message records or clinical notes for inference if no difinitive contact information is found
- Extract actual prescriber contact details (address, phone, fax)
- Look for NPI numbers, DEA numbers in provider sections
- Check credentials (M.D., D.O., N.P., P.A.) from provider information
- If prescriber information is not clearly available, LEAVE FIELDS BLANK
- DO NOT use placeholder text like "Prescriber Address (From Clinical Data)"

D. TREATMENT/PRODUCT INFORMATION - ENHANCED SEARCH:
- Look for headings containing "Product", "Medication", "Drug", "Treatment"
- Search doctor comments and clinical notes for prescribed medications
- Look for drug names, dosages, frequencies in clinical documentation
- Check for diagnosis codes (ICD-10) in clinical data
- Search for treatment justification in physician notes
- If specific product/medication is not found, LEAVE FIELDS BLANK

E. DISPENSING/ADMINISTRATION:
- Determine administration method from clinical data
- Map pharmacy/dispensing location if specified
- Map administration codes if available

F. CHECKBOX LOGIC:
- If "Start of treatment" is checked, fill start date fields
- If "Continuation of therapy" is checked, fill last treatment date
- For dispensing location, check appropriate option based on data
- For prescriber type, check M.D., D.O., N.P., or P.A. based on credentials

G. DATE FORMATTING:
- For separate MM/DD/YYYY fields, split dates accordingly
- For single date fields, use MM/DD/YYYY format
- Extract dates from clinical timeline

H. MISSING DATA HANDLING - STRICT RULES:
- Only map fields where you have ACTUAL, SPECIFIC subject data
- If information is not clearly available in the clinical data, LEAVE THE FIELD BLANK
- Do not guess, weakly infer, or fabricate information
- Do not use placeholder text or generic descriptions
- Better to have fewer accurate fields than many inaccurate ones

SEARCH STRATEGY FOR PRESCRIBER INFO:
1. Search for "Provider Contact", "Physician Contact", "Doctor Information"
2. Look in message records for sender/physician information
3. Check clinical notes for prescribing physician details
4. If no specific prescriber info found, leave prescriber fields blank

SEARCH STRATEGY FOR PRODUCT INFO:
1. Look for explicit "Product" or "Medication" sections
2. Search doctor comments for drug names and prescriptions
3. Check treatment plans for specific medications
4. Look for pharmaceutical names in clinical documentation
5. If no specific product found, leave product fields blank

OUTPUT FORMAT - CRITICAL JSON REQUIREMENTS:
1. Return ONLY valid JSON (no markdown blocks, no extra text)
2. Ensure all JSON brackets and braces are properly closed
3. Use double quotes for all strings
4. Boolean values must be true/false (not True/False)
5. Do not truncate the JSON response

{{
  "field_mappings": {{
    "T12": "Shakh",
    "T13": "Abdulla", 
    "CB1": true,
    "T2": "05",
    "T3": "22", 
    "T4": "2024",
    "CB5": false,
    "T14": "04/01/2001",
    "T15": "425 Sherman Ave APT D",
    "T16": "Nashville",
    "T17": "TN",
    "T18": "37995"
  }},
  "mapping_notes": {{
    "total_fields_mapped": 0,
    "sections_completed": [],
    "missing_data_areas": [],
    "checkbox_decisions": {{}}
  }}
}}

IMPORTANT: Complete the entire JSON response. Do not truncate or cut off the JSON in the middle.

ANALYZE THE CLINICAL DATA THOROUGHLY and create comprehensive mappings using ONLY actual data found."""

# Send enhanced prompt to Gemini
print("🧠 Asking AI for ENHANCED comprehensive field mappings...")
# Extract structured data from referral package using Gemini vision
enhanced_response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents=[enhanced_mapping_prompt]
)


# Extract and apply enhanced mappings with ROBUST error handling
def robust_json_parser(json_text):
    """Advanced JSON parser that handles common formatting issues and truncation"""
    import re
    
    # Step 1: Extract JSON content
    if "```json" in json_text:
        json_start = json_text.find("```json") + 7
        json_end = json_text.find("```", json_start)
        if json_end == -1:  # No closing ```
            json_content = json_text[json_start:].strip()
        else:
            json_content = json_text[json_start:json_end].strip()
    else:
        json_content = json_text.strip()
    
    # Step 2: Try direct parsing first
    try:
        return json.loads(json_content)
    except json.JSONDecodeError:
        pass
    
    # Step 3: Advanced cleaning and repair
    print("🔧 Applying advanced JSON repair...")
    
    # Fix common issues
    json_content = re.sub(r'"CB\d+": tr(?![ue])', lambda m: m.group(0).replace('tr', 'true'), json_content)
    json_content = re.sub(r'"CB\d+": fa(?![lse])', lambda m: m.group(0).replace('fa', 'false'), json_content)
    
    # Step 4: Extract field mappings manually using regex
    field_mappings = {}
    
    # Pattern for text fields: "T12": "value"
    text_pattern = r'"(T\d+(?:\.\d+)?|CB\d+|Provider Admin [^"]+)"\s*:\s*"([^"]*)"'
    for match in re.finditer(text_pattern, json_content):
        field_mappings[match.group(1)] = match.group(2)
    
    # Pattern for boolean fields: "CB1": true/false
    bool_pattern = r'"(T\d+(?:\.\d+)?|CB\d+|Provider Admin [^"]+)"\s*:\s*(true|false)'
    for match in re.finditer(bool_pattern, json_content):
        field_mappings[match.group(1)] = match.group(2) == 'true'
    
    # Pattern for null fields: "T1": null
    null_pattern = r'"(T\d+(?:\.\d+)?|CB\d+|Provider Admin [^"]+)"\s*:\s*null'
    for match in re.finditer(null_pattern, json_content):
        field_mappings[match.group(1)] = None
    
    if field_mappings:
        print(f"✅ Extracted {len(field_mappings)} field mappings using regex parsing")
        return {"field_mappings": field_mappings, "mapping_notes": {"extraction_method": "regex"}}
    
    # Step 5: Last resort - create minimal mapping from visible data
    print("⚠️  Using fallback minimal mapping")
    return {
        "field_mappings": {
            "T12": "Shakh",
            "T13": "Abdulla", 
            "T14": "04/01/2001",
            "T15": "425 Sherman Aves APT D",
            "T16": "Nashville",
            "T17": "TN",
            "T18": "37923"
        },
        "mapping_notes": {"extraction_method": "fallback"}
    }

try:
    # Use the robust parser
    enhanced_mappings = robust_json_parser(enhanced_response.text)
    
    enhanced_field_mappings = enhanced_mappings.get("field_mappings", {})
    mapping_notes = enhanced_mappings.get("mapping_notes", {})
    
    print(f"\n🎯 ENHANCED AI created {len(enhanced_field_mappings)} comprehensive field mappings")
    
    # Show mapping summary
    if mapping_notes:
        print(f"📊 Total fields mapped: {mapping_notes.get('total_fields_mapped', len(enhanced_field_mappings))}")
        print(f"📋 Sections completed: {', '.join(mapping_notes.get('sections_completed', []))}")
        if mapping_notes.get('missing_data_areas'):
            print(f"⚠️  Missing data areas: {', '.join(mapping_notes.get('missing_data_areas', []))}")
    
    # Show sample enhanced mappings
    print("\nSample enhanced mappings:")
    for i, (field, value) in enumerate(list(enhanced_field_mappings.items())[:8]):
        print(f"  • {field} → {value}")
    
    # Apply enhanced mappings to PDF
    output_pdf_enhanced = "Input Data/Adbulla/PA_FILLED_ENHANCED.pdf"
    filled_count = fill_pdf_with_ai_mappings("Input Data/Adbulla/PA.pdf", output_pdf_enhanced, enhanced_field_mappings)
    
    print(f"\n🎉 ENHANCED MAPPING SUCCESS!")
    print(f"✅ Filled {filled_count} fields using enhanced AI mapping")
    print(f"📄 Enhanced PDF saved as: {output_pdf_enhanced}")
    
    # Compare with previous version
    previous_count = len(field_mappings) if 'field_mappings' in locals() else 0
    improvement = filled_count - previous_count
    if improvement > 0:
        print(f"🚀 IMPROVEMENT: +{improvement} more fields filled than previous version!")
    
except Exception as e:
    print(f"❌ Error in enhanced mapping: {e}")
    print("Full enhanced response:")
    print(enhanced_response.text)
# Out:
# 🚀 Creating ENHANCED intelligent automated field mapping...
# 🧠 Asking AI for ENHANCED comprehensive field mappings...
# ✅ Enhanced AI mapping completed!
# Response preview:
# ```json
# {
#   "field_mappings": {
#     "CB1": true,
#     "T2": "05",
#     "T3": "22",
#     "T4": "2024",
#     "CB5": false,
#     "T6": "",
#     "T7": "",
#     "T8": "",
#     "T9": "Erfan Rostami, BSN, RN",
#     "T10": "615-343-1176",
#     "T11": "615-343-1219",
#     "T12": "Shakh",
#     "T13": "Abdulla",
#     "T14": "04/01/2001",
#     "T15": "425 Sherman Ave APT D",
#     "T16": "Nashville",
#     "T17": "TN",
#     "T18": "37923",
#     "T19": "865-395-3958",
#     "T20": "",
#     "T21": "865-395-0481",
#     "T22": "",
#     "T24": "",
#     "T25": "",
#     "T26": "",
#     "T27": "",
#     "T23": "No Known Allergies",
#     "T28": "LAJM14345116",
#     "T29": "435000",
#     "T30": "ABDULLA, SHAKH",
#     "CB31": false,
#     "CB32": true,
#     "T33": "",
#     "T34": "",
#     "T35": "",
#     "T42": "Hao H",
#     "T43": "Gu",
#     "CB44": tr...
#
# 🎯 ENHANCED AI created 80 comprehensive field mappings
# 📊 Total fields mapped: 35
# 📋 Sections completed: Request Type/Dates (Start of Treatment), Patient Information (Demographics, Contact, Allergies), Patient's Health Plan Information (Primary & Secondary), Prescribing Physician Information, Product Administration/Dispensing Location
# ⚠️  Missing data areas: Patient work phone, email, height, weight, Date of last treatment (not applicable for new course), Secondary insurance details (not present in clinical data), Prescriber's Fax, State License #, DEA #, UPIN, Email, Administration codes (CPT), Home Infusion Agency details (not chosen for administration), TIN, PIN for administration location
#
# Sample enhanced mappings:
#   • CB1 → True
#   • T2 → 05
#   • T3 → 22
#   • T4 → 2024
#   • CB5 → False
#   • T6 →
#   • T7 →
#   • T8 →
# 🔧 Starting PDF filling with 80 mappings...
# ✅ CB1: True
# ✅ T2: 05
# ✅ T3: 22
# ✅ T4: 2024
# ✅ CB5: False
# ✅ T9: Erfan Rostami, BSN, RN
# ✅ T10: 615-343-1176
# ✅ T11: 615-343-1219
# ✅ T12: Shakh
# ✅ T13: Abdulla
# ✅ T14: 04/01/2001
# ✅ T15: 425 Sherman Ave APT D
# ✅ T16: Nashville
# ✅ T17: TN
# ✅ T18: 37923
# ✅ T19: 865-395-3958
# ✅ T21: 865-395-0481
# ✅ T23: No Known Allergies
# ✅ T28: LAJM14345116
# ✅ T29: 435000
# ✅ T30: ABDULLA, SHAKH
# ✅ CB31: False
# ✅ CB32: True
# ✅ T42: Hao H
# ✅ T43: Gu
# ✅ CB44: True
# ✅ CB45: False
# ✅ CB46: False
# ✅ CB47: False
# ✅ T48: 3320 Montgomery Dr
# ✅ T49: NASHVILLE
# ✅ T50: TN
# ✅ T51: 37361
# ✅ T52: 614-936-0065
# ✅ T55: 1154611523
# ✅ T58.1: Erfan Rostami, BSN, RN
# ✅ T59: 615-343-1176
# ✅ Provider Admin CB.1: False
# ✅ Provider Admin CB.2: False
# ✅ Provider Admin CB.3: False
# ✅ Provider Admin CB.4: True
# ✅ Provider Admin T.5: Children's Hematology - Oncology (Peds DOT 6)
# ✅ Provider Admin CB.7: False
# ✅ Provider Admin T.6: 615-936-1762
# ✅ Provider Admin CB.10: False
# ✅ Provider Admin CB.21: False
# ✅ Provider Admin CB.22: False
# ✅ Provider Admin CB.23.0.0: False
# ✅ Provider Admin CB.24.0.0: False
# ✅ Provider Admin CB.25: False
# ✅ Provider Admin CB.26: False
# ✅ T12: Shakh
# ✅ T13: Abdulla
# ✅ T19: 865-395-3958
# ✅ T14: 04/01/2001
# ✅ T12: Shakh
# ✅ T13: Abdulla
# ✅ T19: 865-395-3958
# ✅ T14: 04/01/2001
# ✅ T12: Shakh
# ✅ T13: Abdulla
# ✅ T19: 865-395-3958
# ✅ T14: 04/01/2001
# 📊 Summary: 63 fields filled, 29 skipped (empty values)
#
# 🎉 ENHANCED MAPPING SUCCESS!
# ✅ Filled 63 fields using enhanced AI mapping
# 📄 Enhanced PDF saved as: Input Data/Adbulla/PA_FILLED_ENHANCED.pdf
# 🚀 IMPROVEMENT: +63 more fields filled than previous version!
