# %% [markdown]
# ## Loading Model and Input Files

# %%
# 🔄 CLEAN INITIALIZATION - RESTART KERNEL IF NEEDED
print("🔄 Initializing environment...")
import pathlib
from google import genai
from google.genai import types
import os
import asyncio
import json
import fitz  # PyMuPDF for PDF processing
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Check if API key is loaded
api_key = os.getenv("GOOGLE_API_KEY")
if not api_key:
    raise ValueError("GOOGLE_API_KEY not found in environment variables. Please check your .env file.")

# Configure the API
client = genai.Client(api_key=api_key)


pa_file = "PA.pdf"
referral_file = "referral_package.pdf"

# Retrieve and encode the PDF byte
filepath = pathlib.Path('Input Data/Adbulla/' + pa_file)

print("✅ Setup complete!")
# Out:
# 🔄 Initializing environment...
# ✅ Setup complete!

# %% [markdown]
# ## Referral Package Analysis & Information Extraction to Json Using Google Gemini

# %%
# 🔄 DIRECT GEMINI OCR & ANALYSIS - Bypassing Mistral
print("🔄 Using Gemini directly for OCR and information extraction...")

# Enhanced prompt for direct PDF analysis
referral_prompt = """You are analyzing a referral package PDF (collection of scanned medical documents) to extract patient information that will be used to fill a Prior Authorization form.

CONTEXT: This referral package contains scanned documents like insurance cards, medical history notes, test results, and other supporting documentation. You need to perform OCR on the PDF and extract structured information.

EXTRACTION FOCUS: Use your vision capabilities to read and extract all available information and display it in order as it is read from the PDF. Then turn that output into JSON format:

PATIENT DEMOGRAPHICS:
- Full name, DOB, gender, address, phone numbers
- Patient ID numbers, MRN, account numbers
- Emergency contacts and relationships

INSURANCE INFORMATION:
- Insurance company name and plan details
- Member ID, group number, policy number
- Subscriber information and relationship to patient
- Coverage details and effective dates

CLINICAL INFORMATION:
- Primary and secondary diagnoses with ICD codes
- Current medications, dosages, and frequencies
- Allergies and adverse reactions
- Vital signs and lab results
- Previous treatments and outcomes
- Medical history and comorbidities

PROVIDER INFORMATION:
- Referring physician name, specialty, and contact info
- Practice name and address
- NPI numbers and license information
- Facility details where treatment will occur

TREATMENT DETAILS:
- Requested medication/procedure/device
- Dosage, frequency, duration
- Medical necessity justification
- Previous treatment failures
- Clinical criteria met for approval

SUPPORTING EVIDENCE:
- Lab results supporting diagnosis
- Imaging studies and results
- Functional assessments
- Specialist consultations
- Treatment response documentation

INSTRUCTIONS:
1. Carefully read through all pages of the PDF
2. Extract text and data from tables, forms, and documents
3. Pay attention to medical terminology and abbreviations
4. Look for provider contact information sections
5. Identify medication/product information from clinical notes
6. First return all info read in the document. List all information from tables including reference ranges and other details. Do not skip anything that has information
7. Then return a structured JSON with all relevant extracted information, using null for missing data"""

# Load and process the referral package PDF directly with Gemini
referral_pdf_path = 'Input Data/Adbulla/referral_package.pdf'

# Upload the PDF file to Gemini using new API
print(f"📄 Loading referral package: {referral_pdf_path}")
referral_file = client.files.upload(file=referral_pdf_path)
print(f"✅ File uploaded successfully: {referral_file.name}")

# Wait for file processing
import time
while referral_file.state == "PROCESSING":
    print("⏳ Processing file...")
    time.sleep(2)
    referral_file = client.files.get(name=referral_file.name)

if referral_file.state == "FAILED":
    raise ValueError("❌ File processing failed")
print("✅ File processed successfully")

# Extract structured data from referral package using Gemini vision
referral_response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents=[referral_prompt, referral_file]
)
referral_data = referral_response.text
print("📊 Referral Package Data Extracted:")
print(referral_data)

# Store the extracted text for compatibility with existing code
referral_package_text = referral_data
# Out:
# 🔄 Using Gemini directly for OCR and information extraction...
# 📄 Loading referral package: Input Data/Adbulla/referral_package.pdf
# ✅ File uploaded successfully: files/mvg635k614g9
# ✅ File processed successfully
# 📊 Referral Package Data Extracted:
# Here is the extracted information from the PDF, presented first as raw text, and then in a structured JSON format.
#
# ---
#
# ## Raw Information Extracted from PDF:
#
# **Page 1/15**
#
# *   **FAX TRANSMISSION**
#     *   Date: 04/22/2024 WED 11:32 FAX
#     *   Page Number: 001/028
# *   **Sender:**
#     *   Name: Better Life Multiple Sclerosis Center
#     *   Address: 3320 Montgomery Dr. Nashville, TN 37361
#     *   Fax: 615-562-4820
#     *   Phone: 615-562-4848
#     *   Doctors: Dr. Asriel Han | Dr. Aditya Shah
# *   **Recipient:**
#     *   Name: Golden Gate Infusion Center
#     *   Fax: 614-278-3355
#     *   Phone: 614-895-7655
# *   **From (Sender's Contact):**
#     *   Name: Erfan Rostami, BSN, RN
#     *   Phone: 615-343-1176
#     *   Fax: 615-343-1219
# *   **Pages:** (including cover sheet) - Not specified, but document implies 28 pages total.
# *   **Comments:**
#     *   Arabic - Spoken / English - Written
#     *   Rituxan (Truxima) TP
#     *   MRI Reports
#     *   Hospital D/C note
#     *   Demographics
# *   **Confidentiality Notice:**
#     *   The documents accompanying this transmission may contain health information that is legally protected. This information is intended only for the use of the Individual or entity named above. The authorized recipient of this information is prohibited from disclosing this Information to any other party unless permitted by law or regulation.
#     *   If you are not the intended recipient, you are hereby notified that any use, disclosure, copying or distribution of these documents is strictly prohibited. If you have received this Information in error, please notify the sender Immediately and arrange for the return or destruction of these documents.
#
# **Page 2/15**
#
# *   Header: 05/22/2024 WED 11:32 FAX, 5/22/24, 11:10 AM
# *   Patient Name: Abdulla, Shakh
# *   MRN: 041152153
# *   **Communication 5/16/2024**
#     *   Status: Open
#     *   Clinic: Better Life Multiple Sclerosis Center
#     *   Provider: Erfan Rostami, RN
#     *   Reason for call: Truxima Second Initial Dose Needed Week of June 3
# *   **All Conversations: Truxima Second Initial Dose Needed Week of June 3** (Newest Message First)
#     *   **May 21, 2024**
#         *   From: Jha, Vedant to Erfan Rostami, RN (5/21/24 4:44 PM)
#             *   Message: Hi Erfan, The only way Extraordinary Care could see his Medicaid plan would be at home :( I'm not sure if he is able to be seen at a hospital based infusion center closer to home? We will hold off on this one for now- let me know if you're not able to find a provider who can see him in the infusion suite and we will re-open the referral.
#     *   Erfan Rostami, RN routed this conversation to Jha, Vedant (5/21/24 2:32 PM)
#     *   **May 20, 2024**
#         *   From: Gu, Hao H, MD to Erfan Rostami, RN (5/20/24 5:13 PM)
#             *   Note: No home infusion. Her first dose is scheduled may 23. Second dos 2 weeks from may 23 first
#     *   Erfan Rostami, RN routed this conversation to Gu, Hao H, MD (5/20/24 3:41 PM)
#     *   From: Jha, Vedant to Erfan Rostami, RN (5/20/24 2:54 PM)
#         *   Message: Hi, Is Dr. Gu comfortable with this patient being seen for home infusion? Thanks,
#
# **Page 3/15**
#
# *   Header: Abdulnabi, Shakh (MR #041152153) DOB: 04/01/2001, 05/22/2024 WED 11:33 FAX, 5/22/24, 10:33 AM
# *   Patient Name: Shakh Abdulla
# *   MRN: 041152153
# *   Description: male DOB: 4/1/2001
# *   Therapy Plan 1 Summary
# *   **Patient Demographics Table:**
#     *   Patient Name: Abdulla. Shakh
#     *   Legal Sex: male
#     *   DOB: 4/1/2001
#     *   Address: 425 Sherman Ave, Nashville TN 37995
#     *   Phone (Home): 865-395-3958
#     *   Phone (Mobile): 865-395-0481 (*Preferred*)
# *   **Medication:**
#     *   Rituximab Or Biosimilar Days 1, 15 Load Then Once Every 24 Weeks
# *   **Associated Problems:**
#     *   Problem: Multiple sclerosis in pediatric patient (CMS/HCC) [G35]
#     *   Selected Diagnosis: Multiple sclerosis in pediatric patient (CMS/HCC) [G35]
# *   **Infusion Orders - All Current Orders Table:**
#     *   **Nursing Orders: IV access**
#         *   Interval: Every visit
#         *   Due: Every visit
#         *   Care Instructions: Obtain IV access (PIV, PORT, etc.) and start NS 0.9% @ KVO Until discontinued Starting when released Until Specified
#         *   Last released: Never
#         *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
#     *   **Nursing Orders: Monitor pt for hypersensitivity reaction**
#         *   Interval: Every visit
#         *   Due: Every visit
#         *   Care Instructions: Once Starting when released for 1 occurrence If allergic reaction or infusion related reaction occurs, initiate adult hypersensitivity reaction protocol or pediatric guideline and CALL MD for additional orders.
#         *   Last released: Never
#         *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
#     *   **Nursing Orders: NURSING COMMUNICATION**
#         *   Interval: Every visit
#         *   Due: Every visit
#         *   Care Instructions: Ensure that patient has not taken antihypertensive medications in the 12 hours prior to infusion Until discontinued Starting when released Until Specified
#         *   Last released: Never
#         *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
#     *   **Nursing Orders: NURSING COMMUNICATION**
#         *   Interval: Every visit
#         *   Due: Every visit
#         *   Care Instructions: For Hypotension, place patient in Trendelenberg position, support with NS, and call MD Until discontinued Starting when released Until Specified
#         *   Last released: Never
#         *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
#
# **Page 4/15**
#
# *   Header: Abdulnabi, Shakh (MR #041152153) DOB: 04/01/2001, 05/22/2024 WED 11:33 FAX, 6/22/24, 10:33 AM
# *   **Labs:**
#     *   **IgG**
#         *   Interval: Every 24 weeks
#         *   Due: Week of 5/19/2024
#         *   Care Instructions: Clinic Collect, Blood
#         *   Last released: Never
#         *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
#     *   **CBC w/ Differential**
#         *   Interval: Every visit
#         *   Due: Every visit
#         *   Care Instructions: Once Starting when released, Blood
#         *   Last released: Never
#         *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
#     *   **Flow Lymphocytes Subsets (TBNK)**
#         *   Interval: Every visit
#         *   Due: Every visit
#         *   Care Instructions: Once Starting when released, Blood
#         *   Last released: Never
#         *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
# *   **Vitals:**
#     *   **Vital Signs**
#         *   Interval: Every visit
#         *   Due: Every visit
#         *   Care Instructions: Obtain VS prior to start therapy, Q30 minutes with each dose increase and at the end of treatment. As needed Starting when released Until Specified
#         *   Last released: Never
#         *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024
# *   **Hydration:**
#     *   **heparin, porcine (PF) 100 unit/mL syringe 5 mL**
#         *   Interval: PRN
#         *   Due: PRN
#         *   Care Instructions: 5 mL, intraVENOUS, As needed, For flushing Ports/ PICC lines/ Central Lines IF NEEDED, Starting when released, Until Discontinued
#         *   Last released: Never
#         *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
# *   **Pre-Medications:**
#     *   **acetaminophen (TYLENOL) tablet 650 mg**
#         *   Interval: Every visit
#         *   Due: Every visit
#         *   Care Instructions: 650 mg, oral, Once, Starting when released
#         *   Last released: Never
#         *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
#     *   **diphenhydrAMINE (BENADRYL) 50 mg in 50 mL NS**
#         *   Interval: Every visit
#         *   Due: Every visit
#         *   Care Instructions: 50 mg, intraVENOUS, Once, Administer 30 minutes before starting infusion.
#         *   Last released: Never
#         *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
#     *   **methylPREDNISolone sod succinate (SOLU-Medral) (20 mg/mL) 125 mg in NS 6.2 mL**
#         *   Interval: Every visit
#         *   Due: Every visit
#         *   Care Instructions: 125 mg, intraVENOUS, Once, Administer 30 minutes before starting infusion.
#         *   Last released: Never
#         *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
#
# **Page 5/15**
#
# *   Header: Abdulnabi, Noor (MR #048152163) DOS: 01/01/2008, 05/22/2024 WED 11:33 FAX, 5/22/24, 10:33 AM (Note: Patient and MRN inconsistent with previous pages. Assuming this is a template error and prior patient details hold.)
# *   **Infusion Therapy:**
#     *   **NURSING COMMUNICATION**
#         *   Interval: Every visit
#         *   Due: Every visit
#         *   Care Instructions: Until discontinued Starting when released Until Specified. Infusion rate (standard only) 1st infusion - initiate at 50mg/hr and if no infusion toxicity reaction, may increase by 50mg/hr ever 30 minutes; Max Rate 400mg/hr. Subsequent infusions - initiate at 100mg/hr and if no infusion toxicity reaction, may increase by 100mg/hr every 30 min; Max Rate 400mg/hr
#         *   Last released: Never
#         *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
#     *   **Infusion Therapy - Initial Dose: riTUXimab-abbs (TRUXIMA) IVPB**
#         *   Interval: Every 2 weeks
#         *   Duration: 2/2 remaining
#         *   Due: Week of 5/19/2024
#         *   Care Instructions: 694 mg (rounded from 693.75 mg = 375 mg/m2 x 1.85 m2 - BSA might be out of date), intraVENOUS, Once, Starting 30 minutes after treatment start time
#         *   Last released: Never
#         *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
#     *   **Infusion Therapy - Maintenance Dose: riTUXimab-abbs (TRUXIMA) IVPB**
#         *   Interval: Every 24 weeks
#         *   Due: Mon 11/4/2024
#         *   Care Instructions: Defer until: Mon 11/4/2024. 694 mg (rounded from 693.75 mg = 375 mg/m2 x 1.85 m2 - BSA might be out of date), intraVENOUS, Once, Starting when released
#         *   Last released: Never
#         *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
# *   **PRN Medications:**
#     *   **diphenhydrAMINE (BENADRYL) injection 25 mg**
#         *   Interval: PRN
#         *   Due: PRN
#         *   Care Instructions: 25 mg, intraVENOUS, As needed, chills, Starting when released, for 2 doses
#         *   Last released: Never
#         *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
#     *   **meperidine (DEMEROL) injection 25 mg**
#         *   Interval: PRN
#         *   Due: PRN
#         *   Care Instructions: 25 mg, intraVENOUS, As needed, rigors, Starting when released, for 2 doses
#         *   Last released: Never
#         *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
#     *   **ondansetron (ZOFRAN) injection 4 mg**
#         *   Interval: PRN
#         *   Due: PRN
#         *   Care Instructions: 4 mg, intraVENOUS, As needed, nausea, vomiting, Starting when released, for 2 doses. Doses up to 4 mg may be administered undiluted. Inject over at least 30 seconds, but preferably over 2-5 minutes.
#         *   Last released: Never
#         *   Electronically Signed By: Gu, Hao H, MD on 5/15/2024 5:11 PM
# *   **eSignature Information:**
#     *   All order signatures are valid for 1 (one) year from the signature date.
# *   **Provider Contact Information:** (Continues on next page)
#
# **Page 6/15**
#
# *   Header: Abdulnabi, Noor (MR #048152153) DOB: 01/01/2008, 05/22/2024 WED 11:34 FAX, 5/22/24, 10:33 AM (Note: Patient and MRN inconsistent with patient of focus.)
# *   **Provider Contact Information:**
#     *   Provider Name: Hao H Gu, MD
#     *   NPI: 1154611523
#     *   Practice: Better Life Multiple Sclerosis Center
#     *   Address: 3320 Montgomery Dr NASHVILLE TN 37361
#     *   Phone: 614-936-0065
#
# **Page 7/15**
#
# *   Header: 05/22/2024 WED 11:34 FAX, 007/028
# *   **Better Life Multiple Sclerosis Center**
#     *   Patient: Shakh Abdulla
#     *   Hospital A/C: (empty)
#     *   Care Everywhere ID#: VDJ-7KR2-4847-LGF8
# *   **ENCOUNTER:**
#     *   Patient Class: (empty)
#     *   Admission Date/Time: 5/17/2024
#     *   Admission User: (empty)
#     *   Referring Physician: (empty)
#     *   Admitting Provider: (empty)
#     *   Attending Provider: (empty)
#     *   Adm Diagnosis: MyHealth Bundle Status: (empty)
# *   **PATIENT Table:**
#     *   Name: Shakh Abdulla
#     *   Address: 425 Sherman Aves APT D, Nashville TN 37923
#     *   DOB: 4/1/2001 (23 yrs)
#     *   Sex: male
#     *   Primary Care Provider: James David, PNP
#     *   Pref Lang: Arabic
#     *   Marital Status: Single
#     *   Primary Phone: 865-839-7458
#     *   Mobile Phone: 865-839-7458
# *   **EMERGENCY CONTACT Table:**
#     *   Contact Name | Legal Guardian? | Relationship to Patient | Home Phone | Work Phone
#     *   1. Sina, Amin | Yes | Father | (empty) | (empty)
#     *   2. Mohammedreza, Mustala | Yes | Mother | (empty) | (empty)
# *   **GUARANTOR Table:**
#     *   Guarantor: (empty)
#     *   DOB: 10/29/1979
#     *   Address: (empty)
#     *   Sex: Female
#     *   Relation to Patient: (empty)
#     *   Home Phone: (empty)
#     *   Guarantor ID: (empty)
#     *   Mobile Phone: (empty)
#     *   Work Phone: (empty)
# *   **GUARANTOR EMPLOYER:**
#     *   Status: NOT EMPLO
#     *   "There is no guarantor information entered for this encounter."
# *   **COVERAGE - PRIMARY INSURANCE Table:**
#     *   Payor: (empty)
#     *   Plan: TC BLUE CARE NO COPAY
#     *   Group Number: (empty)
#     *   Insurance Type: (empty)
#     *   Subscriber Name: (empty)
#     *   Subscriber DOB: (empty)
#     *   Subscriber ID: (empty)
#     *   Financial Class: (empty)
#     *   Pat. Rel. to Subscriber: (empty)
# *   **COVERAGE - SECONDARY INSURANCE Table:**
#     *   Payor: (empty)
#     *   Plan: (empty)
#     *   Group Number: (empty)
#     *   Insurance Type: (empty)
#     *   Subscriber Name: (empty)
#     *   Subscriber DOB: (empty)
#     *   Subscriber ID: (empty)
#     *   Pat. Rel. to Subscriber: (empty)
# *   Footer: May 22, 2024, Hospital Face Sheet
#
# **Page 8/15**
#
# *   Header: Abdulnabi, Noor (MRN: 041152153) DOB: 4/1/2001, 05/22/2024 WED 11:34 FAX, 5/22/24, 10:37 AM (Note: Patient name inconsistent, MRN and DOB consistent with Shakh Abdulla, likely a template issue.)
# *   **Primary Coverage Table:**
#     *   Payer: BC TENNCARE
#     *   Plan: TC BLUE CARE NO COPAY
#     *   Sponsor Code: (empty)
#     *   Group Number: 435000
#     *   Group Name: TENNCARE/BLUECARE
# *   **Primary Subscriber Table:**
#     *   ID: LAJM14345116
#     *   Name: ABDULLA, SHAKH
#     *   SSN: xxx-xx-8143
#     *   Address: 8327 BROADWAY LN APT D, KNOXVILLE, TN 37923
#
# **Page 9/15**
#
# *   Header: 05/22/2024 WED 11:34 FAX, 5/22/24, 10:39 AM
# *   Patient Name: Abdulla, Shakh
# *   MRN: 048152153 (Note: This MRN is inconsistent with 041152153 seen on other pages for Shakh Abdulla. Will prioritize the one found more consistently.)
# *   **ED to Hosp-Admission:**
#     *   Dates: 5/14/2024 - 5/17/2024 (3 days)
#     *   Status: Discharged
#     *   Facility: Monroe Carell Jr. Children's Hospital
#     *   Last attending: Harry, Tom, MD with Treatment team
#     *   Principal problem: Abnormal MRI
# *   **Discharge Summary:**
#     *   Cosigned by: Gu, Hao H, MD at 5/17/2024 1:56 PM
#     *   Resident Physician: Kaine, Adam Jason, MD - Pediatric Neurology
#     *   Attestation signed by Gu, Hao H, MD at 5/17/2024 1:56 PM (Updated)
#     *   "I saw the patient on: 5/17/2024 with Dr Kaine, I discussed the care with Dr Kaine, patient and his father at bedside and agree with the findings and plan as documented in the attached note. I personally spent more than 30 minutes on the patient's care unit in the preparation and execution of the hospital discharge."
#     *   **Discharge Plan/Treatments:**
#         *   S/p 4 days of high dose IVMP (1g/dose) today-
#         *   Discharge home with oral decadron 180mg (equivalent to 1000mg IVMP) x 1 to round out 5 days of high dose steroid treatment for active demyelinating lesion (family wishes to be discharged today instead of Saturday)
#         *   He will then start oral prednisone taper- instructions provided +PPI
#         *   First dose of Rituximab or biosimilar scheduled for May 22 at 9am; second dose of first course of Rituximab within 2 weeks after, we are working with local infusion facility in Knoxville to get this set up for her moving forward to minimize travel
#         *   He will follow up with ophthalmologist in Knoxville
#         *   School note for this week and next week
#         *   PT/OT locally
#         *   Continue vitamin D
#         *   I will see her tentatively 3 months after completion of 1st course of Rituximab -with same day MRI (she does not need sedation)- looking to early or mid September. Will update family once we have that arranged
#     *   Signed: Hao Gu MD
# *   **Neurology Discharge Summary:**
#     *   Patient Name: Shakh Abdulla
#     *   DOB: 4/1/2001
#     *   Service: Pediatric Neurology
#     *   Attending: Harry, Tom, MD
#     *   Date of Admission: 5/14/2024
#
# **Page 10/15**
#
# *   Header: 05/22/2024 WED 11:34 FAX, 5/22/24, 10:39 AM
# *   Date of Discharge: 5/17/2024
# *   **Diagnosis:**
#     *   Principal Problem: Abnormal MRI
#     *   Resolved Problems: * No resolved hospital problems.
# *   **Procedures:**
#     *   Bedside Procedures: No orders of the defined types were placed in this encounter.
#     *   OR Procedures: * Cannot find OR case *
# *   **Synopsis:**
#     *   "Shakh Abdulla is a 23 year old male who established care with VCH neurology; with MRI brain and spine demonstrating multiple lesions consistent with atypical pediatric MS."
# *   **Hospital Course:**
#     *   "Shakh Abdulla is a 23 year old male with history of optic neuritis and abnormal MRI brain concerning for MS who presented for admission following clinic visit and neuroimaging today. History from primary neurologist, clinic visit and patient and father at bedside. Patient referred to Dr. Gu by Dr. Fazal in East Bay Confirms predominant symptoms since April of numbness in his right hand and urinary hesitancy/urgency. Additionally reporting right eye pain since time of clinic visit this morning. MRI brain and spine obtained following clinic visit and multiple lesions noted on brain and spine suggestive of pediatric MS. Presents for admission for IVMP."
#     *   **Per clinic visit earlier today with Dr. Gu and confirmed with family at bedside:**
#         *   "Shakh is a 23 years old male, previously healthy who has been referred to neuroimmunology clinic for diagnosis of optic neuritis and abnormal brain MRI concerning for MS. He is referred by Dr Fazal-pediatric neurology in East Bay"
#         *   "he is here with dad; patient himself is an excellent historian and provided the following information- I do not have CSF results nor clinic note- I do have MRI report from Jan 21 2024 (no actual images)- with father and his permission, I reached out to Dr Shane- Dr Fazal's colleague on service who can help assist with quick access to Shakh's chart."
#         *   **Symptoms:** around early Oct 2023- he started to notice in right eye "neon bright color" fuzzy vision, and eye pain with movement and perhaps right side of his face in discomfort triggered by physical activities. Symptoms improved once he rested. By end of Oct 2023, he brought this up to parents and was brought to local eye doctor and recalled being told that"right eye being inflamed" and he recalled visual field deficits appreciated during exam.
#         *   **Previous Consultations/Treatments:** He was referred to UT ophthalmology Dr Derrek in Jan this year, per report negative MOG and AQP4 [While waiting on this appt, he thought some improvement but not back to baseline entirely -"not completely normal"]. When he saw UT ophthalmology clinic, recommended brain and orbit and noted WM changes and MS was mentioned. He was treated with 5 days of IVMP and referred to see Dr Kosentka ped neurology.
#         *   **MRI report from Jan 21 2024:** "Diffuse T2 hyperintensity and decreased volume throughout the right optic nerve is similar to prior examination however assocaited abnormal enhancement seen on prior study has resoved, presumably secondary to interveal treatment. Left optic nerve is subtle but diffusely small in caliber without significant change from last exam. Several intracranial WM lesions, stable from last"
#         *   **CSF Results:** He saw Dr Fazal in Feb 2024-who obtained LP and had markers of MS and referred to MS clinic today. Below are information provided by Dr Shane. Per note recommended referral to our MS center for further evaluation and treatment.
#             *   CSF: WBC (not specified), 837 rbc, IgG Index 0.87 (elevated), +OCB
#         *   **History since April:** Prior to appt today May 14- he noted that in April of this year, started to have involvement of LEFT eye - again similar with "neon colors appearance", some eye discomfort; it happened several times during the day for a few days and has since resolved. Since April he has had intermittent numbness In his right hand (dominant hand)+ along with muscle twitch in his hands and shoulder like tics. He has noticed a change with urinary hesitancy- taking a long time to empty his bladder and in addition urinary urgency. He has not noticed weakness but noted intermittent drifting to right side, bumping in to things. He does note that at times when he laughs, bends his neck, does note electrical sensation. Academically doing very well, no difficulty. Sleeps well.
#         *   Family history: parents and brothers are healthy
#     *   **Floor course (05/14 -):**
#         *   "Patient was admitted to the wards in a stable condition."
#         *   "Patient was initiated on high dose steroids for 5 days and tolerated well. MRI consistent with lesions in the brain and spinal cord consistent with atypical MS. ANA was positive as well as SSB so rheumatology was consulted but felt she did not have evidence of another systemic autoimmune disease. PT/OT evaluated his and he will follow outpatient. He will be dc with Decadron and then steroid taper with Pepcid prophylaxis. He was arranged to have outpatient rituximab and Dr. Gu will follow his in clinic."
#
# **Page 11/15**
#
# *   Header: 05/22/2024 WED 11:35 FAX, 6/22/24, 10:39 AM
# *   **Physical Exam (First instance):**
#     *   Temp: [36.5 °C (97.7 °F)-36.7 °C (98.1 °F)] 36.7 °C (98 °F)
#     *   Pulse: [81-99] 84
#     *   Resp: [16-18] 16
#     *   BP: (122-136)/(63-99) 126/63
#     *   SpO2: [98%] 98%
# *   **Physical Exam (Second instance - identical data):**
#     *   Temp: [36.5 °C (97.7 °F)-36.7 °C (98.1 °F)] 36.7 °C (98 °F)
#     *   Pulse: [81-99] 84
#     *   Resp: [16-18] 16
#     *   BP: (122-136)/(63-99) 126/63
#     *   SpO2: [98%] 98%
# *   General: Well appearing; NAD
# *   CV: -RRR
# *   **HIGHER INTEGRATIVE FUNCTIONS:**
#     *   -Attention & concentration: Normal
#     *   -Orientation: Oriented to person, place & time
#     *   -Memory: Recent and remote memory intact
#     *   -Language: Normal
#     *   -Fund of Knowledge: Normal
# *   **CRANIAL NERVES:**
#     *   -CN 2: Visual fields full
#     *   -CN 2,3: PERRL; rAPD
#     *   -CN 3,4,6: EOMI
#     *   -CN 5: Facial sensation intact
#     *   -CN 7: Facial strength/movement intact bilaterally
#
# **Page 12/15**
#
# *   Header: 05/22/2024 WED 11:35 FAX, 5/22/24, 10:39 AM
# *   **CRANIAL NERVES (continued):**
#     *   -CN 8: Hearing normal bilaterally
#     *   -CN 9,10: Palate elevates symmetrically
#     *   -CN 11: Normal shoulder shrug and head turn
#     *   -CN 12: Tongue protrudes midline
# *   **MOTOR:**
#     *   -Muscle tone normal in upper and lower extremities
#     *   -Muscle strength 5/5 In upper and lower extremities; RLE 4+ proximally
# *   **SENSATION:**
#     *   -Intact to light touch in upper and lower extremities bilaterally
# *   **COORDINATION:**
#     *   -Finger/nose intact bilaterally
# *   **GAIT:**
#     *   -Normal gait
# *   **Immunizations/Injections Administered for This Admission:**
#     *   No immunizations on file.
# *   **Allergies:** No Known Allergies
# *   **Diagnostic Studies - Recent Results (from the past 24 hour(s)):**
#     *   **CBC w/ Differential - Collection Time: 05/14/24 10:47 AM**
#         *   Result | Value | Ref Range
#         *   White Blood Cells | 7.7 | 3.4 - 10.2 x10(3)/mcL
#         *   Red Blood Cells | 4.63 | 3.80 - 5.50 x10(6)/mcL
#         *   Hemoglobin | 13.0 | 12.0 - 16.0 gm/dL
#         *   Hematocrit | 40 | 35 - 49 %
#         *   Mean Cell Volume | 86 | 76 - 96 fL
#         *   Mean Cell Hemoglobin | 28.1 | 25.0 - 35.0 pg
#         *   Mean Cell Hemoglobin Concentration | 32.7 | 32.0 - 37.0 gm/dL
#         *   RDW SD | 38.4 | 37.4 - 52.4 fL
#         *   RDW CV | 12.3 | 11.1 - 14.3 %
#         *   Platelet | 300 | 150 - 400 x10(3)/mcL
#
# **Page 13/15**
#
# *   Header: 05/22/2024 WED 11:35 FAX, 5/22/24, 10:30 AM
# *   **Lab Results (continued from previous page):**
#     *   **Mean Platelet Volume:**
#         *   Value: 10.0
#         *   Ref Range: 9.3 - 12.8 fL
#     *   **Nucleated RBC:**
#         *   Value: 0
#         *   Ref Range: 0 - 0/100 WBC
#     *   **Nucleated RBC Abs:**
#         *   Value: 0.00
#         *   Ref Range: 0.00 - 0.00 x10(3)/mcL
#     *   **Auto Neutrophil Absolute:**
#         *   Value: 4.52
#         *   Ref Range: 1.80 - 7.70 x10(3)/mcL
#     *   **CMP - Collection Time: 05/14/24 10:47 AM**
#         *   Result | Value | Ref Range
#         *   Sodium Level | 139 | 138-145 mmol/L
#         *   Potassium Level | 3.8 | 3.3-4.8 mmol/L
#         *   Chloride Level | 101 | 98-107 mmol/L
#         *   Carbon Dioxide | 22 | 17-28 mmol/L
#         *   Anion Gap | 16 | mmol/L
#         *   Glucose Level | 95 | 60-99 mg/dL
#         *   Blood Urea Nitrogen | 13 | 7-18 mg/dL
#         *   Creatinine Level | 0.67 | 0.50-0.90 mg/dL
#         *   Calcium Level Total | 9.9 | 8.4-10.2 mg/dL
#         *   Billrubin Total | 0.4 | 0.0-0.7 mg/dL
#         *   Albumin Level | 4.7 | 4.0-5.3 gm/dL
#         *   Protein Total | 8.4 (H) | 6.3-7.8 gm/dL
#         *   Alkaline Phosphatase | 55 | 50-117 unit/L
#         *   Aspartate Aminotransferase | 25 | 21-34 unit/L
#         *   Alanine Aminotransferase | <6 | 0-17 unit/L
#     *   **Hepatitis B Pnl - Collection Time: 05/14/24 10:47 AM**
#         *   Result | Value | Ref Range
#         *   Hepatitis B Surface Antigen | Negative | Negative
#         *   Hep B Core Ab Total | Negative | Negative
#         *   Hepatitis B Surface Ab Unit | 44.7 (H) | <=10.0 mlU/mL
#         *   Hep Bs Ab Interp | Positive (A) | Negative
#     *   **IgG - Collection Time: 05/14/24 10:47 AM**
#         *   Result | Value | Ref Range
#         *   IgG Quantitative | 1,355 (H) | 600-1,310 mg/dL
#
# **Page 14/15**
#
# *   Header: 05/22/2024 WED 11:35 FAX, 6/22/24, 10:39 AM
# *   **Lab Results (continued):**
#     *   **IgA - Collection Time: 05/14/24 10:47 AM**
#         *   Result | Value | Ref Range
#         *   IgA Quantitative | 279 | 40-290 mg/dL
#     *   **Auto Diff - Collection Time: 05/14/24 10:47 AM**
#         *   Result | Value | Ref Range
#         *   Neutrophils | 58.3 | %
#         *   Absolute Neutrophils | 4.52 | 1.80-7.70 x10(3)/mcL
#         *   Lymphs | 33.6 | %
#         *   Absolute Lymphocytes | 2.60 | 1.70-4.50 x10(3)/mcL
#         *   Monocytes | 6.5 | %
#         *   Absolute Monocytes | 0.50 | 0.20-1.00 x10(3)/mcL
#         *   Eosinophils | 0.5 | %
#         *   Absolute Eosinophils | 0.04 | 0.00-0.50 x10(3)/mcL
#         *   Basophils | 0.8 | %
#         *   Absolute Basophils | 0.06 | 0.01-0.08 x10(3)/mcL
#         *   Imm Gran Automated | 0.3 | %
#         *   Absolute Imm Gran Automated | 0.02 | 0.00-0.03 x10(3)/mcL
# *   **Consultations Obtained - Orders Placed This Encounter:**
#     *   Procedures:
#         *   Inpatient Consult to Pediatric Ophthalmology
#         *   Inpatient Consult to Pediatric Rheumatology
#         *   Inpatient consult to Case Management:
# *   **Condition at Discharge:** Stable
# *   **Disposition:** Home or Self Care
# *   **Patient Instructions:**
# *   **Discharge Medications - New Medications Table:**
#     *   Medication | Sig
#     *   dexamethasone 4 mg/mL CONCENTRATED solution | Take 45 mL (180 mg total) by mouth daily for 1 dose. See comment
#     *   famotidine 40 mg tablet (Commonly known as: PEPCID) | Take 1 tablet (40 mg total) by mouth daily.
#
# **Page 15/15**
#
# *   Header: 05/22/2024 WED 11:35 FAX, 5/22/24, 10:39 AM
# *   **Discharge Medications (continued):**
#     *   Medication | Sig
#     *   predniSONE 20 mg tablet (Commonly known as: DELTASONE) | Start taking on: May 16, 2024. Take 3 tablets (60 mg total) by mouth daily for 7 days, THEN 2 tablets (40 mg total) daily for 7 days, THEN 1 tablet (20 mg total) daily for 7 days, THEN 0.5 tablets (10 mg total) daily for 7 days. Then stop.
# *   **Activity Instructions:**
#     *   Discharge activity - Normal Activity: Some medications such as for example pain medications and sleeping or anti-anxiety agents may affect your ability to operate heavy machinery including driving. Please always carefully read the labels on the medications that you take. If you have experienced confusion, seizures, lightheadedness or blackouts then it may not be safe or even legal for you to operate heavy machinery (including driving). Please act in the interest of your own safety and that of others. Speak to a physician If you are not sure whether it is safe or legal for you to drive.
#     *   Care Instructions: You should engage in exercise as tolerated to improve your health. You may go to the website of the American Heart Association for additional information and tips on how to exercise right (www.americanheart.org).
# *   **Scheduled Appointments:**
#     *   Date/Time: May 22, 2024 10:30 AM
#     *   Appointment Type: Peds Infusion (Leantaas) with PEDS INF UMBRELLA, PEDS 241+ MIN INFUSION, Children's Hematology - Oncology (Peds DOT 6)
#     *   Address: 2211 Broad Way, Tower 4th FL, Suite 6102, Nashville TN 37232
#     *   Phone: 615-936-1762
#
# ---
#
# ## Structured JSON Output:
#
# ```json
# {
#   "PATIENT_DEMOGRAPHICS": {
#     "full_name": "Shakh Abdulla",
#     "dob": "04/01/2001",
#     "age": "23 yrs",
#     "gender": "male",
#     "address": "425 Sherman Ave APT D, Nashville, TN 37923",
#     "phone_numbers": {
#       "home": "865-395-3958",
#       "mobile": "865-395-0481 (Preferred)",
#       "primary": "865-839-7458"
#     },
#     "patient_id_numbers": {
#       "mrn": "041152153",
#       "care_everywhere_id": "VDJ-7KR2-4847-LGF8"
#     },
#     "emergency_contacts": [
#       {
#         "name": "Sina, Amin",
#         "relationship": "Father",
#         "legal_guardian": true,
#         "phone_home": null,
#         "phone_work": null
#       },
#       {
#         "name": "Mohammedreza, Mustala",
#         "relationship": "Mother",
#         "legal_guardian": true,
#         "phone_home": null,
#         "phone_work": null
#       }
#     ],
#     "marital_status": "Single",
#     "preferred_language": "Arabic"
#   },
#   "INSURANCE_INFORMATION": {
#     "primary_insurance": {
#       "company_name": "BC TENNCARE",
#       "plan_details": "TC BLUE CARE NO COPAY",
#       "group_number": "435000",
#       "group_name": "TENNCARE/BLUECARE",
#       "member_id": "LAJM14345116",
#       "policy_number": null,
#       "subscriber_information": {
#         "name": "ABDULLA, SHAKH",
#         "dob": null,
#         "ssn_last_4": "8143",
#         "address": "8327 BROADWAY LN APT D, KNOXVILLE, TN 37923",
#         "relationship_to_patient": null
#       },
#       "coverage_details": null,
#       "effective_dates": null
#     },
#     "secondary_insurance": {
#       "company_name": null,
#       "plan_details": null,
#       "group_number": null,
#       "member_id": null,
#       "policy_number": null,
#       "subscriber_information": {
#         "name": null,
#         "dob": null,
#         "ssn_last_4": null,
#         "address": null,
#         "relationship_to_patient": null
#       },
#       "coverage_details": null,
#       "effective_dates": null
#     }
#   },
#   "CLINICAL_INFORMATION": {
#     "primary_diagnoses": [
#       {
#         "description": "Multiple sclerosis in pediatric patient",
#         "icd_code": "G35"
#       },
#       {
#         "description": "Abnormal MRI"
#       },
#       {
#         "description": "Optic neuritis"
#       }
#     ],
#     "secondary_diagnoses": [],
#     "current_medications": [
#       {
#         "name": "Rituximab Or Biosimilar",
#         "dosage": "Days 1, 15 Load",
#         "frequency": "Once Every 24 Weeks",
#         "route": null,
#         "status": "Current Infusion Order"
#       },
#       {
#         "name": "heparin, porcine (PF)",
#         "dosage": "100 unit/mL syringe 5 mL",
#         "frequency": "PRN",
#         "route": "intraVENOUS",
#         "instructions": "For flushing Ports/ PICC lines/ Central Lines IF NEEDED, Starting when released, Until Discontinued",
#         "status": "Current Hydration Order"
#       }
#     ],
#     "pre_medications": [
#       {
#         "name": "acetaminophen (TYLENOL)",
#         "dosage": "650 mg",
#         "frequency": "Once",
#         "route": "oral",
#         "instructions": "Starting when released",
#         "status": "Pre-Med Order"
#       },
#       {
#         "name": "diphenhydrAMINE (BENADRYL)",
#         "dosage": "50 mg in 50 mL NS",
#         "frequency": "Once",
#         "route": "intraVENOUS",
#         "instructions": "Administer 30 minutes before starting infusion.",
#         "status": "Pre-Med Order"
#       },
#       {
#         "name": "methylPREDNISolone sod succinate (SOLU-Medral)",
#         "dosage": "125 mg in NS 6.2 mL (20 mg/mL)",
#         "frequency": "Once",
#         "route": "intraVENOUS",
#         "instructions": "Administer 30 minutes before starting infusion.",
#         "status": "Pre-Med Order"
#       }
#     ],
#     "discharge_medications": [
#       {
#         "name": "dexamethasone",
#         "dosage": "4 mg/mL CONCENTRATED solution, Take 45 mL (180 mg total)",
#         "frequency": "daily for 1 dose",
#         "route": "by mouth",
#         "start_date": null
#       },
#       {
#         "name": "famotidine (PEPCID)",
#         "dosage": "40 mg total",
#         "frequency": "daily",
#         "route": "by mouth",
#         "start_date": null
#       },
#       {
#         "name": "predniSONE (DELTASONE)",
#         "dosage": "20 mg tablet",
#         "frequency_taper": "3 tabs (60 mg total) daily for 7 days, THEN 2 tabs (40 mg total) daily for 7 days, THEN 1 tab (20 mg total) daily for 7 days, THEN 0.5 tabs (10 mg total) daily for 7 days. Then stop.",
#         "route": "by mouth",
#         "start_date": "May 16, 2024"
#       }
#     ],
#     "allergies": "No Known Allergies",
#     "adverse_reactions": null,
#     "vital_signs": {
#       "collection_date": "05/14/2024",
#       "temperature": {
#         "value": "36.7 °C (98 °F)",
#         "range": "36.5 °C (97.7 °F)-36.7 °C (98.1 °F)"
#       },
#       "pulse": {
#         "value": "84",
#         "range": "81-99"
#       },
#       "respiration": {
#         "value": "16",
#         "range": "16-18"
#       },
#       "blood_pressure": {
#         "value": "126/63",
#         "range": "122-136/63-99"
#       },
#       "spo2": {
#         "value": "98%",
#         "range": "98%"
#       }
#     },
#     "lab_results": {
#       "collection_time": "05/14/24 10:47 AM",
#       "cbc_w_differential": [
#         {"test": "White Blood Cells", "value": "7.7", "unit": "x10(3)/mcL", "reference_range": "3.4 - 10.2"},
#         {"test": "Red Blood Cells", "value": "4.63", "unit": "x10(6)/mcL", "reference_range": "3.80 - 5.50"},
#         {"test": "Hemoglobin", "value": "13.0", "unit": "gm/dL", "reference_range": "12.0 - 16.0"},
#         {"test": "Hematocrit", "value": "40", "unit": "%", "reference_range": "35 - 49"},
#         {"test": "Mean Cell Volume", "value": "86", "unit": "fL", "reference_range": "76 - 96"},
#         {"test": "Mean Cell Hemoglobin", "value": "28.1", "unit": "pg", "reference_range": "25.0 - 35.0"},
#         {"test": "Mean Cell Hemoglobin Concentration", "value": "32.7", "unit": "gm/dL", "reference_range": "32.0 - 37.0"},
#         {"test": "RDW SD", "value": "38.4", "unit": "fL", "reference_range": "37.4 - 52.4"},
#         {"test": "RDW CV", "value": "12.3", "unit": "%", "reference_range": "11.1 - 14.3"},
#         {"test": "Platelet", "value": "300", "unit": "x10(3)/mcL", "reference_range": "150 - 400"},
#         {"test": "Mean Platelet Volume", "value": "10.0", "unit": "fL", "reference_range": "9.3 - 12.8"},
#         {"test": "Nucleated RBC", "value": "0", "unit": "/100 WBC", "reference_range": "0 - 0"},
#         {"test": "Nucleated RBC Abs", "value": "0.00", "unit": "x10(3)/mcL", "reference_range": "0.00 - 0.00"},
#         {"test": "Auto Neutrophil Absolute", "value": "4.52", "unit": "x10(3)/mcL", "reference_range": "1.80 - 7.70"}
#       ],
#       "cmp": [
#         {"test": "Sodium Level", "value": "139", "unit": "mmol/L", "reference_range": "138-145"},
#         {"test": "Potassium Level", "value": "3.8", "unit": "mmol/L", "reference_range": "3.3-4.8"},
#         {"test": "Chloride Level", "value": "101", "unit": "mmol/L", "reference_range": "98-107"},
#         {"test": "Carbon Dioxide", "value": "22", "unit": "mmol/L", "reference_range": "17-28"},
#         {"test": "Anion Gap", "value": "16", "unit": "mmol/L", "reference_range": null},
#         {"test": "Glucose Level", "value": "95", "unit": "mg/dL", "reference_range": "60-99"},
#         {"test": "Blood Urea Nitrogen", "value": "13", "unit": "mg/dL", "reference_range": "7-18"},
#         {"test": "Creatinine Level", "value": "0.67", "unit": "mg/dL", "reference_range": "0.50-0.90"},
#         {"test": "Calcium Level Total", "value": "9.9", "unit": "mg/dL", "reference_range": "8.4-10.2"},
#         {"test": "Billrubin Total", "value": "0.4", "unit": "mg/dL", "reference_range": "0.0-0.7"},
#         {"test": "Albumin Level", "value": "4.7", "unit": "gm/dL", "reference_range": "4.0-5.3"},
#         {"test": "Protein Total", "value": "8.4 (H)", "unit": "gm/dL", "reference_range": "6.3-7.8"},
#         {"test": "Alkaline Phosphatase", "value": "55", "unit": "unit/L", "reference_range": "50-117"},
#         {"test": "Aspartate Aminotransferase", "value": "25", "unit": "unit/L", "reference_range": "21-34"},
#         {"test": "Alanine Aminotransferase", "value": "<6", "unit": "unit/L", "reference_range": "0-17"}
#       ],
#       "hepatitis_b_pnl": [
#         {"test": "Hepatitis B Surface Antigen", "value": "Negative", "reference_range": "Negative"},
#         {"test": "Hep B Core Ab Total", "value": "Negative", "reference_range": "Negative"},
#         {"test": "Hepatitis B Surface Ab Unit", "value": "44.7 (H)", "unit": "mlU/mL", "reference_range": "<=10.0"},
#         {"test": "Hep Bs Ab Interp", "value": "Positive (A)", "reference_range": "Negative"}
#       ],
#       "igg": [
#         {"test": "IgG Quantitative", "value": "1,355 (H)", "unit": "mg/dL", "reference_range": "600-1,310"}
#       ],
#       "iga": [
#         {"test": "IgA Quantitative", "value": "279", "unit": "mg/dL", "reference_range": "40-290"}
#       ],
#       "auto_diff": [
#         {"test": "Neutrophils", "value": "58.3", "unit": "%", "reference_range": null},
#         {"test": "Absolute Neutrophils", "value": "4.52", "unit": "x10(3)/mcL", "reference_range": "1.80-7.70"},
#         {"test": "Lymphs", "value": "33.6", "unit": "%", "reference_range": null},
#         {"test": "Absolute Lymphocytes", "value": "2.60", "unit": "x10(3)/mcL", "reference_range": "1.70-4.50"},
#         {"test": "Monocytes", "value": "6.5", "unit": "%", "reference_range": null},
#         {"test": "Absolute Monocytes", "value": "0.50", "unit": "x10(3)/mcL", "reference_range": "0.20-1.00"},
#         {"test": "Eosinophils", "value": "0.5", "unit": "%", "reference_range": null},
#         {"test": "Absolute Eosinophils", "value": "0.04", "unit": "x10(3)/mcL", "reference_range": "0.00-0.50"},
#         {"test": "Basophils", "value": "0.8", "unit": "%", "reference_range": null},
#         {"test": "Absolute Basophils", "value": "0.06", "unit": "x10(3)/mcL", "reference_range": "0.01-0.08"},
#         {"test": "Imm Gran Automated", "value": "0.3", "unit": "%", "reference_range": null},
#         {"test": "Absolute Imm Gran Automated", "value": "0.02", "unit": "x10(3)/mcL", "reference_range": "0.00-0.03"}
#       ],
#       "flow_lymphocytes_subsets": {
#         "status": "Order pending",
#         "last_released": "Never",
#         "electronically_signed": "Gu, Hao H, MD on 5/15/2024 5:11 PM"
#       }
#     },
#     "previous_treatments_and_outcomes": [
#       "Treated with 5 days of IVMP (intravenous methylprednisolone) for demyelinating lesion, tolerated well.",
#       "Discharged home with oral decadron 180mg (equivalent to 1000mg IVMP) to complete 5 days of high dose steroid treatment.",
#       "Oral prednisone taper initiated post-discharge.",
#       "Previous treatment with 5 days of IVMP for brain and orbit issues after UT ophthalmology clinic."
#     ],
#     "medical_history": [
#       "History of optic neuritis.",
#       "Abnormal MRI brain concerning for MS.",
#       "Predominant symptoms since April (onset Oct 2023): numbness in right hand, urinary hesitancy/urgency, right eye pain, 'neon bright color' fuzzy vision, eye pain with movement, right side of face discomfort.",
#       "Symptoms improved with rest, then worsened by Oct 2023 with 'right eye being inflamed' and visual field deficits.",
#       "Intermittent numbness in right hand, muscle twitch in hands and shoulder.",
#       "Intermittent drifting to right side, bumping into things.",
#       "Electrical sensation when laughing/bending neck.",
#       "ANA positive, SSB positive (Rheumatology consulted, no evidence of other systemic autoimmune disease).",
#       "Family history: parents and brothers are healthy."
#     ],
#     "comorbidities": null,
#     "functional_assessments": {
#       "higher_integrative_functions": {
#         "attention_concentration": "Normal",
#         "orientation": "Oriented to person, place & time",
#         "memory": "Recent and remote memory intact",
#         "language": "Normal",
#         "fund_of_knowledge": "Normal"
#       },
#       "cranial_nerves": {
#         "cn2": "Visual fields full",
#         "cn2_3": "PERRL; rAPD",
#         "cn3_4_6": "EOMI",
#         "cn5": "Facial sensation intact",
#         "cn7": "Facial strength/movement intact bilaterally",
#         "cn8": "Hearing normal bilaterally",
#         "cn9_10": "Palate elevates symmetrically",
#         "cn11": "Normal shoulder shrug and head turn",
#         "cn12": "Tongue protrudes midline"
#       },
#       "motor": {
#         "muscle_tone": "Normal in upper and lower extremities",
#         "muscle_strength": "5/5 In upper and lower extremities; RLE 4+ proximally"
#       },
#       "sensation": "Intact to light touch in upper and lower extremities bilaterally",
#       "coordination": "Finger/nose intact bilaterally",
#       "gait": "Normal gait"
#     }
#   },
#   "PROVIDER_INFORMATION": {
#     "referring_physician": {
#       "name": "Dr. Fazal",
#       "specialty": "Pediatric Neurology",
#       "contact_info": null,
#       "practice_name": "East Bay"
#     },
#     "attending_physician": {
#       "name": "Hao H Gu, MD",
#       "specialty": null,
#       "contact_info": {
#         "phone": "614-936-0065"
#       },
#       "practice_name": "Better Life Multiple Sclerosis Center",
#       "npi_number": "1154611523",
#       "license_information": null
#     },
#     "resident_physician": {
#       "name": "Kaine, Adam Jason, MD",
#       "specialty": "Pediatric Neurology",
#       "contact_info": null
#     },
#     "primary_care_provider": {
#       "name": "James David, PNP",
#       "specialty": null,
#       "contact_info": null
#     },
#     "nursing_contact": {
#       "name": "Erfan Rostami, BSN, RN",
#       "contact_info": {
#         "phone": "615-343-1176",
#         "fax": "615-343-1219"
#       }
#     },
#     "additional_physicians": [
#       {"name": "Dr. Asriel Han", "specialty": null},
#       {"name": "Dr. Aditya Shah", "specialty": null},
#       {"name": "Harry, Tom, MD", "specialty": null, "role": "Last attending for hospital admission"},
#       {"name": "Dr. Shane", "specialty": null, "role": "Dr Fazal's colleague"},
#       {"name": "Dr Derrek", "specialty": "UT ophthalmology"},
#       {"name": "Dr Kosentka", "specialty": "ped neurology"}
#     ],
#     "practice_name": "Better Life Multiple Sclerosis Center",
#     "practice_address": "3320 Montgomery Dr. Nashville, TN 37361",
#     "facility_details_treatment": {
#       "name": "Golden Gate Infusion Center (Recipient)",
#       "address": null,
#       "contact_info": {
#         "fax": "614-278-3355",
#         "phone": "614-895-7655"
#       }
#     },
#     "facility_details_admission": {
#       "name": "Monroe Carell Jr. Children's Hospital",
#       "address": null,
#       "contact_info": null
#     },
#     "scheduled_infusion_facility": {
#       "name": "Peds Infusion (Leantaas) with PEDS INF UMBRELLA, PEDS 241+ MIN INFUSION",
#       "address": "2211 Broad Way, Tower 4th FL, Suite 6102, Nashville TN 37232",
#       "contact_info": {
#         "phone": "615-936-1762"
#       }
#     }
#   },
#   "TREATMENT_DETAILS": {
#     "requested_medication_procedure_device": "riTUXimab-abbs (TRUXIMA) IVPB infusion",
#     "dosage_frequency_duration": {
#       "initial_dose": {
#         "medication": "riTUXimab-abbs (TRUXIMA) IVPB",
#         "dosage": "694 mg (rounded from 693.75 mg = 375 mg/m2 x 1.85 m2 - BSA might be out of date)",
#         "frequency": "Every 2 weeks",
#         "duration": "2/2 remaining",
#         "route": "intraVENOUS",
#         "start_time": "30 minutes after treatment start time",
#         "due_date": "Week of 5/19/2024"
#       },
#       "maintenance_dose": {
#         "medication": "riTUXimab-abbs (TRUXIMA) IVPB",
#         "dosage": "694 mg (rounded from 693.75 mg = 375 mg/m2 x 1.85 m2 - BSA might be out of date)",
#         "frequency": "Every 24 weeks",
#         "duration": null,
#         "route": "intraVENOUS",
#         "due_date": "Mon 11/4/2024",
#         "defer_until": "Mon 11/4/2024"
#       },
#       "infusion_rate_instructions": {
#         "first_infusion": "initiate at 50mg/hr and if no infusion toxicity reaction, may increase by 50mg/hr every 30 minutes; Max Rate 400mg/hr",
#         "subsequent_infusions": "initiate at 100mg/hr and if no infusion toxicity reaction, may increase by 100mg/hr every 30 min; Max Rate 400mg/hr"
#       }
#     },
#     "medical_necessity_justification": "Patient diagnosed with Multiple Sclerosis (pediatric) based on abnormal MRI brain/spine demonstrating multiple lesions, history of optic neuritis, and CSF markers. Patient requires ongoing treatment for active demyelinating lesion and to minimize travel.",
#     "previous_treatment_failures": null,
#     "clinical_criteria_met_for_approval": "Diagnosis of Multiple Sclerosis in pediatric patient (G35). Symptoms and MRI findings support active disease. Patient's history of IVMP response and need for ongoing management."
#   },
#   "SUPPORTING_EVIDENCE": {
#     "lab_results_supporting_diagnosis": [
#       "CSF: IgG Index 0.87 (elevated), +OCB (Oligoclonal bands) - indicative of MS."
#     ],
#     "imaging_studies_and_results": [
#       {
#         "type": "MRI Brain and Spine",
#         "date": "Jan 21, 2024",
#         "results": "Diffuse T2 hyperintensity and decreased volume throughout the right optic nerve similar to prior examination; associated abnormal enhancement seen on prior study has resolved. Left optic nerve subtle but diffusely small in caliber without significant change from last exam. Several intracranial WM lesions, stable from last."
#       },
#       {
#         "type": "MRI Brain and Spine",
#         "date": "5/17/2024 (Admission)",
#         "results": "Multiple lesions consistent with atypical pediatric MS."
#       }
#     ],
#     "functional_assessments": [
#       "Physical Exam findings (Temp, Pulse, Resp, BP, SpO2, general appearance, CV).",
#       "Higher Integrative Functions assessment (Attention, Orientation, Memory, Language, Fund of Knowledge - all normal).",
#       "Cranial Nerves assessment (CN 2-12 details - largely intact with specific findings like visual fields full, PERRL, rAPD, EOMI, facial sensation/strength intact, normal hearing, palate elevates, normal shoulder shrug/head turn, tongue midline).",
#       "Motor assessment (Muscle tone normal, muscle strength 5/5 in upper/lower extremities, RLE 4+ proximally).",
#       "Sensation assessment (Intact to light touch bilaterally).",
#       "Coordination assessment (Finger/nose intact bilaterally).",
#       "Gait assessment (Normal gait)."
#     ],
#     "specialist_consultations": [
#       "Inpatient Consult to Pediatric Ophthalmology (ordered).",
#       "Inpatient Consult to Pediatric Rheumatology (ordered).",
#       "Inpatient consult to Case Management (ordered).",
#       "Consultation with Dr Kaine (Resident Physician, Pediatric Neurology).",
#       "Patient referred to Dr. Gu by Dr. Fazal (Pediatric Neurology).",
#       "Consultation with Dr Shane (Dr Fazal's colleague).",
#       "Referral to UT ophthalmology Dr Derrek (Jan this year).",
#       "Referral to Dr Kosentka (Pediatric Neurology)."
#     ],
#     "treatment_response_documentation": [
#       "IVMP tolerated well during hospital stay.",
#       "Symptoms improved once patient rested (early Oct 2023 symptom onset).",
#       "Patient thought some improvement after previous IVMP, but 'not back to baseline entirely'."
#     ]
#   }
# }
# ```

# %% [markdown]
# ## PA widget input info extraction

# %%
import fitz

# Code from Headstarter tutorial to extract fields from PDF
def extracting_fields_from_pdf(pdf_file):
    """
    Extracts form fields from a PDF file and returns them as a list of dictionaries.
    Each dictionary contains field name, type, value, page number, and other metadata.
    """
    if not pathlib.Path(pdf_file).exists():
        raise FileNotFoundError(f"The file {pdf_file} does not exist.")
    doc = fitz.open(pdf_file)
    fields = []
    for page_num, page in enumerate(doc, start = 1):
        for w in page.widgets() or []:
            field = {
                "name": w.field_name,
                "type": "checkbox" if w.field_type == fitz.PDF_WIDGET_TYPE_CHECKBOX else "text",
                "value": w.field_value,
                "page": page_num,
                "field_type": w.field_type,
                "field_type_string": w.field_type_string,
                "field_label": w.field_label,
            }
            print(field)
            fields.append(field)

    field_by_page = {}
    for field in fields:
        page_num = field["page"]
        if page_num not in field_by_page:
            field_by_page[page_num] = []
    
    return field_by_page

pa_fields = extracting_fields_from_pdf("Input Data/Adbulla/PA.pdf")
# Out:
# {'name': 'CB1', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Start of treatment'}
# {'name': 'T2', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Start date: (MM)'}
# {'name': 'T3', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Start date: (DD)'}
# {'name': 'T4', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Start date: (YYYY)'}
# {'name': 'CB5', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Continuation of therapy'}
# {'name': 'T6', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date of last treatment: (MM)'}
# {'name': 'T7', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date of last treatment: (DD)'}
# {'name': 'T8', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date of last treatment: (YYYY)'}
# {'name': 'T9', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Precertification Requested By:'}
# {'name': 'T10', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Phone:'}
# {'name': 'T11', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Fax:'}
# {'name': 'T12', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient First Name'}
# {'name': 'T13', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient Last Name'}
# {'name': 'T14', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient DOB (MM/DD/YYYY)'}
# {'name': 'T15', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Address:'}
# {'name': 'T16', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'City:'}
# {'name': 'T17', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'State:'}
# {'name': 'T18', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'ZIP:'}
# {'name': 'T19', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient Phone'}
# {'name': 'T20', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Work Phone:'}
# {'name': 'T21', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Cell Phone:'}
# {'name': 'T22', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'E-mail:'}
# {'name': 'T24', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'lbs'}
# {'name': 'T25', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'kgs'}
# {'name': 'T26', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'inches'}
# {'name': 'T27', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'cms'}
# {'name': 'T23', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Allergies:'}
# {'name': 'T28', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Member ID #:'}
# {'name': 'T29', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Group #:'}
# {'name': 'T30', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Insured:'}
# {'name': 'CB31', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB32', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'T33', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'If yes, provide ID#:'}
# {'name': 'T34', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Carrier Name:'}
# {'name': 'T35', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Insured:'}
# {'name': 'T42', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'First Name:'}
# {'name': 'T43', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Last Name:'}
# {'name': 'CB44', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'M.D.'}
# {'name': 'CB45', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'D.O.'}
# {'name': 'CB46', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'N.P.'}
# {'name': 'CB47', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'P.A.'}
# {'name': 'T48', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Address:'}
# {'name': 'T49', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'City:'}
# {'name': 'T50', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'State:'}
# {'name': 'T51', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'ZIP:'}
# {'name': 'T52', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Phone:'}
# {'name': 'T53', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Fax:'}
# {'name': 'T54', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'St Lic #:'}
# {'name': 'T55', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'NPI #:'}
# {'name': 'T56', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'DEA #:'}
# {'name': 'T57', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'UPIN:'}
# {'name': 'T58.0', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Provider Email:'}
# {'name': 'T58.1', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Office Contact Name:'}
# {'name': 'T59', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Phone:'}
# {'name': 'Provider Admin CB.1', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Self-administered'}
# {'name': 'Provider Admin CB.2', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Physician’s Office'}
# {'name': 'Provider Admin CB.3', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Home'}
# {'name': 'Provider Admin CB.4', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Outpatient Infusion Center'}
# {'name': 'Provider Admin T.5', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Name:'}
# {'name': 'Provider Admin CB.7', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Home Infusion Center'}
# {'name': 'Provider Admin T.6', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Phone:'}
# {'name': 'Provider Admin T.8', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Agency Name:'}
# {'name': 'Provider Admin CB.10', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Administration code(s)'}
# {'name': 'Provider Admin T.9', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'CPT:'}
# {'name': 'Provider Admin T.11A', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Address:'}
# {'name': 'Provider Admin T.13', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'City:'}
# {'name': 'Provider Admin T.14', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'State:'}
# {'name': 'Provider Admin T.15', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'ZIP:'}
# {'name': 'Provider Admin T.16', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Phone:'}
# {'name': 'Provider Admin T.17A', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Fax:'}
# {'name': 'Provider Admin T.18', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'TIN:'}
# {'name': 'Provider Admin T.19', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'PIN:'}
# {'name': 'Provider Admin T.20', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'NPI:'}
# {'name': 'Provider Admin CB.21', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Outpatient Dialysis Center'}
# {'name': 'Provider Admin CB.22', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Physician’s Office'}
# {'name': 'Provider Admin CB.23.0.0', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Retail Pharmacy'}
# {'name': 'Provider Admin CB.24.0.0', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Specialty Pharmacy'}
# {'name': 'Provider Admin CB.25', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Mail Order'}
# {'name': 'Provider Admin CB.26', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Other:'}
# {'name': 'Provider Admin T.27', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Other:'}
# {'name': 'Provider Admin T.28', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Name:'}
# {'name': 'Provider Admin T.29a', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Address:'}
# {'name': 'Provider Admin T.30a', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'City:'}
# {'name': 'Provider Admin T.31', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'State:'}
# {'name': 'Provider Admin T.32', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'ZIP:'}
# {'name': 'Provider Admin T.33', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Phone:'}
# {'name': 'Provider Admin T.34', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Fax:'}
# {'name': 'Provider Admin T.35', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'TIN:'}
# {'name': 'Provider Admin T.36', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'PIN:'}
# {'name': 'Provider Admin T.37', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'NPI:'}
# {'name': 'CB60', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Riabni (rituximab-arrx)'}
# {'name': 'CB61', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Rituxan (rituximab)'}
# {'name': 'CB62', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Ruxience (rituximab-pvvr)'}
# {'name': 'CB63', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Truxima (rituximab-abbs)'}
# {'name': 'T64', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Dose:'}
# {'name': 'T65', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Directions for Use:'}
# {'name': 'T66', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'HCPCS Code:'}
# {'name': 'T67', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Primary ICD Code:'}
# {'name': 'CB68', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Other ICD Code:'}
# {'name': 'T69', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Other ICD Code:'}
# {'name': 'CB70', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB71', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB72', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB73', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Ruxience (rituximab-pvvr)'}
# {'name': 'CB74', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Truxima (rituximab-abbs)'}
# {'name': 'T75', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'When was the member’s trial and failure of the preferred drug?'}
# {'name': 'T76', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please describe the nature of the failure of the preferred drug'}
# {'name': 'CB77', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB78', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Ruxience (rituximab-pvvr)'}
# {'name': 'CB79', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Truxima (rituximab-abbs)'}
# {'name': 'T80', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'When was the member’s adverse reaction to the preferred drug?'}
# {'name': 'T81', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please describe the nature of the adverse reaction to the preferred drug'}
# {'name': 'T84', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please explain if there are any contraindications or other medical reason(s) that the patient cannot use any of the following preferred biosimilar products when indicated for the patient’s diagnosis?'}
# {'name': 'CB82', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Ruxience (rituximab-pvvr)'}
# {'name': 'CB83', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Truxima (rituximab-abbs)'}
# {'name': 'T12', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient First Name'}
# {'name': 'T13', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient Last Name'}
# {'name': 'T19', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient Phone'}
# {'name': 'T14', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient DOB (MM/DD/YYYY)'}
# {'name': 'CB86', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Inflectra (infliximab-dyyb)'}
# {'name': 'CB87', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Renflexis (infliximab-abda)'}
# {'name': 'CB88', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Simponi Aria (golimumab)'}
# {'name': 'T89', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'When was the member’s trial and failure of the preferred drug?'}
# {'name': 'T90', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please describe the nature of the failure of the preferred drug'}
# {'name': 'CB85', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB92', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Inflectra (infliximab-dyyb)'}
# {'name': 'CB93', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Renflexis (infliximab-abda)'}
# {'name': 'CB94', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Simponi Aria (golimumab)'}
# {'name': 'T95', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'When was the member’s adverse reaction to the preferred drug?'}
# {'name': 'T96a', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please describe the nature of the adverse reaction to the preferred drug'}
# {'name': 'CB91', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB98a', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Enbrel (etanercept)'}
# {'name': 'CB99a', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Humira (adalimumab)'}
# {'name': 'CB100a', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Idacio (adalimumab-aacf)'}
# {'name': 'CB101a', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Rinvoq (upadacitinib)'}
# {'name': 'CB102a', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Tyenne SC (tocilizumab-aazg)'}
# {'name': 'CB103a', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Xeljanz/Xeljanz XR (tofacitinib)'}
# {'name': 'T104', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'When was the member’s trial and failure of the preferred drug?'}
# {'name': 'T105', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please describe the nature of the failure of the preferred drug'}
# {'name': 'CB97', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB107z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Enbrel (etanercept)'}
# {'name': 'CB108z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Humira (adalimumab)'}
# {'name': 'CB109z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Idacio (adalimumab-aacf)'}
# {'name': 'CB110z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Rinvoq (upadacitinib)'}
# {'name': 'CB111z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Tyenne SC (tocilizumab-aazg)'}
# {'name': 'CB112z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Xeljanz/Xeljanz XR (tofacitinib)'}
# {'name': 'T113', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'When was the member’s adverse reaction to the preferred drug?'}
# {'name': 'T114', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please describe the nature of the adverse reaction to the preferred drug'}
# {'name': 'CB106z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'T118', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please explain if there are any contraindications or other medical reason(s) that the patient cannot use any of the following preferred products when indicated for the patient’s diagnosis?'}
# {'name': 'CB115z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Inflectra (infliximab-dyyb)'}
# {'name': 'CB116z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Renflexis (infliximab-abda)'}
# {'name': 'CB117z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Simponi Aria (golimumab)'}
# {'name': 'T125', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please explain if there are contraindications or any other medical reason(s) that the patient cannot use any of the following preferred products when indicated for the patient’s diagnosis?'}
# {'name': 'CB119z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Enbrel (etanercept)'}
# {'name': 'CB120z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Humira (adalimumab)'}
# {'name': 'CB121z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Idacio (adalimumab-aacf)'}
# {'name': 'CB122z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Rinvoq (upadacitinib)'}
# {'name': 'CB123z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Tyenne SC (tocilizumab-aazg)'}
# {'name': 'CB124z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Xeljanz/Xeljanz XR (tofacitinib)'}
# {'name': 'CB96.4.0', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB98', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB99.0', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB100.0', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB101.0', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB102.0', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB103', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB104', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB104a', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Wegener granulomatosis'}
# {'name': 'CB104b', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Churg-Strauss syndrome'}
# {'name': 'CB104c', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'microscopic polyangiitis'}
# {'name': 'CB104d', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'pauci-immune glomerulonephritis'}
# {'name': 'CB105', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB106', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB106a', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB107', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'pemphigus vulgaris'}
# {'name': 'CB108', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'pemphigus folliaceus'}
# {'name': 'CB109', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'bullous pemphigoid'}
# {'name': 'CB110', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'cicatricial pemphigoid'}
# {'name': 'CB111', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'epidermolysis bullosa acquisita'}
# {'name': 'CB112', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'paraneoplastic pemphigus'}
# {'name': 'CB113', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'None of the above'}
# {'name': 'CB106b', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB114', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'AIDS-related B-cell lymphoma'}
# {'name': 'CB115', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Burkitt lymphoma'}
# {'name': 'CB116', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Diffuse large B-cell lymphoma'}
# {'name': 'CB117', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Follicular lymphoma'}
# {'name': 'CB118', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Gastric MALT lymphoma'}
# {'name': 'CB119', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'High-grade B-Cell lymphoma'}
# {'name': 'CB120', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Mantle cell lymphoma'}
# {'name': 'CB121', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Nodal marginal zone lymphoma'}
# {'name': 'CB122', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Nongastric MALT lymphoma'}
# {'name': 'CB123', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Primary cutaneous B-cell lymphomas'}
# {'name': 'CB124', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Splenic marginal zone lymphoma'}
# {'name': 'CB125', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Other:'}
# {'name': 'T126', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Other:'}
# {'name': 'T12', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient First Name'}
# {'name': 'T13', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient Last Name'}
# {'name': 'T19', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient Phone'}
# {'name': 'T14', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient DOB (MM/DD/YYYY)'}
# {'name': 'CB127', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB128', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB129', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'leptomeningeal metastases from lymphoma'}
# {'name': 'CB130', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'primary CNS lymphoma'}
# {'name': 'CB131', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'none of the above'}
# {'name': 'CB132', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'chronic lymphocytic leukemia (CLL)'}
# {'name': 'CB133', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'small lymphocytic leukemia'}
# {'name': 'CB134', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'none of the above'}
# {'name': 'CB135', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB136', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB139', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB140', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB144', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB145', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB141', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'relapsed hairy cell leukemia'}
# {'name': 'CB142', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'refractory hairy cell leukemia'}
# {'name': 'CB143', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'none of the above'}
# {'name': 'CB137', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB146', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'heart transplant recipient'}
# {'name': 'CB147', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'other solid organ transplant recipient'}
# {'name': 'CB138', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB148', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Bavencio (avelumab)'}
# {'name': 'CB149', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Imfinzi (durvalumab)'}
# {'name': 'CB150', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Keytruda (pembrolizumab)'}
# {'name': 'CB151', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Opdivo (nivolumab)'}
# {'name': 'CB152', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Tecentriq (atezolizumab)'}
# {'name': 'CB153', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yervoy (ipilimumab)'}
# {'name': 'CB154', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Other:'}
# {'name': 'T155', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Other:'}
# {'name': 'CB156', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB158', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'refractory immune thrombocytopenic purpura'}
# {'name': 'CB159', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'idiopathic thrombocytopenic purpura (ITP)'}
# {'name': 'CB157', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB160', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB161', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB162', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB163', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB164', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Relapsing-remitting MS (RRMS)'}
# {'name': 'CB165', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Secondary-progressive MS (SPMS)'}
# {'name': 'CB166', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Primary-progressive MS (PPMS)'}
# {'name': 'CB167', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Progressive-relapsing MS (PRMS)'}
# {'name': 'CB168', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB169', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB170', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB172', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB173', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB171', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB174', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB175', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB176', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB177', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB178', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB179', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB180', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'T189', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Medication:'}
# {'name': 'T190', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T191', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T192', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}
# {'name': 'T193', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T194', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T195', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}
# {'name': 'T196', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Medication:'}
# {'name': 'T197', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T198', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T199', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}
# {'name': 'T200', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T201', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T202', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}
# {'name': 'CB181', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB203', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB204', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB205', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB206', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'T12', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient First Name'}
# {'name': 'T13', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient Last Name'}
# {'name': 'T19', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient Phone'}
# {'name': 'T14', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient DOB (MM/DD/YYYY)'}
# {'name': 'CB207', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Mild'}
# {'name': 'CB208', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Moderate'}
# {'name': 'CB209', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Severe'}
# {'name': 'CB210', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB211', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB212', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB213', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB214', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB216', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'ineffective'}
# {'name': 'CB217', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'not tolerated'}
# {'name': 'CB218', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'contraindicated'}
# {'name': 'CB215', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB223', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB225', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'azathioprine'}
# {'name': 'CB226', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'cyclosporine'}
# {'name': 'CB227', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'hydroxychloroquine'}
# {'name': 'CB228', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'leflunomide'}
# {'name': 'CB229', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'sulfasalazine'}
# {'name': 'CB224', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB281', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB282', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB283', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'T285', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Medication:'}
# {'name': 'T286', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T287', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T288', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}
# {'name': 'T289', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T290', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T291', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}
# {'name': 'T292', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Medication:'}
# {'name': 'T293', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T294', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T295', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}
# {'name': 'T296', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T297', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T298', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}
# {'name': 'CB284', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB299', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB300', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB301', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB302', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB303', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB304', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'T305', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please indicate the length of time on Rituxan (rituximab):'}
# {'name': 'CB310', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Mild'}
# {'name': 'CB311', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Moderate'}
# {'name': 'CB312', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Severe'}
# {'name': 'CB306', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB307', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB308', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB309', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB313', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB314', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB315', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB316', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'T317', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T318', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T319', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}

# %% [markdown]
# ## PA field organization Prompt template for Google Gemini

# %%
def format_fields_for_pa(pa_fields):
  return """
  You are given an array of dictionaries, each representing a form field extracted from a PDF. Each dictionary contains:
  - "name": the field name
  - "type": the field type (e.g., "text", "checkbox")
  - "value": the field value (may be null)
  - "page": the 1-based page number
  - "field_type": the PDF widget type code
  - "field_type_string": the PDF widget type as a string
  - "field_label": the field label (may be null)

  TASK:
  1. Organize these fields into a hierarchical JSON tree grouped by page number.
  2. For each page, create an array of fields, preserving all metadata.
  3. The top-level JSON should be:
  {
    "pages": {
      "1": [ ...fields... ],
      "2": [ ...fields... ],
      ...
    }
  }
  4. Do not omit any fields or metadata.
  5. Return only valid JSON (no markdown, no extra commentary).

  Example output:
  {
    "pages": {
      "1": [
        {
          "name": "T1",
          "type": "text",
          "value": "",
          "page": 1,
          "field_type": 2,
          "field_type_string": "Text",
          "field_label": "First Name"
        },
        ...
      ],
      "2": [
        ...
      ]
    }
  }

  <PA_FIELDS>
  {pa_fields}
  </PA_FIELDS> """

# %% [markdown]
# ## Send Prompt to Google Gemini

# %%
# Send to Gemini using NEW 2025 SDK

async def query_gemini_async(prompt, pdf_path, model_name='gemini-2.5-flash'):
    """
    Async function to query Gemini with a PDF and prompt using the new 2025 Google Gen AI SDK
    """
    filepath = pathlib.Path(pdf_path)
    
    # Create PDF part using new SDK structure
    pdf_bytes = filepath.read_bytes()
    pdf_part = types.Part.from_bytes(
        data=pdf_bytes, 
        mime_type="application/pdf"
    )
    
    # Use async client from new SDK
    response = await client.aio.models.generate_content(
        model=model_name,
        contents=[pdf_part, prompt]
    )
    
    print(response.text)
    return response.text

# %%
pa_fields_context = {}

# Process each page of the PA form
async def process_page(page):
    prompt = format_fields_for_pa(pa_fields[page])
    print (prompt)

    result = await query_gemini_async(prompt, "Input Data/Adbulla/PA.pdf")
    print ("---------------------------------")
    return page, result
# create a list of tasks to run in parallel
tasks = [process_page(page) for page in pa_fields]

# running the tasks in parallel
results = await asyncio.gather(*tasks)

# 
for page, result in results:
    pa_fields_context[page] = result
# Out:
#   You are given an array of dictionaries, each representing a form field extracted from a PDF. Each dictionary contains:
#   - "name": the field name
#   - "type": the field type (e.g., "text", "checkbox")
#   - "value": the field value (may be null)
#   - "page": the 1-based page number
#   - "field_type": the PDF widget type code
#   - "field_type_string": the PDF widget type as a string
#   - "field_label": the field label (may be null)
#
#   TASK:
#   1. Organize these fields into a hierarchical JSON tree grouped by page number.
#   2. For each page, create an array of fields, preserving all metadata.
#   3. The top-level JSON should be:
#   {
#     "pages": {
#       "1": [ ...fields... ],
#       "2": [ ...fields... ],
#       ...
#     }
#   }
#   4. Do not omit any fields or metadata.
#   5. Return only valid JSON (no markdown, no extra commentary).
#
#   Example output:
#   {
#     "pages": {
#       "1": [
#         {
#           "name": "T1",
#           "type": "text",
#           "value": "",
#           "page": 1,
#           "field_type": 2,
#           "field_type_string": "Text",
#           "field_label": "First Name"
#         },
#         ...
#       ],
#       "2": [
#         ...
#       ]
#     }
#   }
#
#   <PA_FIELDS>
#   {pa_fields}
#   </PA_FIELDS>
#
#   You are given an array of dictionaries, each representing a form field extracted from a PDF. Each dictionary contains:
#   - "name": the field name
#   - "type": the field type (e.g., "text", "checkbox")
#   - "value": the field value (may be null)
#   - "page": the 1-based page number
#   - "field_type": the PDF widget type code
#   - "field_type_string": the PDF widget type as a string
#   - "field_label": the field label (may be null)
#
#   TASK:
#   1. Organize these fields into a hierarchical JSON tree grouped by page number.
#   2. For each page, create an array of fields, preserving all metadata.
#   3. The top-level JSON should be:
#   {
#     "pages": {
#       "1": [ ...fields... ],
#       "2": [ ...fields... ],
#       ...
#     }
#   }
#   4. Do not omit any fields or metadata.
#   5. Return only valid JSON (no markdown, no extra commentary).
#
#   Example output:
#   {
#     "pages": {
#       "1": [
#         {
#           "name": "T1",
#           "type": "text",
#           "value": "",
#           "page": 1,
#           "field_type": 2,
#           "field_type_string": "Text",
#           "field_label": "First Name"
#         },
#         ...
#       ],
#       "2": [
#         ...
#       ]
#     }
#   }
#
#   <PA_FIELDS>
#   {pa_fields}
#   </PA_FIELDS>
#
#   You are given an array of dictionaries, each representing a form field extracted from a PDF. Each dictionary contains:
#   - "name": the field name
#   - "type": the field type (e.g., "text", "checkbox")
#   - "value": the field value (may be null)
#   - "page": the 1-based page number
#   - "field_type": the PDF widget type code
#   - "field_type_string": the PDF widget type as a string
#   - "field_label": the field label (may be null)
#
#   TASK:
#   1. Organize these fields into a hierarchical JSON tree grouped by page number.
#   2. For each page, create an array of fields, preserving all metadata.
#   3. The top-level JSON should be:
#   {
#     "pages": {
#       "1": [ ...fields... ],
#       "2": [ ...fields... ],
#       ...
#     }
#   }
#   4. Do not omit any fields or metadata.
#   5. Return only valid JSON (no markdown, no extra commentary).
#
#   Example output:
#   {
#     "pages": {
#       "1": [
#         {
#           "name": "T1",
#           "type": "text",
#           "value": "",
#           "page": 1,
#           "field_type": 2,
#           "field_type_string": "Text",
#           "field_label": "First Name"
#         },
#         ...
#       ],
#       "2": [
#         ...
#       ]
#     }
#   }
#
#   <PA_FIELDS>
#   {pa_fields}
#   </PA_FIELDS>
#
#   You are given an array of dictionaries, each representing a form field extracted from a PDF. Each dictionary contains:
#   - "name": the field name
#   - "type": the field type (e.g., "text", "checkbox")
#   - "value": the field value (may be null)
#   - "page": the 1-based page number
#   - "field_type": the PDF widget type code
#   - "field_type_string": the PDF widget type as a string
#   - "field_label": the field label (may be null)
#
#   TASK:
#   1. Organize these fields into a hierarchical JSON tree grouped by page number.
#   2. For each page, create an array of fields, preserving all metadata.
#   3. The top-level JSON should be:
#   {
#     "pages": {
#       "1": [ ...fields... ],
#       "2": [ ...fields... ],
#       ...
#     }
#   }
#   4. Do not omit any fields or metadata.
#   5. Return only valid JSON (no markdown, no extra commentary).
#
#   Example output:
#   {
#     "pages": {
#       "1": [
#         {
#           "name": "T1",
#           "type": "text",
#           "value": "",
#           "page": 1,
#           "field_type": 2,
#           "field_type_string": "Text",
#           "field_label": "First Name"
#         },
#         ...
#       ],
#       "2": [
#         ...
#       ]
#     }
#   }
#
#   <PA_FIELDS>
#   {pa_fields}
#   </PA_FIELDS>
# ```json
# {
#   "pages": {
#     "1": [
#       {
#         "name": "Phone",
#         "type": "text",
#         "value": "1-866-503-0857 (TTY: 711)",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax",
#         "type": "text",
#         "value": "1-844-268-7263",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity",
#         "type": "text",
#         "value": "https://www.aetna.com/health-care-professionals/resource-center/availity.html",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_2",
#         "type": "text",
#         "value": "1-855-463-0933",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_2",
#         "type": "text",
#         "value": "1-833-280-5224",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_2",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/virginia-hmosnp/providers/portal",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_3",
#         "type": "text",
#         "value": "1-844-362-0934",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_3",
#         "type": "text",
#         "value": "1-833-322-0034",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_3",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/new-jersey-hmosnp/providers/portal.html",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_4",
#         "type": "text",
#         "value": "1-866-600-2139",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "FAX",
#         "type": "text",
#         "value": "1-855-320-8445",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_4",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/illinois/providers/portal",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_5",
#         "type": "text",
#         "value": "1-855-364-0974",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_4",
#         "type": "text",
#         "value": "1-855-734-9389",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_5",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/ohio/providers/portal",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_6",
#         "type": "text",
#         "value": "1-855-676-5772",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_5",
#         "type": "text",
#         "value": "1-844-241-2495",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_6",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/michigan/providers/portal.html",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       }
#     ],
#     "2": [
#       {
#         "name": "Start of treatment",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Start date",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Continuation of therapy",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Date of last treatment",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_7",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_6",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "First Name_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "First Name"
#       },
#       {
#         "name": "Last Name_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Last Name"
#       },
#       {
#         "name": "DOB",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "DOB"
#       },
#       {
#         "name": "Address",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Address"
#       },
#       {
#         "name": "City",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "City"
#       },
#       {
#         "name": "State",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "State"
#       },
#       {
#         "name": "ZIP",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "ZIP"
#       },
#       {
#         "name": "Home Phone",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Home Phone"
#       },
#       {
#         "name": "Work Phone",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Work Phone"
#       },
#       {
#         "name": "Cell Phone",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Cell Phone"
#       },
#       {
#         "name": "E-mail",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "E-mail"
#       },
#       {
#         "name": "Current Weight lbs or kgs",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Current Weight"
#       },
#       {
#         "name": "Height inches or cms",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Height"
#       },
#       {
#         "name": "Allergies",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Allergies"
#       },
#       {
#         "name": "Member ID #",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Member ID #"
#       },
#       {
#         "name": "Does patient have other coverage",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Group #",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Group #"
#       },
#       {
#         "name": "If yes, provide ID",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "If yes, provide ID#"
#       },
#       {
#         "name": "Carrier Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Carrier Name"
#       },
#       {
#         "name": "Insured",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Insured"
#       },
#       {
#         "name": "First Name_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "First Name"
#       },
#       {
#         "name": "Last Name_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Last Name"
#       },
#       {
#         "name": "Check one M.D.",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "D.O.",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "N.P.",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "P.A.",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Address_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Address"
#       },
#       {
#         "name": "City_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "City"
#       },
#       {
#         "name": "State_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "State"
#       },
#       {
#         "name": "ZIP_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "ZIP"
#       },
#       {
#         "name": "Phone_8",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Phone"
#       },
#       {
#         "name": "Fax_7",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Fax"
#       },
#       {
#         "name": "St Lic #",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "St Lic #"
#       },
#       {
#         "name": "NPI #",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "NPI #"
#       },
#       {
#         "name": "DEA #",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "DEA #"
#       },
#       {
#         "name": "UPIN",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "UPIN"
#       },
#       {
#         "name": "Provider Email",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Provider Email"
#       },
#       {
#         "name": "Office Contact Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Office Contact Name"
#       },
#       {
#         "name": "Self-administered",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Physician's Office",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Home",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Outpatient Infusion Center Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Outpatient Infusion Center Name"
#       },
#       {
#         "name": "Home Infusion Center Agency Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Home Infusion Center Agency Name"
#       },
#       {
#         "name": "Phone_9",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Phone"
#       },
#       {
#         "name": "Administration code(s) (CPT)",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Administration code(s) (CPT)"
#       },
#       {
#         "name": "Address_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Address"
#       },
#       {
#         "name": "City_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "City"
#       },
#       {
#         "name": "State_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "State"
#       },
#       {
#         "name": "ZIP_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "ZIP"
#       },
#       {
#         "name": "Phone_10",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Phone"
#       },
#       {
#         "name": "Fax_8",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Fax"
#       },
#       {
#         "name": "TIN",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "TIN"
#       },
#       {
#         "name": "PIN",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "PIN"
#       },
#       {
#         "name": "NPI",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "NPI"
#       },
#       {
#         "name": "Outpatient Dialysis Center",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Retail Pharmacy",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Mail Order",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Physician's Office_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Specialty Pharmacy",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Other",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Name"
#       },
#       {
#         "name": "Address_4",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Address"
#       },
#       {
#         "name": "City_4",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "City"
#       },
#       {
#         "name": "State_4",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "State"
#       },
#       {
#         "name": "ZIP_4",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "ZIP"
#       },
#       {
#         "name": "Phone_11",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Phone"
#       },
#       {
#         "name": "Fax_9",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Fax"
#       },
#       {
#         "name": "PIN_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "PIN"
#       },
#       {
#         "name": "TIN_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "TIN"
#       },
#       {
#         "name": "NPI_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "NPI"
#       },
#       {
#         "name": "Riabni",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": "Riabni (rituximab-arrx)"
#       },
#       {
#         "name": "Rituxan",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": "Rituxan (rituximab)"
#       },
#       {
#         "name": "Ruxience",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": "Ruxience (rituximab-pvvr)"
#       },
#       {
#         "name": "Truxima",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": "Truxima (rituximab-abbs)"
#       },
#       {
#         "name": "Dose",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Dose"
#       },
#       {
#         "name": "Directions for Use",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Directions for Use"
#       },
#       {
#         "name": "HCPCS Code",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "HCPCS Code"
#       },
#       {
#         "name": "Primary ICD Code",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Primary ICD Code"
#       },
#       {
#         "name": "Other ICD Code",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Other ICD Code"
#       },
#       {
#         "name": "Has the patient had prior therapy with the requested product within the last 365 days",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Has the patient had a trial and failure of any of the following rituximab biosimilars",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Ruxience (rituximab-pvvr)",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Truxima (rituximab-abbs)",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "When was the member's trial and failure of the preferred drug",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the failure of the preferred drug",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Has the patient had an adverse reaction to any of the following rituximab biosimilars",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Ruxience (rituximab-pvvr)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Truxima (rituximab-abbs)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "When was the member's adverse reaction to the preferred drug",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the adverse reaction to the preferred drug",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Ruxience (rituximab-pvvr)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Truxima (rituximab-abbs)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       }
#     ],
#     "3": [
#       {
#         "name": "Patient First Name",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient First Name"
#       },
#       {
#         "name": "Patient Last Name",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient Last Name"
#       },
#       {
#         "name": "Patient Phone",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient Phone"
#       },
#       {
#         "name": "Patient DOB",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient DOB"
#       },
#       {
#         "name": "Has the patient had a trial and failure of any of the following",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Inflectra (infliximab-dyyb)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Renflexis (infliximab-abda)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Simponi Aria (golimumab)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "When was the member's trial and failure of the preferred drug_2",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the failure of the preferred drug_2",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Has the patient had an adverse reaction to any of the following",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Inflectra (infliximab-dyyb)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Renflexis (infliximab-abda)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Simponi Aria (golimumab)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "When was the member's adverse reaction to the preferred drug_2",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the adverse reaction to the preferred drug_2",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Has the patient had a trial and failure of any of the following_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Enbrel (etanercept)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Humira (adalimumab)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Idacio (adalimumab-aacf)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Rinvoq (upadacitinib)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Tyenne SC (tocilizumab-aazg)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Xeljanz/Xeljanz XR (tofacitinib)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "When was the member's trial and failure of the preferred drug_3",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the failure of the preferred drug_3",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Has the patient had a trial and failure of any of the following_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Enbrel (etanercept)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Humira (adalimumab)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Idacio (adalimumab-aacf)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Rinvoq (upadacitinib)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Tyenne SC (tocilizumab-aazg)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Xeljanz/Xeljanz XR (tofacitinib)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "When was the member's adverse reaction to the preferred drug_3",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the adverse reaction to the preferred drug_3",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Inflectra (infliximab-dyyb)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Renflexis (infliximab-abda)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Simponi Aria (golimumab)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Enbrel (etanercept)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Humira (adalimumab)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Idacio (adalimumab-aacf)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Rinvoq (upadacitinib)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Tyenne SC (tocilizumab-aazg)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Xeljanz/Xeljanz XR (tofacitinib)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Will Rituxan (rituximab) be used concomitantly with apremilast, tofacitinib, or other biologic DMARDs (e.g., adalimumab, infliximab)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Does the patient have a documented diagnosis of Philadelphia chromosome-negative acute lymphoid leukemia (ALL)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Is Rituxan (rituximab) being used as induction/consolidation therapy",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Does the patient have a documented diagnosis of refractory autoimmune hemolytic anemia",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Wegener granulomatosis",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Churg-Strauss syndrome",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "microscopic polyangiitis",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "pauci-immune glomerulonephritis",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Will Rituxan (rituximab) be given in conjunction with glucocorticoids",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Does the patient have a documented diagnosis of corticosteroid-refractory autoimmune blistering disease",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "pemphigus vulgaris",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "pemphigus folliaceus",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "bullous pemphigoid",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "cicatricial pemphigoid",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "epidermolysis bullosa acquisita",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "paraneoplastic pemphigus",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "None of the above",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "AIDS-related B-cell lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Burkitt lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Diffuse large B-cell lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Follicular lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Gastric MALT lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "High-grade B-Cell lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Mantle cell lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Nodal marginal zone lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Nongastric MALT lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Primary cutaneous B-cell lymphomas",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Splenic marginal zone lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Other_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Button",
#         "field_label": null
#       }
#     ],
#     "4": [
#       {
#         "name": "Patient First Name_2",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient First Name"
#       },
#       {
#         "name": "Patient Last Name_2",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient Last Name"
#       },
#       {
#         "name": "Patient Phone_2",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient Phone"
#       },
#       {
# ...
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Neuromyelitis optica (Devic's disease)_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Neuromyelitis optica (Devic's disease)_Ineffective_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Neuromyelitis optica (Devic's disease)_Ineffective_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Opsoclonus-myoclonus-ataxia (OMA)_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Opsoclonus-myoclonus-ataxia (OMA)_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Opsoclonus-myoclonus-ataxia (OMA)_Refractory to steroids_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Opsoclonus-myoclonus-ataxia (OMA)_Refractory to steroids_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Medication 1",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Dates 1",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Medication 2",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Dates 2",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Post-transplant lymphoproliferative disorder_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Post-transplant lymphoproliferative disorder_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Post-transplant lymphoproliferative disorder_Prophylaxis for Epstein-Barr virus (EBV)_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Post-transplant lymphoproliferative disorder_Prophylaxis for Epstein-Barr virus (EBV)_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       }
#     ],
#     "5": [
#       {
#         "name": "Patient First Name",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Patient Last Name",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Patient Phone",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Patient DOB",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Rheumatoid Arthritis_Severity_Mild",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Rheumatoid Arthritis_Severity_Moderate",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Rheumatoid Arthritis_Severity_Severe",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Rheumatoid Arthritis_Disease active_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Rheumatoid Arthritis_Disease active_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Rituxan in combination with methotrexate_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Rituxan in combination with methotrexate_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Methotrexate ineffective_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Methotrexate ineffective_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Methotrexate_ineffective",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Methotrexate_not tolerated",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Methotrexate_contraindicated",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Conventional DMARD ineffective_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Conventional DMARD ineffective_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "DMARD_azathioprine",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "DMARD_cyclosporine",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "DMARD_hydroxychloroquine",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "DMARD_leflunomide",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "DMARD_sulfasalazine",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Sjögren syndrome_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Sjögren syndrome_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Corticosteroids and other immunosuppressive agents ineffective_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Corticosteroids and other immunosuppressive agents ineffective_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Corticosteroids Medication 1",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Corticosteroids Dates 1",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Corticosteroids Medication 2",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Corticosteroids Dates 2",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Thrombotic thrombocytopenic purpura (TTP)_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Thrombotic thrombocytopenic purpura (TTP)_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Waldenström macroglobulinemia_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Waldenström macroglobulinemia_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Continuation Request_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Continuation Request_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Length of time on Rituxan",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Rheumatoid Arthritis only_Disease severity at baseline_Mild",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Rheumatoid Arthritis only_Disease severity at baseline_Moderate",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Rheumatoid Arthritis only_Disease severity at baseline_Severe",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Rheumatoid Arthritis only_Disease stability_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Rheumatoid Arthritis only_Disease stability_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Rheumatoid Arthritis only_Disease improvement_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Rheumatoid Arthritis only_Disease improvement_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "All other indications_Disease stability_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "All other indications_Disease stability_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "All other indications_Disease improvement_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "All other indications_Disease improvement_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Request Completed By_Signature Required",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Date",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       }
#     ]
#   }
# }
# ```
# ---------------------------------

# %%
# Create PA_form_analysis from pa_fields_context
# This combines all the processed PA field data into a single analysis

if 'pa_fields_context' in locals() and pa_fields_context:
    # Combine all page results into a single analysis
    PA_form_analysis = ""
    for page, result in pa_fields_context.items():
        PA_form_analysis += f"PAGE {page}:\n{result}\n\n"
    print("✅ PA_form_analysis created successfully!")
    print(f"Length: {len(PA_form_analysis)} characters")
else:
    # Fallback: create from raw pa_fields if pa_fields_context isn't ready
    PA_form_analysis = json.dumps(pa_fields, indent=2)
    print("⚠️  Using fallback: PA_form_analysis created from raw pa_fields")
    print("Note: Run cell 12 first to get processed analysis")

print("PA_form_analysis preview:")
print(PA_form_analysis)
# Out:
# ✅ PA_form_analysis created successfully!
# Length: 271880 characters
# PA_form_analysis preview:
# PAGE 2:
# ```json
# {
#   "pages": {
#     "1": [
#       {
#         "name": "Phone_1",
#         "type": "text",
#         "value": "1-866-503-0857",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_1",
#         "type": "text",
#         "value": "1-844-268-7263",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_1",
#         "type": "text",
#         "value": "https://www.aetna.com/health-care-professionals/resource-center/availity.html",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_2",
#         "type": "text",
#         "value": "1-855-463-0933",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_2",
#         "type": "text",
#         "value": "1-833-280-5224",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_2",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/virginia-hmosnp/providers/portal",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_3",
#         "type": "text",
#         "value": "1-844-362-0934",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_3",
#         "type": "text",
#         "value": "1-833-322-0034",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_3",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/new-jersey-hmosnp/providers/portal.html",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_4",
#         "type": "text",
#         "value": "1-866-600-2139",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "FAX",
#         "type": "text",
#         "value": "1-855-320-8445",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_4",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/illinois/providers/portal",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_5",
#         "type": "text",
#         "value": "1-855-364-0974",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_5",
#         "type": "text",
#         "value": "1-855-734-9389",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_5",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/ohio/providers/portal",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_6",
#         "type": "text",
#         "value": "1-855-676-5772",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_6",
#         "type": "text",
#         "value": "1-844-241-2495",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_6",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/michigan/providers/portal.html",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       }
#     ],
#     "2": [
#       {
#         "name": "Start of treatment",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Date",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Continuation of therapy",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Date_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "First Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Last Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Address",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "City",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "State",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "DOB",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "ZIP",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Home Phone",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Work Phone",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Cell Phone",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "E-mail",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Ibs",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "kgs",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "inches",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "cms",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Allergies",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Member ID #",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Carrier Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "ID",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Group #",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Insured_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Insured",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "M.D.",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "D.O.",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "N.P.",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "P.A.",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "First Name_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Last Name_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Address_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "City_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "State_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "ZIP_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_2_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_2_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "St Lic #",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "NPI #",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "DEA #",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "UPIN",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Provider Email",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Office Contact Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_3_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Self-administered",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Physician's Office",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Home",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Outpatient Infusion Center Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Home Infusion Center",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Phone_4_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Outpatient Dialysis Center",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Retail Pharmacy",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Mail Order",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Physician's Office_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Specialty Pharmacy",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Other",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Agency Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Administration code(s) (CPT)",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Address_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "City_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "State_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "ZIP_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_5_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_3_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "PIN",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "TIN",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "NPI",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "City_4",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "State_4",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "ZIP_4",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_6_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "PIN_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "TIN_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "NPI_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Riabni (rituximab-arrx)",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Rituxan (rituximab)",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Ruxience (rituximab-pvvr)",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Truxima (rituximab-abbs)",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Dose",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Directions for Use",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "HCPCS Code",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Primary ICD Code",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Other ICD Code",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Yes_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Ruxience (rituximab-pvvr)",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Truxima (rituximab-abbs)",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "When was the member's trial and failure of the preferred drug",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the failure of the preferred drug",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "No_4",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Ruxience (rituximab-pvvr)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Truxima (rituximab-abbs)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "When was the member's adverse reaction to the preferred drug",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the adverse reaction to the preferred drug",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Ruxience (rituximab-pvvr)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Truxima (rituximab-abbs)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       }
#     ],
#     "3": [
#       {
#         "name": "Patient First Name",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Patient Last Name",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Patient Phone",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Patient DOB",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "No_5",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Inflectra (infliximab-dyyb)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Renflexis (infliximab-abda)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Simponi Aria (golimumab)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "When was the member's trial and failure of the preferred drug",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the failure of the preferred drug",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "No_6",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Inflectra (infliximab-dyyb)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Renflexis (infliximab-abda)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Simponi Aria (golimumab)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "When was the member's adverse reaction to the preferred drug",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the adverse reaction to the preferred drug",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "No_7",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Enbrel (etanercept)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Humira (adalimumab)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Idacio (adalimumab-aacf)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Rinvoq (upadacitinib)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Tyenne SC (tocilizumab-aazg)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Xeljanz/Xeljanz XR (tofacitinib)",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "When was the member's trial and failure of the preferred drug_2",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the failure of the preferred drug_2",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "No_8",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Enbrel (etanercept)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Humira (adalimumab)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Idacio (adalimumab-aacf)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Rinvoq (upadacitinib)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Tyenne SC (tocilizumab-aazg)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Xeljanz/Xeljanz XR (tofacitinib)_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "When was the member's adverse reaction to the preferred drug_2",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the adverse reaction to the preferred drug_2",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Inflectra (infliximab-dyyb)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Renflexis (infliximab-abda)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Simponi Aria (golimumab)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Enbrel (etanercept)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Humira (adalimumab)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Idacio (adalimumab-aacf)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Rinvoq (upadacitinib)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Tyenne SC (tocilizumab-aazg)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Xeljanz/Xeljanz XR (tofacitinib)_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_4",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_9",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_5",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_10",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_6",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_11",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_7",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_12",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Wegener granulomatosis",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "microscopic polyangiitis",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Churg-Strauss syndrome",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "pauci-immune glomerulonephritis",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_8",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_13",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": null,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Yes_9",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_14",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "pemphigus vulgaris",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "pemphigus folliaceus",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "bullous pemphigoid",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "cicatricial pemphigoid",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "epidermolysis bullosa acquisita",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "paraneoplastic pemphigus",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "None of the above",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "AIDS-related B-cell lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Burkitt lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Diffuse large B-cell lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Follicular lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Gastric MALT lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "High-grade B-Cell lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Mantle cell lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Nodal marginal zone lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Nongastric MALT lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Primary cutaneous B-cell lymphomas",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Splenic marginal zone lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Other_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       }
#     ],
#     "4": [
#       {
#         "name": "Patient First Name",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Patient Last Name",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Patient Phone",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Patient DOB",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Yes_10",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_15",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "leptomeningeal metastases from lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "primary CNS lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "none of the above",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "chronic lymphocytic leukemia (CLL)",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "small lymphocytic leukemia",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "none of the above_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_11",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_16",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_12",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_17",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_13",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_18",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "relapsed hairy cell leukemia",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "refractory hairy cell leukemia",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "none of the above_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_14",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No_19",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
# ...
#         "field_label": null
#       },
#       {
#         "name": "Yes_8",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "No_8",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Relapsing-remitting MS (RRMS)",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Secondary-progressive MS (SPMS)",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Primary-progressive MS (PPMS)",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Progressive-relapsing MS (PRMS)",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_9",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "No_9",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_10",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "No_10",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_11",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "No_11",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_12",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "No_12",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_13",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "No_13",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_14",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "No_14",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Medication",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Dates",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Medication_2",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Dates_2",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Yes_15",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "No_15",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_16",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "No_16",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       }
#     ],
#     "5": [
#       {
#         "name": "Mild",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Moderate",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Severe",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "No",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "No_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "No_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "ineffective",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "not tolerated",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "contraindicated",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_4",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "No_4",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "azathioprine",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "cyclosporine",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "hydroxychloroquine",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "leflunomide",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "sulfasalazine",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_5",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "No_5",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_6",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "No_6",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Medication_2",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Dates",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Medication_3",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Dates_2",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Yes_7",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "No_7",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_8",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "No_8",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_9",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "No_9",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_10",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "No_10",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "length of time on Rituxan (rituximab)",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Mild_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Moderate_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Severe_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_11",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "No_11",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_12",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "No_12",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_13",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "No_13",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes_14",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "No_14",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 1,
#         "field_type_string": "Radio Button",
#         "field_label": null
#       },
#       {
#         "name": "Request Completed By (Signature Required)",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Date",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       }
#     }
#   }
# }
# ```

# %%
pa_fields_context
# Out:
# {2: '```json\n{\n  "pages": {\n    "1": [\n      {\n        "name": "Phone_1",\n        "type": "text",\n        "value": "1-866-503-0857",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_1",\n        "type": "text",\n        "value": "1-844-268-7263",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_1",\n        "type": "text",\n        "value": "https://www.aetna.com/health-care-professionals/resource-center/availity.html",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_2",\n        "type": "text",\n        "value": "1-855-463-0933",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_2",\n        "type": "text",\n        "value": "1-833-280-5224",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_2",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/virginia-hmosnp/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_3",\n        "type": "text",\n        "value": "1-844-362-0934",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_3",\n        "type": "text",\n        "value": "1-833-322-0034",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_3",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/new-jersey-hmosnp/providers/portal.html",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_4",\n        "type": "text",\n        "value": "1-866-600-2139",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "FAX",\n        "type": "text",\n        "value": "1-855-320-8445",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_4",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/illinois/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_5",\n        "type": "text",\n        "value": "1-855-364-0974",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_5",\n        "type": "text",\n        "value": "1-855-734-9389",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_5",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/ohio/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_6",\n        "type": "text",\n        "value": "1-855-676-5772",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_6",\n        "type": "text",\n        "value": "1-844-241-2495",\n        "page": 1,\n        "field_type": 2,\n        "field_t ...
#  3: '```json\n{\n  "pages": {\n    "1": [\n      {\n        "name": "Phone",\n        "type": "text",\n        "value": "1-866-503-0857 (TTY: 711)",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax",\n        "type": "text",\n        "value": "1-844-268-7263",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity",\n        "type": "text",\n        "value": "https://www.aetna.com/health-care-professionals/resource-center/availity.html",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_2",\n        "type": "text",\n        "value": "1-855-463-0933",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_2",\n        "type": "text",\n        "value": "1-833-280-5224",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_2",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/virginia-hmosnp/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_3",\n        "type": "text",\n        "value": "1-844-362-0934",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_3",\n        "type": "text",\n        "value": "1-833-322-0034",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_3",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/new-jersey-hmosnp/providers/portal.html",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_4",\n        "type": "text",\n        "value": "1-866-600-2139",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "FAX",\n        "type": "text",\n        "value": "1-855-320-8445",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_4",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/illinois/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_5",\n        "type": "text",\n        "value": "1-855-364-0974",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_4",\n        "type": "text",\n        "value": "1-855-734-9389",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_5",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/ohio/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_6",\n        "type": "text",\n        "value": "1-855-676-5772",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_5",\n        "type": "text",\n        "value": "1-844-241-2495",\n        "page": 1,\n        "field_type": 2,\n        "fi ...
#  4: '```json\n{\n  "pages": {\n    "1": [\n      {\n        "name": "Phone_1",\n        "type": "text",\n        "value": "1-866-503-0857",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_1",\n        "type": "text",\n        "value": "1-844-268-7263",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_1",\n        "type": "text",\n        "value": "https://www.aetna.com/health-care-professionals/resource-center/availity.html",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_2",\n        "type": "text",\n        "value": "1-855-463-0933",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_2",\n        "type": "text",\n        "value": "1-833-280-5224",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_2",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/virginia-hmosnp/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_3",\n        "type": "text",\n        "value": "1-844-362-0934",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_3",\n        "type": "text",\n        "value": "1-833-322-0034",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_3",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/new-jersey-hmosnp/providers/portal.html",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_4",\n        "type": "text",\n        "value": "1-866-600-2139",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "FAX_4",\n        "type": "text",\n        "value": "1-855-320-8445",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_4",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/illinois/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_5",\n        "type": "text",\n        "value": "1-855-364-0974",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_5",\n        "type": "text",\n        "value": "1-855-734-9389",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_5",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/ohio/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_6",\n        "type": "text",\n        "value": "1-855-676-5772",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_6",\n        "type": "text",\n        "value": "1-844-241-2495",\n        "page": 1,\n        "field_type": 2,\n        "field ...
#  5: '```json\n{\n  "pages": {\n    "1": [\n      {\n        "name": "Phone",\n        "type": "text",\n        "value": "1-866-503-0857",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax",\n        "type": "text",\n        "value": "1-844-268-7263",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity",\n        "type": "text",\n        "value": "https://www.aetna.com/health-care-professionals/resource-center/availity.html",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_2",\n        "type": "text",\n        "value": "1-855-463-0933",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_2",\n        "type": "text",\n        "value": "1-833-280-5224",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_2",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/virginia-hmosnp/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_3",\n        "type": "text",\n        "value": "1-844-362-0934",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_3",\n        "type": "text",\n        "value": "1-833-322-0034",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_3",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/new-jersey-hmosnp/providers/portal.html",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_4",\n        "type": "text",\n        "value": "1-866-600-2139",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "FAX",\n        "type": "text",\n        "value": "1-855-320-8445",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_4",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/illinois/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_5",\n        "type": "text",\n        "value": "1-855-364-0974",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_4",\n        "type": "text",\n        "value": "1-855-734-9389",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_5",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/ohio/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_6",\n        "type": "text",\n        "value": "1-855-676-5772",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_5",\n        "type": "text",\n        "value": "1-844-241-2495",\n        "page": 1,\n        "field_type": 2,\n        "field_type_st ...

# %% [markdown]
# ## Form filling strategy

# %%
# 🤖 INTELLIGENT AUTO-MAPPING: Let AI map actual field names to patient data
print("🤖 Creating intelligent automated field mapping...")

# Get all actual PDF fields with their labels
doc = fitz.open("Input Data/Adbulla/PA.pdf")
pdf_fields = []
for page_num in range(len(doc)):
    page = doc[page_num]
    for widget in page.widgets():
        if widget.field_name and widget.field_label:
            pdf_fields.append({
                'field_name': widget.field_name,
                'field_type': widget.field_type_string,
                'field_label': widget.field_label,
                'page': page_num + 1
            })
doc.close()

    # Fill PDF with AI mappings - Enhanced with debugging
def fill_pdf_with_ai_mappings(input_pdf_path, output_pdf_path, mappings):
    doc = fitz.open(input_pdf_path)
    filled_count = 0
    skipped_count = 0
    unmapped_count = 0
    
    print(f"🔧 Starting PDF filling with {len(mappings)} mappings...")
    
    for page_num in range(len(doc)):
        page = doc[page_num]
        
        for widget in page.widgets():
            field_name = widget.field_name
            
            if field_name in mappings:
                value = mappings[field_name]
                
                # Skip empty values
                if value == "" or value is None:
                    skipped_count += 1
                    continue
                
                try:
                    if widget.field_type == fitz.PDF_WIDGET_TYPE_CHECKBOX:
                        widget.field_value = bool(value)
                    elif widget.field_type == fitz.PDF_WIDGET_TYPE_TEXT:
                        widget.field_value = str(value)
                    else:
                        print(f"⚠️  Unknown field type for {field_name}: {widget.field_type}")
                        continue
                    
                    widget.update()
                    filled_count += 1
                    print(f"✅ {field_name}: {value}")
                    
                except Exception as e:
                    print(f"⚠️  Error filling {field_name}: {e}")
            else:
                unmapped_count += 1
                # Debug: Show unmapped fields (first 50 only)
                if unmapped_count < 50:
                    print(f"🔍 Field '{field_name}' not in mappings (Page {page.number + 1})")
    
    print(f"📊 Summary: {filled_count} fields filled, {skipped_count} skipped (empty values), {unmapped_count} not in mappings.")
    doc.save(output_pdf_path)
    doc.close()
    return filled_count
# Out:
# 🤖 Creating intelligent automated field mapping...

# %%
# 🚀 IMPROVED INTELLIGENT AUTO-MAPPING with Enhanced Coverage
print("🚀 Creating ENHANCED intelligent automated field mapping...")

# Enhanced mapping prompt that addresses all the gaps
enhanced_mapping_prompt = f"""You are an expert medical form automation specialist. Create comprehensive JSON mapping for a Prior Authorization form.

Pay attention to the whole context of the form and the patient data. And pay attention to this whole prompt including the middle parts

CRITICAL REQUIREMENTS:
1. Fill ALL possible fields where patient data is available
2. Handle checkbox dependencies (if main checkbox is checked, fill related sub-fields)
3. Include product/treatment information from clinical data
4. Use medical terminology appropriately
5. Format dates correctly for each field type
6. Handle multiple choice selections intelligently
7. NEVER use placeholder text like "(From Clinical Data)" - use actual data or leave blank

PDF FIELDS AVAILABLE:
{json.dumps(pdf_fields, indent=2)}

PATIENT DATA AVAILABLE:
{referral_data}

SPECIFIC MAPPING INSTRUCTIONS:

A. PATIENT INFORMATION SECTION:
- Map full name to separate first/last name fields
- Map complete address (street, city, state, zip)
- Map all phone numbers (home, work, cell)
- Map DOB in correct format
- Map patient demographics

B. INSURANCE INFORMATION:
- Map member ID, group number, insured name
- Check for secondary coverage and map if available
- Map insurance carrier information

C. PRESCRIBER INFORMATION - CRITICAL RULES:
- Look for "Provider Contact Information" or similar headings in the clinical data
- Search for doctor/physician names in message records or clinical notes for inference if no difinitive contact information is found
- Extract actual prescriber contact details (address, phone, fax)
- Look for NPI numbers, DEA numbers in provider sections
- Check credentials (M.D., D.O., N.P., P.A.) from provider information
- If prescriber information is not clearly available, LEAVE FIELDS BLANK
- DO NOT use placeholder text like "Prescriber Address (From Clinical Data)"

D. TREATMENT/PRODUCT INFORMATION - ENHANCED SEARCH:
- Look for headings containing "Product", "Medication", "Drug", "Treatment"
- Search doctor comments and clinical notes for prescribed medications
- Look for drug names, dosages, frequencies in clinical documentation
- Check for diagnosis codes (ICD-10) in clinical data
- Search for treatment justification in physician notes
- If specific product/medication is not found, LEAVE FIELDS BLANK

E. DISPENSING/ADMINISTRATION:
- Determine administration method from clinical data
- Map pharmacy/dispensing location if specified
- Map administration codes if available

F. CHECKBOX LOGIC:
- If "Start of treatment" is checked, fill start date fields
- If "Continuation of therapy" is checked, fill last treatment date
- For dispensing location, check appropriate option based on data
- For prescriber type, check M.D., D.O., N.P., or P.A. based on credentials

G. DATE FORMATTING:
- For separate MM/DD/YYYY fields, split dates accordingly
- For single date fields, use MM/DD/YYYY format
- Extract dates from clinical timeline

H. MISSING DATA HANDLING - STRICT RULES:
- Only map fields where you have ACTUAL, SPECIFIC subject data
- If information is not clearly available in the clinical data, LEAVE THE FIELD BLANK
- Do not guess, weakly infer, or fabricate information
- Do not use placeholder text or generic descriptions
- Better to have fewer accurate fields than many inaccurate ones

SEARCH STRATEGY FOR PRESCRIBER INFO:
1. Search for "Provider Contact", "Physician Contact", "Doctor Information"
2. Look in message records for sender/physician information
3. Check clinical notes for prescribing physician details
4. If no specific prescriber info found, leave prescriber fields blank

SEARCH STRATEGY FOR PRODUCT INFO:
1. Look for explicit "Product" or "Medication" sections
2. Search doctor comments for drug names and prescriptions
3. Check treatment plans for specific medications
4. Look for pharmaceutical names in clinical documentation
5. If no specific product found, leave product fields blank

OUTPUT FORMAT - CRITICAL JSON REQUIREMENTS:
1. Return ONLY valid JSON (no markdown blocks, no extra text)
2. Ensure all JSON brackets and braces are properly closed
3. Use double quotes for all strings
4. Boolean values must be true/false (not True/False)
5. Do not truncate the JSON response

{{
  "field_mappings": {{
    "T12": "Shakh",
    "T13": "Abdulla", 
    "CB1": true,
    "T2": "05",
    "T3": "22", 
    "T4": "2024",
    "CB5": false,
    "T14": "04/01/2001",
    "T15": "425 Sherman Ave APT D",
    "T16": "Nashville",
    "T17": "TN",
    "T18": "37995"
  }},
  "mapping_notes": {{
    "total_fields_mapped": 0,
    "sections_completed": [],
    "missing_data_areas": [],
    "checkbox_decisions": {{}}
  }}
}}

IMPORTANT: Complete the entire JSON response. Do not truncate or cut off the JSON in the middle.

ANALYZE THE CLINICAL DATA THOROUGHLY and create comprehensive mappings using ONLY actual data found."""

# Send enhanced prompt to Gemini
print("🧠 Asking AI for ENHANCED comprehensive field mappings...")
# Extract structured data from referral package using Gemini vision
enhanced_response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents=[enhanced_mapping_prompt]
)


# Extract and apply enhanced mappings with ROBUST error handling
def robust_json_parser(json_text):
    """Advanced JSON parser that handles common formatting issues and truncation"""
    import re
    
    # Step 1: Extract JSON content
    if "```json" in json_text:
        json_start = json_text.find("```json") + 7
        json_end = json_text.find("```", json_start)
        if json_end == -1:  # No closing ```
            json_content = json_text[json_start:].strip()
        else:
            json_content = json_text[json_start:json_end].strip()
    else:
        json_content = json_text.strip()
    
    # Step 2: Try direct parsing first
    try:
        return json.loads(json_content)
    except json.JSONDecodeError:
        pass
    
    # Step 3: Advanced cleaning and repair
    print("🔧 Applying advanced JSON repair...")
    
    # Fix common issues
    json_content = re.sub(r'"CB\d+": tr(?![ue])', lambda m: m.group(0).replace('tr', 'true'), json_content)
    json_content = re.sub(r'"CB\d+": fa(?![lse])', lambda m: m.group(0).replace('fa', 'false'), json_content)
    
    # Step 4: Extract field mappings manually using regex
    field_mappings = {}
    
    # Pattern for text fields: "T12": "value"
    text_pattern = r'"(T\d+(?:\.\d+)?|CB\d+|Provider Admin [^"]+)"\s*:\s*"([^"]*)"'
    for match in re.finditer(text_pattern, json_content):
        field_mappings[match.group(1)] = match.group(2)
    
    # Pattern for boolean fields: "CB1": true/false
    bool_pattern = r'"(T\d+(?:\.\d+)?|CB\d+|Provider Admin [^"]+)"\s*:\s*(true|false)'
    for match in re.finditer(bool_pattern, json_content):
        field_mappings[match.group(1)] = match.group(2) == 'true'
    
    # Pattern for null fields: "T1": null
    null_pattern = r'"(T\d+(?:\.\d+)?|CB\d+|Provider Admin [^"]+)"\s*:\s*null'
    for match in re.finditer(null_pattern, json_content):
        field_mappings[match.group(1)] = None
    
    if field_mappings:
        print(f"✅ Extracted {len(field_mappings)} field mappings using regex parsing")
        return {"field_mappings": field_mappings, "mapping_notes": {"extraction_method": "regex"}}
    
    # Step 5: Last resort - create minimal mapping from visible data
    print("⚠️  Using fallback minimal mapping")
    return {
        "field_mappings": {
            "T12": "Shakh",
            "T13": "Abdulla", 
            "T14": "04/01/2001",
            "T15": "425 Sherman Aves APT D",
            "T16": "Nashville",
            "T17": "TN",
            "T18": "37923"
        },
        "mapping_notes": {"extraction_method": "fallback"}
    }

try:
    # Use the robust parser
    enhanced_mappings = robust_json_parser(enhanced_response.text)
    
    enhanced_field_mappings = enhanced_mappings.get("field_mappings", {})
    mapping_notes = enhanced_mappings.get("mapping_notes", {})
    
    print(f"\n🎯 ENHANCED AI created {len(enhanced_field_mappings)} comprehensive field mappings")
    
    # Show mapping summary
    if mapping_notes:
        print(f"📊 Total fields mapped: {mapping_notes.get('total_fields_mapped', len(enhanced_field_mappings))}")
        print(f"📋 Sections completed: {', '.join(mapping_notes.get('sections_completed', []))}")
        if mapping_notes.get('missing_data_areas'):
            print(f"⚠️  Missing data areas: {', '.join(mapping_notes.get('missing_data_areas', []))}")
    
    # Show sample enhanced mappings
    print("\nSample enhanced mappings:")
    for i, (field, value) in enumerate(list(enhanced_field_mappings.items())[:8]):
        print(f"  • {field} → {value}")
    
    # Apply enhanced mappings to PDF
    output_pdf_enhanced = "Input Data/Adbulla/PA_FILLED_ENHANCED.pdf"
    filled_count = fill_pdf_with_ai_mappings("Input Data/Adbulla/PA.pdf", output_pdf_enhanced, enhanced_field_mappings)
    
    print(f"\n🎉 ENHANCED MAPPING SUCCESS!")
    print(f"✅ Filled {filled_count} fields using enhanced AI mapping")
    print(f"📄 Enhanced PDF saved as: {output_pdf_enhanced}")
    
    # Compare with previous version
    previous_count = len(field_mappings) if 'field_mappings' in locals() else 0
    improvement = filled_count - previous_count
    if improvement > 0:
        print(f"🚀 IMPROVEMENT: +{improvement} more fields filled than previous version!")
    
except Exception as e:
    print(f"❌ Error in enhanced mapping: {e}")
    print("Full enhanced response:")
    print(enhanced_response.text)
# Out:
# 🚀 Creating ENHANCED intelligent automated field mapping...
# 🧠 Asking AI for ENHANCED comprehensive field mappings...
#
# 🎯 ENHANCED AI created 322 comprehensive field mappings
#
# Sample enhanced mappings:
#   • CB1 → True
#   • T2 → 05
#   • T3 → 23
#   • T4 → 2024
#   • CB5 → False
#   • T6 → None
#   • T7 → None
#   • T8 → None
# 🔧 Starting PDF filling with 322 mappings...
# ✅ CB1: True
# ✅ T2: 05
# ✅ T3: 23
# ✅ T4: 2024
# ✅ CB5: False
# ✅ T9: Erfan Rostami, BSN, RN
# ✅ T10: 615-343-1176
# ✅ T11: 615-343-1219
# ✅ T12: Shakh
# ✅ T13: Abdulla
# ✅ T14: 04/01/2001
# ✅ T15: 425 Sherman Ave APT D
# ✅ T16: Nashville
# ✅ T17: TN
# ✅ T18: 37923
# ✅ T19: 865-839-7458
# ✅ T21: 865-395-0481
# ✅ T23: No Known Allergies
# ✅ T28: LAJM14345116
# ✅ T29: 435000
# ✅ T30: ABDULLA, SHAKH
# ✅ CB31: True
# ✅ CB32: False
# ✅ T33: LAJM14345116
# ✅ T34: BC TENNCARE
# ✅ T42: Hao H
# ✅ T43: Gu
# ✅ CB44: True
# ✅ CB45: False
# ✅ CB46: False
# ✅ CB47: False
# ✅ T48: 3320 Montgomery Dr
# ✅ T49: NASHVILLE
# ✅ T50: TN
# ✅ T51: 37361
# ✅ T52: 614-936-0065
# ✅ T55: 1154611523
# ✅ T58.1: Erfan Rostami, BSN, RN
# ✅ T59: 615-343-1176
# ✅ Provider Admin CB.1: False
# ✅ Provider Admin CB.2: False
# ✅ Provider Admin CB.3: False
# ✅ Provider Admin CB.4: True
# ✅ Provider Admin T.5: Peds Infusion (Leantaas)
# ✅ Provider Admin CB.7: False
# ✅ Provider Admin T.6: 615-936-1762
# ✅ Provider Admin CB.10: False
# ✅ Provider Admin T.11A: 2211 Broad Way, Tower 4th FL, Suite 6102
# ✅ Provider Admin T.13: Nashville
# ✅ Provider Admin T.14: TN
# ✅ Provider Admin T.15: 37232
# ✅ Provider Admin T.16: 615-936-1762
# ✅ Provider Admin CB.21: False
# ✅ Provider Admin CB.22: False
# ✅ Provider Admin CB.23.0.0: False
# ✅ Provider Admin CB.24.0.0: False
# ✅ Provider Admin CB.25: False
# ✅ Provider Admin CB.26: False
# ✅ CB60: False
# ✅ CB61: False
# ✅ CB62: False
# ✅ CB63: True
# ✅ T64: 694 mg (rounded from 693.75 mg)
# ✅ T65: Initial dose: 694 mg IVPB, once, 30 min after treatment start. Maintenance dose: 694 mg IVPB, once, every 24 weeks. Infusion rate: 1st infusion - initiate at 50mg/hr, increase by 50mg/hr every 30 min, Max Rate 400mg/hr. Subsequent infusions - initiate at 100mg/hr, increase by 100mg/hr every 30 min, Max Rate 400mg/hr.
# ✅ T67: G35
# ✅ CB68: False
# ✅ CB70: False
# ✅ CB71: True
# ✅ CB72: False
# ✅ CB73: False
# 🔍 Field 'CB74' not in mappings (Page 2)
# ✅ CB77: False
# ✅ CB78: False
# ✅ CB79: False
# ✅ CB82: False
# ✅ CB83: False
# ✅ T12: Shakh
# ✅ T13: Abdulla
# ✅ T19: 865-839-7458
# ✅ T14: 04/01/2001
# ✅ CB86: False
# ✅ CB87: False
# ✅ CB88: False
# ✅ CB85: True
# ✅ CB92: False
# ✅ CB93: False
# ✅ CB94: False
# ✅ CB91: True
# ✅ CB98a: False
# ✅ CB99a: False
# ✅ CB100a: False
# ✅ CB101a: False
# ✅ CB102a: False
# ✅ CB103a: False
# ✅ CB97: True
# ✅ CB107z: False
# ✅ CB108z: False
# ✅ CB109z: False
# ✅ CB110z: False
# ✅ CB111z: False
# ✅ CB112z: False
# ✅ CB106z: True
# ✅ CB115z: False
# ✅ CB116z: False
# ✅ CB117z: False
# ✅ CB119z: False
# ✅ CB120z: False
# ✅ CB121z: False
# ✅ CB122z: False
# ✅ CB123z: False
# ✅ CB124z: False
# ✅ CB96.4.0: False
# ✅ CB98: True
# ✅ CB99.0: False
# ✅ CB100.0: True
# ✅ CB101.0: False
# ✅ CB102.0: True
# ✅ CB103: False
# ✅ CB104: True
# ✅ CB104a: False
# ✅ CB104b: False
# ✅ CB104c: False
# ✅ CB104d: False
# ✅ CB105: False
# ✅ CB106: True
# ✅ CB106a: False
# ✅ CB107: False
# ✅ CB108: False
# ✅ CB109: False
# ✅ CB110: False
# ✅ CB111: False
# ✅ CB112: False
# ✅ CB113: True
# ✅ CB106b: True
# ✅ CB114: False
# ✅ CB115: False
# ✅ CB116: False
# ✅ CB117: False
# ✅ CB118: False
# ✅ CB119: False
# ✅ CB120: False
# ✅ CB121: False
# ✅ CB122: False
# ✅ CB123: False
# ✅ CB124: False
# ✅ CB125: False
# ✅ T12: Shakh
# ✅ T13: Abdulla
# ✅ T19: 865-839-7458
# ✅ T14: 04/01/2001
# ✅ CB127: False
# ✅ CB128: True
# ✅ CB129: False
# ✅ CB130: False
# ✅ CB131: True
# ✅ CB132: False
# ✅ CB133: False
# ✅ CB134: True
# ✅ CB135: False
# ✅ CB136: True
# ✅ CB139: False
# ✅ CB140: True
# ✅ CB144: False
# ✅ CB145: True
# ✅ CB141: False
# ✅ CB142: False
# ✅ CB143: True
# ✅ CB137: False
# ✅ CB146: False
# ✅ CB147: False
# ✅ CB138: True
# ✅ CB148: False
# ✅ CB149: False
# ✅ CB150: False
# ✅ CB151: False
# ✅ CB152: False
# ✅ CB153: False
# ✅ CB154: False
# ✅ CB156: False
# ✅ CB158: False
# ✅ CB159: False
# ✅ CB157: True
# ✅ CB160: False
# ✅ CB161: True
# ✅ CB162: False
# ✅ CB163: True
# ✅ CB164: True
# ✅ CB165: False
# ✅ CB166: False
# ✅ CB167: False
# ✅ CB168: True
# ✅ CB169: False
# ✅ CB170: True
# ✅ CB172: True
# ✅ CB173: False
# ✅ CB171: False
# ✅ CB174: False
# ✅ CB175: True
# ✅ CB176: False
# ✅ CB177: True
# ✅ CB178: False
# ✅ CB179: True
# ✅ CB180: False
# ✅ CB181: True
# ✅ CB203: False
# ✅ CB204: True
# ✅ CB205: True
# ✅ CB206: False
# ✅ T12: Shakh
# ✅ T13: Abdulla
# ✅ T19: 865-839-7458
# ✅ T14: 04/01/2001
# ✅ CB207: False
# ✅ CB208: False
# ✅ CB209: True
# ✅ CB210: False
# ✅ CB211: True
# ✅ CB212: True
# ✅ CB213: False
# ✅ CB214: False
# ✅ CB215: True
# ✅ CB223: False
# ✅ CB225: False
# ✅ CB226: False
# ✅ CB227: False
# ✅ CB228: False
# ✅ CB229: False
# ✅ CB224: True
# ✅ CB281: False
# ✅ CB282: True
# ✅ CB283: False
# ✅ CB284: True
# ✅ CB299: False
# ✅ CB300: True
# ✅ CB301: False
# ✅ CB302: True
# ✅ CB303: False
# ✅ CB304: True
# ✅ CB306: False
# ✅ CB307: True
# ✅ CB308: False
# ✅ CB309: True
# ✅ CB313: False
# ✅ CB314: True
# ✅ CB315: False
# ✅ CB316: True
# 📊 Summary: 245 fields filled, 89 skipped (empty values), 1 not in mappings.
#
# 🎉 ENHANCED MAPPING SUCCESS!
# ✅ Filled 245 fields using enhanced AI mapping
# 📄 Enhanced PDF saved as: Input Data/Adbulla/PA_FILLED_ENHANCED.pdf
# 🚀 IMPROVEMENT: +245 more fields filled than previous version!
