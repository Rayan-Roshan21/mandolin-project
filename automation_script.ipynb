# %% [markdown]
# ## Loading Model and Input Files

# %%
# 🔄 CLEAN INITIALIZATION - RESTART KERNEL IF NEEDED
print("🔄 Initializing environment...")
import pathlib
from google import genai
from google.genai import types
import os
import asyncio
import json
import fitz  # PyMuPDF for PDF processing
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Check if API key is loaded
api_key = os.getenv("GOOGLE_API_KEY")
if not api_key:
    raise ValueError("GOOGLE_API_KEY not found in environment variables. Please check your .env file.")

# Configure the API
client = genai.Client(api_key=api_key)


pa_file = "PA.pdf"
referral_file = "referral_package.pdf"

# Retrieve and encode the PDF byte
filepath = pathlib.Path('Input Data/Adbulla/' + pa_file)

print("✅ Setup complete!")
# Out:
# 🔄 Initializing environment...
# ✅ Setup complete!

# %% [markdown]
# ## 📄 Referral Package Analysis & Information Extraction to Json Using Gemeni

# %%
# 🔄 DIRECT GEMINI OCR & ANALYSIS - Bypassing Mistral
print("🔄 Using Gemini directly for OCR and information extraction...")

# Enhanced prompt for direct PDF analysis
referral_prompt = """You are analyzing a referral package PDF (collection of scanned medical documents) to extract patient information that will be used to fill a Prior Authorization form.

CONTEXT: This referral package contains scanned documents like insurance cards, medical history notes, test results, and other supporting documentation. You need to perform OCR on the PDF and extract structured information.

EXTRACTION FOCUS: Use your vision capabilities to read and extract all available information and display it in order as it is read from the PDF. Then turn that output into JSON format:

PATIENT DEMOGRAPHICS:
- Full name, DOB, gender, address, phone numbers
- Patient ID numbers, MRN, account numbers
- Emergency contacts and relationships

INSURANCE INFORMATION:
- Insurance company name and plan details
- Member ID, group number, policy number
- Subscriber information and relationship to patient
- Coverage details and effective dates

CLINICAL INFORMATION:
- Primary and secondary diagnoses with ICD codes
- Current medications, dosages, and frequencies
- Allergies and adverse reactions
- Vital signs and lab results
- Previous treatments and outcomes
- Medical history and comorbidities

PROVIDER INFORMATION:
- Referring physician name, specialty, and contact info
- Practice name and address
- NPI numbers and license information
- Facility details where treatment will occur

TREATMENT DETAILS:
- Requested medication/procedure/device
- Dosage, frequency, duration
- Medical necessity justification
- Previous treatment failures
- Clinical criteria met for approval

SUPPORTING EVIDENCE:
- Lab results supporting diagnosis
- Imaging studies and results
- Functional assessments
- Specialist consultations
- Treatment response documentation

INSTRUCTIONS:
1. Carefully read through all pages of the PDF
2. Extract text and data from tables, forms, and documents
3. Pay attention to medical terminology and abbreviations
4. Look for provider contact information sections
5. Identify medication/product information from clinical notes
6. First return all info read in the document. List all information from tables including reference ranges and other details. Do not skip anything that has information
7. Then return a structured JSON with all relevant extracted information, using null for missing data"""

# Load and process the referral package PDF directly with Gemini
referral_pdf_path = 'Input Data/Adbulla/referral_package.pdf'

# Upload the PDF file to Gemini using new API
print(f"📄 Loading referral package: {referral_pdf_path}")
referral_file = client.files.upload(file=referral_pdf_path)
print(f"✅ File uploaded successfully: {referral_file.name}")

# Wait for file processing
import time
while referral_file.state == "PROCESSING":
    print("⏳ Processing file...")
    time.sleep(2)
    referral_file = client.files.get(name=referral_file.name)

if referral_file.state == "FAILED":
    raise ValueError("❌ File processing failed")
print("✅ File processed successfully")

# Extract structured data from referral package using Gemini vision
referral_response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents=[referral_prompt, referral_file]
)
referral_data = referral_response.text
print("📊 Referral Package Data Extracted:")
print(referral_data)

# Store the extracted text for compatibility with existing code
referral_package_text = referral_data
# Out:
# 🔄 Using Gemini directly for OCR and information extraction...
# 📄 Loading referral package: Input Data/Adbulla/referral_package.pdf
# ✅ File uploaded successfully: files/xjzg0y7w5g4l
# ✅ File processed successfully
# ✅ File uploaded successfully: files/xjzg0y7w5g4l
# ✅ File processed successfully
# 📊 Referral Package Data Extracted:
# Here's the extracted information as read from the PDF, followed by the structured JSON output.
#
# ## Information Read from the PDF:
#
# **Page 1/28: FAX TRANSMISSION**
# *   **Date:** 04/22/2024 WED 11:32
# *   **Sender Organization:** Better Life Multiple Sclerosis Center
# *   **Sender Address:** 3320 Montgomery Dr. Nashville, TN 37361
# *   **Sender Fax:** F: 615-562-4820
# *   **Sender Phone:** P: 615-562-4848
# *   **Sender Doctors:** Dr. Asriel Han | Dr. Aditya Shah
# *   **Recipient:** TO: Golden Gate Infusion Center
# *   **Recipient Fax:** Fax: 614-278-3355
# *   **Recipient Phone:** Phone: 614-895-7655
# *   **Sender (Individual):** From: Erfan Rostami, BSN, RN
# *   **Sender Individual Phone:** P: 615-343-1176
# *   **Sender Individual Fax:** F: 615-343-1219
# *   **Pages:** 1 (including cover sheet)
# *   **Comments:**
#     *   Arabic - Spoken / English - Written
#     *   Rituxan (Truxima) TP
#     *   MRI Reports
#     *   Hospital D/C Note
#     *   Demographics
# *   **Confidentiality Statement:** "The documents accompanying this transmission may contain health information that is legally protected. This information is intended only for the use of the Individual or entity named above. The authorized recipient of this information is prohibited from disclosing this Information to any other party unless permitted by law or regulation. If you are not the intended recipient, you are hereby notified that any use, disclosure, copying or distribution of these documents is strictly prohibited. If you have received this Information in error, please notify the sender Immediately and arrange for the return or destruction of these documents."
#
# **Page 2/28: Communication Log**
# *   **Date/Time:** 05/22/2024 WED 11:32 FAX, 5/22/24, 11:10 AM
# *   **Patient Name:** Abdulla, Shakh
# *   **MRN:** 041152153
# *   **Communication Date:** 5/16/2024
# *   **Status:** Open
# *   **Referring Entity:** Better Life Multiple Sclerosis Center
# *   **Provider:** Erfan Rostami, RN
# *   **Reason for call:** Truxima Second Initial Dose Needed Week of June 3
# *   **All Conversations: Truxima Second Initial Dose Needed Week of June 3 (Newest Message First)**
#     *   **May 21, 2024 - 5/21/24 4:44 PM**
#         *   **From:** Jha, Vedant
#         *   **To:** Erfan Rostami, RN
#         *   **Message:** "Hi Erfan The only way Extraodinary Care could see his Medicaid plan would be at home :( I'm not sure if he is able to be seen at a hospital based infusion center closer to home? We will hold off on this one for now- let me know if you're not able to find a provider who can see him in the infusion suite and we will re-open the referral."
#     *   **Routing:** Erfan Rostami, RN routed this conversation to Jha, Vedant (5/21/24 2:32 PM)
#     *   **May 20, 2024 - 5/20/24 5:13 PM**
#         *   **From:** Gu, Hao H, MD
#         *   **To:** Erfan Rostami, RN
#         *   **Note:** "No home infusion. Her first dose is scheduled may 23. Second dos 2 weeks from may 23 first."
#     *   **Routing:** Erfan Rostami, RN routed this conversation to Gu, Hao H, MD (5/20/24 3:41 PM)
#     *   **5/20/24 2:54 PM**
#         *   **From:** Jha, Vedant
#         *   **To:** Erfan Rostami, RN
#         *   **Message:** "Hi, Is Dr. Gu comfortable with this patient being seen for home infusion? Thanks,"
#
# **Page 3/28: Therapy Plan 1 Summary**
# *   **Patient Name:** Abdulla, Shakh (MR #041152153) DOB: 04/01/2001 (Header)
# *   **Patient Name:** Shakh Abdulla
# *   **MRN:** 041152153
# *   **Description:** male DOB: 4/1/2001
# *   **Patient Demographics**
#     *   **Patient Name:** Abdulla, Shakh
#     *   **Legal Sex:** male
#     *   **DOB:** 4/1/2001
#     *   **Address:** 425 Sherman Ave, Nashville TN 37995
#     *   **Phone (Home):** 865-395-3958
#     *   **Phone (Mobile):** 865-395-0481 (*Preferred*)
# *   **Medication:** Rituximab Or Biosimilar Days 1, 15 Load Then Once Every 24 Weeks
# *   **Associated Problems**
#     *   **Problem:** Multiple sclerosis in pediatric patient (CMS/HCC) [G35]
#     *   **Selected Diagnosis:** Multiple sclerosis in pediatric patient (CMS/HCC) [G35]
# *   **Infusion Orders - All Current Orders**
#     *   **IV access**
#         *   **Interval:** Every visit
#         *   **Duration:** Every visit
#         *   **Due:** Every visit
#         *   **Care Instructions:** Obtain IV access (PIV, PORT, etc.) and start NS 0.9% @ KVO. Until discontinued Starting when released Until Specified.
#         *   **Last released:** Never
#         *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024 5:11 PM
#     *   **Monitor pt for hypersensitivity reaction**
#         *   **Interval:** Every visit
#         *   **Duration:** Every visit
#         *   **Due:** Every visit
#         *   **Care Instructions:** Once Starting when released for 1 occurrence. If allergic reaction or infusion related reaction occurs, initiate adult hypersensitivity reaction protocol or pediatric guideline and CALL MD for additional orders.
#         *   **Last released:** Never
#         *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024 5:11 PM
#     *   **NURSING COMMUNICATION**
#         *   **Interval:** Every visit
#         *   **Duration:** Every visit
#         *   **Due:** Every visit
#         *   **Care Instructions:** Ensure that patient has not taken antihypertensive medications in the 12 hours prior to infusion. Until discontinued Starting when released Until Specified.
#         *   **Last released:** Never
#         *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024 5:11 PM
#     *   **NURSING COMMUNICATION**
#         *   **Interval:** Every visit
#         *   **Duration:** Every visit
#         *   **Due:** Every visit
#         *   **Care Instructions:** For Hypotension, place patient in Trendelenberg position, support with NS, and call MD. Until discontinued Starting when released Until Specified.
#
# **Page 4/28: Therapy Plan 1 Summary (Cont.)**
# *   **Labs**
#     *   **IgG**
#         *   **Interval:** Every 24 weeks
#         *   **Due:** Week of 5/19/2024
#         *   **Care Instructions:** Clinic Collect, Blood.
#         *   **Last released:** Never
#         *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024 5:11 PM
#     *   **CBC w/ Differential**
#         *   **Interval:** Every visit
#         *   **Due:** Every visit
#         *   **Care Instructions:** Once Starting when released, Blood.
#         *   **Last released:** Never
#         *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024 5:11 PM
#     *   **Flow Lymphocytes Subsets (TBNK)**
#         *   **Interval:** Every visit
#         *   **Due:** Every visit
#         *   **Care Instructions:** Once Starting when released, Blood.
#         *   **Last released:** Never
#         *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024 5:11 PM
# *   **Vitals**
#     *   **Vital Signs**
#         *   **Interval:** Every visit
#         *   **Due:** Every visit
#         *   **Care Instructions:** Obtain VS prior to start therapy, Q30 minutes with each dose increase and at the end of treatment. As needed Starting when released Until Specified.
#         *   **Last released:** Never
#         *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024
# *   **Hydration**
#     *   **heparin, porcine (PF) 100 unit/mL syringe 5 mL**
#         *   **Interval:** PRN
#         *   **Due:** PRN
#         *   **Care Instructions:** 5 mL, intraVENOUS, As needed, For flushing Ports/ PICC lines/ Central Lines IF NEEDED, Starting when released, Until Discontinued.
#         *   **Last released:** Never
#         *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024 5:11 PM
# *   **Pre-Medications**
#     *   **acetaminophen (TYLENOL) tablet 650 mg**
#         *   **Interval:** Every visit
#         *   **Due:** Every visit
#         *   **Care Instructions:** 650 mg, oral, Once, Starting when released.
#         *   **Last released:** Never
#         *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024 5:11 PM
#     *   **diphenhydrAMINE (BENADRYL) 50 mg in 50 mL NS**
#         *   **Interval:** Every visit
#         *   **Due:** Every visit
#         *   **Care Instructions:** 50 mg, intraVENOUS, Once, Administer 30 minutes before starting infusion.
#         *   **Last released:** Never
#         *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024 5:11 PM
#     *   **methylPREDNISolone sod succinate (SOLU-Medral) (20 mg/mL) 125 mg in NS 6.2 mL**
#         *   **Interval:** Every visit
#         *   **Due:** Every visit
#
# **Page 5/28: Therapy Plan 1 Summary (Cont.)**
# *   **methylPREDNISolone sod succinate (cont.)**
#     *   **Care Instructions:** 125 mg, intraVENOUS, Once, Starting when released. Administer 30 minutes before starting infusion.
#     *   **Last released:** Never
#     *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024 5:11 PM
# *   **Infusion Therapy**
#     *   **NURSING COMMUNICATION**
#         *   **Interval:** Every visit
#         *   **Due:** Every visit
#         *   **Care Instructions:** Until discontinued Starting when released Until Specified. Infusion rate (standard only): 1st infusion - initiate at 50mg/hr and if no infusion toxicity reaction, may increase by 50mg/hr ever 30 minutes; Max Rate 400mg/hr. Subsequent infusions - initiate at 100mg/hr and if no infusion toxicity reaction, may increase by 100mg/hr every 30 min; Max Rate 400mg/hr.
#         *   **Last released:** Never
#         *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024 5:11 PM
#     *   **Infusion Therapy - Initial Dose**
#         *   **riTUXimab-abbs (TRUXIMA) IVPB**
#             *   **Interval:** Every 2 weeks
#             *   **Duration:** 2/2 remaining
#             *   **Due:** Week of 5/19/2024
#             *   **Care Instructions:** 694 mg (rounded from 693.75 mg = 375 mg/m2 x 1.85 m2 - BSA might be out of date), intraVENOUS, Once, Starting 30 minutes after treatment start time.
#             *   **Last released:** Never
#             *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024 5:11 PM
#     *   **Infusion Therapy - Maintenance Dose**
#         *   **riTUXimab-abbs (TRUXIMA) IVPB**
#             *   **Interval:** Every 24 weeks
#             *   **Due:** Mon 11/4/2024
#             *   **Defer until:** Mon 11/4/2024
#             *   **Care Instructions:** 694 mg (rounded from 693.75 mg = 375 mg/m2 x 1.85 m2 - BSA might be out of date), intraVENOUS, Once, Starting when released.
#             *   **Last released:** Never
#             *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024 5:11 PM
# *   **PRN Medications**
#     *   **diphenhydrAMINE (BENADRYL) injection 25 mg**
#         *   **Interval:** PRN
#         *   **Due:** PRN
#         *   **Care Instructions:** 25 mg, intraVENOUS, As needed, chills, Starting when released, for 2 doses.
#         *   **Last released:** Never
#         *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024 5:11 PM
#     *   **meperidine (DEMEROL) injection 25 mg**
#         *   **Interval:** PRN
#         *   **Due:** PRN
#         *   **Care Instructions:** 25 mg, intraVENOUS, As needed, rigors, Starting when released, for 2 doses.
#         *   **Last released:** Never
#         *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024 5:11 PM
#     *   **ondansetron (ZOFRAN) injection 4 mg**
#         *   **Interval:** PRN
#         *   **Due:** PRN
#         *   **Care Instructions:** 4 mg, intraVENOUS, As needed, nausea, vomiting, Starting when released, for 2 doses. Doses up to 4 mg may be administered undiluted. Inject over at least 30 seconds, but preferably over 2-5 minutes.
#         *   **Last released:** Never
#         *   **Electronically Signed By:** Gu, Hao H, MD on 5/15/2024 5:11 PM
# *   **eSignature Information:** All order signatures are valid for 1 (one) year from the signature date.
#
# **Page 6/28: Provider Contact Information**
# *   **Provider Name:** Hao H Gu, MD
# *   **NPI:** 1154611523
# *   **Practice Name:** Better Life Multiple Sclerosis Center
# *   **Practice Address:** 3320 Montgomery Dr NASHVILLE TN 37361
# *   **Practice Phone:** 614-936-0065
#
# **Page 7/28: Hospital Face Sheet**
# *   **Patient:** Shakh Abdulla
# *   **Care Everywhere ID#:** VDJ-7KR2-4847-LGF8
# *   **ENCOUNTER**
#     *   **Admission Date/Time:** 5/17/2024
# *   **PATIENT**
#     *   **Name:** Shakh Abdulla
#     *   **DOB:** 4/1/200 (23 yrs)
#     *   **Sex:** male
#     *   **Address:** 425 Sherman Aves APT D, Nashville TN 37923
#     *   **Pref Lang:** Arabic
#     *   **Primary Care Provider:** James David, PNP
#     *   **Primary Phone:** 865-839-7458
#     *   **Marital Status:** Single
#     *   **Mobile Phone:** 865-839-7458
# *   **EMERGENCY CONTACT**
#     *   **1. Contact Name:** Sina, Amin
#     *   **Legal Guardian?:** Yes
#     *   **Relationship to Patient:** Father
#     *   **2. Contact Name:** Mohammedreza, Mustala
#     *   **Legal Guardian?:** Yes
#     *   **Relationship to Patient:** Mother
# *   **GUARANTOR**
#     *   **DOB:** 10/29/1979
#     *   **Sex:** Female
# *   **GUARANTOR EMPLOYER**
#     *   **Status:** NOT EMPLO
# *   **COVERAGE**
#     *   **PRIMARY INSURANCE**
#         *   **Payor:** TC BLUE CARE NO COPAY
#         *   **Plan:** TC BLUE CARE NO COPAY
#     *   **SECONDARY INSURANCE:** (No information provided)
#
# **Page 8/28: Primary Coverage Details**
# *   **Payer:** BC TENNCARE
# *   **Plan:** TC BLUE CARE NO COPAY
# *   **Group Number:** 435000
# *   **Group Name:** TENNCARE/BLUECARE
# *   **Primary Subscriber**
#     *   **ID:** LAJM14345116
#     *   **Name:** ABDULLA, SHAKH
#     *   **SSN:** xxx-xx-8143
#     *   **Address:** 8327 BROADWAY LN APT D, KNOXVILLE, TN 37923
#
# **Page 9/28: Discharge Summary**
# *   **Patient Name:** Abdulla, Shakh
# *   **MRN:** 048152153 (Note: This MRN is inconsistent with the primary MRN 041152153 found on other pages. Prioritizing 041152153 as it appears more consistently.)
# *   **ED to Hosp-Admission**
#     *   **Dates:** 5/14/2024 - 5/17/2024 (3 days)
#     *   **Status:** Discharged
#     *   **Facility:** Monroe Carell Jr. Children's Hospital
#     *   **Last attending:** Harry, Tom, MD with Treatment team
#     *   **Principal problem:** Abnormal MRI
# *   **Discharge Summary**
#     *   **Cosigned by:** Gu, Hao H, MD at 5/17/2024 1:56 PM
#     *   **Resident Physician:** Kaine, Adam Jason, MD - Pediatric Neurology
#     *   **Attestation signed by:** Gu, Hao H, MD at 5/17/2024 1:56 PM (Updated)
#     *   **Patient seen on:** 5/17/2024 with Dr Kaine.
#     *   **Discharge Information:**
#         *   S/p 4 days of high dose IVMP (1g/dose) today.
#         *   Discharge home with oral decadron 180mg (equivalent to 1000mg IVMP) x 1 to round out 5 days of high dose steroid treatment for active demyelinating lesion (family wishes to be discharged today instead of Saturday).
#         *   He will then start oral prednisone taper- instructions provided +PPI.
#         *   First dose of Rituximab or biosimilar scheduled for May 22 at 9am; second dose of first course of Rituximab within 2 weeks after. Working with local infusion facility in Knoxville to get this set up for her moving forward to minimize travel.
#         *   He will follow up with ophthalmologist in Knoxville.
#         *   School note for this week and next week.
#         *   PT/OT locally.
#         *   Continue vitamin D.
#         *   Will see her tentatively 3 months after completion of 1st course of Rituximab -with same day MRI (she does not need sedation)- looking at early or mid September.
#     *   **Physician:** Hao Gu MD
# *   **Neurology Discharge Summary (Footer)**
#     *   **Patient Name:** Shakh Abdulla
#     *   **DOB:** 4/1/2001
#     *   **Service:** Pediatric Neurology
#     *   **Attending:** Harry, Tom, MD
#     *   **Date of Admission:** 5/14/2024
#
# **Page 10/28: Discharge Summary (Cont.)**
# *   **Date of Discharge:** 5/17/2024
# *   **Diagnosis:**
#     *   **Principal Problem:** Abnormal MRI
#     *   **Resolved Problems:** * No resolved hospital problems. *
# *   **Procedures:**
#     *   **Bedside Procedures:** No orders of the defined types were placed in this encounter.
#     *   **OR Procedures:** * Cannot find OR case *
# *   **Synopsis:** Shakh Abdulla is a 23 year old male who established care with VCH neurology; with MRI brain and spine demonstrating multiple lesions consistent with atypical pediatric MS.
# *   **Hospital Course:**
#     *   Shakh Abdulla is a 23 year old male with history of optic neuritis and abnormal MRI brain concerning for MS who presented for admission following clinic visit and neuroimaging today.
#     *   History from primary neurologist, clinic visit and patient and father at bedside.
#     *   Patient referred to Dr. Gu by Dr. Fazal in East Bay.
#     *   **Symptoms:** Predominant symptoms since April of numbness in his right hand and urinary hesitancy/urgency. Additionally reporting right eye pain since time of clinic visit this morning.
#     *   **Imaging Findings:** MRI brain and spine obtained following clinic visit and multiple lesions noted on brain and spine suggestive of pediatric MS.
#     *   **Reason for Admission:** IVMP.
#     *   **Clinic visit earlier today with Dr. Gu and confirmed with family at bedside:** Shakh is a 23 years old male, previously healthy who has been referred to neuroimmunology clinic for diagnosis of optic neuritis and abnormal brain MRI concerning for MS. He is referred by Dr Fazal-pediatric neurology in East Bay.
#     *   **Information from patient/father:** Patient is an excellent historian. No CSF results or clinic note available to sender. MRI report from Jan 21 2024 available (no actual images). Reached out to Dr Shane- Dr Fazal's colleague on service for chart access.
#     *   **Onset of Symptoms:** Around early Oct 2023 - started to notice in right eye "neon bright color" fuzzy vision, and eye pain with movement, and perhaps right side of his face in discomfort triggered by physical activities. Symptoms improved once he rested. By end of Oct 2023, brought this up to parents and was brought to local eye doctor and recalled being told that "right eye being inflamed" and he recalled visual field deficits appreciated during exam.
#     *   **Referral to UT ophthalmology Dr Derrek:** In Jan this year, per report negative MOG and AQP4. Thought some improvement but not back to baseline entirely -"not completely normal".
#     *   **UT ophthalmology clinic findings:** Recommended brain and orbit and noted WM changes and MS was mentioned. Treated with 5 days of IVMP and referred to see Dr Kosentka ped neurology.
#     *   **MRI report from Jan 21 2024:** "Diffuse T2 hyperintensity and decreased volume throughout the right optic nerve is similar to prior examination however assocaited abnormal enhancement seen on prior study has resoved, presumably secondary to interveal treatment. Left optic nerve is subtle but diffusely small in caliber without significant change from last exam. Several intracranial WM lesions, stable from last."
#     *   **Dr Fazal (Feb 2024):** Obtained LP and had markers of MS and referred to MS clinic today.
#     *   **Information by Dr Shane:** Per note recommended referral to our MS center for further evaluation and treatment.
#
# **Page 11/28: Discharge Summary (Cont.)**
# *   **CSF results:** WBC 8, 37 rbc, IgG Index 0.87 (elevated), +OCB
# *   **Patient notes prior to May 14 appt (April this year):** Involvement of LEFT eye - "neon colors appearance", eye discomfort; happened several times during the day for a few days and has since resovied. Intermittent numbness in his right hand (dominant hand)+ along with muscle twitch in his hands and shoulder like tics. Noticed a change with urinary hesitancy- taking a long time to empty his bladder and in addition urinary urgency. Has not noticed weakness but noted intermittent drifting to right side, bumping in to things. Does note that at times when he laughs, bends his neck, does note electrical sensation. Academically doing very well, no difficulty. Sleeps well.
# *   **Family history:** parents and brothers are healthy.
# *   **Floor course (05/14 - ):**
#     *   Patient was admitted to the wards in a stable condition.
#     *   Patient was initiated on high dose steroids for 5 days and tolerated well.
#     *   MRI consistent with lesions in the brain and spinal cord consistent with atypical MS.
#     *   ANA was positive as well as SSB so rheumatology was consulted but felt she did not have evidence of another systemic autoimmune disease.
#     *   PT/OT evaluated his and he will follow outpatient.
#     *   He was dc with Decadron and then steroid taper with Pepcid prophylaxis.
#     *   He was arranged to have outpatient rituximab and Dr. Gu will follow his in clinic.
# *   **Physical Exam:**
#     *   Temp: 36.7 °C (98 °F) [Ref Range: 36.5 °C (97.7 °F)-36.7 °C (98.1 °F)]
#     *   Pulse: 84 [Ref Range: 81-99]
#     *   Resp: 16 [Ref Range: 16-18]
#     *   BP: 126/63 [Ref Range: (122-136)/(63-99)]
#     *   SpO2: 98% [Ref Range: 98%]
#     *   (Repeated identical physical exam section)
# *   **General Appearance:** Well appearing; NAD (No acute distress)
# *   **CV:** RRR (Regular rate and rhythm)
# *   **HIGHER INTEGRATIVE FUNCTIONS:**
#     *   Attention & concentration: Normal
#     *   Orientation: Oriented to person, place & time
#     *   Memory: Recent and remote memory Intact
#     *   Language: Normal
#     *   Fund of Knowledge: Normal
# *   **CRANIAL NERVES:**
#     *   CN 2: Visual fields full
#     *   CN 2,3: PERRL; rAPD
#     *   CN 3,4,6: EOMI
#     *   CN 5: Facial sensation intact
#     *   CN 7: Facial strength/movement intact bilaterally
#
# **Page 12/28: Discharge Summary (Cont.)**
# *   **CRANIAL NERVES (Cont.):**
#     *   CN 8: Hearing normal bilaterally
#     *   CN 9,10: Palate elevates symmetrically
#     *   CN 11: Normal shoulder shrug and head turn
#     *   CN 12: Tongue protrudes midline
# *   **MOTOR:**
#     *   Muscle tone normal in upper and lower extremities
#     *   Muscle strength 5/5 In upper and lower extremities; RLE 4+ proximally
# *   **SENSATION:**
#     *   Intact to light touch in upper and lower extremities bilaterally
# *   **COORDINATION:**
#     *   Finger/nose intact bilaterally
# *   **GAIT:**
#     *   Normal gait
# *   **Immunizations/Injections Administered for This Admission:** No immunizations on file.
# *   **Allergies:** No Known Allergies
# *   **Diagnostic Studies: Recent Results (from the past 24 hour(s))**
#     *   **CBC w/ Differential**
#         *   **Collection Time:** 05/14/24 10:47 AM
#         *   **Results (Value, Ref Range, Units):**
#             *   White Blood Cells: 7.7 (3.4-10.2 x10(3)/mcL)
#             *   Red Blood Cells: 4.63 (3.80-5.50 x10(6)/mcL)
#             *   Hemoglobin: 13.0 (12.0-16.0 gm/dL)
#             *   Hematocrit: 40 (35-49 %)
#             *   Mean Cell Volume: 86 (76-96 fL)
#             *   Mean Cell Hemoglobin: 28.1 (25.0-35.0 pg)
#             *   Mean Cell Hemoglobin Concentration: 32.7 (32.0-37.0 gm/dL)
#             *   RDW SD: 38.4 (37.4-52.4 fL)
#             *   RDW CV: 12.3 (11.1-14.3 %)
#             *   Platelet: 300 (150-400 x10(3)/mcL)
#
# **Page 13/28: Diagnostic Studies (Cont.)**
# *   **CBC w/ Differential (Cont.)**
#     *   **Results (Value, Ref Range, Units):**
#         *   Mean Platelet Volume: 10.0 (9.3-12.8 fL)
#         *   Nucleated RBC: 0 (0-0/100 WBC)
#         *   Nucleated RBC Abs: 0.00 (0.00-0.00 x10(3)/mcL)
#         *   Auto Neutrophil Absolute: 4.52 (1.80-7.70 x10(3)/mcL)
# *   **CMP (Comprehensive Metabolic Panel)**
#     *   **Collection Time:** 05/14/24 10:47 AM
#     *   **Results (Value, Ref Range, Units):**
#         *   Sodium Level: 139 (138-145 mmol/L)
#         *   Potassium Level: 3.8 (3.3-4.8 mmol/L)
#         *   Chloride Level: 101 (98-107 mmol/L)
#         *   Carbon Dioxide: 22 (17-28 mmol/L)
#         *   Anion Gap: 16 (mmol/L)
#         *   Glucose Level: 95 (60-99 mg/dL)
#         *   Blood Urea Nitrogen: 13 (7-18 mg/dL)
#         *   Creatinine Level: 0.67 (0.50-0.90 mg/dL)
#         *   Calcium Level Total: 9.9 (8.4-10.2 mg/dL)
#         *   Bilirubin Total: 0.4 (0.0-0.7 mg/dL)
#         *   Albumin Level: 4.7 (4.0-5.3 gm/dL)
#         *   Protein Total: 8.4 (H) (6.3-7.8 gm/dL)
#         *   Alkaline Phosphatase: 55 (50-117 unit/L)
#         *   Aspartate Aminotransferase: 25 (21-34 unit/L)
#         *   Alanine Aminotransferase: <6 (0-17 unit/L)
# *   **Hepatitis B Pnl**
#     *   **Collection Time:** 05/14/24 10:47 AM
#     *   **Results (Value, Ref Range):**
#         *   Hepatitis B Surface Antigen: Negative (Negative)
#         *   Hep B Core Ab Total: Negative (Negative)
#         *   Hepatitis B Surface Ab Unit: 44.7 (H) (<=10.0 mlU/mL)
#         *   Hep Bs Ab Interp: Positive (A) (Negative)
# *   **IgG**
#     *   **Collection Time:** 05/14/24 10:47 AM
#     *   **Results (Value, Ref Range, Units):**
#         *   IgG Quantitative: 1,355 (H) (600-1,310 mg/dL)
#
# **Page 14/28: Diagnostic Studies (Cont.)**
# *   **IgA**
#     *   **Collection Time:** 05/14/24 10:47 AM
#     *   **Results (Value, Ref Range, Units):**
#         *   IgA Quantitative: 279 (40-290 mg/dL)
# *   **Auto Diff**
#     *   **Collection Time:** 05/14/24 10:47 AM
#     *   **Results (Value, Ref Range, Units):**
#         *   Neutrophils: 58.3 (%)
#         *   Absolute Neutrophils: 4.52 (1.80-7.70 x10(3)/mcL)
#         *   Lymphs: 33.6 (%)
#         *   Absolute Lymphocytes: 2.60 (1.70-4.50 x10(3)/mcL)
#         *   Monocytes: 6.5 (%)
#         *   Absolute Monocytes: 0.50 (0.20-1.00 x10(3)/mcL)
#         *   Eosinophils: 0.5 (%)
#         *   Absolute Eosinophils: 0.04 (0.00-0.50 x10(3)/mcL)
#         *   Basophils: 0.8 (%)
#         *   Absolute Basophils: 0.06 (0.01-0.08 x10(3)/mcL)
#         *   Imm Gran Automated: 0.3 (%)
#         *   Absolute Imm Gran Automated: 0.02 (0.00-0.03 x10(3)/mcL)
# *   **Consultations Obtained: Orders Placed This Encounter**
#     *   Inpatient Consult to Pediatric Ophthalmology
#     *   Inpatient Consult to Pediatric Rheumatology
#     *   Inpatient consult to Case Management
# *   **Condition at Discharge:** Stable
# *   **Disposition:** Home or Self Care
# *   **Patient Instructions:**
#     *   **Discharge Medications**
#         *   **dexamethasone 4 mg/mL CONCENTRATED solution**
#             *   **Sig:** Take 45 mL (180 mg total) by mouth daily for 1 dose. See comment.
#         *   **famotidine 40 mg tablet**
#             *   **Commonly known as:** PEPCID
#             *   **Sig:** Take 1 tablet (40 mg total) by mouth daily.
#
# **Page 15/28: Discharge Summary (Cont.)**
# *   **Discharge Medications (Cont.)**
#     *   **predniSONE 20 mg tablet**
#         *   **Commonly known as:** DELTASONE
#         *   **Start taking on:** May 16, 2024
#         *   **Sig:** Take 3 tablets (60 mg total) by mouth daily for 7 days, THEN 2 tablets (40 mg total) daily for 7 days, THEN 1 tablet (20 mg total) daily for 7 days, THEN 0.5 tablets (10 mg total) daily for 7 days. Then stop.
# *   **Activity Instructions**
#     *   **Discharge activity:** Normal Activity
#     *   **Driving/Medication warning:** Some medications such as for example pain medications and sleeping or anti-anxiety agents may affect your ability to operate heavy machinery including driving. Always carefully read the labels on the medications that you take. If you have experienced confusion, seizures, lightheadedness or blackouts then it may not be safe or even legal for you to operate heavy machinery (including driving). Please act in the interest of your own safety and that of others. Speak to a physician If you are not sure whether it is safe or legal for you to drive.
#     *   **Care Instructions:** You should engage in exercise as tolerated to improve your health. You may go to the website of the American Heart Association for additional information and tips on how to exercise right (www.americanheart.org).
# *   **Scheduled Appointments**
#     *   **Date/Time:** May 22, 2024 10:30 AM
#     *   **Appointment Type:** Peds Infusion (Leantaas) with PEDS INF UMBRELLA, PEDS 241+ MIN INFUSION
#     *   **Department:** Children's Hematology - Oncology (Peds DOT 6)
#     *   **Address:** 2211 Broad Way, Tower 4th FL, Suite 6102, Nashville TN 37232
#     *   **Phone:** 615-936-1762
#
# ---
#
# ## Structured JSON Output:
#
# ```json
# {
#   "PATIENT_DEMOGRAPHICS": {
#     "Full_name": "Shakh Abdulla",
#     "DOB": "2001-04-01",
#     "Gender": "male",
#     "Address": {
#       "Street": "425 Sherman Aves APT D",
#       "City": "Nashville",
#       "State": "TN",
#       "Zip_code": "37923"
#     },
#     "Phone_numbers": {
#       "Home": "865-395-3958",
#       "Mobile": "865-395-0481",
#       "Primary_Care_Provider_Phone": "865-839-7458"
#     },
#     "Patient_ID_numbers": {
#       "MRN": "041152153",
#       "Care_Everywhere_ID": "VDJ-7KR2-4847-LGF8"
#     },
#     "Emergency_contacts": [
#       {
#         "Name": "Sina, Amin",
#         "Relationship": "Father",
#         "Legal_Guardian": true,
#         "Phone_Home": null,
#         "Phone_Work": null
#       },
#       {
#         "Name": "Mohammedreza, Mustala",
#         "Relationship": "Mother",
#         "Legal_Guardian": true,
#         "Phone_Home": null,
#         "Phone_Work": null
#       }
#     ],
#     "Marital_Status": "Single",
#     "Preferred_Language": "Arabic"
#   },
#   "INSURANCE_INFORMATION": {
#     "Primary_Insurance": {
#       "Company_name": "BC TENNCARE",
#       "Plan_details": "TC BLUE CARE NO COPAY",
#       "Member_ID": "LAJM14345116",
#       "Group_number": "435000",
#       "Group_name": "TENNCARE/BLUECARE",
#       "Subscriber_information": {
#         "Name": "ABDULLA, SHAKH",
#         "Relationship_to_patient": "Self",
#         "SSN_Last4": "8143",
#         "Address": {
#           "Street": "8327 BROADWAY LN APT D",
#           "City": "KNOXVILLE",
#           "State": "TN",
#           "Zip_code": "37923"
#         }
#       },
#       "Coverage_details": null,
#       "Effective_dates": null
#     },
#     "Secondary_Insurance": {
#       "Company_name": null,
#       "Plan_details": null,
#       "Member_ID": null,
#       "Group_number": null,
#       "Policy_number": null,
#       "Subscriber_information": {
#         "Name": null,
#         "Relationship_to_patient": null
#       },
#       "Coverage_details": null,
#       "Effective_dates": null
#     }
#   },
#   "CLINICAL_INFORMATION": {
#     "Primary_diagnoses": [
#       {
#         "Diagnosis": "Multiple sclerosis in pediatric patient",
#         "ICD_code": "G35",
#         "Type": "CMS/HCC"
#       },
#       {
#         "Diagnosis": "Abnormal MRI",
#         "Type": "Principal Problem"
#       },
#       {
#         "Diagnosis": "Atypical pediatric MS with multiple lesions (brain & spine MRI)",
#         "Type": "Synopsis"
#       },
#       {
#         "Diagnosis": "Active demyelinating lesion",
#         "Type": "Implied from steroid treatment"
#       }
#     ],
#     "Secondary_diagnoses": [],
#     "Current_medications": [
#       {
#         "Name": "Rituximab Or Biosimilar",
#         "Dosage": "694 mg",
#         "Frequency": "Days 1, 15 Load Then Once Every 24 Weeks",
#         "Route": "IVPB"
#       }
#     ],
#     "Discharge_medications": [
#       {
#         "Name": "dexamethasone",
#         "Form": "CONCENTRATED solution",
#         "Strength": "4 mg/mL",
#         "Dosage": "45 mL (180 mg total)",
#         "Frequency": "daily for 1 dose",
#         "Route": "oral"
#       },
#       {
#         "Name": "famotidine",
#         "Commonly_known_as": "PEPCID",
#         "Form": "tablet",
#         "Strength": "40 mg",
#         "Dosage": "1 tablet (40 mg total)",
#         "Frequency": "daily",
#         "Route": "oral"
#       },
#       {
#         "Name": "predniSONE",
#         "Commonly_known_as": "DELTASONE",
#         "Form": "tablet",
#         "Strength": "20 mg",
#         "Dosage_schedule": [
#           "3 tablets (60 mg total) daily for 7 days",
#           "2 tablets (40 mg total) daily for 7 days",
#           "1 tablet (20 mg total) daily for 7 days",
#           "0.5 tablets (10 mg total) daily for 7 days"
#         ],
#         "Start_date": "2024-05-16",
#         "Route": "oral",
#         "Duration": "Then stop"
#       }
#     ],
#     "Pre_medications": [
#       {
#         "Name": "acetaminophen (TYLENOL)",
#         "Dosage": "650 mg",
#         "Route": "oral",
#         "Frequency": "Once, Every visit",
#         "Instructions": "Starting when released"
#       },
#       {
#         "Name": "diphenhydrAMINE (BENADRYL)",
#         "Dosage": "50 mg",
#         "Route": "intraVENOUS",
#         "Frequency": "Once, Every visit",
#         "Instructions": "Administer 30 minutes before starting infusion"
#       },
#       {
#         "Name": "methylPREDNISolone sod succinate (SOLU-Medral)",
#         "Strength": "20 mg/mL",
#         "Dosage": "125 mg in NS 6.2 mL",
#         "Route": "intraVENOUS",
#         "Frequency": "Once, Every visit",
#         "Instructions": "Administer 30 minutes before starting infusion"
#       }
#     ],
#     "PRN_medications": [
#       {
#         "Name": "heparin, porcine (PF)",
#         "Strength": "100 unit/mL",
#         "Dosage": "5 mL",
#         "Route": "intraVENOUS",
#         "Frequency": "PRN",
#         "Instructions": "For flushing Ports/ PICC lines/ Central Lines IF NEEDED, Starting when released, Until Discontinued"
#       },
#       {
#         "Name": "diphenhydrAMINE (BENADRYL)",
#         "Form": "injection",
#         "Dosage": "25 mg",
#         "Route": "intraVENOUS",
#         "Frequency": "PRN",
#         "Instructions": "As needed, chills, Starting when released, for 2 doses"
#       },
#       {
#         "Name": "meperidine (DEMEROL)",
#         "Form": "injection",
#         "Dosage": "25 mg",
#         "Route": "intraVENOUS",
#         "Frequency": "PRN",
#         "Instructions": "As needed, rigors, Starting when released, for 2 doses"
#       },
#       {
#         "Name": "ondansetron (ZOFRAN)",
#         "Form": "injection",
#         "Dosage": "4 mg",
#         "Route": "intraVENOUS",
#         "Frequency": "PRN",
#         "Instructions": "As needed, nausea, vomiting, Starting when released, for 2 doses. Doses up to 4 mg may be administered undiluted. Inject over at least 30 seconds, but preferably over 2-5 minutes."
#       }
#     ],
#     "Allergies": "No Known Allergies",
#     "Vital_signs": [
#       {
#         "Collection_date": "2024-05-14",
#         "Temperature_C": "36.7",
#         "Temperature_F": "98",
#         "Temperature_Ref_Range_C": "36.5-36.7",
#         "Temperature_Ref_Range_F": "97.7-98.1",
#         "Pulse": "84",
#         "Pulse_Ref_Range": "81-99",
#         "Respirations": "16",
#         "Respirations_Ref_Range": "16-18",
#         "Blood_Pressure": "126/63",
#         "Blood_Pressure_Ref_Range": "(122-136)/(63-99)",
#         "SpO2_percent": "98",
#         "SpO2_Ref_Range_percent": "98"
#       }
#     ],
#     "Lab_results": {
#       "Collection_Time": "2024-05-14 10:47 AM",
#       "CBC_w_Differential": [
#         { "Test": "White Blood Cells", "Value": "7.7", "Unit": "x10(3)/mcL", "Ref_Range": "3.4-10.2" },
#         { "Test": "Red Blood Cells", "Value": "4.63", "Unit": "x10(6)/mcL", "Ref_Range": "3.80-5.50" },
#         { "Test": "Hemoglobin", "Value": "13.0", "Unit": "gm/dL", "Ref_Range": "12.0-16.0" },
#         { "Test": "Hematocrit", "Value": "40", "Unit": "%", "Ref_Range": "35-49" },
#         { "Test": "Mean Cell Volume", "Value": "86", "Unit": "fL", "Ref_Range": "76-96" },
#         { "Test": "Mean Cell Hemoglobin", "Value": "28.1", "Unit": "pg", "Ref_Range": "25.0-35.0" },
#         { "Test": "Mean Cell Hemoglobin Concentration", "Value": "32.7", "Unit": "gm/dL", "Ref_Range": "32.0-37.0" },
#         { "Test": "RDW SD", "Value": "38.4", "Unit": "fL", "Ref_Range": "37.4-52.4" },
#         { "Test": "RDW CV", "Value": "12.3", "Unit": "%", "Ref_Range": "11.1-14.3" },
#         { "Test": "Platelet", "Value": "300", "Unit": "x10(3)/mcL", "Ref_Range": "150-400" },
#         { "Test": "Mean Platelet Volume", "Value": "10.0", "Unit": "fL", "Ref_Range": "9.3-12.8" },
#         { "Test": "Nucleated RBC", "Value": "0", "Unit": "WBC", "Ref_Range": "0-0/100" },
#         { "Test": "Nucleated RBC Abs", "Value": "0.00", "Unit": "x10(3)/mcL", "Ref_Range": "0.00-0.00" },
#         { "Test": "Auto Neutrophil Absolute", "Value": "4.52", "Unit": "x10(3)/mcL", "Ref_Range": "1.80-7.70" }
#       ],
#       "CMP": [
#         { "Test": "Sodium Level", "Value": "139", "Unit": "mmol/L", "Ref_Range": "138-145" },
#         { "Test": "Potassium Level", "Value": "3.8", "Unit": "mmol/L", "Ref_Range": "3.3-4.8" },
#         { "Test": "Chloride Level", "Value": "101", "Unit": "mmol/L", "Ref_Range": "98-107" },
#         { "Test": "Carbon Dioxide", "Value": "22", "Unit": "mmol/L", "Ref_Range": "17-28" },
#         { "Test": "Anion Gap", "Value": "16", "Unit": "mmol/L", "Ref_Range": null },
#         { "Test": "Glucose Level", "Value": "95", "Unit": "mg/dL", "Ref_Range": "60-99" },
#         { "Test": "Blood Urea Nitrogen", "Value": "13", "Unit": "mg/dL", "Ref_Range": "7-18" },
#         { "Test": "Creatinine Level", "Value": "0.67", "Unit": "mg/dL", "Ref_Range": "0.50-0.90" },
#         { "Test": "Calcium Level Total", "Value": "9.9", "Unit": "mg/dL", "Ref_Range": "8.4-10.2" },
#         { "Test": "Bilirubin Total", "Value": "0.4", "Unit": "mg/dL", "Ref_Range": "0.0-0.7" },
#         { "Test": "Albumin Level", "Value": "4.7", "Unit": "gm/dL", "Ref_Range": "4.0-5.3" },
#         { "Test": "Protein Total", "Value": "8.4", "Unit": "gm/dL", "Ref_Range": "6.3-7.8", "Abnormal_Flag": "H" },
#         { "Test": "Alkaline Phosphatase", "Value": "55", "Unit": "unit/L", "Ref_Range": "50-117" },
#         { "Test": "Aspartate Aminotransferase", "Value": "25", "Unit": "unit/L", "Ref_Range": "21-34" },
#         { "Test": "Alanine Aminotransferase", "Value": "<6", "Unit": "unit/L", "Ref_Range": "0-17" }
#       ],
#       "Hepatitis_B_Pnl": [
#         { "Test": "Hepatitis B Surface Antigen", "Value": "Negative", "Ref_Range": "Negative" },
#         { "Test": "Hep B Core Ab Total", "Value": "Negative", "Ref_Range": "Negative" },
#         { "Test": "Hepatitis B Surface Ab Unit", "Value": "44.7", "Unit": "mlU/mL", "Ref_Range": "<=10.0", "Abnormal_Flag": "H" },
#         { "Test": "Hep Bs Ab Interp", "Value": "Positive (A)", "Ref_Range": "Negative" }
#       ],
#       "IgG": [
#         { "Test": "IgG Quantitative", "Value": "1,355", "Unit": "mg/dL", "Ref_Range": "600-1,310", "Abnormal_Flag": "H" }
#       ],
#       "IgA": [
#         { "Test": "IgA Quantitative", "Value": "279", "Unit": "mg/dL", "Ref_Range": "40-290" }
#       ],
#       "Auto_Diff": [
#         { "Test": "Neutrophils", "Value": "58.3", "Unit": "%", "Ref_Range": null },
#         { "Test": "Absolute Neutrophils", "Value": "4.52", "Unit": "x10(3)/mcL", "Ref_Range": "1.80-7.70" },
#         { "Test": "Lymphs", "Value": "33.6", "Unit": "%", "Ref_Range": null },
#         { "Test": "Absolute Lymphocytes", "Value": "2.60", "Unit": "x10(3)/mcL", "Ref_Range": "1.70-4.50" },
#         { "Test": "Monocytes", "Value": "6.5", "Unit": "%", "Ref_Range": null },
#         { "Test": "Absolute Monocytes", "Value": "0.50", "Unit": "x10(3)/mcL", "Ref_Range": "0.20-1.00" },
#         { "Test": "Eosinophils", "Value": "0.5", "Unit": "%", "Ref_Range": null },
#         { "Test": "Absolute Eosinophils", "Value": "0.04", "Unit": "x10(3)/mcL", "Ref_Range": "0.00-0.50" },
#         { "Test": "Basophils", "Value": "0.8", "Unit": "%", "Ref_Range": null },
#         { "Test": "Absolute Basophils", "Value": "0.06", "Unit": "x10(3)/mcL", "Ref_Range": "0.01-0.08" },
#         { "Test": "Imm Gran Automated", "Value": "0.3", "Unit": "%", "Ref_Range": null },
#         { "Test": "Absolute Imm Gran Automated", "Value": "0.02", "Unit": "x10(3)/mcL", "Ref_Range": "0.00-0.03" }
#       ]
#     },
#     "Previous_treatments_and_outcomes": [
#       {
#         "Treatment": "High dose IVMP (Intravenous Methylprednisolone)",
#         "Dosage": "1g/dose",
#         "Duration": "5 days",
#         "Dates": "2024-05-14 to 2024-05-17",
#         "Outcome": "Tolerated well, lesions consistent with atypical MS in brain and spinal cord, discharged with oral Decadron and prednisone taper."
#       },
#       {
#         "Treatment": "5 days of IVMP",
#         "Dates": "Jan 2024",
#         "Outcome": "Followed recognition of WM changes and MS, thought some improvement but not completely normal."
#       }
#     ],
#     "Medical_history_and_comorbidities": [
#       "History of optic neuritis and abnormal MRI brain concerning for MS.",
#       "Atypical pediatric MS with multiple lesions.",
#       "ANA positive, SSB positive (Rheumatology consulted, no evidence of another systemic autoimmune disease).",
#       "Family history: Parents and brothers are healthy."
#     ],
#     "Physical_Exam_Findings": {
#       "General_Appearance": "Well appearing; NAD (No acute distress)",
#       "Cardiovascular": "RRR (Regular rate and rhythm)",
#       "Higher_Integrative_Functions": {
#         "Attention_Concentration": "Normal",
#         "Orientation": "Oriented to person, place & time",
#         "Memory": "Recent and remote memory Intact",
#         "Language": "Normal",
#         "Fund_of_Knowledge": "Normal"
#       },
#       "Cranial_Nerves": [
#         "CN 2: Visual fields full",
#         "CN 2,3: PERRL; rAPD",
#         "CN 3,4,6: EOMI",
#         "CN 5: Facial sensation intact",
#         "CN 7: Facial strength/movement intact bilaterally",
#         "CN 8: Hearing normal bilaterally",
#         "CN 9,10: Palate elevates symmetrically",
#         "CN 11: Normal shoulder shrug and head turn",
#         "CN 12: Tongue protrudes midline"
#       ],
#       "Motor": [
#         "Muscle tone normal in upper and lower extremities",
#         "Muscle strength 5/5 In upper and lower extremities; RLE 4+ proximally"
#       ],
#       "Sensation": "Intact to light touch in upper and lower extremities bilaterally",
#       "Coordination": "Finger/nose intact bilaterally",
#       "Gait": "Normal gait"
#     },
#     "Symptoms_History": [
#       "Intermittent numbness in right hand (dominant hand)",
#       "Muscle twitch in hands and shoulder",
#       "Urinary hesitancy (taking a long time to empty bladder), urinary urgency",
#       "Intermittent drifting to right side, bumping into things (no weakness)",
#       "Electrical sensation when laughing/bending neck",
#       "Right eye 'neon bright color' fuzzy vision, eye pain with movement (Oct 2023, resolved with rest)",
#       "Visual field deficits (Oct 2023)",
#       "Left eye involvement - 'neon colors appearance', eye discomfort (April this year, resolved)"
#     ],
#     "CSF_Results": {
#       "WBC": "8",
#       "RBC": "37",
#       "IgG_Index": "0.87",
#       "IgG_Index_Status": "elevated",
#       "OCB": "Positive"
#     }
#   },
#   "PROVIDER_INFORMATION": {
#     "Referring_physician": {
#       "Name": "Erfan Rostami",
#       "Specialty": "BSN, RN",
#       "Contact_info": {
#         "Phone": "615-343-1176",
#         "Fax": "615-343-1219"
#       }
#     },
#     "Ordering_physician": {
#       "Name": "Hao H Gu",
#       "Specialty": "MD",
#       "NPI": "1154611523",
#       "Practice_name": "Better Life Multiple Sclerosis Center",
#       "Practice_address": {
#         "Street": "3320 Montgomery Dr",
#         "City": "Nashville",
#         "State": "TN",
#         "Zip_code": "37361"
#       },
#       "Contact_info": {
#         "Phone": "615-562-4848",
#         "Fax": "615-562-4820",
#         "Direct_phone": "614-936-0065"
#       }
#     },
#     "Primary_Care_Provider": {
#       "Name": "James David",
#       "Specialty": "PNP",
#       "Contact_info": {
#         "Phone": "865-839-7458"
#       }
#     },
#     "Hospital_Attending_Physician": {
#       "Name": "Harry, Tom",
#       "Specialty": "MD, Pediatric Neurology"
#     },
#     "Resident_Physician": {
#       "Name": "Kaine, Adam Jason",
#       "Specialty": "MD, Pediatric Neurology"
#     },
#     "Other_Consulting_Physicians": [
#       { "Name": "Dr. Asriel Han", "Specialty": null, "Practice": "Better Life Multiple Sclerosis Center" },
#       { "Name": "Dr. Aditya Shah", "Specialty": null, "Practice": "Better Life Multiple Sclerosis Center" },
#       { "Name": "Dr. Fazal", "Specialty": "Pediatric Neurology", "Location": "East Bay" },
#       { "Name": "Dr. Shane", "Specialty": null, "Relationship": "Dr. Fazal's colleague" },
#       { "Name": "Dr. Derrek", "Specialty": "Ophthalmology", "Practice": "UT ophthalmology" },
#       { "Name": "Dr. Kosentka", "Specialty": "Pediatric Neurology" }
#     ],
#     "Facility_details_where_treatment_will_occur": [
#       {
#         "Name": "Golden Gate Infusion Center",
#         "Type": "Infusion Center (Fax recipient)",
#         "Contact_info": {
#           "Fax": "614-278-3355",
#           "Phone": "614-895-7655"
#         }
#       },
#       {
#         "Name": "Monroe Carell Jr. Children's Hospital",
#         "Type": "Hospital (Previous Admission)",
#         "Admission_Date": "2024-05-14",
#         "Discharge_Date": "2024-05-17"
#       },
#       {
#         "Name": "Children's Hematology - Oncology (Peds DOT 6)",
#         "Type": "Infusion / Clinic (Scheduled Appointment)",
#         "Address": {
#           "Street": "2211 Broad Way, Tower 4th FL, Suite 6102",
#           "City": "Nashville",
#           "State": "TN",
#           "Zip_code": "37232"
#         },
#         "Contact_info": {
#           "Phone": "615-936-1762"
#         },
#         "Appointment_Date": "2024-05-22 10:30 AM"
#       },
#       {
#         "Name": "Local infusion facility in Knoxville",
#         "Type": "Infusion Center (Future plan)",
#         "Notes": "Setting up for patient moving forward to minimize travel"
#       }
#     ]
#   },
#   "TREATMENT_DETAILS": {
#     "Requested_medication_procedure_device": {
#       "Name": "riTUXimab-abbs (TRUXIMA)",
#       "Type": "Medication (IVPB)",
#       "Initial_Dose": {
#         "Dosage": "694 mg (rounded from 693.75 mg = 375 mg/m2 x 1.85 m2 - BSA might be out of date)",
#         "Frequency": "Every 2 weeks",
#         "Duration": "2 doses (2/2 remaining)",
#         "Administration_notes": "intraVENOUS, Once, Starting 30 minutes after treatment start time",
#         "Due_date": "Week of 2024-05-19"
#       },
#       "Maintenance_Dose": {
#         "Dosage": "694 mg (rounded from 693.75 mg = 375 mg/m2 x 1.85 m2 - BSA might be out of date)",
#         "Frequency": "Every 24 weeks",
#         "Administration_notes": "intraVENOUS, Once, Starting when released",
#         "Due_date": "2024-11-04",
#         "Defer_until": "2024-11-04"
#       }
#     },
#     "Medical_necessity_justification": [
#       "Diagnosis: Multiple sclerosis in pediatric patient (G35).",
#       "History of optic neuritis and abnormal MRI brain concerning for MS.",
#       "MRI brain and spine demonstrating multiple lesions consistent with atypical pediatric MS.",
#       "Active demyelinating lesion (treated with high dose steroids).",
#       "CSF results: IgG Index elevated, +OCB."
#     ],
#     "Previous_treatment_failures": [
#       "Patient was treated with 5 days of IVMP in Jan 2024 and 5 days of high dose IVMP during recent hospitalization (May 2024). The subsequent plan for Rituximab suggests IVMP alone may not be sufficient for long-term management of MS."
#     ],
#     "Clinical_criteria_met_for_approval": [
#       "Confirmed diagnosis of Atypical Pediatric MS based on MRI and CSF findings.",
#       "Evidence of active demyelinating lesion.",
#       "Clinical symptoms consistent with MS exacerbation/progression."
#     ]
#   },
#   "SUPPORTING_EVIDENCE": {
#     "Lab_results_supporting_diagnosis": {
#       "CSF_results": {
#         "IgG_Index": "0.87 (elevated)",
#         "OCB": "positive"
#       },
#       "Immunology": {
#         "ANA": "positive",
#         "SSB": "positive"
#       },
#       "Quantitative_Immunoglobulins": {
#         "IgG": "1,355 mg/dL (High, Ref: 600-1,310)"
#       }
#     },
#     "Imaging_studies_and_results": [
#       {
#         "Study": "MRI brain and spine",
#         "Date": null,
#         "Results": "Multiple lesions consistent with atypical pediatric MS."
#       },
#       {
#         "Study": "MRI report",
#         "Date": "2024-01-21",
#         "Results": "Diffuse T2 hyperintensity and decreased volume throughout the right optic nerve (prior abnormal enhancement resolved). Left optic nerve subtle but diffusely small. Several intracranial WM lesions, stable from last."
#       },
#       {
#         "Study": "Same day MRI",
#         "Date": "Early/Mid September (tentative, 3 months after 1st Rituximab course)",
#         "Results": null,
#         "Notes": "No sedation needed."
#       }
#     ],
#     "Functional_assessments": [
#       "PT/OT evaluated, will follow outpatient."
#     ],
#     "Specialist_consultations": [
#       "Pediatric Ophthalmology (inpatient consult, follow-up in Knoxville)",
# ...
#       }
#     ],
#     "PRN_medications": [
#       {
#         "Name": "heparin, porcine (PF)",
#         "Strength": "100 unit/mL",
#         "Dosage": "5 mL",
#         "Route": "intraVENOUS",
#         "Frequency": "PRN",
#         "Instructions": "For flushing Ports/ PICC lines/ Central Lines IF NEEDED, Starting when released, Until Discontinued"
#       },
#       {
#         "Name": "diphenhydrAMINE (BENADRYL)",
#         "Form": "injection",
#         "Dosage": "25 mg",
#         "Route": "intraVENOUS",
#         "Frequency": "PRN",
#         "Instructions": "As needed, chills, Starting when released, for 2 doses"
#       },
#       {
#         "Name": "meperidine (DEMEROL)",
#         "Form": "injection",
#         "Dosage": "25 mg",
#         "Route": "intraVENOUS",
#         "Frequency": "PRN",
#         "Instructions": "As needed, rigors, Starting when released, for 2 doses"
#       },
#       {
#         "Name": "ondansetron (ZOFRAN)",
#         "Form": "injection",
#         "Dosage": "4 mg",
#         "Route": "intraVENOUS",
#         "Frequency": "PRN",
#         "Instructions": "As needed, nausea, vomiting, Starting when released, for 2 doses. Doses up to 4 mg may be administered undiluted. Inject over at least 30 seconds, but preferably over 2-5 minutes."
#       }
#     ],
#     "Allergies": "No Known Allergies",
#     "Vital_signs": [
#       {
#         "Collection_date": "2024-05-14",
#         "Temperature_C": "36.7",
#         "Temperature_F": "98",
#         "Temperature_Ref_Range_C": "36.5-36.7",
#         "Temperature_Ref_Range_F": "97.7-98.1",
#         "Pulse": "84",
#         "Pulse_Ref_Range": "81-99",
#         "Respirations": "16",
#         "Respirations_Ref_Range": "16-18",
#         "Blood_Pressure": "126/63",
#         "Blood_Pressure_Ref_Range": "(122-136)/(63-99)",
#         "SpO2_percent": "98",
#         "SpO2_Ref_Range_percent": "98"
#       }
#     ],
#     "Lab_results": {
#       "Collection_Time": "2024-05-14 10:47 AM",
#       "CBC_w_Differential": [
#         { "Test": "White Blood Cells", "Value": "7.7", "Unit": "x10(3)/mcL", "Ref_Range": "3.4-10.2" },
#         { "Test": "Red Blood Cells", "Value": "4.63", "Unit": "x10(6)/mcL", "Ref_Range": "3.80-5.50" },
#         { "Test": "Hemoglobin", "Value": "13.0", "Unit": "gm/dL", "Ref_Range": "12.0-16.0" },
#         { "Test": "Hematocrit", "Value": "40", "Unit": "%", "Ref_Range": "35-49" },
#         { "Test": "Mean Cell Volume", "Value": "86", "Unit": "fL", "Ref_Range": "76-96" },
#         { "Test": "Mean Cell Hemoglobin", "Value": "28.1", "Unit": "pg", "Ref_Range": "25.0-35.0" },
#         { "Test": "Mean Cell Hemoglobin Concentration", "Value": "32.7", "Unit": "gm/dL", "Ref_Range": "32.0-37.0" },
#         { "Test": "RDW SD", "Value": "38.4", "Unit": "fL", "Ref_Range": "37.4-52.4" },
#         { "Test": "RDW CV", "Value": "12.3", "Unit": "%", "Ref_Range": "11.1-14.3" },
#         { "Test": "Platelet", "Value": "300", "Unit": "x10(3)/mcL", "Ref_Range": "150-400" },
#         { "Test": "Mean Platelet Volume", "Value": "10.0", "Unit": "fL", "Ref_Range": "9.3-12.8" },
#         { "Test": "Nucleated RBC", "Value": "0", "Unit": "WBC", "Ref_Range": "0-0/100" },
#         { "Test": "Nucleated RBC Abs", "Value": "0.00", "Unit": "x10(3)/mcL", "Ref_Range": "0.00-0.00" },
#         { "Test": "Auto Neutrophil Absolute", "Value": "4.52", "Unit": "x10(3)/mcL", "Ref_Range": "1.80-7.70" }
#       ],
#       "CMP": [
#         { "Test": "Sodium Level", "Value": "139", "Unit": "mmol/L", "Ref_Range": "138-145" },
#         { "Test": "Potassium Level", "Value": "3.8", "Unit": "mmol/L", "Ref_Range": "3.3-4.8" },
#         { "Test": "Chloride Level", "Value": "101", "Unit": "mmol/L", "Ref_Range": "98-107" },
#         { "Test": "Carbon Dioxide", "Value": "22", "Unit": "mmol/L", "Ref_Range": "17-28" },
#         { "Test": "Anion Gap", "Value": "16", "Unit": "mmol/L", "Ref_Range": null },
#         { "Test": "Glucose Level", "Value": "95", "Unit": "mg/dL", "Ref_Range": "60-99" },
#         { "Test": "Blood Urea Nitrogen", "Value": "13", "Unit": "mg/dL", "Ref_Range": "7-18" },
#         { "Test": "Creatinine Level", "Value": "0.67", "Unit": "mg/dL", "Ref_Range": "0.50-0.90" },
#         { "Test": "Calcium Level Total", "Value": "9.9", "Unit": "mg/dL", "Ref_Range": "8.4-10.2" },
#         { "Test": "Bilirubin Total", "Value": "0.4", "Unit": "mg/dL", "Ref_Range": "0.0-0.7" },
#         { "Test": "Albumin Level", "Value": "4.7", "Unit": "gm/dL", "Ref_Range": "4.0-5.3" },
#         { "Test": "Protein Total", "Value": "8.4", "Unit": "gm/dL", "Ref_Range": "6.3-7.8", "Abnormal_Flag": "H" },
#         { "Test": "Alkaline Phosphatase", "Value": "55", "Unit": "unit/L", "Ref_Range": "50-117" },
#         { "Test": "Aspartate Aminotransferase", "Value": "25", "Unit": "unit/L", "Ref_Range": "21-34" },
#         { "Test": "Alanine Aminotransferase", "Value": "<6", "Unit": "unit/L", "Ref_Range": "0-17" }
#       ],
#       "Hepatitis_B_Pnl": [
#         { "Test": "Hepatitis B Surface Antigen", "Value": "Negative", "Ref_Range": "Negative" },
#         { "Test": "Hep B Core Ab Total", "Value": "Negative", "Ref_Range": "Negative" },
#         { "Test": "Hepatitis B Surface Ab Unit", "Value": "44.7", "Unit": "mlU/mL", "Ref_Range": "<=10.0", "Abnormal_Flag": "H" },
#         { "Test": "Hep Bs Ab Interp", "Value": "Positive (A)", "Ref_Range": "Negative" }
#       ],
#       "IgG": [
#         { "Test": "IgG Quantitative", "Value": "1,355", "Unit": "mg/dL", "Ref_Range": "600-1,310", "Abnormal_Flag": "H" }
#       ],
#       "IgA": [
#         { "Test": "IgA Quantitative", "Value": "279", "Unit": "mg/dL", "Ref_Range": "40-290" }
#       ],
#       "Auto_Diff": [
#         { "Test": "Neutrophils", "Value": "58.3", "Unit": "%", "Ref_Range": null },
#         { "Test": "Absolute Neutrophils", "Value": "4.52", "Unit": "x10(3)/mcL", "Ref_Range": "1.80-7.70" },
#         { "Test": "Lymphs", "Value": "33.6", "Unit": "%", "Ref_Range": null },
#         { "Test": "Absolute Lymphocytes", "Value": "2.60", "Unit": "x10(3)/mcL", "Ref_Range": "1.70-4.50" },
#         { "Test": "Monocytes", "Value": "6.5", "Unit": "%", "Ref_Range": null },
#         { "Test": "Absolute Monocytes", "Value": "0.50", "Unit": "x10(3)/mcL", "Ref_Range": "0.20-1.00" },
#         { "Test": "Eosinophils", "Value": "0.5", "Unit": "%", "Ref_Range": null },
#         { "Test": "Absolute Eosinophils", "Value": "0.04", "Unit": "x10(3)/mcL", "Ref_Range": "0.00-0.50" },
#         { "Test": "Basophils", "Value": "0.8", "Unit": "%", "Ref_Range": null },
#         { "Test": "Absolute Basophils", "Value": "0.06", "Unit": "x10(3)/mcL", "Ref_Range": "0.01-0.08" },
#         { "Test": "Imm Gran Automated", "Value": "0.3", "Unit": "%", "Ref_Range": null },
#         { "Test": "Absolute Imm Gran Automated", "Value": "0.02", "Unit": "x10(3)/mcL", "Ref_Range": "0.00-0.03" }
#       ]
#     },
#     "Previous_treatments_and_outcomes": [
#       {
#         "Treatment": "High dose IVMP (Intravenous Methylprednisolone)",
#         "Dosage": "1g/dose",
#         "Duration": "5 days",
#         "Dates": "2024-05-14 to 2024-05-17",
#         "Outcome": "Tolerated well, lesions consistent with atypical MS in brain and spinal cord, discharged with oral Decadron and prednisone taper."
#       },
#       {
#         "Treatment": "5 days of IVMP",
#         "Dates": "Jan 2024",
#         "Outcome": "Followed recognition of WM changes and MS, thought some improvement but not completely normal."
#       }
#     ],
#     "Medical_history_and_comorbidities": [
#       "History of optic neuritis and abnormal MRI brain concerning for MS.",
#       "Atypical pediatric MS with multiple lesions.",
#       "ANA positive, SSB positive (Rheumatology consulted, no evidence of another systemic autoimmune disease).",
#       "Family history: Parents and brothers are healthy."
#     ],
#     "Physical_Exam_Findings": {
#       "General_Appearance": "Well appearing; NAD (No acute distress)",
#       "Cardiovascular": "RRR (Regular rate and rhythm)",
#       "Higher_Integrative_Functions": {
#         "Attention_Concentration": "Normal",
#         "Orientation": "Oriented to person, place & time",
#         "Memory": "Recent and remote memory Intact",
#         "Language": "Normal",
#         "Fund_of_Knowledge": "Normal"
#       },
#       "Cranial_Nerves": [
#         "CN 2: Visual fields full",
#         "CN 2,3: PERRL; rAPD",
#         "CN 3,4,6: EOMI",
#         "CN 5: Facial sensation intact",
#         "CN 7: Facial strength/movement intact bilaterally",
#         "CN 8: Hearing normal bilaterally",
#         "CN 9,10: Palate elevates symmetrically",
#         "CN 11: Normal shoulder shrug and head turn",
#         "CN 12: Tongue protrudes midline"
#       ],
#       "Motor": [
#         "Muscle tone normal in upper and lower extremities",
#         "Muscle strength 5/5 In upper and lower extremities; RLE 4+ proximally"
#       ],
#       "Sensation": "Intact to light touch in upper and lower extremities bilaterally",
#       "Coordination": "Finger/nose intact bilaterally",
#       "Gait": "Normal gait"
#     },
#     "Symptoms_History": [
#       "Intermittent numbness in right hand (dominant hand)",
#       "Muscle twitch in hands and shoulder",
#       "Urinary hesitancy (taking a long time to empty bladder), urinary urgency",
#       "Intermittent drifting to right side, bumping into things (no weakness)",
#       "Electrical sensation when laughing/bending neck",
#       "Right eye 'neon bright color' fuzzy vision, eye pain with movement (Oct 2023, resolved with rest)",
#       "Visual field deficits (Oct 2023)",
#       "Left eye involvement - 'neon colors appearance', eye discomfort (April this year, resolved)"
#     ],
#     "CSF_Results": {
#       "WBC": "8",
#       "RBC": "37",
#       "IgG_Index": "0.87",
#       "IgG_Index_Status": "elevated",
#       "OCB": "Positive"
#     }
#   },
#   "PROVIDER_INFORMATION": {
#     "Referring_physician": {
#       "Name": "Erfan Rostami",
#       "Specialty": "BSN, RN",
#       "Contact_info": {
#         "Phone": "615-343-1176",
#         "Fax": "615-343-1219"
#       }
#     },
#     "Ordering_physician": {
#       "Name": "Hao H Gu",
#       "Specialty": "MD",
#       "NPI": "1154611523",
#       "Practice_name": "Better Life Multiple Sclerosis Center",
#       "Practice_address": {
#         "Street": "3320 Montgomery Dr",
#         "City": "Nashville",
#         "State": "TN",
#         "Zip_code": "37361"
#       },
#       "Contact_info": {
#         "Phone": "615-562-4848",
#         "Fax": "615-562-4820",
#         "Direct_phone": "614-936-0065"
#       }
#     },
#     "Primary_Care_Provider": {
#       "Name": "James David",
#       "Specialty": "PNP",
#       "Contact_info": {
#         "Phone": "865-839-7458"
#       }
#     },
#     "Hospital_Attending_Physician": {
#       "Name": "Harry, Tom",
#       "Specialty": "MD, Pediatric Neurology"
#     },
#     "Resident_Physician": {
#       "Name": "Kaine, Adam Jason",
#       "Specialty": "MD, Pediatric Neurology"
#     },
#     "Other_Consulting_Physicians": [
#       { "Name": "Dr. Asriel Han", "Specialty": null, "Practice": "Better Life Multiple Sclerosis Center" },
#       { "Name": "Dr. Aditya Shah", "Specialty": null, "Practice": "Better Life Multiple Sclerosis Center" },
#       { "Name": "Dr. Fazal", "Specialty": "Pediatric Neurology", "Location": "East Bay" },
#       { "Name": "Dr. Shane", "Specialty": null, "Relationship": "Dr. Fazal's colleague" },
#       { "Name": "Dr. Derrek", "Specialty": "Ophthalmology", "Practice": "UT ophthalmology" },
#       { "Name": "Dr. Kosentka", "Specialty": "Pediatric Neurology" }
#     ],
#     "Facility_details_where_treatment_will_occur": [
#       {
#         "Name": "Golden Gate Infusion Center",
#         "Type": "Infusion Center (Fax recipient)",
#         "Contact_info": {
#           "Fax": "614-278-3355",
#           "Phone": "614-895-7655"
#         }
#       },
#       {
#         "Name": "Monroe Carell Jr. Children's Hospital",
#         "Type": "Hospital (Previous Admission)",
#         "Admission_Date": "2024-05-14",
#         "Discharge_Date": "2024-05-17"
#       },
#       {
#         "Name": "Children's Hematology - Oncology (Peds DOT 6)",
#         "Type": "Infusion / Clinic (Scheduled Appointment)",
#         "Address": {
#           "Street": "2211 Broad Way, Tower 4th FL, Suite 6102",
#           "City": "Nashville",
#           "State": "TN",
#           "Zip_code": "37232"
#         },
#         "Contact_info": {
#           "Phone": "615-936-1762"
#         },
#         "Appointment_Date": "2024-05-22 10:30 AM"
#       },
#       {
#         "Name": "Local infusion facility in Knoxville",
#         "Type": "Infusion Center (Future plan)",
#         "Notes": "Setting up for patient moving forward to minimize travel"
#       }
#     ]
#   },
#   "TREATMENT_DETAILS": {
#     "Requested_medication_procedure_device": {
#       "Name": "riTUXimab-abbs (TRUXIMA)",
#       "Type": "Medication (IVPB)",
#       "Initial_Dose": {
#         "Dosage": "694 mg (rounded from 693.75 mg = 375 mg/m2 x 1.85 m2 - BSA might be out of date)",
#         "Frequency": "Every 2 weeks",
#         "Duration": "2 doses (2/2 remaining)",
#         "Administration_notes": "intraVENOUS, Once, Starting 30 minutes after treatment start time",
#         "Due_date": "Week of 2024-05-19"
#       },
#       "Maintenance_Dose": {
#         "Dosage": "694 mg (rounded from 693.75 mg = 375 mg/m2 x 1.85 m2 - BSA might be out of date)",
#         "Frequency": "Every 24 weeks",
#         "Administration_notes": "intraVENOUS, Once, Starting when released",
#         "Due_date": "2024-11-04",
#         "Defer_until": "2024-11-04"
#       }
#     },
#     "Medical_necessity_justification": [
#       "Diagnosis: Multiple sclerosis in pediatric patient (G35).",
#       "History of optic neuritis and abnormal MRI brain concerning for MS.",
#       "MRI brain and spine demonstrating multiple lesions consistent with atypical pediatric MS.",
#       "Active demyelinating lesion (treated with high dose steroids).",
#       "CSF results: IgG Index elevated, +OCB."
#     ],
#     "Previous_treatment_failures": [
#       "Patient was treated with 5 days of IVMP in Jan 2024 and 5 days of high dose IVMP during recent hospitalization (May 2024). The subsequent plan for Rituximab suggests IVMP alone may not be sufficient for long-term management of MS."
#     ],
#     "Clinical_criteria_met_for_approval": [
#       "Confirmed diagnosis of Atypical Pediatric MS based on MRI and CSF findings.",
#       "Evidence of active demyelinating lesion.",
#       "Clinical symptoms consistent with MS exacerbation/progression."
#     ]
#   },
#   "SUPPORTING_EVIDENCE": {
#     "Lab_results_supporting_diagnosis": {
#       "CSF_results": {
#         "IgG_Index": "0.87 (elevated)",
#         "OCB": "positive"
#       },
#       "Immunology": {
#         "ANA": "positive",
#         "SSB": "positive"
#       },
#       "Quantitative_Immunoglobulins": {
#         "IgG": "1,355 mg/dL (High, Ref: 600-1,310)"
#       }
#     },
#     "Imaging_studies_and_results": [
#       {
#         "Study": "MRI brain and spine",
#         "Date": null,
#         "Results": "Multiple lesions consistent with atypical pediatric MS."
#       },
#       {
#         "Study": "MRI report",
#         "Date": "2024-01-21",
#         "Results": "Diffuse T2 hyperintensity and decreased volume throughout the right optic nerve (prior abnormal enhancement resolved). Left optic nerve subtle but diffusely small. Several intracranial WM lesions, stable from last."
#       },
#       {
#         "Study": "Same day MRI",
#         "Date": "Early/Mid September (tentative, 3 months after 1st Rituximab course)",
#         "Results": null,
#         "Notes": "No sedation needed."
#       }
#     ],
#     "Functional_assessments": [
#       "PT/OT evaluated, will follow outpatient."
#     ],
#     "Specialist_consultations": [
#       "Pediatric Ophthalmology (inpatient consult, follow-up in Knoxville)",
#       "Pediatric Rheumatology (inpatient consult, concluded no other systemic autoimmune disease)",
#       "Case Management (inpatient consult)",
#       "Neuroimmunology clinic (Dr. Gu)",
#       "Pediatric Neurology (Dr. Fazal, Dr. Kosentka)",
#       "UT Ophthalmology (Dr. Derrek)"
#     ],
#     "Treatment_response_documentation": [
#       "High dose IVMP (May 2024) tolerated well.",
#       "High dose IVMP (Jan 2024) resulted in some improvement."
#     ]
#   }
# }
# ```

# %% [markdown]
# ## PA widget input info extraction

# %%
import fitz

# Code from Headstarter tutorial to extract fields from PDF
def extracting_fields_from_pdf(pdf_file):
    """
    Extracts form fields from a PDF file and returns them as a list of dictionaries.
    Each dictionary contains field name, type, value, page number, and other metadata.
    """
    if not pathlib.Path(pdf_file).exists():
        raise FileNotFoundError(f"The file {pdf_file} does not exist.")
    doc = fitz.open(pdf_file)
    fields = []
    for page_num, page in enumerate(doc, start = 1):
        for w in page.widgets() or []:
            field = {
                "name": w.field_name,
                "type": "checkbox" if w.field_type == fitz.PDF_WIDGET_TYPE_CHECKBOX else "text",
                "value": w.field_value,
                "page": page_num,
                "field_type": w.field_type,
                "field_type_string": w.field_type_string,
                "field_label": w.field_label,
            }
            print(field)
            fields.append(field)

    field_by_page = {}
    for field in fields:
        page_num = field["page"]
        if page_num not in field_by_page:
            field_by_page[page_num] = []
    
    return field_by_page

pa_fields = extracting_fields_from_pdf("Input Data/Adbulla/PA.pdf")
# Out:
# {'name': 'CB1', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Start of treatment'}
# {'name': 'T2', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Start date: (MM)'}
# {'name': 'T3', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Start date: (DD)'}
# {'name': 'T4', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Start date: (YYYY)'}
# {'name': 'CB5', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Continuation of therapy'}
# {'name': 'T6', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date of last treatment: (MM)'}
# {'name': 'T7', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date of last treatment: (DD)'}
# {'name': 'T8', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date of last treatment: (YYYY)'}
# {'name': 'T9', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Precertification Requested By:'}
# {'name': 'T10', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Phone:'}
# {'name': 'T11', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Fax:'}
# {'name': 'T12', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient First Name'}
# {'name': 'T13', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient Last Name'}
# {'name': 'T14', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient DOB (MM/DD/YYYY)'}
# {'name': 'T15', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Address:'}
# {'name': 'T16', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'City:'}
# {'name': 'T17', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'State:'}
# {'name': 'T18', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'ZIP:'}
# {'name': 'T19', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient Phone'}
# {'name': 'T20', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Work Phone:'}
# {'name': 'T21', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Cell Phone:'}
# {'name': 'T22', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'E-mail:'}
# {'name': 'T24', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'lbs'}
# {'name': 'T25', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'kgs'}
# {'name': 'T26', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'inches'}
# {'name': 'T27', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'cms'}
# {'name': 'T23', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Allergies:'}
# {'name': 'T28', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Member ID #:'}
# {'name': 'T29', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Group #:'}
# {'name': 'T30', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Insured:'}
# {'name': 'CB31', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB32', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'T33', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'If yes, provide ID#:'}
# {'name': 'T34', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Carrier Name:'}
# {'name': 'T35', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Insured:'}
# {'name': 'T42', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'First Name:'}
# {'name': 'T43', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Last Name:'}
# {'name': 'CB44', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'M.D.'}
# {'name': 'CB45', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'D.O.'}
# {'name': 'CB46', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'N.P.'}
# {'name': 'CB47', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'P.A.'}
# {'name': 'T48', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Address:'}
# {'name': 'T49', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'City:'}
# {'name': 'T50', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'State:'}
# {'name': 'T51', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'ZIP:'}
# {'name': 'T52', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Phone:'}
# {'name': 'T53', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Fax:'}
# {'name': 'T54', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'St Lic #:'}
# {'name': 'T55', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'NPI #:'}
# {'name': 'T56', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'DEA #:'}
# {'name': 'T57', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'UPIN:'}
# {'name': 'T58.0', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Provider Email:'}
# {'name': 'T58.1', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Office Contact Name:'}
# {'name': 'T59', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Phone:'}
# {'name': 'Provider Admin CB.1', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Self-administered'}
# {'name': 'Provider Admin CB.2', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Physician’s Office'}
# {'name': 'Provider Admin CB.3', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Home'}
# {'name': 'Provider Admin CB.4', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Outpatient Infusion Center'}
# {'name': 'Provider Admin T.5', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Name:'}
# {'name': 'Provider Admin CB.7', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Home Infusion Center'}
# {'name': 'Provider Admin T.6', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Phone:'}
# {'name': 'Provider Admin T.8', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Agency Name:'}
# {'name': 'Provider Admin CB.10', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Administration code(s)'}
# {'name': 'Provider Admin T.9', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'CPT:'}
# {'name': 'Provider Admin T.11A', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Address:'}
# {'name': 'Provider Admin T.13', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'City:'}
# {'name': 'Provider Admin T.14', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'State:'}
# {'name': 'Provider Admin T.15', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'ZIP:'}
# {'name': 'Provider Admin T.16', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Phone:'}
# {'name': 'Provider Admin T.17A', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Fax:'}
# {'name': 'Provider Admin T.18', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'TIN:'}
# {'name': 'Provider Admin T.19', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'PIN:'}
# {'name': 'Provider Admin T.20', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'NPI:'}
# {'name': 'Provider Admin CB.21', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Outpatient Dialysis Center'}
# {'name': 'Provider Admin CB.22', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Physician’s Office'}
# {'name': 'Provider Admin CB.23.0.0', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Retail Pharmacy'}
# {'name': 'Provider Admin CB.24.0.0', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Specialty Pharmacy'}
# {'name': 'Provider Admin CB.25', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Mail Order'}
# {'name': 'Provider Admin CB.26', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Other:'}
# {'name': 'Provider Admin T.27', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Other:'}
# {'name': 'Provider Admin T.28', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Name:'}
# {'name': 'Provider Admin T.29a', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Address:'}
# {'name': 'Provider Admin T.30a', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'City:'}
# {'name': 'Provider Admin T.31', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'State:'}
# {'name': 'Provider Admin T.32', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'ZIP:'}
# {'name': 'Provider Admin T.33', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Phone:'}
# {'name': 'Provider Admin T.34', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Fax:'}
# {'name': 'Provider Admin T.35', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'TIN:'}
# {'name': 'Provider Admin T.36', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'PIN:'}
# {'name': 'Provider Admin T.37', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'NPI:'}
# {'name': 'CB60', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Riabni (rituximab-arrx)'}
# {'name': 'CB61', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Rituxan (rituximab)'}
# {'name': 'CB62', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Ruxience (rituximab-pvvr)'}
# {'name': 'CB63', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Truxima (rituximab-abbs)'}
# {'name': 'T64', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Dose:'}
# {'name': 'T65', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Directions for Use:'}
# {'name': 'T66', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'HCPCS Code:'}
# {'name': 'T67', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Primary ICD Code:'}
# {'name': 'CB68', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Other ICD Code:'}
# {'name': 'T69', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Other ICD Code:'}
# {'name': 'CB70', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB71', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB72', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB73', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Ruxience (rituximab-pvvr)'}
# {'name': 'CB74', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Truxima (rituximab-abbs)'}
# {'name': 'T75', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'When was the member’s trial and failure of the preferred drug?'}
# {'name': 'T76', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please describe the nature of the failure of the preferred drug'}
# {'name': 'CB77', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB78', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Ruxience (rituximab-pvvr)'}
# {'name': 'CB79', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Truxima (rituximab-abbs)'}
# {'name': 'T80', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'When was the member’s adverse reaction to the preferred drug?'}
# {'name': 'T81', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please describe the nature of the adverse reaction to the preferred drug'}
# {'name': 'T84', 'type': 'text', 'value': '', 'page': 2, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please explain if there are any contraindications or other medical reason(s) that the patient cannot use any of the following preferred biosimilar products when indicated for the patient’s diagnosis?'}
# {'name': 'CB82', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Ruxience (rituximab-pvvr)'}
# {'name': 'CB83', 'type': 'checkbox', 'value': '', 'page': 2, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Truxima (rituximab-abbs)'}
# {'name': 'T12', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient First Name'}
# {'name': 'T13', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient Last Name'}
# {'name': 'T19', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient Phone'}
# {'name': 'T14', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient DOB (MM/DD/YYYY)'}
# {'name': 'CB86', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Inflectra (infliximab-dyyb)'}
# {'name': 'CB87', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Renflexis (infliximab-abda)'}
# {'name': 'CB88', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Simponi Aria (golimumab)'}
# {'name': 'T89', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'When was the member’s trial and failure of the preferred drug?'}
# {'name': 'T90', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please describe the nature of the failure of the preferred drug'}
# {'name': 'CB85', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB92', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Inflectra (infliximab-dyyb)'}
# {'name': 'CB93', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Renflexis (infliximab-abda)'}
# {'name': 'CB94', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Simponi Aria (golimumab)'}
# {'name': 'T95', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'When was the member’s adverse reaction to the preferred drug?'}
# {'name': 'T96a', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please describe the nature of the adverse reaction to the preferred drug'}
# {'name': 'CB91', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB98a', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Enbrel (etanercept)'}
# {'name': 'CB99a', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Humira (adalimumab)'}
# {'name': 'CB100a', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Idacio (adalimumab-aacf)'}
# {'name': 'CB101a', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Rinvoq (upadacitinib)'}
# {'name': 'CB102a', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Tyenne SC (tocilizumab-aazg)'}
# {'name': 'CB103a', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Xeljanz/Xeljanz XR (tofacitinib)'}
# {'name': 'T104', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'When was the member’s trial and failure of the preferred drug?'}
# {'name': 'T105', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please describe the nature of the failure of the preferred drug'}
# {'name': 'CB97', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB107z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Enbrel (etanercept)'}
# {'name': 'CB108z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Humira (adalimumab)'}
# {'name': 'CB109z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Idacio (adalimumab-aacf)'}
# {'name': 'CB110z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Rinvoq (upadacitinib)'}
# {'name': 'CB111z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Tyenne SC (tocilizumab-aazg)'}
# {'name': 'CB112z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Xeljanz/Xeljanz XR (tofacitinib)'}
# {'name': 'T113', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'When was the member’s adverse reaction to the preferred drug?'}
# {'name': 'T114', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please describe the nature of the adverse reaction to the preferred drug'}
# {'name': 'CB106z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'T118', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please explain if there are any contraindications or other medical reason(s) that the patient cannot use any of the following preferred products when indicated for the patient’s diagnosis?'}
# {'name': 'CB115z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Inflectra (infliximab-dyyb)'}
# {'name': 'CB116z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Renflexis (infliximab-abda)'}
# {'name': 'CB117z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Simponi Aria (golimumab)'}
# {'name': 'T125', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please explain if there are contraindications or any other medical reason(s) that the patient cannot use any of the following preferred products when indicated for the patient’s diagnosis?'}
# {'name': 'CB119z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Enbrel (etanercept)'}
# {'name': 'CB120z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Humira (adalimumab)'}
# {'name': 'CB121z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Idacio (adalimumab-aacf)'}
# {'name': 'CB122z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Rinvoq (upadacitinib)'}
# {'name': 'CB123z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Tyenne SC (tocilizumab-aazg)'}
# {'name': 'CB124z', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Xeljanz/Xeljanz XR (tofacitinib)'}
# {'name': 'CB96.4.0', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB98', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB99.0', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB100.0', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB101.0', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB102.0', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB103', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB104', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB104a', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Wegener granulomatosis'}
# {'name': 'CB104b', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Churg-Strauss syndrome'}
# {'name': 'CB104c', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'microscopic polyangiitis'}
# {'name': 'CB104d', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'pauci-immune glomerulonephritis'}
# {'name': 'CB105', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB106', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB106a', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB107', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'pemphigus vulgaris'}
# {'name': 'CB108', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'pemphigus folliaceus'}
# {'name': 'CB109', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'bullous pemphigoid'}
# {'name': 'CB110', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'cicatricial pemphigoid'}
# {'name': 'CB111', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'epidermolysis bullosa acquisita'}
# {'name': 'CB112', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'paraneoplastic pemphigus'}
# {'name': 'CB113', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'None of the above'}
# {'name': 'CB106b', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB114', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'AIDS-related B-cell lymphoma'}
# {'name': 'CB115', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Burkitt lymphoma'}
# {'name': 'CB116', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Diffuse large B-cell lymphoma'}
# {'name': 'CB117', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Follicular lymphoma'}
# {'name': 'CB118', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Gastric MALT lymphoma'}
# {'name': 'CB119', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'High-grade B-Cell lymphoma'}
# {'name': 'CB120', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Mantle cell lymphoma'}
# {'name': 'CB121', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Nodal marginal zone lymphoma'}
# {'name': 'CB122', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Nongastric MALT lymphoma'}
# {'name': 'CB123', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Primary cutaneous B-cell lymphomas'}
# {'name': 'CB124', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Splenic marginal zone lymphoma'}
# {'name': 'CB125', 'type': 'checkbox', 'value': '', 'page': 3, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Other:'}
# {'name': 'T126', 'type': 'text', 'value': '', 'page': 3, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Other:'}
# {'name': 'T12', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient First Name'}
# {'name': 'T13', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient Last Name'}
# {'name': 'T19', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient Phone'}
# {'name': 'T14', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient DOB (MM/DD/YYYY)'}
# {'name': 'CB127', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB128', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB129', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'leptomeningeal metastases from lymphoma'}
# {'name': 'CB130', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'primary CNS lymphoma'}
# {'name': 'CB131', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'none of the above'}
# {'name': 'CB132', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'chronic lymphocytic leukemia (CLL)'}
# {'name': 'CB133', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'small lymphocytic leukemia'}
# {'name': 'CB134', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'none of the above'}
# {'name': 'CB135', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB136', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB139', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB140', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB144', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB145', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB141', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'relapsed hairy cell leukemia'}
# {'name': 'CB142', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'refractory hairy cell leukemia'}
# {'name': 'CB143', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'none of the above'}
# {'name': 'CB137', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB146', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'heart transplant recipient'}
# {'name': 'CB147', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'other solid organ transplant recipient'}
# {'name': 'CB138', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB148', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Bavencio (avelumab)'}
# {'name': 'CB149', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Imfinzi (durvalumab)'}
# {'name': 'CB150', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Keytruda (pembrolizumab)'}
# {'name': 'CB151', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Opdivo (nivolumab)'}
# {'name': 'CB152', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Tecentriq (atezolizumab)'}
# {'name': 'CB153', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yervoy (ipilimumab)'}
# {'name': 'CB154', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Other:'}
# {'name': 'T155', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Other:'}
# {'name': 'CB156', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB158', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'refractory immune thrombocytopenic purpura'}
# {'name': 'CB159', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'idiopathic thrombocytopenic purpura (ITP)'}
# {'name': 'CB157', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB160', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB161', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB162', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB163', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB164', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Relapsing-remitting MS (RRMS)'}
# {'name': 'CB165', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Secondary-progressive MS (SPMS)'}
# {'name': 'CB166', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Primary-progressive MS (PPMS)'}
# {'name': 'CB167', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Progressive-relapsing MS (PRMS)'}
# {'name': 'CB168', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB169', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB170', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB172', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB173', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB171', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB174', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB175', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB176', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB177', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB178', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB179', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB180', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'T189', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Medication:'}
# {'name': 'T190', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T191', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T192', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}
# {'name': 'T193', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T194', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T195', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}
# {'name': 'T196', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Medication:'}
# {'name': 'T197', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T198', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T199', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}
# {'name': 'T200', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T201', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T202', 'type': 'text', 'value': '', 'page': 4, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}
# {'name': 'CB181', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB203', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB204', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB205', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB206', 'type': 'checkbox', 'value': '', 'page': 4, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'T12', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient First Name'}
# {'name': 'T13', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient Last Name'}
# {'name': 'T19', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient Phone'}
# {'name': 'T14', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Patient DOB (MM/DD/YYYY)'}
# {'name': 'CB207', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Mild'}
# {'name': 'CB208', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Moderate'}
# {'name': 'CB209', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Severe'}
# {'name': 'CB210', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB211', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB212', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB213', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB214', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB216', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'ineffective'}
# {'name': 'CB217', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'not tolerated'}
# {'name': 'CB218', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'contraindicated'}
# {'name': 'CB215', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB223', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB225', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'azathioprine'}
# {'name': 'CB226', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'cyclosporine'}
# {'name': 'CB227', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'hydroxychloroquine'}
# {'name': 'CB228', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'leflunomide'}
# {'name': 'CB229', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'sulfasalazine'}
# {'name': 'CB224', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB281', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB282', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB283', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'T285', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Medication:'}
# {'name': 'T286', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T287', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T288', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}
# {'name': 'T289', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T290', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T291', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}
# {'name': 'T292', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Medication:'}
# {'name': 'T293', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T294', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T295', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}
# {'name': 'T296', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T297', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T298', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}
# {'name': 'CB284', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB299', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB300', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB301', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB302', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB303', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB304', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'T305', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Please indicate the length of time on Rituxan (rituximab):'}
# {'name': 'CB310', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Mild'}
# {'name': 'CB311', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Moderate'}
# {'name': 'CB312', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Severe'}
# {'name': 'CB306', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB307', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB308', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB309', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB313', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB314', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'CB315', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'Yes'}
# {'name': 'CB316', 'type': 'checkbox', 'value': '', 'page': 5, 'field_type': 2, 'field_type_string': 'CheckBox', 'field_label': 'No'}
# {'name': 'T317', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (MM)'}
# {'name': 'T318', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (DD)'}
# {'name': 'T319', 'type': 'text', 'value': '', 'page': 5, 'field_type': 7, 'field_type_string': 'Text', 'field_label': 'Date: (YYYY)'}

# %% [markdown]
# ## PA feild organization Prompt template for Gemeni

# %%
def format_fields_for_pa(pa_fields):
  return """
  You are given an array of dictionaries, each representing a form field extracted from a PDF. Each dictionary contains:
  - "name": the field name
  - "type": the field type (e.g., "text", "checkbox")
  - "value": the field value (may be null)
  - "page": the 1-based page number
  - "field_type": the PDF widget type code
  - "field_type_string": the PDF widget type as a string
  - "field_label": the field label (may be null)

  TASK:
  1. Organize these fields into a hierarchical JSON tree grouped by page number.
  2. For each page, create an array of fields, preserving all metadata.
  3. The top-level JSON should be:
  {
    "pages": {
      "1": [ ...fields... ],
      "2": [ ...fields... ],
      ...
    }
  }
  4. Do not omit any fields or metadata.
  5. Return only valid JSON (no markdown, no extra commentary).

  Example output:
  {
    "pages": {
      "1": [
        {
          "name": "T1",
          "type": "text",
          "value": "",
          "page": 1,
          "field_type": 2,
          "field_type_string": "Text",
          "field_label": "First Name"
        },
        ...
      ],
      "2": [
        ...
      ]
    }
  }

  <PA_FIELDS>
  {pa_fields}
  </PA_FIELDS> """

# %% [markdown]
# ## Send Prompt to Gemeni

# %%
# Send to Gemini using NEW 2025 SDK

async def query_gemini_async(prompt, pdf_path, model_name='gemini-2.5-flash'):
    """
    Async function to query Gemini with a PDF and prompt using the new 2025 Google Gen AI SDK
    """
    filepath = pathlib.Path(pdf_path)
    
    # Create PDF part using new SDK structure
    pdf_bytes = filepath.read_bytes()
    pdf_part = types.Part.from_bytes(
        data=pdf_bytes, 
        mime_type="application/pdf"
    )
    
    # Use async client from new SDK
    response = await client.aio.models.generate_content(
        model=model_name,
        contents=[pdf_part, prompt]
    )
    
    print(response.text)
    return response.text

# %%
pa_fields_context = {}

# Process each page of the PA form
async def process_page(page):
    prompt = format_fields_for_pa(pa_fields[page])
    print (prompt)

    result = await query_gemini_async(prompt, "Input Data/Adbulla/PA.pdf")
    print ("---------------------------------")
    return page, result
# create a list of tasks to run in parallel
tasks = [process_page(page) for page in pa_fields]

# running the tasks in parallel
results = await asyncio.gather(*tasks)

# 
for page, result in results:
    pa_fields_context[page] = result
# Out:
#   You are given an array of dictionaries, each representing a form field extracted from a PDF. Each dictionary contains:
#   - "name": the field name
#   - "type": the field type (e.g., "text", "checkbox")
#   - "value": the field value (may be null)
#   - "page": the 1-based page number
#   - "field_type": the PDF widget type code
#   - "field_type_string": the PDF widget type as a string
#   - "field_label": the field label (may be null)
#
#   TASK:
#   1. Organize these fields into a hierarchical JSON tree grouped by page number.
#   2. For each page, create an array of fields, preserving all metadata.
#   3. The top-level JSON should be:
#   {
#     "pages": {
#       "1": [ ...fields... ],
#       "2": [ ...fields... ],
#       ...
#     }
#   }
#   4. Do not omit any fields or metadata.
#   5. Return only valid JSON (no markdown, no extra commentary).
#
#   Example output:
#   {
#     "pages": {
#       "1": [
#         {
#           "name": "T1",
#           "type": "text",
#           "value": "",
#           "page": 1,
#           "field_type": 2,
#           "field_type_string": "Text",
#           "field_label": "First Name"
#         },
#         ...
#       ],
#       "2": [
#         ...
#       ]
#     }
#   }
#
#   <PA_FIELDS>
#   {pa_fields}
#   </PA_FIELDS>
#
#   You are given an array of dictionaries, each representing a form field extracted from a PDF. Each dictionary contains:
#   - "name": the field name
#   - "type": the field type (e.g., "text", "checkbox")
#   - "value": the field value (may be null)
#   - "page": the 1-based page number
#   - "field_type": the PDF widget type code
#   - "field_type_string": the PDF widget type as a string
#   - "field_label": the field label (may be null)
#
#   TASK:
#   1. Organize these fields into a hierarchical JSON tree grouped by page number.
#   2. For each page, create an array of fields, preserving all metadata.
#   3. The top-level JSON should be:
#   {
#     "pages": {
#       "1": [ ...fields... ],
#       "2": [ ...fields... ],
#       ...
#     }
#   }
#   4. Do not omit any fields or metadata.
#   5. Return only valid JSON (no markdown, no extra commentary).
#
#   Example output:
#   {
#     "pages": {
#       "1": [
#         {
#           "name": "T1",
#           "type": "text",
#           "value": "",
#           "page": 1,
#           "field_type": 2,
#           "field_type_string": "Text",
#           "field_label": "First Name"
#         },
#         ...
#       ],
#       "2": [
#         ...
#       ]
#     }
#   }
#
#   <PA_FIELDS>
#   {pa_fields}
#   </PA_FIELDS>
#
#   You are given an array of dictionaries, each representing a form field extracted from a PDF. Each dictionary contains:
#   - "name": the field name
#   - "type": the field type (e.g., "text", "checkbox")
#   - "value": the field value (may be null)
#   - "page": the 1-based page number
#   - "field_type": the PDF widget type code
#   - "field_type_string": the PDF widget type as a string
#   - "field_label": the field label (may be null)
#
#   TASK:
#   1. Organize these fields into a hierarchical JSON tree grouped by page number.
#   2. For each page, create an array of fields, preserving all metadata.
#   3. The top-level JSON should be:
#   {
#     "pages": {
#       "1": [ ...fields... ],
#       "2": [ ...fields... ],
#       ...
#     }
#   }
#   4. Do not omit any fields or metadata.
#   5. Return only valid JSON (no markdown, no extra commentary).
#
#   Example output:
#   {
#     "pages": {
#       "1": [
#         {
#           "name": "T1",
#           "type": "text",
#           "value": "",
#           "page": 1,
#           "field_type": 2,
#           "field_type_string": "Text",
#           "field_label": "First Name"
#         },
#         ...
#       ],
#       "2": [
#         ...
#       ]
#     }
#   }
#
#   <PA_FIELDS>
#   {pa_fields}
#   </PA_FIELDS>
#
#   You are given an array of dictionaries, each representing a form field extracted from a PDF. Each dictionary contains:
#   - "name": the field name
#   - "type": the field type (e.g., "text", "checkbox")
#   - "value": the field value (may be null)
#   - "page": the 1-based page number
#   - "field_type": the PDF widget type code
#   - "field_type_string": the PDF widget type as a string
#   - "field_label": the field label (may be null)
#
#   TASK:
#   1. Organize these fields into a hierarchical JSON tree grouped by page number.
#   2. For each page, create an array of fields, preserving all metadata.
#   3. The top-level JSON should be:
#   {
#     "pages": {
#       "1": [ ...fields... ],
#       "2": [ ...fields... ],
#       ...
#     }
#   }
#   4. Do not omit any fields or metadata.
#   5. Return only valid JSON (no markdown, no extra commentary).
#
#   Example output:
#   {
#     "pages": {
#       "1": [
#         {
#           "name": "T1",
#           "type": "text",
#           "value": "",
#           "page": 1,
#           "field_type": 2,
#           "field_type_string": "Text",
#           "field_label": "First Name"
#         },
#         ...
#       ],
#       "2": [
#         ...
#       ]
#     }
#   }
#
#   <PA_FIELDS>
#   {pa_fields}
#   </PA_FIELDS>
# ```json
# {
#   "pages": {
#     "1": [
#       {
#         "name": "Phone",
#         "type": "text",
#         "value": "1-866-503-0857 (TTY: 711)",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax",
#         "type": "text",
#         "value": "1-844-268-7263",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity",
#         "type": "text",
#         "value": "https://www.aetna.com/health-care-professionals/resource-center/availity.html",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_2",
#         "type": "text",
#         "value": "1-855-463-0933",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_2",
#         "type": "text",
#         "value": "1-833-280-5224",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_2",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/virginia-hmosnp/providers/portal",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_3",
#         "type": "text",
#         "value": "1-844-362-0934",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_3",
#         "type": "text",
#         "value": "1-833-322-0034",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_3",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/new-jersey-hmosnp/providers/portal.html",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_4",
#         "type": "text",
#         "value": "1-866-600-2139",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "FAX_4",
#         "type": "text",
#         "value": "1-855-320-8445",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_4",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/illinois/providers/portal",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_5",
#         "type": "text",
#         "value": "1-855-364-0974",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_5",
#         "type": "text",
#         "value": "1-855-734-9389",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_5",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/ohio/providers/portal",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_6",
#         "type": "text",
#         "value": "1-855-676-5772",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_6",
#         "type": "text",
#         "value": "1-844-241-2495",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_6",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/michigan/providers/portal.html",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       }
#     ],
#     "2": [
#       {
#         "name": "Start of treatment",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Start date",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Start date"
#       },
#       {
#         "name": "Continuation of therapy",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Date of last treatment",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "First Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "First Name"
#       },
#       {
#         "name": "Last Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Last Name"
#       },
#       {
#         "name": "Address",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Address"
#       },
#       {
#         "name": "City",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "City"
#       },
#       {
#         "name": "State",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "State"
#       },
#       {
#         "name": "DOB",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "DOB"
#       },
#       {
#         "name": "Home Phone",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Home Phone"
#       },
#       {
#         "name": "Work Phone",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Work Phone"
#       },
#       {
#         "name": "Cell Phone",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Cell Phone"
#       },
#       {
#         "name": "ZIP",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "ZIP"
#       },
#       {
#         "name": "Current Weight Ibs or",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "kgs",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "kgs"
#       },
#       {
#         "name": "Height inches or",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "cms",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "cms"
#       },
#       {
#         "name": "E-mail",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "E-mail"
#       },
#       {
#         "name": "Allergies",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Allergies"
#       },
#       {
#         "name": "Member ID",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Member ID #"
#       },
#       {
#         "name": "Does patient have other coverage",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Group",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Group #"
#       },
#       {
#         "name": "If yes, provide ID",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Carrier Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Carrier Name"
#       },
#       {
#         "name": "Insured",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Insured"
#       },
#       {
#         "name": "Insured_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Insured"
#       },
#       {
#         "name": "First Name_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "First Name"
#       },
#       {
#         "name": "MD",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "DO",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "NP",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "PA",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Last Name_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Last Name"
#       },
#       {
#         "name": "Address_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Address"
#       },
#       {
#         "name": "City_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "City"
#       },
#       {
#         "name": "State_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "State"
#       },
#       {
#         "name": "ZIP_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "ZIP"
#       },
#       {
#         "name": "Phone_2_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Phone"
#       },
#       {
#         "name": "Fax_2_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Fax"
#       },
#       {
#         "name": "St Lic",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "St Lic #"
#       },
#       {
#         "name": "NPI",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "NPI #"
#       },
#       {
#         "name": "DEA",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "DEA #"
#       },
#       {
#         "name": "UPIN",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "UPIN"
#       },
#       {
#         "name": "Provider Email",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Provider Email"
#       },
#       {
#         "name": "Office Contact Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Office Contact Name"
#       },
#       {
#         "name": "Phone_3_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Phone"
#       },
#       {
#         "name": "Self-administered",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Physician's Office",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Outpatient Dialysis Center",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Physician's Office_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Home",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Retail Pharmacy",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Specialty Pharmacy",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Outpatient Infusion Center Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Mail Order",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Other",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Home Infusion Center Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Agency Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Agency Name"
#       },
#       {
#         "name": "Administration code(s) (CPT)",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Address_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Address"
#       },
#       {
#         "name": "Home_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Home"
#       },
#       {
#         "name": "City_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "City"
#       },
#       {
#         "name": "State_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "State"
#       },
#       {
#         "name": "ZIP_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "ZIP"
#       },
#       {
#         "name": "Phone_4_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Phone"
#       },
#       {
#         "name": "Fax_4_2",
#         "type": 2,
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Fax"
#       },
#       {
#         "name": "TIN",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "TIN"
#       },
#       {
#         "name": "PIN",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "PIN"
#       },
#       {
#         "name": "NPI",
#         "type": 2,
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "NPI"
#       },
#       {
#         "name": "TIN_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "TIN"
#       },
#       {
#         "name": "NPI_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "NPI"
#       },
#       {
#         "name": "Request is for Riabni rituximab-arrx",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Rituxan rituximab",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Ruxience rituximab-pvvr",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Truxima rituximab-abbs",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Dose",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Dose"
#       },
#       {
#         "name": "Directions for Use",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Directions for Use"
#       },
#       {
#         "name": "HCPCS Code",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "HCPCS Code"
#       },
#       {
#         "name": "Primary ICD Code",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Primary ICD Code"
#       },
#       {
#         "name": "Other ICD Code",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Other ICD Code"
#       },
#       {
#         "name": "Has the patient had prior therapy with the requested product within the last 365 days",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "No",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Has the patient had a trial and failure of any of the following rituximab biosimilars",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Ruxience rituximab-pvvr",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Truxima rituximab-abbs",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "When was the member's trial and failure of the preferred drug",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the failure of the preferred drug",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Has the patient had an adverse reaction to any of the following rituximab biosimilars",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Ruxience rituximab-pvvr_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Truxima rituximab-abbs_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "When was the member's adverse reaction to the preferred drug",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the adverse reaction to the preferred drug",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Ruxience rituximab-pvvr_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Truxima rituximab-abbs_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       }
#     ],
#     "3": [
#       {
#         "name": "Has the patient had a trial and failure of any of the following",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Inflectra infliximab-dyyb",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Renflexis infliximab-abda",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Simponi Aria golimumab",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "When was the member's trial and failure of the preferred drug",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the failure of the preferred drug",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Has the patient had an adverse reaction to any of the following",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Inflectra infliximab-dyyb_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Renflexis infliximab-abda_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Simponi Aria golimumab_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "When was the member's adverse reaction to the preferred drug",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the adverse reaction to the preferred drug",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Has the patient had a trial and failure of any of the following_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Enbrel etanercept",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Humira adalimumab",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Idacio adalimumab-aacf",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Rinvoq upadacitinib",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Tyenne SC tocilizumab-aazg",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "XeljanzXeljanz XR tofacitinib",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "When was the member's trial and failure of the preferred drug_2",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the failure of the preferred drug_2",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Has the patient had a trial and failure of any of the following_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Enbrel etanercept_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Humira adalimumab_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Idacio adalimumab-aacf_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Rinvoq upadacitinib_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Tyenne SC tocilizumab-aazg_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "XeljanzXeljanz XR tofacitinib_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "When was the member's adverse reaction to the preferred drug_2",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Please describe the nature of the adverse reaction to the preferred drug_2",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Inflectra infliximab-dyyb_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Renflexis infliximab-abda_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Simponi Aria golimumab_3",
#         "type": "checkbox",
#         "value": null,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Enbrel etanercept_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Humira adalimumab_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Idacio adalimumab-aacf_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Rinvoq upadacitinib_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Tyenne SC tocilizumab-aazg_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "XeljanzXeljanz XR tofacitinib_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Will Rituxan rituximab be used concomitantly with apremilast, tofacitinib, or other biologic DMARDs e.g., adalimumab, infliximab",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Does the patient have a documented diagnosis of Philadelphia chromosome-negative acute lymphoid leukemia ALL",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Is Rituxan rituximab being used as inductionconsolidation therapy",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Does the patient have a documented diagnosis of refractory autoimmune hemolytic anemia",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Wegener granulomatosis",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Churg-Strauss syndrome",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "microscopic polyangiitis",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "pauci-immune glomerulonephritis",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Will Rituxan rituximab be given in conjunction with glucocorticoids",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Does the patient have a documented diagnosis of corticosteroid-refractory autoimmune blistering disease",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "pemphigus vulgaris",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "pemphigus folliaceus",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "bullous pemphigoid",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "cicatricial pemphigoid",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "epidermolysis bullosa acquisita",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "paraneoplastic pemphigus",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "None of the above",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "AIDS-related B-cell lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Burkitt lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Diffuse large B-cell lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Follicular lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Gastric MALT lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "High-grade B-Cell lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Mantle cell lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Nodal marginal zone lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Nongastric MALT lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Primary cutaneous B-cell lymphomas",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Splenic marginal zone lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Other",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       }
#     ],
#     "4": [
#       {
#         "name": "Does the patient have a documented diagnosis of multicentric Castleman's disease angiofollicular lymph node hyperplasia",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "leptomeningeal metastases from lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "primary CNS lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "none of the above",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "chronic lymphocytic leukemia CLL",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "small lymphocytic leukemia",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "none of the above_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Does the patient have a documented diagnosis of cryoglobulinemia",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
# ...
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_OMA_Refractory_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_OMA_Refractory_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_Medication1",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Medication"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_Dates1",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Dates"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_Medication2",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Medication"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_Dates2",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Dates"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_PostTransplantLymphoproliferativeDisorder_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_PostTransplantLymphoproliferativeDisorder_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_EBVProphylaxis_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_EBVProphylaxis_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "No"
#       }
#     ],
#     "5": [
#       {
#         "name": "aetna_logo_image",
#         "type": "image",
#         "value": null,
#         "page": 5,
#         "field_type": 0,
#         "field_type_string": "Unknown",
#         "field_label": null
#       },
#       {
#         "name": "PatientFirstname",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient First Name"
#       },
#       {
#         "name": "PatientLastname",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient Last Name"
#       },
#       {
#         "name": "PatientPhone",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient Phone"
#       },
#       {
#         "name": "PatientDOB",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Patient DOB"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_RheumatoidArthritis_Severity_Mild",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "Mild"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_RheumatoidArthritis_Severity_Moderate",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "Moderate"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_RheumatoidArthritis_Severity_Severe",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "Severe"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_RheumatoidArthritis_DiseaseActive_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_RheumatoidArthritis_DiseaseActive_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_RheumatoidArthritis_RituxanMethotrexate_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_RheumatoidArthritis_RituxanMethotrexate_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_RheumatoidArthritis_MethotrexateIneffective_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_RheumatoidArthritis_MethotrexateIneffective_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_RheumatoidArthritis_MethotrexateStatus_Ineffective",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "ineffective"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_RheumatoidArthritis_MethotrexateStatus_NotTolerated",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "not tolerated"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_RheumatoidArthritis_MethotrexateStatus_Contraindicated",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "contraindicated"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_RheumatoidArthritis_DMARDIneffective_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_RheumatoidArthritis_DMARDIneffective_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_RheumatoidArthritis_DMARDType_Azathioprine",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "azathioprine"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_RheumatoidArthritis_DMARDType_Cyclosporine",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "cyclosporine"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_RheumatoidArthritis_DMARDType_Hydroxychloroquine",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "hydroxychloroquine"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_RheumatoidArthritis_DMARDType_Leflunomide",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "leflunomide"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_RheumatoidArthritis_DMARDType_Sulfasalazine",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "sulfasalazine"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_SjogrenSyndrome_Diagnosis_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_SjogrenSyndrome_Diagnosis_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_SjogrenSyndrome_TreatmentIneffective_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_SjogrenSyndrome_TreatmentIneffective_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_SjogrenSyndrome_Medication1",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Medication"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_SjogrenSyndrome_Dates1",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Dates"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_SjogrenSyndrome_Medication2",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Medication"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_SjogrenSyndrome_Dates2",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Dates"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_ThromboticThrombocytopenicPurpura_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_ThromboticThrombocytopenicPurpura_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_WaldenstromsMacroglobulinemia_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_WaldenstromsMacroglobulinemia_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_ContinuationRequests_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_ContinuationRequests_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_ContinuationRequests_LengthOfTime",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Please indicate the length of time on Rituxan (rituximab)"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_RheumatoidArthritisOnly_Severity_Mild",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "Mild"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_RheumatoidArthritisOnly_Severity_Moderate",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "Moderate"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_RheumatoidArthritisOnly_Severity_Severe",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "Severe"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_RheumatoidArthritisOnly_DiseaseStability_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_RheumatoidArthritisOnly_DiseaseStability_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_RheumatoidArthritisOnly_DiseaseImprovement_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_RheumatoidArthritisOnly_DiseaseImprovement_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_AllOtherIndications_DiseaseStability_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_AllOtherIndications_DiseaseStability_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_AllOtherIndications_DiseaseImprovement_Yes",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "Yes"
#       },
#       {
#         "name": "CLINICAL_INFORMATION_AllOtherIndications_DiseaseImprovement_No",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": "No"
#       },
#       {
#         "name": "ACKNOWLEDGEMENT_RequestCompletedBy",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Request Completed By (Signature Required)"
#       },
#       {
#         "name": "ACKNOWLEDGEMENT_Date",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": "Date"
#       }
#     ]
#   }
# }
# ```
# ---------------------------------

# %%
# Create PA_form_analysis from pa_fields_context
# This combines all the processed PA field data into a single analysis

if 'pa_fields_context' in locals() and pa_fields_context:
    # Combine all page results into a single analysis
    PA_form_analysis = ""
    for page, result in pa_fields_context.items():
        PA_form_analysis += f"PAGE {page}:\n{result}\n\n"
    print("✅ PA_form_analysis created successfully!")
    print(f"Length: {len(PA_form_analysis)} characters")
else:
    # Fallback: create from raw pa_fields if pa_fields_context isn't ready
    PA_form_analysis = json.dumps(pa_fields, indent=2)
    print("⚠️  Using fallback: PA_form_analysis created from raw pa_fields")
    print("Note: Run cell 12 first to get processed analysis")

print("PA_form_analysis preview:")
print(PA_form_analysis)
# Out:
# ✅ PA_form_analysis created successfully!
# Length: 271530 characters
# PA_form_analysis preview:
# PAGE 2:
# ```json
# {
#   "pages": {
#     "1": [
#       {
#         "name": "Phone_2",
#         "type": "text",
#         "value": "1-866-503-0857",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax",
#         "type": "text",
#         "value": "1-844-268-7263",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity",
#         "type": "text",
#         "value": "https://www.aetna.com/health-care-professionals/resource-center/availity.html",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_4",
#         "type": "text",
#         "value": "1-855-463-0933",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_2",
#         "type": "text",
#         "value": "1-833-280-5224",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_2",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/virginia-hmosnp/providers/portal",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_6",
#         "type": "text",
#         "value": "1-844-362-0934",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_3",
#         "type": "text",
#         "value": "1-833-322-0034",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_3",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/new-jersey-hmosnp/providers/portal.html",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_8",
#         "type": "text",
#         "value": "1-866-600-2139",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_4",
#         "type": "text",
#         "value": "1-855-320-8445",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_4",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/illinois/providers/portal",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_10",
#         "type": "text",
#         "value": "1-855-364-0974",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_5",
#         "type": "text",
#         "value": "1-855-734-9389",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_5",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/ohio/providers/portal",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_12",
#         "type": "text",
#         "value": "1-855-676-5772",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_6",
#         "type": "text",
#         "value": "1-844-241-2495",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Availity_6",
#         "type": "text",
#         "value": "https://www.aetnabetterhealth.com/michigan/providers/portal.html",
#         "page": 1,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       }
#     ],
#     "2": [
#       {
#         "name": "StartDate",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "ContinuationTherapyDate",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_13",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_7",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "FirstName",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "LastName",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Address",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "City",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "State",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "DOB",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "ZIP",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "HomePhone",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "WorkPhone",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "CellPhone",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Email",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "CurrentWeight_lbs",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "CurrentWeight_kgs",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Height_inches",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Height_cms",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Allergies",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "MemberID",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Yes_5",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "No_5",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "CarrierName",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "GroupID",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Insured",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "FirstName_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "LastName_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "CheckOne_MD",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "CheckOne_DO",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "CheckOne_NP",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "CheckOne_PA",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Address_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "City_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "State_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "ZIP_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_14",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_8",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "StLic",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "NPI",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "DEA",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "UPIN",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "ProviderEmail",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "OfficeContactName",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_15",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "SelfAdministered",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "PhysiciansOffice",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Home",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "OutpatientInfusionCenterName",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "HomeInfusionCenterAgencyName",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_16",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "AdminCodes",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Address_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "City_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "State_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "ZIP_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_17",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "TIN",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "NPI_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "OutpatientDialysisCenter",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "PhysiciansOffice_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "RetailPharmacy",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "SpecialtyPharmacy",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "MailOrder",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Other",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Name",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Address_4",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "City_4",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "State_4",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "ZIP_4",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Phone_18",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Fax_9",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "PIN",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "TIN_2",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "NPI_3",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Riabni",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Rituxan",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Ruxience",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Truxima",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Dose",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "DirectionsForUse",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "HCPCSCode",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "PrimaryICDCode",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "OtherICDCode",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Yes_6",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "No_6",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "No_7",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Ruxience_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Truxima_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "FailureDate",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "FailureDescription",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "No_8",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Ruxience_4",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Truxima_4",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "AdverseReactionDate",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "AdverseReactionDescription",
#         "type": "text",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Ruxience_5",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Truxima_5",
#         "type": "checkbox",
#         "value": null,
#         "page": 2,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       }
#     ],
#     "3": [
#       {
#         "name": "PatientFirstName",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "PatientLastName",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "PatientPhone",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "PatientDOB",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Yes_7",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "No_9",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Inflectra",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Renflexis",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "SimponiAria",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "TrialFailureDate",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "TrialFailureDescription",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "No_10",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Inflectra_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Renflexis_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "SimponiAria_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "AdverseReactionDate_2",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "AdverseReactionDescription_2",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "No_11",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Enbrel",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Humira",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Idacio",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Rinvoq",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "TyenneSC",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Xeljanz",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "TrialFailureDate_2",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "TrialFailureDescription_2",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "No_12",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Enbrel_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Humira_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Idacio_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Rinvoq_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "TyenneSC_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Xeljanz_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "AdverseReactionDate_3",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "AdverseReactionDescription_3",
#         "type": "text",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Inflectra_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Renflexis_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "SimponiAria_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Enbrel_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Humira_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Idacio_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Rinvoq_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "TyenneSC_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Xeljanz_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Yes_8",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "No_13",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Yes_9",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "No_14",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Yes_10",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "No_15",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Yes_11",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "No_16",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "WegenerGranulomatosis",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "MicroscopicPolyangiitis",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "ChurgStraussSyndrome",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "PauciImmuneGlomerulonephritis",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Yes_12",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "No_17",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Yes_13",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "No_18",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "PemphigusVulgaris",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "PemphigusFolliaceus",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "BullousPemphigoid",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "CicatricialPemphigoid",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "EpidermolysisBullosaAcquisita",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "ParaneoplasticPemphigus",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "NoneOfTheAbove",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "AIDSRelatedBCellLymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "BurkittLymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "DiffuseLargeBCellLymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "FollicularLymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "GastricMALTLymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "HighGradeBCellLymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "MantleCellLymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "NodalMarginalZoneLymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "NongastricMALTLymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "PrimaryCutaneousBCellLymphomas",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "SplenicMarginalZoneLymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Other_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 3,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       }
#     ],
#     "4": [
#       {
#         "name": "PatientFirstName_2",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "PatientLastName_2",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "PatientPhone_2",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "PatientDOB_2",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Yes_14",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "No_19",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "LeptomeningealMetastasesFromLymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "PrimaryCNSLymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "NoneOfTheAbove_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "ChronicLymphocyticLeukemia",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "SmallLymphocyticLeukemia",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "NoneOfTheAbove_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Yes_15",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "No_20",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Yes_16",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "No_21",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Yes_17",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "No_22",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "RelapsedHairyCellLeukemia",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "RefractoryHairyCellLeukemia",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "NoneOfTheAbove_4",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Yes_18",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "No_23",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "HeartTransplantRecipient",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "OtherSolidOrganTransplantRecipient",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Bavencio",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Imfinzi",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Keytruda",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Opdivo",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Tecentriq",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Yervoy",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
#         "field_label": null
#       },
#       {
#         "name": "Other_3",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Checkbox",
# ...
#       },
#       {
#         "name": "Is there a documentation that Rituxan rituximab is being used for treatment or prevention desensitization of highly sensitized patients with antibody mediated rejection in heart transplant recipients and other solid organ transplant recipients",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "heart transplant recipient",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "other solid organ transplant recipient",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Bavencio avelumab",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Imfinzi durvalumab",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Keytruda pembrolizumab",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Opdivo nivolumab",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Tecentriq atezolizumab",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Yervoy ipilimumab",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Other_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Does the patient have a documented diagnosis of refractory immune or idiopathic thrombocytopenic purpura ITP",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "refractory immune thrombocytopenic purpura",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "idiopathic thrombocytopenic purpura ITP",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Is Rituxan rituximab being used as rejection prophylaxis in sensitized kidney transplant recipients with donor specific antibodies",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Does the patient have a documented diagnosis of lymphocyte-predominant Hodgkin's lymphoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Relapsing-remitting MS RRMS",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Secondary-progressive MS SPMS",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Primary-progressive MS PPMS",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Progressive-relapsing MS PRMS",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Has the patient discontinued other medications used for treating MS not including Ampyra",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Does the patient have a documented diagnosis of muscle-specific tyrosine kinase myasthenia gravis MuSk-MG",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Has the patient had an unsatisfactory response to initial immunotherapy",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Does the patient have a documented diagnosis of neuromyelitis optica Devic's disease",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Was the treatment with at least one immunotherapy ineffective",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Does the patient have a documented diagnosis of opsoclonus-myoclonus-ataxia OMA associated with neuroblastoma",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Is the patient refractory to steroids, chemotherapy and intravenous immunoglobulins",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Medication",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Dates",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Medication_2",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Dates_2",
#         "type": "text",
#         "value": null,
#         "page": 4,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Is Rituxan rituximab being used as treatment of post-transplant lymphoproliferative disorder",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Is Rituxan rituximab being used as prophylaxis for Epstein-Barr virus EBV post-transplant lymphoproliferative disorder",
#         "type": "checkbox",
#         "value": null,
#         "page": 4,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       }
#     ],
#     "5": [
#       {
#         "name": "Please indicate the severity of the patient's rheumatoid arthritis Mild",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Moderate",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Severe",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Is there evidence that the disease is active",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Will Rituxan rituximab be used in combination with methotrexate",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Was treatment with methotrexate ineffective, not tolerated or contraindicated",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "ineffective",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "not tolerated",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "contraindicated",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Was treatment with another conventional DMARD ineffective",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "azathioprine",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "cyclosporine",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "hydroxychloroquine",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "leflunomide",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "sulfasalazine",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Does the patient have a documented diagnosis of Sjögren's syndrome",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Was treatment with corticosteroids and other immunosuppressive agents ineffective",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Medication_3",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Dates_3",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Medication_4",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Dates_4",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Does the patient have a documented diagnosis of refractory thrombotic thrombocytopenic purpura TTP",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Does the patient have a documented diagnosis of Waldenström macroglobulinemia",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Is this continuation request a result of the patient receiving samples of Rituxan rituximab",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Please indicate the severity of the disease at baseline pretreatment with Rituxan rituximab Mild",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Moderate_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Severe_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Is there clinical documentation supporting disease stability",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Is there clinical documentation supporting disease improvement",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Is there clinical documentation supporting disease stability_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Is there clinical documentation supporting disease improvement_2",
#         "type": "checkbox",
#         "value": null,
#         "page": 5,
#         "field_type": 8,
#         "field_type_string": "Button",
#         "field_label": null
#       },
#       {
#         "name": "Request Completed By Signature Required",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       },
#       {
#         "name": "Date",
#         "type": "text",
#         "value": null,
#         "page": 5,
#         "field_type": 2,
#         "field_type_string": "Text",
#         "field_label": null
#       }
#     ]
#   }
# }
# ```

# %%
pa_fields_context
# Out:
# {2: '```json\n{\n  "pages": {\n    "1": [\n      {\n        "name": "Phone_2",\n        "type": "text",\n        "value": "1-866-503-0857",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax",\n        "type": "text",\n        "value": "1-844-268-7263",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity",\n        "type": "text",\n        "value": "https://www.aetna.com/health-care-professionals/resource-center/availity.html",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_4",\n        "type": "text",\n        "value": "1-855-463-0933",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_2",\n        "type": "text",\n        "value": "1-833-280-5224",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_2",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/virginia-hmosnp/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_6",\n        "type": "text",\n        "value": "1-844-362-0934",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_3",\n        "type": "text",\n        "value": "1-833-322-0034",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_3",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/new-jersey-hmosnp/providers/portal.html",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_8",\n        "type": "text",\n        "value": "1-866-600-2139",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_4",\n        "type": "text",\n        "value": "1-855-320-8445",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_4",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/illinois/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_10",\n        "type": "text",\n        "value": "1-855-364-0974",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_5",\n        "type": "text",\n        "value": "1-855-734-9389",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_5",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/ohio/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_12",\n        "type": "text",\n        "value": "1-855-676-5772",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_6",\n        "type": "text",\n        "value": "1-844-241-2495",\n        "page": 1,\n        "field_type": 2,\n        "field_t ...
#  3: '```json\n{\n  "pages": {\n    "1": [\n      {\n        "name": "Phone: 1-866-503-0857 (TTY: 711)",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax: 1-844-268-7263",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity: https://www.aetna.com/health-care-professionals/resource-center/availity.html",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone: 1-855-463-0933",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax: 1-833-280-5224",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity: https://www.aetnabetterhealth.com/virginia-hmosnp/providers/portal",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone: 1-844-362-0934",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax: 1-833-322-0034",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity: https://www.aetnabetterhealth.com/new-jersey-hmosnp/providers/portal.html",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone: 1-866-600-2139",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "FAX: 1-855-320-8445",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity: https://www.aetnabetterhealth.com/illinois/providers/portal",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone: 1-855-364-0974",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax: 1-855-734-9389",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity: https://www.aetnabetterhealth.com/ohio/providers/portal",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone: 1-855-676-5772",\n        "type": "text",\n        "value": null,\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax: 1-844-241-2495",\n        "type": "text",\n        "value": null,\n        "page": ...
#  4: '```json\n{\n  "pages": {\n    "1": [\n      {\n        "name": "aetna_logo_image",\n        "type": "image",\n        "value": null,\n        "page": 1,\n        "field_type": 0,\n        "field_type_string": "Unknown",\n        "field_label": null\n      }\n    ],\n    "2": [\n      {\n        "name": "aetna_logo_image",\n        "type": "image",\n        "value": null,\n        "page": 2,\n        "field_type": 0,\n        "field_type_string": "Unknown",\n        "field_label": null\n      },\n      {\n        "name": "Date",\n        "type": "text",\n        "value": null,\n        "page": 2,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": "start date"\n      },\n      {\n        "name": "Yes",\n        "type": "checkbox",\n        "value": null,\n        "page": 2,\n        "field_type": 8,\n        "field_type_string": "Button",\n        "field_label": "Start of treatment"\n      },\n      {\n        "name": "Yes_2",\n        "type": "checkbox",\n        "value": null,\n        "page": 2,\n        "field_type": 8,\n        "field_type_string": "Button",\n        "field_label": "Continuation of therapy"\n      },\n      {\n        "name": "Date_2",\n        "type": "text",\n        "value": null,\n        "page": 2,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": "date of last treatment"\n      },\n      {\n        "name": "Phone",\n        "type": "text",\n        "value": null,\n        "page": 2,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax",\n        "type": "text",\n        "value": null,\n        "page": 2,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "PATIENT_INFORMATION_FirstName",\n        "type": "text",\n        "value": null,\n        "page": 2,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": "First Name"\n      },\n      {\n        "name": "PATIENT_INFORMATION_LastName",\n        "type": "text",\n        "value": null,\n        "page": 2,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": "Last Name"\n      },\n      {\n        "name": "PATIENT_INFORMATION_DOB",\n        "type": "text",\n        "value": null,\n        "page": 2,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": "DOB"\n      },\n      {\n        "name": "PATIENT_INFORMATION_Address",\n        "type": "text",\n        "value": null,\n        "page": 2,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": "Address"\n      },\n      {\n        "name": "PATIENT_INFORMATION_City",\n        "type": "text",\n        "value": null,\n        "page": 2,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": "City"\n      },\n      {\n        "name": "PATIENT_INFORMATION_State",\n        "type": "text",\n        "value": null,\n        "page": 2,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": "State"\n      },\n      {\n        "name": "PATIENT_INFORMATION_ZIP",\n        "type": "text",\n        "value": null,\n        "page": 2,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": "ZIP"\n      },\n      {\n        "name": "PATIENT_INFORMATION_HomePhone",\n        "type": "text",\n        "value": null,\n        "page": 2,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": "Home Phone"\n      },\n      {\n        "name": "PATIENT_INFORMATION_WorkPhone",\n        "type": "text",\n        "value": null,\n        "page": 2,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": "Work Phone"\n      },\n      {\n        "name": "PATIENT_INFORMATION_CellPhone",\n        "type": "text" ...
#  5: '```json\n{\n  "pages": {\n    "1": [\n      {\n        "name": "Phone",\n        "type": "text",\n        "value": "1-866-503-0857 (TTY: 711)",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax",\n        "type": "text",\n        "value": "1-844-268-7263",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity",\n        "type": "text",\n        "value": "https://www.aetna.com/health-care-professionals/resource-center/availity.html",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_2",\n        "type": "text",\n        "value": "1-855-463-0933",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_2",\n        "type": "text",\n        "value": "1-833-280-5224",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_2",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/virginia-hmosnp/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_3",\n        "type": "text",\n        "value": "1-844-362-0934",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_3",\n        "type": "text",\n        "value": "1-833-322-0034",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_3",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/new-jersey-hmosnp/providers/portal.html",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_4",\n        "type": "text",\n        "value": "1-866-600-2139",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "FAX_4",\n        "type": "text",\n        "value": "1-855-320-8445",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_4",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/illinois/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_5",\n        "type": "text",\n        "value": "1-855-364-0974",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_5",\n        "type": "text",\n        "value": "1-855-734-9389",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Availity_5",\n        "type": "text",\n        "value": "https://www.aetnabetterhealth.com/ohio/providers/portal",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Phone_6",\n        "type": "text",\n        "value": "1-855-676-5772",\n        "page": 1,\n        "field_type": 2,\n        "field_type_string": "Text",\n        "field_label": null\n      },\n      {\n        "name": "Fax_6",\n        "type": "text",\n        "value": "1-844-241-2495",\n        "page": 1,\n        "field_type": 2,\n        " ...

# %% [markdown]
# ## form filling strategy

# %%
# 🤖 INTELLIGENT AUTO-MAPPING: Let AI map actual field names to patient data
print("🤖 Creating intelligent automated field mapping...")

# Get all actual PDF fields with their labels
doc = fitz.open("Input Data/Adbulla/PA.pdf")
pdf_fields = []
for page_num in range(len(doc)):
    page = doc[page_num]
    for widget in page.widgets():
        if widget.field_name and widget.field_label:
            pdf_fields.append({
                'field_name': widget.field_name,
                'field_type': widget.field_type_string,
                'field_label': widget.field_label,
                'page': page_num + 1
            })
doc.close()

    # Fill PDF with AI mappings - Enhanced with debugging
def fill_pdf_with_ai_mappings(input_pdf_path, output_pdf_path, mappings):
    doc = fitz.open(input_pdf_path)
    filled_count = 0
    skipped_count = 0
    unmapped_count = 0
    
    print(f"🔧 Starting PDF filling with {len(mappings)} mappings...")
    
    for page_num in range(len(doc)):
        page = doc[page_num]
        
        for widget in page.widgets():
            field_name = widget.field_name
            
            if field_name in mappings:
                value = mappings[field_name]
                
                # Skip empty values
                if value == "" or value is None:
                    skipped_count += 1
                    continue
                
                try:
                    if widget.field_type == fitz.PDF_WIDGET_TYPE_CHECKBOX:
                        widget.field_value = bool(value)
                    elif widget.field_type == fitz.PDF_WIDGET_TYPE_TEXT:
                        widget.field_value = str(value)
                    else:
                        print(f"⚠️  Unknown field type for {field_name}: {widget.field_type}")
                        continue
                    
                    widget.update()
                    filled_count += 1
                    print(f"✅ {field_name}: {value}")
                    
                except Exception as e:
                    print(f"⚠️  Error filling {field_name}: {e}")
            else:
                unmapped_count += 1
                # Debug: Show unmapped fields (first 50 only)
                if unmapped_count < 50:
                    print(f"🔍 Field '{field_name}' not in mappings (Page {page.number + 1})")
    
    print(f"📊 Summary: {filled_count} fields filled, {skipped_count} skipped (empty values), {unmapped_count} not in mappings.")
    doc.save(output_pdf_path)
    doc.close()
    return filled_count
# Out:
# 🤖 Creating intelligent automated field mapping...

# %%
# 🚀 IMPROVED INTELLIGENT AUTO-MAPPING with Enhanced Coverage
print("🚀 Creating ENHANCED intelligent automated field mapping...")

# Enhanced mapping prompt that addresses all the gaps
enhanced_mapping_prompt = f"""You are an expert medical form automation specialist. Create comprehensive JSON mapping for a Prior Authorization form.

Pay attention to the whole context of the form and the patient data. And pay attention to this whole prompt including the middle parts

CRITICAL REQUIREMENTS:
1. Fill ALL possible fields where patient data is available
2. Handle checkbox dependencies (if main checkbox is checked, fill related sub-fields)
3. Include product/treatment information from clinical data
4. Use medical terminology appropriately
5. Format dates correctly for each field type
6. Handle multiple choice selections intelligently
7. NEVER use placeholder text like "(From Clinical Data)" - use actual data or leave blank

PDF FIELDS AVAILABLE:
{json.dumps(pdf_fields[:80], indent=2)}

PATIENT DATA AVAILABLE:
{referral_data}

SPECIFIC MAPPING INSTRUCTIONS:

A. PATIENT INFORMATION SECTION:
- Map full name to separate first/last name fields
- Map complete address (street, city, state, zip)
- Map all phone numbers (home, work, cell)
- Map DOB in correct format
- Map patient demographics

B. INSURANCE INFORMATION:
- Map member ID, group number, insured name
- Check for secondary coverage and map if available
- Map insurance carrier information

C. PRESCRIBER INFORMATION - CRITICAL RULES:
- Look for "Provider Contact Information" or similar headings in the clinical data
- Search for doctor/physician names in message records or clinical notes for inference if no difinitive contact information is found
- Extract actual prescriber contact details (address, phone, fax)
- Look for NPI numbers, DEA numbers in provider sections
- Check credentials (M.D., D.O., N.P., P.A.) from provider information
- If prescriber information is not clearly available, LEAVE FIELDS BLANK
- DO NOT use placeholder text like "Prescriber Address (From Clinical Data)"

D. TREATMENT/PRODUCT INFORMATION - ENHANCED SEARCH:
- Look for headings containing "Product", "Medication", "Drug", "Treatment"
- Search doctor comments and clinical notes for prescribed medications
- Look for drug names, dosages, frequencies in clinical documentation
- Check for diagnosis codes (ICD-10) in clinical data
- Search for treatment justification in physician notes
- If specific product/medication is not found, LEAVE FIELDS BLANK

E. DISPENSING/ADMINISTRATION:
- Determine administration method from clinical data
- Map pharmacy/dispensing location if specified
- Map administration codes if available

F. CHECKBOX LOGIC:
- If "Start of treatment" is checked, fill start date fields
- If "Continuation of therapy" is checked, fill last treatment date
- For dispensing location, check appropriate option based on data
- For prescriber type, check M.D., D.O., N.P., or P.A. based on credentials

G. DATE FORMATTING:
- For separate MM/DD/YYYY fields, split dates accordingly
- For single date fields, use MM/DD/YYYY format
- Extract dates from clinical timeline

H. MISSING DATA HANDLING - STRICT RULES:
- Only map fields where you have ACTUAL, SPECIFIC subject data
- If information is not clearly available in the clinical data, LEAVE THE FIELD BLANK
- Do not guess, weakly infer, or fabricate information
- Do not use placeholder text or generic descriptions
- Better to have fewer accurate fields than many inaccurate ones

SEARCH STRATEGY FOR PRESCRIBER INFO:
1. Search for "Provider Contact", "Physician Contact", "Doctor Information"
2. Look in message records for sender/physician information
3. Check clinical notes for prescribing physician details
4. If no specific prescriber info found, leave prescriber fields blank

SEARCH STRATEGY FOR PRODUCT INFO:
1. Look for explicit "Product" or "Medication" sections
2. Search doctor comments for drug names and prescriptions
3. Check treatment plans for specific medications
4. Look for pharmaceutical names in clinical documentation
5. If no specific product found, leave product fields blank

OUTPUT FORMAT - CRITICAL JSON REQUIREMENTS:
1. Return ONLY valid JSON (no markdown blocks, no extra text)
2. Ensure all JSON brackets and braces are properly closed
3. Use double quotes for all strings
4. Boolean values must be true/false (not True/False)
5. Do not truncate the JSON response

{{
  "field_mappings": {{
    "T12": "Shakh",
    "T13": "Abdulla", 
    "CB1": true,
    "T2": "05",
    "T3": "22", 
    "T4": "2024",
    "CB5": false,
    "T14": "04/01/2001",
    "T15": "425 Sherman Ave APT D",
    "T16": "Nashville",
    "T17": "TN",
    "T18": "37995"
  }},
  "mapping_notes": {{
    "total_fields_mapped": 0,
    "sections_completed": [],
    "missing_data_areas": [],
    "checkbox_decisions": {{}}
  }}
}}

IMPORTANT: Complete the entire JSON response. Do not truncate or cut off the JSON in the middle.

ANALYZE THE CLINICAL DATA THOROUGHLY and create comprehensive mappings using ONLY actual data found."""

# Send enhanced prompt to Gemini
print("🧠 Asking AI for ENHANCED comprehensive field mappings...")
# Extract structured data from referral package using Gemini vision
enhanced_response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents=[enhanced_mapping_prompt]
)


# Extract and apply enhanced mappings with ROBUST error handling
def robust_json_parser(json_text):
    """Advanced JSON parser that handles common formatting issues and truncation"""
    import re
    
    # Step 1: Extract JSON content
    if "```json" in json_text:
        json_start = json_text.find("```json") + 7
        json_end = json_text.find("```", json_start)
        if json_end == -1:  # No closing ```
            json_content = json_text[json_start:].strip()
        else:
            json_content = json_text[json_start:json_end].strip()
    else:
        json_content = json_text.strip()
    
    # Step 2: Try direct parsing first
    try:
        return json.loads(json_content)
    except json.JSONDecodeError:
        pass
    
    # Step 3: Advanced cleaning and repair
    print("🔧 Applying advanced JSON repair...")
    
    # Fix common issues
    json_content = re.sub(r'"CB\d+": tr(?![ue])', lambda m: m.group(0).replace('tr', 'true'), json_content)
    json_content = re.sub(r'"CB\d+": fa(?![lse])', lambda m: m.group(0).replace('fa', 'false'), json_content)
    
    # Step 4: Extract field mappings manually using regex
    field_mappings = {}
    
    # Pattern for text fields: "T12": "value"
    text_pattern = r'"(T\d+(?:\.\d+)?|CB\d+|Provider Admin [^"]+)"\s*:\s*"([^"]*)"'
    for match in re.finditer(text_pattern, json_content):
        field_mappings[match.group(1)] = match.group(2)
    
    # Pattern for boolean fields: "CB1": true/false
    bool_pattern = r'"(T\d+(?:\.\d+)?|CB\d+|Provider Admin [^"]+)"\s*:\s*(true|false)'
    for match in re.finditer(bool_pattern, json_content):
        field_mappings[match.group(1)] = match.group(2) == 'true'
    
    # Pattern for null fields: "T1": null
    null_pattern = r'"(T\d+(?:\.\d+)?|CB\d+|Provider Admin [^"]+)"\s*:\s*null'
    for match in re.finditer(null_pattern, json_content):
        field_mappings[match.group(1)] = None
    
    if field_mappings:
        print(f"✅ Extracted {len(field_mappings)} field mappings using regex parsing")
        return {"field_mappings": field_mappings, "mapping_notes": {"extraction_method": "regex"}}
    
    # Step 5: Last resort - create minimal mapping from visible data
    print("⚠️  Using fallback minimal mapping")
    return {
        "field_mappings": {
            "T12": "Shakh",
            "T13": "Abdulla", 
            "T14": "04/01/2001",
            "T15": "425 Sherman Aves APT D",
            "T16": "Nashville",
            "T17": "TN",
            "T18": "37923"
        },
        "mapping_notes": {"extraction_method": "fallback"}
    }

try:
    # Use the robust parser
    enhanced_mappings = robust_json_parser(enhanced_response.text)
    
    enhanced_field_mappings = enhanced_mappings.get("field_mappings", {})
    mapping_notes = enhanced_mappings.get("mapping_notes", {})
    
    print(f"\n🎯 ENHANCED AI created {len(enhanced_field_mappings)} comprehensive field mappings")
    
    # Show mapping summary
    if mapping_notes:
        print(f"📊 Total fields mapped: {mapping_notes.get('total_fields_mapped', len(enhanced_field_mappings))}")
        print(f"📋 Sections completed: {', '.join(mapping_notes.get('sections_completed', []))}")
        if mapping_notes.get('missing_data_areas'):
            print(f"⚠️  Missing data areas: {', '.join(mapping_notes.get('missing_data_areas', []))}")
    
    # Show sample enhanced mappings
    print("\nSample enhanced mappings:")
    for i, (field, value) in enumerate(list(enhanced_field_mappings.items())[:8]):
        print(f"  • {field} → {value}")
    
    # Apply enhanced mappings to PDF
    output_pdf_enhanced = "Input Data/Adbulla/PA_FILLED_ENHANCED.pdf"
    filled_count = fill_pdf_with_ai_mappings("Input Data/Adbulla/PA.pdf", output_pdf_enhanced, enhanced_field_mappings)
    
    print(f"\n🎉 ENHANCED MAPPING SUCCESS!")
    print(f"✅ Filled {filled_count} fields using enhanced AI mapping")
    print(f"📄 Enhanced PDF saved as: {output_pdf_enhanced}")
    
    # Compare with previous version
    previous_count = len(field_mappings) if 'field_mappings' in locals() else 0
    improvement = filled_count - previous_count
    if improvement > 0:
        print(f"🚀 IMPROVEMENT: +{improvement} more fields filled than previous version!")
    
except Exception as e:
    print(f"❌ Error in enhanced mapping: {e}")
    print("Full enhanced response:")
    print(enhanced_response.text)
# Out:
# 🚀 Creating ENHANCED intelligent automated field mapping...
# 🧠 Asking AI for ENHANCED comprehensive field mappings...
#
# 🎯 ENHANCED AI created 80 comprehensive field mappings
# 📊 Total fields mapped: 45
# 📋 Sections completed: Patient Information, Treatment Type / Dates, Requesting Party, Insurance Information, Prescriber Information, Dispensing/Administration Location
# ⚠️  Missing data areas: Patient work phone, email, weight, height, Secondary insurance details, Prescriber State License #, DEA #, UPIN, Email, Office Contact Name and Phone, Administration facility's fax, TIN, PIN, NPI, or specific CPT administration codes
#
# Sample enhanced mappings:
#   • CB1 → True
#   • T2 → 05
#   • T3 → 22
#   • T4 → 2024
#   • CB5 → False
#   • T6 →
#   • T7 →
#   • T8 →
# 🔧 Starting PDF filling with 80 mappings...
# ✅ CB1: True
# ✅ T2: 05
# ✅ T3: 22
# ✅ T4: 2024
# ✅ CB5: False
# ✅ T9: Erfan Rostami, BSN, RN
# ✅ T10: 615-343-1176
# ✅ T11: 615-343-1219
# ✅ T12: Shakh
# ✅ T13: Abdulla
# ✅ T14: 04/01/2001
# ✅ T15: 425 Sherman Aves APT D
# ✅ T16: Nashville
# ✅ T17: TN
# ✅ T18: 37923
# ✅ T19: 865-395-3958
# ✅ T21: 865-395-0481
# ✅ T23: No Known Allergies
# ✅ T28: LAJM14345116
# ✅ T29: 435000
# ✅ T30: Abdulla, Shakh
# ✅ CB31: False
# ✅ CB32: True
# ✅ T42: Hao H
# ✅ T43: Gu
# ✅ CB44: True
# ✅ CB45: False
# ✅ CB46: False
# ✅ CB47: False
# ✅ T48: 3320 Montgomery Dr
# ✅ T49: Nashville
# ✅ T50: TN
# ✅ T51: 37361
# ✅ T52: 614-936-0065
# ✅ T53: 615-562-4820
# ✅ T55: 1154611523
# ✅ Provider Admin CB.1: False
# ✅ Provider Admin CB.2: False
# ✅ Provider Admin CB.3: False
# ✅ Provider Admin CB.4: True
# ✅ Provider Admin T.5: Children's Hematology - Oncology (Peds DOT 6)
# ✅ Provider Admin CB.7: False
# ✅ Provider Admin T.6: 615-936-1762
# ✅ Provider Admin CB.10: False
# ✅ Provider Admin T.11A: 2211 Broad Way, Tower 4th FL, Suite 6102
# ✅ Provider Admin T.13: Nashville
# ✅ Provider Admin T.14: TN
# ✅ Provider Admin T.15: 37232
# ✅ Provider Admin T.16: 615-936-1762
# ✅ Provider Admin CB.21: False
# ✅ Provider Admin CB.22: False
# ✅ Provider Admin CB.23.0.0: False
# ✅ Provider Admin CB.24.0.0: False
# ✅ Provider Admin CB.25: False
# ✅ Provider Admin CB.26: False
# 🔍 Field 'Provider Admin T.28' not in mappings (Page 2)
# 🔍 Field 'Provider Admin T.29a' not in mappings (Page 2)
# 🔍 Field 'Provider Admin T.30a' not in mappings (Page 2)
# 🔍 Field 'Provider Admin T.31' not in mappings (Page 2)
# 🔍 Field 'Provider Admin T.32' not in mappings (Page 2)
# 🔍 Field 'Provider Admin T.33' not in mappings (Page 2)
# 🔍 Field 'Provider Admin T.34' not in mappings (Page 2)
# 🔍 Field 'Provider Admin T.35' not in mappings (Page 2)
# 🔍 Field 'Provider Admin T.36' not in mappings (Page 2)
# 🔍 Field 'Provider Admin T.37' not in mappings (Page 2)
# 🔍 Field 'CB60' not in mappings (Page 2)
# 🔍 Field 'CB61' not in mappings (Page 2)
# 🔍 Field 'CB62' not in mappings (Page 2)
# 🔍 Field 'CB63' not in mappings (Page 2)
# 🔍 Field 'T64' not in mappings (Page 2)
# 🔍 Field 'T65' not in mappings (Page 2)
# 🔍 Field 'T66' not in mappings (Page 2)
# 🔍 Field 'T67' not in mappings (Page 2)
# 🔍 Field 'CB68' not in mappings (Page 2)
# 🔍 Field 'T69' not in mappings (Page 2)
# 🔍 Field 'CB70' not in mappings (Page 2)
# 🔍 Field 'CB71' not in mappings (Page 2)
# 🔍 Field 'CB72' not in mappings (Page 2)
# 🔍 Field 'CB73' not in mappings (Page 2)
# 🔍 Field 'CB74' not in mappings (Page 2)
# 🔍 Field 'T75' not in mappings (Page 2)
# 🔍 Field 'T76' not in mappings (Page 2)
# 🔍 Field 'CB77' not in mappings (Page 2)
# 🔍 Field 'CB78' not in mappings (Page 2)
# 🔍 Field 'CB79' not in mappings (Page 2)
# 🔍 Field 'T80' not in mappings (Page 2)
# 🔍 Field 'T81' not in mappings (Page 2)
# 🔍 Field 'T84' not in mappings (Page 2)
# 🔍 Field 'CB82' not in mappings (Page 2)
# 🔍 Field 'CB83' not in mappings (Page 2)
# ✅ T12: Shakh
# ✅ T13: Abdulla
# ✅ T19: 865-395-3958
# ✅ T14: 04/01/2001
# 🔍 Field 'CB86' not in mappings (Page 3)
# 🔍 Field 'CB87' not in mappings (Page 3)
# 🔍 Field 'CB88' not in mappings (Page 3)
# 🔍 Field 'T89' not in mappings (Page 3)
# 🔍 Field 'T90' not in mappings (Page 3)
# 🔍 Field 'CB85' not in mappings (Page 3)
# 🔍 Field 'CB92' not in mappings (Page 3)
# 🔍 Field 'CB93' not in mappings (Page 3)
# 🔍 Field 'CB94' not in mappings (Page 3)
# 🔍 Field 'T95' not in mappings (Page 3)
# 🔍 Field 'T96a' not in mappings (Page 3)
# 🔍 Field 'CB91' not in mappings (Page 3)
# 🔍 Field 'CB98a' not in mappings (Page 3)
# 🔍 Field 'CB99a' not in mappings (Page 3)
# ✅ T12: Shakh
# ✅ T13: Abdulla
# ✅ T19: 865-395-3958
# ✅ T14: 04/01/2001
# ✅ T12: Shakh
# ✅ T13: Abdulla
# ✅ T19: 865-395-3958
# ✅ T14: 04/01/2001
# 📊 Summary: 67 fields filled, 25 skipped (empty values), 243 not in mappings.
#
# 🎉 ENHANCED MAPPING SUCCESS!
# ✅ Filled 67 fields using enhanced AI mapping
# 📄 Enhanced PDF saved as: Input Data/Adbulla/PA_FILLED_ENHANCED.pdf
# 🚀 IMPROVEMENT: +67 more fields filled than previous version!
#
# 🎯 ENHANCED AI created 80 comprehensive field mappings
# 📊 Total fields mapped: 45
# 📋 Sections completed: Patient Information, Treatment Type / Dates, Requesting Party, Insurance Information, Prescriber Information, Dispensing/Administration Location
# ⚠️  Missing data areas: Patient work phone, email, weight, height, Secondary insurance details, Prescriber State License #, DEA #, UPIN, Email, Office Contact Name and Phone, Administration facility's fax, TIN, PIN, NPI, or specific CPT administration codes
#
# Sample enhanced mappings:
#   • CB1 → True
#   • T2 → 05
#   • T3 → 22
#   • T4 → 2024
#   • CB5 → False
#   • T6 →
#   • T7 →
#   • T8 →
# 🔧 Starting PDF filling with 80 mappings...
# ✅ CB1: True
# ✅ T2: 05
# ✅ T3: 22
# ✅ T4: 2024
# ✅ CB5: False
# ✅ T9: Erfan Rostami, BSN, RN
# ✅ T10: 615-343-1176
# ✅ T11: 615-343-1219
# ✅ T12: Shakh
# ✅ T13: Abdulla
# ✅ T14: 04/01/2001
# ✅ T15: 425 Sherman Aves APT D
# ✅ T16: Nashville
# ✅ T17: TN
# ✅ T18: 37923
# ✅ T19: 865-395-3958
# ✅ T21: 865-395-0481
# ✅ T23: No Known Allergies
# ✅ T28: LAJM14345116
# ✅ T29: 435000
# ✅ T30: Abdulla, Shakh
# ✅ CB31: False
# ✅ CB32: True
# ✅ T42: Hao H
# ✅ T43: Gu
# ✅ CB44: True
# ✅ CB45: False
# ✅ CB46: False
# ✅ CB47: False
# ✅ T48: 3320 Montgomery Dr
# ✅ T49: Nashville
# ✅ T50: TN
# ✅ T51: 37361
# ✅ T52: 614-936-0065
# ✅ T53: 615-562-4820
# ✅ T55: 1154611523
# ✅ Provider Admin CB.1: False
# ✅ Provider Admin CB.2: False
# ✅ Provider Admin CB.3: False
# ✅ Provider Admin CB.4: True
# ✅ Provider Admin T.5: Children's Hematology - Oncology (Peds DOT 6)
# ✅ Provider Admin CB.7: False
# ✅ Provider Admin T.6: 615-936-1762
# ✅ Provider Admin CB.10: False
# ✅ Provider Admin T.11A: 2211 Broad Way, Tower 4th FL, Suite 6102
# ✅ Provider Admin T.13: Nashville
# ✅ Provider Admin T.14: TN
# ✅ Provider Admin T.15: 37232
# ✅ Provider Admin T.16: 615-936-1762
# ✅ Provider Admin CB.21: False
# ✅ Provider Admin CB.22: False
# ✅ Provider Admin CB.23.0.0: False
# ✅ Provider Admin CB.24.0.0: False
# ✅ Provider Admin CB.25: False
# ✅ Provider Admin CB.26: False
# 🔍 Field 'Provider Admin T.28' not in mappings (Page 2)
# 🔍 Field 'Provider Admin T.29a' not in mappings (Page 2)
# 🔍 Field 'Provider Admin T.30a' not in mappings (Page 2)
# 🔍 Field 'Provider Admin T.31' not in mappings (Page 2)
# 🔍 Field 'Provider Admin T.32' not in mappings (Page 2)
# 🔍 Field 'Provider Admin T.33' not in mappings (Page 2)
# 🔍 Field 'Provider Admin T.34' not in mappings (Page 2)
# 🔍 Field 'Provider Admin T.35' not in mappings (Page 2)
# 🔍 Field 'Provider Admin T.36' not in mappings (Page 2)
# 🔍 Field 'Provider Admin T.37' not in mappings (Page 2)
# 🔍 Field 'CB60' not in mappings (Page 2)
# 🔍 Field 'CB61' not in mappings (Page 2)
# 🔍 Field 'CB62' not in mappings (Page 2)
# 🔍 Field 'CB63' not in mappings (Page 2)
# 🔍 Field 'T64' not in mappings (Page 2)
# 🔍 Field 'T65' not in mappings (Page 2)
# 🔍 Field 'T66' not in mappings (Page 2)
# 🔍 Field 'T67' not in mappings (Page 2)
# 🔍 Field 'CB68' not in mappings (Page 2)
# 🔍 Field 'T69' not in mappings (Page 2)
# 🔍 Field 'CB70' not in mappings (Page 2)
# 🔍 Field 'CB71' not in mappings (Page 2)
# 🔍 Field 'CB72' not in mappings (Page 2)
# 🔍 Field 'CB73' not in mappings (Page 2)
# 🔍 Field 'CB74' not in mappings (Page 2)
# 🔍 Field 'T75' not in mappings (Page 2)
# 🔍 Field 'T76' not in mappings (Page 2)
# 🔍 Field 'CB77' not in mappings (Page 2)
# 🔍 Field 'CB78' not in mappings (Page 2)
# 🔍 Field 'CB79' not in mappings (Page 2)
# 🔍 Field 'T80' not in mappings (Page 2)
# 🔍 Field 'T81' not in mappings (Page 2)
# 🔍 Field 'T84' not in mappings (Page 2)
# 🔍 Field 'CB82' not in mappings (Page 2)
# 🔍 Field 'CB83' not in mappings (Page 2)
# ✅ T12: Shakh
# ✅ T13: Abdulla
# ✅ T19: 865-395-3958
# ✅ T14: 04/01/2001
# 🔍 Field 'CB86' not in mappings (Page 3)
# 🔍 Field 'CB87' not in mappings (Page 3)
# 🔍 Field 'CB88' not in mappings (Page 3)
# 🔍 Field 'T89' not in mappings (Page 3)
# 🔍 Field 'T90' not in mappings (Page 3)
# 🔍 Field 'CB85' not in mappings (Page 3)
# 🔍 Field 'CB92' not in mappings (Page 3)
# 🔍 Field 'CB93' not in mappings (Page 3)
# 🔍 Field 'CB94' not in mappings (Page 3)
# 🔍 Field 'T95' not in mappings (Page 3)
# 🔍 Field 'T96a' not in mappings (Page 3)
# 🔍 Field 'CB91' not in mappings (Page 3)
# 🔍 Field 'CB98a' not in mappings (Page 3)
# 🔍 Field 'CB99a' not in mappings (Page 3)
# ✅ T12: Shakh
# ✅ T13: Abdulla
# ✅ T19: 865-395-3958
# ✅ T14: 04/01/2001
# ✅ T12: Shakh
# ✅ T13: Abdulla
# ✅ T19: 865-395-3958
# ✅ T14: 04/01/2001
# 📊 Summary: 67 fields filled, 25 skipped (empty values), 243 not in mappings.
#
# 🎉 ENHANCED MAPPING SUCCESS!
# ✅ Filled 67 fields using enhanced AI mapping
# 📄 Enhanced PDF saved as: Input Data/Adbulla/PA_FILLED_ENHANCED.pdf
# 🚀 IMPROVEMENT: +67 more fields filled than previous version!
